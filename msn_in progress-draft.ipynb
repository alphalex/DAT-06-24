# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import os
import pytz
from google.cloud import bigquery
from datetime import timedelta, datetime

# %%
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7',
    'Connection': 'keep-alive',
    'Accept-Encoding':'gzip, deflate, br'
}

# %%
s = requests.session()

# %%
url_re = s.get('https://www.msn.com', headers=headers)

# %%
url_re.status_code
# Out:
# 200

# %%
type(url_re.text)
# Out:
# str

# %%
url_re.text
# Out:
# '<!DOCTYPE html><html prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"  lang="en-US"  style="font-size:62.5%"  class="hiperf"  dir="ltr" >\n\n<head data-info="v:20190824_17864432;a:adf2c4fc-9919-462f-aac9-e0440ae41cb8;cn:14;az:{did:9a9a6dcc560c4a5a958f3f1a2bcb24f4, rid: 14, sn: eastus-prod-hp, dt: 2019-07-23T02:12:59.9597358Z, bt: 2019-08-25T00:14:05.8140966Z};ddpi:1;dpio:;dpi:1;dg:tmx.pc.webkit.chrome.chrome76plus;th:start;PageName:startPage;m:en-us;cb:;l:en-us;mu:en-us;ud:{cid:,vk:homepage,n:,l:en-us,ck:};xd:BBnbhK2;ovc:f;al:;fxd:f;xdpub:2019-08-28 13:19:40Z;xdmap:2019-08-28 22:10:53Z;axd:;f:msnallexpusers,muidflt27cf,muidflt301cf,muidflt312cf,sam-dynamicfloor,startedge1cf,bingcollabedge2cf,platagyhp1cf,audexhp2cf,moneyhz1cf,adrtscanconfiant,jslltelemetry,routesportssf,nlsinglepage;userOptOut:false;userOptOutOptions:"  data-js="{&quot;dpi&quot;:1.0,&quot;ddpi&quot;:1.0,&quot;dpio&quot;:null,&quot;forcedpi&quot;:null,&quot;dms&quot;:6000,&quot;ps&quot;:1000,&quot;bds&quot;:7,&quot;dg&quot;:&quot;tmx.pc.webkit.chrome.chrome76plus&quot;,&quot;ssl&quot;:true,&quot;moduleapi&quot;:&quot;https://www.msn.com/en-us/homepage/api/modules/fetch&quot;,&quot;cdnmoduleapi&quot;:&quot;https://static-global-s-msn-com.akamaized.net/en-us/homepage/api/modules/cdnfetch&quot;,&quot;pdpdeltaupdateapi&quot;:&quot;https://www.msn.com/en-us/homepage/api/pdp/updatepdpdata&quot;,&quot;xd&quot;:&quot;bbnbhk2&quot;,&quot;signedin&quot;:0,&quot;sso&quot;:&quot;https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;checkda=1&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=lbi&amp;wreply=https%3a%2f%2fwww.msn.com%2fen-us%2fhomepage%2fsecure%2fsilentpassport%3fsecure%3dtrue&amp;lc=1033&amp;id=1184&amp;mkt=en-us&quot;,&quot;exchangeenabled&quot;:true,&quot;twitterimpenabled&quot;:true,&quot;greenidcallenabled&quot;:false,&quot;ispreload&quot;:false,&quot;anonckname&quot;:&quot;&quot;,&quot;ssocomplete&quot;:false}"  data-client-settings="{&quot;geo_country&quot;:&quot;us&quot;,&quot;geo_subdivision&quot;:&quot;new york&quot;,&quot;geo_zip&quot;:&quot;10010&quot;,&quot;geo_ip&quot;:&quot;144.121.201.0&quot;,&quot;geo_lat&quot;:&quot;40.74&quot;,&quot;geo_long&quot;:&quot;-73.9855&quot;,&quot;os_region&quot;:&quot;&quot;,&quot;apps_locale&quot;:&quot;&quot;,&quot;base_url&quot;:&quot;/en-us/homepage/&quot;,&quot;aid&quot;:&quot;adf2c4fc9919462faac9e0440ae41cb8&quot;,&quot;sid&quot;:null,&quot;v&quot;:&quot;20190824_17864432&quot;,&quot;static_page&quot;:false,&quot;empty_gif&quot;:&quot;//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif&quot;,&quot;functionalonly_cookie_experience&quot;:false,&quot;functional_cookies&quot;:&quot;&quot;,&quot;functional_cookie_patterns&quot;:&quot;&quot;,&quot;fbid&quot;:&quot;132970837947&quot;,&quot;lvk&quot;:&quot;homepage&quot;,&quot;vk&quot;:&quot;homepage&quot;,&quot;cat&quot;:null,&quot;autorefresh&quot;:true,&quot;bingssl&quot;:false,&quot;autorefreshsettings&quot;:{&quot;is_market_enabled&quot;:false,&quot;timeout&quot;:0,&quot;idle_enabled&quot;:false,&quot;idle_timeout&quot;:&quot;2&quot;},&quot;uipr&quot;:true,&quot;uiprsettings&quot;:{&quot;enabled&quot;:true,&quot;frequency_minutes&quot;:5,&quot;banner_delay_minutes&quot;:null,&quot;maxfresh_display&quot;:null,&quot;minfresh_count&quot;:&quot;5&quot;,&quot;ajaxtimeoutinseconds&quot;:&quot;60&quot;},&quot;imgsrc&quot;:{&quot;quality_high&quot;:&quot;60&quot;,&quot;quality_low&quot;:&quot;5&quot;,&quot;order_timeout&quot;:&quot;1000&quot;},&quot;adsettings&quot;:{&quot;wait_for_ad_in_sec&quot;:&quot;3&quot;,&quot;retry_for_ad&quot;:&quot;2&quot;},&quot;mecontroluri&quot;:&quot;https://mem.gfx.ms/meversion/?partner=msn&amp;market=en-us&quot;,&quot;mecontrolv2uri&quot;:&quot;&quot;,&quot;lazyload&quot;:{&quot;enabled&quot;:true}}"  data-xd-id="BBnbhK2"    data-delayed-js="//static-global-s-msn-com.akamaized.net/hp-eus/en-us/homepage/_sc/js/b443689a-2923b6c2/direction=ltr.locales=en-us.themes=start.dpi=resolution1x/41-0bee62-68ddb2ab?ver=2019 ...

# %%
soup = BeautifulSoup(url_re.text)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="hiperf" dir="ltr" lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" style="font-size:62.5%">
# <head data-client-settings='{"geo_country":"us","geo_subdivision":"new york","geo_zip":"10010","geo_ip":"144.121.201.0","geo_lat":"40.74","geo_long":"-73.9855","os_region":"","apps_locale":"","base_url":"/en-us/homepage/","aid":"adf2c4fc9919462faac9e0440ae41cb8","sid":null,"v":"20190824_17864432","static_page":false,"empty_gif":"//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif","functionalonly_cookie_experience":false,"functional_cookies":"","functional_cookie_patterns":"","fbid":"132970837947","lvk":"homepage","vk":"homepage","cat":null,"autorefresh":true,"bingssl":false,"autorefreshsettings":{"is_market_enabled":false,"timeout":0,"idle_enabled":false,"idle_timeout":"2"},"uipr":true,"uiprsettings":{"enabled":true,"frequency_minutes":5,"banner_delay_minutes":null,"maxfresh_display":null,"minfresh_count":"5","ajaxtimeoutinseconds":"60"},"imgsrc":{"quality_high":"60","quality_low":"5","order_timeout":"1000"},"adsettings":{"wait_for_ad_in_sec":"3","retry_for_ad":"2"},"mecontroluri":"https://mem.gfx.ms/meversion/?partner=msn&amp;market=en-us","mecontrolv2uri":"","lazyload":{"enabled":true}}' data-delayed-js="//static-global-s-msn-com.akamaized.net/hp-eus/en-us/homepage/_sc/js/b443689a-2923b6c2/direction=ltr.locales=en-us.themes=start.dpi=resolution1x/41-0bee62-68ddb2ab?ver=20190824_17864432&amp;fdhead=msnallexpusers,muidflt27cf,muidflt301cf,muidflt312cf,sam-dynamicfloor,startedge1cf,bingcollabedge2cf,platagyhp1cf,audexhp2cf,moneyhz1cf,adrtscanconfiant,jslltelemetry,routesportssf,nlsinglepage&amp;csopd=20190813221457&amp;csopdb=20190814203844" data-info="v:20190824_17864432;a:adf2c4fc-9919-462f-aac9-e0440ae41cb8;cn:14;az:{did:9a9a6dcc560c4a5a958f3f1a2bcb24f4, rid: 14, sn: eastus-prod-hp, dt: 2019-07-23T02:12:59.9597358Z, bt: 2019-08-25T00:14:05.8140966Z};ddpi:1;dpio:;dpi:1;dg:tmx.pc.webkit.chrome.chrome76plus;th:start;PageName:startPage;m:en-us;cb:;l:en-us;mu:en-us;ud:{cid:,vk:homepage,n:,l:en-us,ck:};xd:BBnbhK2;ovc:f;al:;fxd:f;xdpub:2019-08-28 13:19:40Z;xdmap:2019-08-28 22:10:53Z;axd:;f:msnallexpusers,muidflt27cf,muidflt301cf,muidflt312cf,sam-dynamicfloor,startedge1cf,bingcollabedge2cf,platagyhp1cf,audexhp2cf,moneyhz1cf,adrtscanconfiant,jslltelemetry,routesportssf,nlsinglepage;userOptOut:false;userOptOutOptions:" data-js='{"dpi":1.0,"ddpi":1.0,"dpio":null,"forcedpi":null,"dms":6000,"ps":1000,"bds":7,"dg":"tmx.pc.webkit.chrome.chrome76plus","ssl":true,"moduleapi":"https://www.msn.com/en-us/homepage/api/modules/fetch","cdnmoduleapi":"https://static-global-s-msn-com.akamaized.net/en-us/homepage/api/modules/cdnfetch","pdpdeltaupdateapi":"https://www.msn.com/en-us/homepage/api/pdp/updatepdpdata","xd":"bbnbhk2","signedin":0,"sso":"https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;checkda=1&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=lbi&amp;wreply=https%3a%2f%2fwww.msn.com%2fen-us%2fhomepage%2fsecure%2fsilentpassport%3fsecure%3dtrue&amp;lc=1033&amp;id=1184&amp;mkt=en-us","exchangeenabled":true,"twitterimpenabled":true,"greenidcallenabled":false,"ispreload":false,"anonckname":"","ssocomplete":false}' data-xd-id="BBnbhK2" iris-modules-settings='[{"n":"banner","pid":"10837393","phdiv":"irisbannerph","tmpl":"Banner_Generic1","pos":"top","canvas":"homepage"}]'>
# <script>if(window&&(typeof window.performance=="object")){if(typeof window.performance.mark=="function"){window.performance.mark("TimeToHeadStart");}}</script>
# <meta charset="utf-8"/>
# <script>window.performance&&window.performance.mark&&window.performance.mark("Ars-begin")</script>
# <script>
#                 /*<![CDATA[*///Copyright Instart Fri May 24 2019 - All rights reserved - version: 10.6.32
# function Ha(){var t=window;if(function(){var n=!0,i=!1,e="";try{var r="object"==typeof t.IXC_144_5393438182331658&&t.IXC_144_5393438182331658;if(n=!r||void 0===r.CanRun||"_144_5393438182331658"!==r._144_5393438182331658||r.CanRun("abd"))r=t.IXC_144_5393438182331658=t.IXC_144_5393438182331658||{},r.InitStartTime=(t.performance?t.performance:Date).now(),r._144_5393438182331658="_144_5393438182331658",t.INSTART_TARGET_NAME="abd",t.I12C=t.I12C||{};else{var o=t.INSTART_TARGET_NAME;e="double nanovisor injection: abd after "+o,(i="abd"!==o)&&console.warn(e)}t.INSTART=t.INSTART||{},t.INSTART.Init=function(){i&&console.error("ignored Init call after ",e)},r&&(r.ComputeAll=(function(){var module={exports:{}};var exports=module.exports;//copyright Wed Aug 28 2019 15:39:25 GMT+0000 (Coordinated Universal Time)
# Object.defineProperty(exports,"__esModule",{value:!0});var i=function(t,n){n({iadb:{ipknildaoler:[{ias:"script",irusl:["https://www.googletagservices.com/tag/js/gpt.js","https://securepubads.g.doubleclick.net/gpt/pubads_impl_2019032901.js","https://www.googletagservices.com/activeview/js/current/osd.js","https://c.amazon-adsystem.com/aax2/apstag.js","https://z.moatads.com/nativo483ETsY34/moatad.js"]},{ias:"style",irusl:["https://cdn.revcontent.com/build/css/rev2.min.css"]}]}})},r=function(t,n){(t.req.browser("chrome",46,1e3)||t.req.browser("safari",10,1e3))&&n({iadb:{ierelbanenoitcerid:!0}}),(t.req.browser("chrome",46,1e3)||t.req.browser("firefox",38,1e3)||t.req.browser("safari",10,1e3)||t.req.browser("ie",10,1e3)&&document&&document.documentMode<10||t.req.browser("edge",12,1e3))&&n({iadb:{idelbanenoitcete:!0}}),n({iadb:{ivetatselbaira:"MorphState",iolbetatseulavdekc:"blocked",ilbtonetatseulavdekco:"not-blocked",iycnetalelbairav:"Abdt",iircsdekcolbmunsrotcetedkniltp:4,ihtnemelemunsrotcetededi:4,iidekcolbmunsrotcetedgm:4,inoitceteddlohserht:3,ilufelbanenoitcetedl:!0,iyrotsihelbanenoitceriderrof:!1,irotsihmundlohserhty:1,itemeletdbatniopdneyr:"/g00/2_d3d3LmJvc3Rvbi5jb20%3D_/TU9SRVBIRVVTOCRodHRwOi8vY3AtaW4ubmFub3Zpc29yLmlvL2NsaWVudHByb2ZpbGVyL2FkYj9pMTBjLm1hcmsuc2NyaXB0LnR5cGU%3D_$/$/$",iceriderelbasidnoissesrofnoit:!1,isabnoitceriderelbanesrotcetedkniltpircsde:!0,ietedtratsemitnoitc:0,iolbnoreggirterutangisrekc:!1}}),t.req.cookie("i10c.expt.link","true")&&i(t,n),t.req.browser("safari",10,1e3)&&n({iadb:{icolbdaslru_k:["https://s0.2mdn.net/ads/richmedia/studio/pv2/60282074/20170720084443516/script.js","https://cdn.doubleverify.com/dv-match4.js","https://cdn.springserve.com/vd/vd0.2.82.8.js","https://cdn.revcontent.com/build/css/rev2.min.css","https://c.betrad.com/a/n/269/635.js","https://s0.2mdn.net/6440533/1495124845208/Raise%20Your%20Hands_728x90/global.min.css"]}}),(t.req.browser("firefox",38,1e3)||t.req.browser("safari",10,1e3)||t.req.browser("ie",10,1e3)&&document&&document.documentMode<10||t.req.browser("edge",12,1e3))&&n({iadb:{ilufelbanenoitcetedl:!1,iyrotsihelbanenoitceriderrof:!1,iceriderelbasidnoissesrofnoit:!1}})},e=function(t,n){t.req.host("www.101x.com")&&n({iadb:{ithdekcolbstnemelelm:['<div data-size="970x90"></div>',"<div amp4ads></div>"]}})},u=function(t,n){t.req.idtoorniamo("popsci.com")&&n({iadb:{isabnoitceriderelbanesrotcetedkniltpircsde:!1}})},o=function(t,n){t.req.idtoorniamo("cnet.com")&&!(t.req.host("www.cnet.com")||t.req.host("test.cnet.com")||t.req.host("download.cnet.com")||t.req.host("download.stage.cnet.com"))&&n({iadb:{idelbanenoitcete:!1}}),t.req.browser("firefox")&&t.req.host("test.cnet.com")&&n({iadb:{ierelbanenoitcerid:!0}}),t.req.host("www.cnet.com")&&n({iadb:{ithdekcolbstnemelelm:['<div data-load-complete="true"></div>','<div class="d2016-topdeals"></div>','<div data-ad="incontent-ad-plus-billboard-top"></div>',"<div data-ad-cid></div>",'<div class="trc_elastic"></div>','<div data-load-complete="true"></div>']}}),t.req.domain("www.cbssports.com")&&(n({iadb:{ithdekcolbstnemelelm:['<div class="cc-skybox"></div>','<div class="leaderboard-wrap"></div>','<div data-ad="incontent-ad-plus-billboard-top"></div>','<div id="skybox-top-wrapper"></div>']}}),i(t,n))},s=function(t,n){t.req.idtoorniamo("diversitybestpractices.com")&&n({iadb:{iolbnoreggirterutangisrekc:!0}})},c=function(t,n){t.req.idtoorniamo("homes.com")&&t.req.browser("firefox",54,1e3)&&n({iadb:{ierelbanenoitcerid:!0}})},a=function(t,n){t.req.idtoorniamo("edmunds.com")&&t.req.browser("firefox",54,1e3)&&n({iadb:{ierelbanenoitcerid:!0}})},h=function(t,n){t.req.idtoorniamo("geek.com")&&n({iadb:{ipknildaoler:[{ias:"script",irusl:["https://securepubads.g.doubleclick.net/gpt/pubads_impl_2019032901.js","https://googleads.g.doubleclick.net/pagead/xbfe_backfill.js"]}]}})},f=function(t,n){t.req.idtoorniamo("trend-chaser.com")&&t.req.browser("firefox",54,1e3)&&n({iadb:{ierelbanenoitcerid:!0}})},l=function(t,n){(t.req.host("www.msn.com")||t.req.host("int1 ...
#         </script>
# <script>Object.prototype.watch||(Object.defineProperty(Object.prototype,"watch",{value:function(n,t){var i=this[n],r=function(){return i},u=function(r){var u=i;return i=r,u!=r?i=t.call(this,n,u,r):i};delete this[n]&&(Object.defineProperty?Object.defineProperty(this,n,{get:r,set:u}):Object.prototype.__defineGetter__&&Object.prototype.__defineSetter__&&(Object.prototype.__defineGetter__.call(this,n,r),Object.prototype.__defineSetter__.call(this,n,u)))},enumerable:!1,writable:!0}),Object.defineProperty(Object.prototype,"unwatch",{value:function(n){var t=this[n];delete this[n];this[n]=t},enumerable:!1}));window.performance&&window.performance.mark&&(window.performance.mark("Ars-end"),window.performance.measure&&window.performance.measure("InstartExecutionTime","Ars-begin","Ars-end"))</script>
# <meta content="index, follow" name="robots"/> <link as="font" crossorigin="anonymous" href="//static-global-s-msn-com.akamaized.net/hp-eus/sc/57/06635e.woff2" rel="preload" type="font/woff2"/>
# <link href="img-s-msn-com.akamaized.net" rel="preconnect"/><link href="c.msn.com" rel="preconnect"/><link href="c.msn.cn" rel="preconnect"/><link href="https://www.bing.com" rel="preconnect"/><link href="//web.vortex.data.msn.com" rel="preconnect"/><link href="img-s-msn-com.akamaized.net" rel="dns-prefetch"/><link href="c.msn.com" rel="dns-prefetch"/><link href="c.msn.cn" rel="dns-prefetch"/><link href="https://www.bing.com" rel="dns-prefetch"/><link href="//web.vortex.data.msn.com" rel="dns-prefetch"/><link href="https://www.msn.com/" rel="canonical"/><meta content="#224f7b" name="msapplication-TileColor"/><meta content="//static-global-s-msn-com.akamaized.net/hp-eus/sc/1f/08ced4.png" name="msapplication-TileImage"/><meta content="none" name="msapplication-config"/><link href="https://chrome.google.com/webstore/detail/msn-homepage-bing-search/aodojjhnfnfhaplflfohfddffmjkdjak" rel="chrome-webstore-item"/> <title>MSN | Outlook, Office, Skype, Bing, Breaking News, and Latest Videos</title>
# <meta content="Your customizable and curated collection of the best in trusted news plus coverage of sports, entertainment, money, weather, travel, health and lifestyle, combined with Outlook/Hotmail, Facebook, Twitter, Bing, Skype and more." name="description"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/>
# <link href="//static-global-s-msn-com.akamaized.net/hp-eus/en-us/homepage/_sc/css/b443689a-29c081be/direction=ltr.locales=en-us.themes=start.dpi=resolution1x/cf-e3b06a-c1936139/9d-4f9990-d0192583/31-c31fb0-68ddb2ab/49-481f80-677c872a/a9-58f66e-f64ad38d/35-f09450-d91a920/69-8f5e1d-d8da69e2/25-dd7b49-d55835e5/85-d5cc0b-f6fc6aac/18-56aa26-dbc6220a/7e-9493f9-5fe1842f/b8-cbc6ea-793099c5/67-f5a030-95aa7dda/1e-ed96c4-6163f058/b5-77bbe0-e1d32d27/d0-c37c5e-e329ca6a/18-840e30-8975ceac/89-b918c0-e8cb1e4c/c3-6de9e8-d256b11b/ee-376c22-e92f4bc3/50-43536d-a174d24c/bd-a43d36-423c26e1/ae-0f4566-a484bc65/7f-3aeb1d-f1c08ae4/eb-0afd66-dd61d236/23-5d0d80-cbf31fb5/8a-19583d-17636285/be-cca965-3380d0ba?ver=20190824_17864432&amp;fdhead=msnallexpusers,muidflt27cf,muidflt301cf,muidflt312cf,sam-dynamicfloor,startedge1cf,bingcollabedge2cf,platagyhp1cf,audexhp2cf,moneyhz1cf,adrtscanconfiant,jslltelemetry,routesportssf,nlsinglepage&amp;csopd=20190813221457&amp;csopdb=20190814203844" media="all" rel="stylesheet" type="text/css"/><script>(function(n){function i(i,r){try{var u=new n.FontFace(i,r,{}).load();t.push(u)}catch(f){}}var t=[];typeof n.FontFace=="function"&&i("ps_g","url(//static-global-s-msn-com.akamaized.net/hp-eus/sc/57/06635e.woff2)")})(window),function(n,t){function h(n,i,r){typeof n!="string"&&(r=i,i=n,n=t);i&&i.splice||(r=i,i=[]);n==it?a=!0:n==rt&&(v=!0);l(n,i,r,!1,!1)}function l(n,t,i,r,f,e){var s,y;if(!n||!c[n]){var h=ot(n,t),o=h.dependencyNotFound,l=h.resolved;if(o){typeof u[o]=="undefined"&&(u[o]=[]);u[o].push(e||{i:n,d:t,f:i,r:r,s:f});return}s=typeof i=="function";y=v&&a&&s&&!f;y?et(n,i,l,r):ft(s,n,i,l,r)}}function ft(n,t,i,r,u){var f;f=n?i.apply(null,r):i;d(t,f,u)}function et(n,t,i,r){setTimeout(function(){var u=t.apply(null,i);d(n,u,r)},1)}function d(t,i,r){r&&(i={});t&&(i?(c[t]=i,f.push(t),g()):n.console&&console.error("Dependencies resolved, but object still not defined (or is otherwise falsey). id:"+t+"; typeof obj: "+typeof i))}function g(){var t,s,h,i,o,c,r,n;if(e)e&&(e=2);else{t=[];do{for(e=1,h=f.length,i=0;i<h;i++)o=f[i],c=u[o]||[],t=t.concat(c),delete u[o];for(f=[],s=t.length,r=0;r<s;r++)n=t[r],l(n.i,n.d,n.f,n.r,n.s,n);t=[]}while(e>1);e=0}}function ot(n,t){for(var e,i=[],r,o=t?t.length:0,u=0;u<o;u++){var f=t[u],s=c[f],h=typeof s!="undefined";if(!h){if(e=st(n,f),e){i.push(e);continue}r||(r=f);break}i.push(s)}return o===i.length?{resolved:i}:{dependencyNotFound:r}}function st(i,r){var f=k.exec(r),e,u;if(f){if(e=f[1],u=n[e],u!==t)return u;s||(s=setTimeout(nt,w))}}function nt(){var i,r,e,o,h;s=0;i=!1;for(r in u)e=k.exec(r),e&&(o=e[1],h=n[o],h!==t?f.push(r):i=!0);i&&!s&&(s=setTimeout(nt,w));f.length&&g()}function ht(n,t,i){if((typeof n!="object"||n&&n.splice)&&(i=t,t=n,n={}),t&&t.splice||(i=t,t=[]),ct(n.js),i){var r,u=n.synchronous||!1;l(r,t,i,!0,u)}}function ct(n){if(typeof n=="string")tt(n);else if(n)for(var t=0;t<n.length;t++)tt(n[t])}function tt(n){if(!b[n]){b[n]=1;var i=o.getElementsByTagName("script")[0],t=o.createElement("script");t.src=n;t.onload=t.onreadystatechange=function(){this.readyState&&this.readyState!="loaded"&&this.readyState!="complete"||(t.onload=t.onreadystatechange=null,t.parentNode&&t.parentNode.removeChild(t))};i.parentNode.insertBefore(t,i)}}function lt(n){return ut?n?i.now():Math.round(i.now()):new Date-y}var it=n._jsLoaderAsyncCanary||"c.dom",rt="c.pageReveal",a=!1,v=typeof n._jsLoaderRevealMode=="undefined"?!0:n._jsLoaderRevealMode,i=n.performance,ut=i&&typeof i.now=="function",r=" ----- ",y=((i||{}).timing||{}).navigationStart||+new Date,o=n.document,p=null;try{p=n.localStorage}catch(at){}var c={date:Date,document:o,image:n.Image,localStorage:p,location:o&&o.location,navigator:navigator,pageStart:y,pageTime:lt,screen:n.screen,window:n},u={},f=[],e,w=50,s,b={},k=/^window\.(.+)$/;h.amd={jQuery:1};h.is=function(n){return typeof c[n]!="undefined"};n.define=h;n.require=ht;h.showUserMarks=function(){var n=["Mark Name"+r+"Start time in ms"];return i.getEntriesByType("mark").forEach(function(t){n.push(t.name+r+t ...
# <script>(function(){function u(){window.performance.mark("frame");console.timeStamp("frame");i||s();performance.now()<o&&requestAnimationFrame(u)}function s(){r=n;n=performance.now();n-r<=e?n-t>=f&&(window._pageTimings||(window._pageTimings={}),window._pageTimings.TimeToPageInteractive=Math.round(t),i=!0):t=n}var i=!1,n=0,r=0,t=0,f=1e3,e=200,o=3e4;window.performance&&window.performance.mark&&window.performance.now&&window.requestAnimationFrame&&requestAnimationFrame(u)})()</script>
# <script>window._perfMarker && window._perfMarker("TimeToHeadEnd"); window._perfMeasure && window._perfMeasure("TimeForHead", "TimeToHeadStart", "TimeToHeadEnd", true);</script>
# </head>
# <body class="startpage sp center-content start tmx pc webkit chrome chrome76plus fltmsnallexpusers fltmuidflt27cf fltmuidflt301cf fltmuidflt312cf fltsam-dynamicfloor fltstartedge1cf fltbingcollabedge2cf fltplatagyhp1cf fltaudexhp2cf fltmoneyhz1cf fltadrtscanconfiant fltjslltelemetry fltroutesportssf fltnlsinglepage">
# <script>window._perfMarker && window._perfMarker("TimeToBodyStart");</script>
# <script>
#                 require(["headData", "pageInstance", "mediator"], function (headData, pageInstance, mediator)
#                 {
#                     var url = '//c.msn.com/c.gif?udc=true&rid=adf2c4fc9919462faac9e0440ae41cb8&rnd=637026271247521881&rf=&tp=https%253A%252F%252Fwww.msn.com%252F&di=340&lng=en-us&activityId=adf2c4fc9919462faac9e0440ae41cb8&d.dgk=tmx.pc.webkit.chrome.chrome76plus&d.imd=0&st.dpt=&st.sdpt=&subcvs=homepage&pg.n=startpage&pg.t=hp&pg.c=&pg.p=prime&anoncknm=&issso=0&aadState=0';
#                     if (headData && headData.clientSettings && headData.clientSettings.static_page)
#                     {
#                         mediator.pub(pageInstance.eventName);
#                         var rid = pageInstance.getActivityId();
#                         url = url.replace(/([?&]rid=)[^&#]*/i, "$1" + rid);
#                     }
#
#                     var img = new Image();
#                     img.onload = img.onerror = function ()
#                     {
#                         img.onload = img.onerror = null;
#                     };
#                     img.src = url;
#
#  });
# </script>
# <script>
# /*<![CDATA[*/
#  require(["jsll-bootstrap"],function(jsllbt){jsllbt.initialize({"isLoggedIn":"False","logLevel":"1","jsError":"false","env":"prod","appId":"MSN","endpoint":"https://web.vortex.data.msn.com/collect/v1"});});require(["track","track.generic","c.track.mobi"],function(t,g,o){t.extend({"sitePage":{"department":"","subDepartment":"","channel":"homepage","page_name":"startpage","page_type":"hp","page_product":"prime","storeocid":"msn","pageUrl":"https%3A%2F%2Fwww.msn.com%2F","autoRefresh":"0","requestId":"adf2c4fc9919462faac9e0440ae41cb8","serverImpressionGuid":"adf2c4fc9919462faac9e0440ae41cb8","canvas":"Browser","vertical":"homepage","entityId":"","entityCollectionId":"","entitySrc":"","cvAuthor":"","d_dgk":"tmx.pc.webkit.chrome.chrome76plus","d_imd":"0","cvPartner":"","cvPublcat":"","provid":"","templ":"RR:0;lo:Y_cec865fe-ed84-49a8-b88a-4a23446ea7f1;EAggMo:0;bingclicklda;IP:Cb;RV:Cb;infopane:0;cat:0;EP:0;CI:0;mIpH:2;mRvH:2","pageIndex":"","pageTotalCount":"","isStaticPage":"False","pageVersion":"15","contentType":"unknown_use_metadata_to_set_the_content_type","isCorePV":"","chartBeatUID":"42635","chartBeatDomain":"msn.com","chartBeatBase":"https://static.chartbeat.com","otfURL":"//otf.msn.com/c.gif?","flightid":"msnallexpusers,muidflt27cf,muidflt301cf,muidflt312cf,sam-dynamicfloor,startedge1cf,bingcollabedge2cf,platagyhp1cf,audexhp2cf,moneyhz1cf,adrtscanconfiant,jslltelemetry,routesportssf,nlsinglepage","exa":"msnallexpusers,muidflt27cf,muidflt301cf,muidflt312cf,sam-dynamicfloor,startedge1cf,bingcollabedge2cf,platagyhp1cf,audexhp2cf,moneyhz1cf,adrtscanconfiant,jslltelemetry,routesportssf,nlsinglepage","device":"Unknown Unknown","domainId":"340","propertyId":"","propertySpecifier":"","pageMode":"","localeCode":"en-us"},"userStatic":{"isSignedIn":"False","beginRequestTicks":"637026271247521881"}});t.register(new g({"base":"//c.msn.com/c.gif?","id":"ctag","disableOnAutoRefresh":"scorecard","isGeneratedEarly":1,"rmca":1,"impr":{"param":{'udc': 'true'},"paramMap":{"event":{'evt':'type'},"userDynamic":{'rid':'requestId','rnd':'timeStamp'},"client":{'rf':'referrer','tp':'pageUrl','scr':'screenResolution','anoncknm':'getAnonCookieName','issso':'getSsoComplete','aadState':'getAadAuthentication'},"sitePage":{'di':'domainId','lng':'localeCode','activityId':'requestId','d.dgk':'d_dgk','d.imd':'d_imd','st.dpt':'department','st.sdpt':'subDepartment','subcvs':'vertical','pg.n':'page_name','pg.t':'page_type','pg.c':'page_configuration','pg.p':'page_product'}}}}),new g({"base":"https://sb.scorecardresearch.com/b?","id":"scorecard","disableOnAutoRefresh":"scorecard","isGeneratedEarly":0,"impr":{"param":{'c1': '2', 'c2': '3000001', 'cs_ucfr': '1'},"paramMap":{"userDynamic":{'rn':'timeStamp'},"client":{'c7':'pageUrl','c8':'pageTitle','c9':'referrer'}}},"page_candidate":{"paramMap":{"event":{'evt':'type'},"userDynamic":{'rn':'timeStamp'},"client":{'c7':'pageUrl','c8':'pageTitle','c9':'referrer'}}}}),new g({"base":"//otf.msn.com/c.gif?","id":"udc","disableOnAutoRefresh":"scorecard","commonMap":{"userDynamic":{'rid':'requestId','cts':'timeStamp','idx':'currentEventIndex'},"client":{'clid':'clientId','anoncknm':'getAnonCookieName','issso':'getSsoComplete','aadState':'getAadAuthentication'},"sitePage":{'di':'domainId','mkt':'localeCode','su':'pageUrl','flightid':'flightid','activityId':'requestId','cvs':'canvas','subcvs':'vertical','pg.n':'page_name','pg.t':'page_type','pg.c':'page_configuration','pg.p':'page_product','pivot':'pagePivot','pageuid':'pageUserId','pageutype':'pageUserType'}},"isGeneratedEarly":0,"impr":{"param":{'evt': 'impr', 'js': '1'},"paramMap":{"userStatic":{'pp':'isSignedIn'},"userDynamic":{'dv.snlogin':'settings','dv.grpfrmod':'defaultSlotTrees'},"client":{'rf':'referrer','cu':'pageUrl','scr':'screenResolution','bh':'height','bw':'width','dv.Title1':'pageTitle','viewType':'viewType','e1':'OTFTelemetry','prs':'personalization','oscm':'connectionMode','osver':'buildVersion'},"sitePage":{'st.dpt':'department','st.sdpt':'subDepartment','cv ...
# //]]>
# </script>
# <noscript>
# <img alt="image beacon" height="1" src="//c.msn.com/c.gif?udc=true&amp;rid=adf2c4fc9919462faac9e0440ae41cb8&amp;rnd=637026271247521881&amp;rf=&amp;tp=https%253A%252F%252Fwww.msn.com%252F&amp;di=340&amp;lng=en-us&amp;activityId=adf2c4fc9919462faac9e0440ae41cb8&amp;d.dgk=tmx.pc.webkit.chrome.chrome76plus&amp;d.imd=0&amp;st.dpt=&amp;st.sdpt=&amp;subcvs=homepage&amp;pg.n=startpage&amp;pg.t=hp&amp;pg.c=&amp;pg.p=prime&amp;anoncknm=&amp;issso=0&amp;aadState=0" width="1"/><img alt="image beacon" height="1" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=3000001&amp;cs_ucfr=1&amp;rn=637026271247521881&amp;c7=https%253A%252F%252Fwww.msn.com%252F&amp;c8=&amp;c9=" width="1"/><img alt="image beacon" height="1" src="https://web.vortex.data.msn.com/collect/v1/t.gif?name='Ms.Webi.PageView'&amp;ver='2.1'&amp;appId='JS:MSN'&amp;ext-app-env='prod'&amp;ext-javascript-libver='4.0.0-beta-10'&amp;ext-user-localId='t:393355E0C4436EB0366F5826C5CB6F3E'&amp;*baseType='Ms.Content.PageView'&amp;*isJs=False&amp;*title=''&amp;*isLoggedIn=False&amp;*isManual=True&amp;*serverImpressionGuid='adf2c4fc-9919-462f-aac9-e0440ae41cb8'&amp;-ver='1.0'&amp;-impressionGuid='adf2c4fc-9919-462f-aac9-e0440ae41cb8'&amp;-pageName='startpage'&amp;-uri='https%253A%252F%252Fwww.msn.com%252F'&amp;-referrerUri=''&amp;-pageTags='{&quot;pg.t&quot;:&quot;hp&quot;%2C&quot;pg.p&quot;:&quot;prime&quot;%2C&quot;pg.c&quot;:&quot;&quot;%2C&quot;ex&quot;:&quot;&quot;%2C&quot;rid&quot;:&quot;adf2c4fc-9919-462f-aac9-e0440ae41cb8&quot;%2C&quot;di&quot;:&quot;340&quot;%2C&quot;partner&quot;:&quot;&quot;%2C&quot;publcat&quot;:&quot;&quot;%2C&quot;cvs&quot;:&quot;Browser&quot;%2C&quot;subcvs&quot;:&quot;homepage&quot;%2C&quot;entityId&quot;:&quot;&quot;%2C&quot;entitySrc&quot;:&quot;&quot;%2C&quot;provid&quot;:&quot;&quot;%2C&quot;dpt&quot;:&quot;&quot;%2C&quot;sdpt&quot;:&quot;&quot;%2C&quot;ar&quot;:&quot;0&quot;%2C&quot;dgk&quot;:&quot;tmx.pc.webkit.chrome.chrome76plus&quot;%2C&quot;imd&quot;:&quot;0&quot;%2C&quot;parentId&quot;:&quot;&quot;%2C&quot;pgIdx&quot;:&quot;&quot;%2C&quot;pgTot&quot;:&quot;&quot;%2C&quot;anoncknm&quot;:&quot;&quot;%2C&quot;issso&quot;:&quot;0&quot;%2C&quot;aadState&quot;:&quot;0&quot;}'&amp;-behavior=0&amp;-market='en-us'" width="1"/>
# </noscript>
# <div id="irisbannerph"></div>
# <div class="head">
# <header class="no-overlay" data-id="1" data-m='{"i":1,"n":"header","y":6}' data-region="header" id="header-common" role="banner">
# <div class="logowrapper">
# <a aria-label="back to msn home" class="logo" data-id="2" data-m='{"i":2,"p":1,"n":"msnLogo","y":14,"l":"homepage","o":1}' href="/en-us" tabindex="2">
# <span class="">msn</span> <span class="logohover">refresh page</span>
# </a>
# <a aria-haspopup="true" class="vertical" data-id="3" data-m='{"i":3,"p":1,"n":"HeaderVerticalLink","y":14,"l":"homepage","o":2}' href="/en-us" tabindex="2">msn</a>
# </div>
# <div class="logosubtitle">
#  powered by <span class="msnews">Microsoft News</span>
# </div>
# <ul>
# <li>
# <section class="" data-aop="search" data-id="4" data-m='{"i":4,"p":1,"n":"headersearch","y":9,"o":3}' id="header-search" role="search">
# <form action="https://www.bing.com/search?scope=web" data-bing-action-uri="https://www.bing.com/search?scope=web" data-form-code="PRUSEN" id="srchfrm" method="get" target="_blank">
# <div class="qc">
# <input accesskey="S" aria-label="Search:" autocomplete="off" data-id="5" data-m='{"i":5,"p":4,"n":"searchinput","y":9,"o":1}' id="q" maxlength="250" name="q" title="enter your search term" type="search" value=""/>
# </div>
# <div class="buttons">
# <svg class="bingicon" role="img" viewbox="0 0 40 40" xmlns="http://www.w3.org/2000/svg">
# <path d="M 14 30.94 v -28.14 l -8 -2.8 v 35.54 l 8 4.46 l 20 -11.5 v -9.1 Z" fill="#666"></path>
# <path d="M 25.28 24.43 l 8.72 -5.03 l -17.74 -6.2 l 3.47 8.65 l 5.55 2.58 Z" fill="#666" opacity=".75"></path>
# </svg>
# <button class="text" data-id="6" data-m='{"i":6,"p":4,"n":"search_websearch","y":9,"o":2}' id="sb_form_go" title="web search">web search</button>
# </div>
# <input name="form" type="hidden" value="PRUSEN"/>
# <input name="mkt" type="hidden" value="en-us"/>
# <input name="httpsmsn" type="hidden" value="1"/>
# <input name="refig" type="hidden" value="adf2c4fc9919462faac9e0440ae41cb8"/>
# </form>
# <button data-id="7" data-m='{"i":7,"p":4,"n":"search_sb","y":9,"o":3}' id="sb" title="web search" type="button"></button>
# </section>
# </li>
# <li>
# <button class="skip-to" data-id="8" data-m='{"i":8,"p":1,"n":"skip_to_nav","y":11,"o":4}' id="skip_to_nav">Skip To Navigation</button>
# </li>
# <li>
# <button class="skip-to" data-id="9" data-m='{"i":9,"p":1,"n":"skip_to_con","y":11,"o":5}' id="skip_to_con">Skip To Content</button>
# </li>
# <li>
# <button class="skip-to" data-id="10" data-m='{"i":10,"p":1,"n":"skip_to_footer","y":11,"o":6}' id="skip_to_footer">Skip To Footer</button>
# </li>
# <li>
# <ul data-dhp_cookie_days="0" data-id="11" data-m='{"i":11,"p":1,"n":"header-signin","t":"signin","o":7}' data-module-id="startpage|start.header|header|header-signin|signin" data-sso-dependent="true" id="user-profile">
# <li id="sign-in">
# <div data-anonckname="" data-me-url="https://login.live.com/me.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2F%2Fwww.msn.com%2Fen-us%2Fhomepage%2FSecure%2FPassport%3Fru%3Dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us" data-sign-in-url="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True" data-sign-out-url="https://login.live.com/logout.srf?ct=1567030325&amp;rver=7.0.6730.0&amp;lc=1033&amp;id=1184&amp;lru=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f&amp;mkt=en-us&amp;pcexp=True" id="meCtrl">
# <a data-id="12" data-m='{"i":12,"p":11,"n":"SignInNavigation","y":14,"o":1}' href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True" title="Sign in">
# <span class="mectrlname mectrlsignin">Sign in</span>
# </a>
# </div>
# <script>require(["refreshSigninModule", "c.sso"], function (r) { r() })</script>
# </li>
# <li id="settings" role="presentation">
# <a alt="settings" aria-label="page settings" data-id="13" data-m='{"i":13,"p":11,"n":"settings","y":14,"o":2}' href="#temp"></a>
# <ul>
# <li role="presentation">
# <label>Change language &amp; content:</label>
# <select aria-label="Change language &amp; content:" data-id="14" data-m='{"i":14,"p":11,"n":"changemarket","y":14,"o":3}' id="site-market" rel="nofollow" role="menuitem">
# <option data-mkt="es-xl" data-mkt-url="//www.msn.com/es-xl">América Latina (español)</option>
# <option data-mkt="es-ar" data-mkt-url="//www.msn.com/es-ar">Argentina (español)</option>
# <option data-mkt="en-au" data-mkt-url="//www.msn.com/en-au">Australia (English)</option>
# <option data-mkt="nl-be" data-mkt-url="//www.msn.com/nl-be">België (Nederlands)</option>
# <option data-mkt="fr-be" data-mkt-url="//www.msn.com/fr-be">Belgique (français)</option>
# <option data-mkt="pt-br" data-mkt-url="//www.msn.com/pt-br">Brasil (português)</option>
# <option data-mkt="en-ca" data-mkt-url="//www.msn.com/en-ca">Canada (English)</option>
# <option data-mkt="fr-ca" data-mkt-url="//www.msn.com/fr-ca">Canada (français)</option>
# <option data-mkt="cs-cz" data-mkt-url="//www.msn.com/cs-cz">Česká republika (čeština)</option>
# <option data-mkt="es-cl" data-mkt-url="//www.msn.com/es-cl">Chile (español)</option>
# <option data-mkt="es-co" data-mkt-url="//www.msn.com/es-co">Colombia (español)</option>
# <option data-mkt="da-dk" data-mkt-url="//www.msn.com/da-dk">Danmark (Dansk)</option>
# <option data-mkt="de-de" data-mkt-url="//www.msn.com/de-de">Deutschland (Deutsch)</option>
# <option data-mkt="es-es" data-mkt-url="//www.msn.com/es-es">España (español)</option>
# <option data-mkt="fr-fr" data-mkt-url="//www.msn.com/fr-fr">France (français)</option>
# <option data-mkt="en-in" data-mkt-url="//www.msn.com/en-in">India (English)</option>
# <option data-mkt="mr-in" data-mkt-url="//www.msn.com/mr-in">India (मराठी)</option>
# <option data-mkt="hi-in" data-mkt-url="//www.msn.com/hi-in">India (हिंदी)</option>
# <option data-mkt="te-in" data-mkt-url="//www.msn.com/te-in">India (తెలుగు)</option>
# <option data-mkt="id-id" data-mkt-url="//u.msn.com/id-id">Indonesia (Bahasa Indonesia)</option>
# <option data-mkt="en-xl" data-mkt-url="//www.msn.com/en-xl">International Edition (English)</option>
# <option data-mkt="en-ie" data-mkt-url="//www.msn.com/en-ie">Ireland (English)</option>
# <option data-mkt="it-it" data-mkt-url="//www.msn.com/it-it">Italia (italiano)</option>
# <option data-mkt="hu-hu" data-mkt-url="//www.msn.com/hu-hu">Magyarország (magyar)</option>
# <option data-mkt="en-my" data-mkt-url="//www.msn.com/en-my">Malaysia (English)</option>
# <option data-mkt="es-mx" data-mkt-url="//prodigy.msn.com/es-mx">México (español)</option>
# <option data-mkt="nl-nl" data-mkt-url="//www.msn.com/nl-nl">Nederland (Nederlands)</option>
# <option data-mkt="en-nz" data-mkt-url="//www.msn.com/en-nz">New Zealand (English)</option>
# <option data-mkt="nb-no" data-mkt-url="//www.msn.com/nb-no">Norge (norsk, bokmål)</option>
# <option data-mkt="de-at" data-mkt-url="//www.msn.com/de-at">Österreich (Deutsch)</option>
# <option data-mkt="es-pe" data-mkt-url="//www.msn.com/es-pe">Perú (español)</option>
# <option data-mkt="en-ph" data-mkt-url="//www.msn.com/en-ph">Philippines (English)</option>
# <option data-mkt="pl-pl" data-mkt-url="//www.msn.com/pl-pl">Polska (polski)</option>
# <option data-mkt="pt-pt" data-mkt-url="//www.msn.com/pt-pt">Portugal (Português)</option>
# <option data-mkt="de-ch" data-mkt-url="//www.msn.com/de-ch">Schweiz (Deutsch)</option>
# <option data-mkt="en-sg" data-mkt-url="//www.msn.com/en-sg">Singapore (English)</option>
# <option data-mkt="en-za" data-mkt-url="//www.msn.com/en-za">South Africa (English)</option>
# <option data-mkt="fr-ch" data-mkt-url="//www.msn.com/fr-ch">Suisse (français)</option>
# <option data-mkt="fi-fi" data-mkt-url="//www.msn.com/fi-fi">Suomi (suomi)</option>
# <option data-mkt="sv-se" data-mkt-url="//www.msn.com/sv-se">Sverige (svenska)</option>
# <option data-mkt="tr-tr" data-mkt-url="//www.msn.com/tr-tr">Türkiye (Türkçe)</option>
# <option data-mkt="en-ae" data-mkt-url="//www.msn.com/en-ae">United Arab Emirates (English)</option>
# <option data-mkt="en-gb" data-mkt-url="//www.msn.com/en-gb">United Kingdom (English)</option>
# <option data-mkt="en-us" data-mkt-url="//www.msn.com/en-us" selected="">United States (English)</option>
# <option data-mkt="es-us" data-mkt-url="//www.msn.com/es-us">United States (español)</option>
# <option data-mkt="es-ve" data-mkt-url="//www.msn.com/es-ve">Venezuela (español)</option>
# <option data-mkt="vi-vn" data-mkt-url="//www.msn.com/vi-vn">Việt Nam (Tiếng Việt)</option>
# <option data-mkt="el-gr" data-mkt-url="//www.msn.com/el-gr">Ελλάδα (ελληνικά)</option>
# <option data-mkt="ru-ru" data-mkt-url="//www.msn.com/ru-ru">Россия (Pусский)</option>
# <option data-mkt="he-il" data-mkt-url="//www.msn.com/he-il">ישראל (עברית)‏</option>
# <option data-mkt="ar-ae" data-mkt-url="//www.msn.com/ar-ae">الإمارات العربية المتحدة (العربية‏)</option>
# <option data-mkt="ar-sa" data-mkt-url="//www.msn.com/ar-sa">المملكة العربية السعودية (العربية‏)</option>
# <option data-mkt="ar-eg" data-mkt-url="//www.msn.com/ar-eg">مصر (العربية‏)</option>
# <option data-mkt="th-th" data-mkt-url="//www.msn.com/th-th">ไทย (ไทย)</option>
# <option data-mkt="ko-kr" data-mkt-url="//www.msn.com/ko-kr">한국 (한국어)</option>
# <option data-mkt="zh-cn" data-mkt-url="//www.msn.cn/zh-cn">中华人民共和国 (简体中文)</option>
# <option data-mkt="zh-tw" data-mkt-url="//www.msn.com/zh-tw">台灣 (繁體中文)</option>
# <option data-mkt="ja-jp" data-mkt-url="//www.msn.com/ja-jp">日本 (日本語)</option>
# <option data-mkt="zh-hk" data-mkt-url="//www.msn.com/zh-hk">香港特别行政區 (繁體中文)</option>
# </select>
# </li>
# <li class="marketswitch" data-id="15" data-m='{"i":15,"p":11,"n":"marketswitch","y":14,"o":4}' data-mkt="es-us" data-mkt-url="//www.msn.com/es-us" role="presentation">
# <button data-customhandled="" role="menuitem">Switch to Latino (Español)</button>
# </li>
# <li class="global" role="presentation">
# <button class="personalization" data-id="16" data-m='{"i":16,"p":11,"n":"personalization","y":11,"o":5}' role="menuitem">Customize this page</button>
# </li>
# <li role="presentation">
# <a data-id="17" data-m='{"i":17,"p":11,"n":"homepagelink","y":14,"l":"homepage","o":6}' href="https://chrome.google.com/webstore/detail/msn-homepage-bing-search/aodojjhnfnfhaplflfohfddffmjkdjak" id="makehomepage" role="menuitem" target="_blank">Make MSN my homepage</a>
# </li>
# <li class="feedback" role="presentation">
# <a data-id="18" data-m='{"i":18,"p":11,"n":"feedback","y":14,"o":7}' href="#" id="usermenu-feedback" role="menuitem">
#  Feedback
# </a>
# </li>
# <li role="presentation">
# <a data-id="19" data-m='{"i":19,"p":11,"n":"helpLink","y":14,"l":"homepage","o":8}' href="https://support.microsoft.com/product/msn/msn" role="menuitem" target="_blank">Help</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <div data-id="20" data-m='{"i":20,"p":1,"n":"header-languagetoggle","t":"languagetoggle","o":8}' id="language-toggle">
# <button aria-haspopup="true" aria-label="Choose a language" id="langtoggle">en</button>
# <ul>
# <li>Choose a language</li>
# <li class="langtoggle selected" data-mkt="en-us" data-mkt-url="//www.msn.com/en-us" tabindex="0">United States (English) - <span>en</span></li>
# <li class="langtoggle" data-mkt="es-us" data-mkt-url="//www.msn.com/es-us" tabindex="0">United States (español) - <span>es</span></li>
# </ul>
# </div>
# </li>
# </ul>
# </header>
# <div class="search-overlay" data-aop="search-overlay"></div>
# </div>
# <div data-id="21" data-m='{"i":21,"n":"precontent","y":6}' data-region="precontent" id="precontent">
# <div class="custombanner invisible" data-aop="uipr_bar" data-id="22" data-m='{"i":22,"n":"UIPR_render","y":8}' id="refreshbar" title="refresh page">
# <div class="refreshbody">
# <a data-id="23" data-m='{"i":23,"p":22,"n":"UIPR_button","y":11,"o":1}' href="https://www.msn.com:443/">
# <span class="icon reset"></span>
# <span aria-hidden="true" class="text">New content is available. <span class="underline">Click here to refresh the page.</span></span>
# <span class="button" role="button">REFRESH</span>
# </a>
# <a class="icon delete" data-id="24" data-m='{"i":24,"p":22,"n":"UIPR_close","y":11,"o":2}' href="#" title="close"></a>
# </div>
# </div>
# <div id="mestripebg"></div>
# </div>
# <div id="maincontent">
# <div class="content" id="content">
# <main data-id="25" data-m='{"i":25,"n":"main","y":6}' data-region="main" id="main" role="main">
# <div class="stripeouter mestripeouter" data-aop="mestripe_mestripe" data-emptygif="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" data-id="26" data-m='{"i":26,"p":25,"n":"meStripe","t":"meStripe","o":1}' data-section-id="mestripe">
# <div class="mestripescrollfix">
# <button class="stripearrow" data-aop="leftarrow" data-id="27" data-m='{"i":27,"p":26,"n":"leftarrow","y":12,"o":1}' title="previous"></button>
# <div class="mestripe">
# <h2 class="hide">Portals Navigation</h2>
# <ul role="menubar">
# <li class="mail" data-aop="mestripe.mail_me" data-id="28" data-m='{"i":28,"p":26,"n":"meStripe.mail","t":"me","o":2}' role="presentation">
# <a data-piitxt="mail" href="https://outlook.com/" piiurl="https://outlook.com/" target="_blank">
# <h3>Outlook.com<span></span></h3>
# </a>
# </li>
# <li class="store" data-aop="mestripe.store_mestore2" data-id="29" data-m='{"i":29,"p":26,"n":"meStripe.store","t":"meStore2","o":3}' role="presentation">
# <a data-piitxt="store" href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/home?icid=MSN_storeTILE" piiurl="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/home?icid=MSN_storeTILE" target="_blank">
# <h3>Microsoft Store<span></span></h3>
# </a>
# </li>
# <li class="jsskype" data-aop="mestripe.jsskype_mejsskype" data-id="30" data-m='{"i":30,"p":26,"n":"meStripe.jsSkype","t":"meJsSkype","o":4}' role="presentation">
# <a data-piitxt="jsSkype" href="https://www.skype.com/" piiurl="https://www.skype.com/" target="_blank">
# <h3>Skype<span></span></h3>
# </a>
# </li>
# <li class="custom bingshopping" data-aop="mestripe.bingshopping_me" data-id="31" data-m='{"i":31,"p":26,"n":"meStripe.BingShopping","t":"me","o":5}' onhovercolor="#f24d5c" role="presentation">
# <a data-piitxt="custom BingShopping" href="https://www.bing.com/shop?q=shopping&amp;FORM=PHMSBI" piiurl="https://www.bing.com/shop?q=shopping&amp;FORM=PHMSBI" target="_blank">
# <h3>Shopping<span></span></h3>
# </a>
# </li>
# <li class="facebooklite" data-aop="mestripe.facebooklite2_mefacebooklite" data-id="32" data-m='{"i":32,"p":26,"n":"meStripe.facebooklite2","t":"meFacebookLite","o":6}' role="presentation">
# <a data-piitxt="facebooklite" href="https://www.facebook.com/" piiurl="https://www.facebook.com/" target="_blank">
# <h3>Facebook<span></span></h3>
# </a>
# </li>
# <li class="custom ebay sponsored" data-aop="mestripe.ebay_me" data-id="33" data-m='{"i":33,"p":26,"n":"meStripe.eBay","t":"me","o":7}' onhovercolor="#86b817" role="presentation">
# <a data-piitxt="custom eBay" href="https://rover.ebay.com/rover/1/711-53200-19255-0/1?icep_ff3=1&amp;pub=5575532731&amp;toolid=10001&amp;campid=5338586067&amp;customid=&amp;ipn=psmain&amp;icep_vectorid=229466&amp;kwid=902099&amp;mtid=824&amp;kw=lg" piiurl="https://rover.ebay.com/rover/1/711-53200-19255-0/1?icep_ff3=1&amp;pub=5575532731&amp;toolid=10001&amp;campid=5338586067&amp;customid=&amp;ipn=psmain&amp;icep_vectorid=229466&amp;kwid=902099&amp;mtid=824&amp;kw=lg" target="_blank">
# <img class="editorialMeIcon" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpOUO.img?h=27&amp;w=27&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"/>
# <h3>eBay<span></span></h3>
# <span>ad</span>
# </a>
# </li>
# <li class="bingrewards" data-aop="mestripe.mebingrewards_mebingrewards" data-id="34" data-m='{"i":34,"p":26,"n":"meStripe.mebingrewards","t":"meBingRewards","o":8}' data-module-id="startpage|meStripe|meStripe|meStripe.mebingrewards|meBingRewards" role="presentation">
# <a data-piitxt="bingrewards" href="https://www.bing.com/rewards/dashboard" piiurl="https://www.bing.com/rewards/dashboard" target="_blank">
# <h3>Rewards<span></span></h3>
# </a>
# </li>
# <li class="office" data-aop="mestripe.office_meoffice" data-id="35" data-m='{"i":35,"p":26,"n":"meStripe.office","t":"meOffice","o":9}' role="presentation">
# <a data-piitxt="office" href="//afflnk.microsoft.com/c/1239701/439025/7804?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.office.com/?omkt=en-us%26WT.mc_id=MSN_site" piiurl="//afflnk.microsoft.com/c/1239701/439025/7804?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.office.com/?omkt=en-us%26WT.mc_id=MSN_site" target="_blank">
# <h3>Office<span></span></h3>
# </a>
# </li>
# <li class="onedrive" data-aop="mestripe.onedrive_me" data-id="36" data-m='{"i":36,"p":26,"n":"meStripe.onedrive","t":"me","o":10}' role="presentation">
# <a data-piitxt="onedrive" href="https://onedrive.live.com/?wt.mc_id=oo_msn_msnhomepage_header" piiurl="https://onedrive.live.com/?wt.mc_id=oo_msn_msnhomepage_header" target="_blank">
# <h3>OneDrive<span></span></h3>
# </a>
# </li>
# <li class="maps" data-aop="mestripe.maps_memaps" data-id="37" data-m='{"i":37,"p":26,"n":"meStripe.maps","t":"meMaps","o":11}' role="presentation">
# <a data-piitxt="maps" href="https://bing.com/maps/?FORM=MSNMAP" piiurl="https://bing.com/maps/?FORM=MSNMAP" target="_blank">
# <h3>Maps<span></span></h3>
# </a>
# </li>
# <li class="onenote" data-aop="mestripe.onenote_meonenote" data-id="38" data-m='{"i":38,"p":26,"n":"meStripe.onenote","t":"meOneNote","o":12}' role="presentation">
# <a data-piitxt="onenote" href="https://www.onenote.com/notebooks?WT.mc_id=MSN_OneNote_TopMenu&amp;auth=1&amp;wdorigin=msn" piiurl="https://www.onenote.com/notebooks?WT.mc_id=MSN_OneNote_TopMenu&amp;auth=1&amp;wdorigin=msn" target="_blank">
# <h3>OneNote<span></span></h3>
# </a>
# </li>
# <li class="twitter" data-aop="mestripe.twitter_me" data-id="39" data-m='{"i":39,"p":26,"n":"meStripe.twitter","t":"me","o":13}' role="presentation">
# <a data-piitxt="twitter" href="https://twitter.com/" piiurl="https://twitter.com/" target="_blank">
# <h3>Twitter<span></span></h3>
# </a>
# </li>
# </ul>
# </div>
# <button class="stripearrow" data-aop="rightarrow" data-id="40" data-m='{"i":40,"p":26,"n":"rightarrow","y":12,"o":14}' title="next"></button>
# </div>
# <div class="meflyouts">
# <div class="meflyoutcontainer mail" data-id="41" data-m='{"i":41,"p":26,"n":"meStripe.mail","y":5,"o":15}'>
# <div class="meflyout signout">
# <section>
# <div class="mailsignedoutflyout signout" data-aop="outlooksignedoutflyout" data-id="42" data-m='{"i":42,"p":41,"n":"outlooksignedoutflyout","y":8,"o":1}'>
# <section>
# <h2>Get your mail here</h2>
# <ul>
# <li>See your recent emails</li>
# <li>Send a quick email</li>
# <li>Manage your calendar with easy access</li>
# </ul>
# </section>
# <h3>Sign in with any Microsoft account: Outlook, Hotmail, MSN, Live</h3>
# <p><a data-id="43" data-m='{"i":43,"p":42,"n":"mailsignedoutflyout-accounthelp","y":12,"o":1}' href="https://go.microsoft.com/fwlink/?LinkID=254486">What is a Microsoft account?</a></p>
# <ul>
# <li>
# <a data-id="44" data-m='{"i":44,"p":42,"n":"mailsignedoutflyout-signin","y":12,"o":2}' href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True">SIGN IN</a>
# </li>
# <li>
# <a data-id="45" data-m='{"i":45,"p":42,"n":"mailsignedoutflyout-createaccount","y":12,"o":3}' href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1567030324&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True">Create Now</a>
# </li>
# </ul>
# </div>
# </section>
# </div>
# </div>
# <div class="meflyoutcontainer store" data-id="46" data-m='{"i":46,"p":26,"n":"meStripe.store","y":5,"o":16}'>
# <div class="meflyout signin">
# <section>
# <a data-id="47" data-m='{"i":47,"p":46,"n":"store","y":14,"l":"me_store_headerText_signIn","o":1}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/home?icid=MSN_storeHL" target="_blank"><h3>Microsoft Store</h3></a>
# <div>
# <ul data-module-id="startpage|meStripe|meStripe|meStripe.store|meStore2">
# <li>
# <a data-id="48" data-m='{"i":48,"p":46,"n":"HeadlineItemViewModel","y":13,"o":2}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L1_OFFICE&amp;u=https://products.office.com/en-US/compare-all-microsoft-office-products-b?tab=1" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAf2cjT.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Office - Microsoft"/> <h3>Access your files with Office 365. Save, edit, &amp; share, virtually anywhere</h3>
# </div>
# </a>
# </li>
# <li>
# <a data-id="49" data-m='{"i":49,"p":46,"n":"HeadlineItemViewModel","y":13,"o":3}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L3_SURFACEBUNDLES&amp;u=https://www.microsoft.com/en-us/store/collections/surfacebundles" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBRMWiy.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Surface Essential Bundles - Microsoft"/> <h3>Save BIG on Surface Essentials Bundles</h3>
# </div>
# </a>
# </li>
# <li>
# <a data-id="50" data-m='{"i":50,"p":46,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L4_CONNECTEDLIFE&amp;u=https://www.microsoft.com/en-us/store/b/connected-life" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBMIwGM.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="LIFX Mini Color Smart Light Bulb - Microsoft"/> <h3>Streamline your day-to-day with the latest smart devices</h3>
# </div>
# </a>
# </li>
# <li>
# <a data-id="51" data-m='{"i":51,"p":46,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L5_XBOX_DEALS&amp;u=https://www.microsoft.com/en-us/store/b/xbox-deals" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBQx6uR.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Xbox One Prime - Microsoft"/> <h3>Xbox Sales &amp; Specials: Last minute deals on consoles and more</h3>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </section>
# <ul>
# <li data-id="52" data-m='{"i":52,"p":46,"n":"store","y":14,"l":"me_store_taskLinks_surface","o":6}'>
# <a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/surface?icid=MSN_surface" target="_blank">Surface<span></span></a>
# </li>
# <li data-id="53" data-m='{"i":53,"p":46,"n":"store","y":14,"l":"me_store_taskLinks_windows","o":7}'>
# <a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/windows?icid=MSN_Win10" target="_blank">Windows<span></span></a>
# </li>
# <li data-id="54" data-m='{"i":54,"p":46,"n":"store","y":14,"l":"me_store_taskLinks_support","o":8}'>
# <a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://support.microsoft.com/en-us/products/store" target="_blank">Support<span></span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="meflyoutcontainer jsskype" data-id="55" data-m='{"i":55,"p":26,"n":"meStripe.jsSkype","y":5,"o":17}'>
# <div class="meflyout signout">
# <section>
# <div>
# <div>
# <p class="meloading"></p>
# ...
# <span>Lifestyle</span>
# </button>
# <button aria-label="remove Autos" data-id="813" data-m='{"i":813,"y":12,"l":"stripe_toggle_stripe.autos"}' data-stripe-id="stripe.autos">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Ca1l.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Autos"/>
# <span>Autos</span>
# </button>
# <button aria-label="remove Health &amp; Fitness" data-id="814" data-m='{"i":814,"y":12,"l":"stripe_toggle_stripe.health"}' data-stripe-id="stripe.health">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA5YKmV.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Health &amp; Fitness</span>
# </button>
# <button aria-label="remove Food &amp; Drink" data-id="815" data-m='{"i":815,"y":12,"l":"stripe_toggle_stripe.foodanddrink"}' data-stripe-id="stripe.foodanddrink">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA5Ypq6.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Food &amp; Drink</span>
# </button>
# <button aria-label="remove Travel" data-id="816" data-m='{"i":816,"y":12,"l":"stripe_toggle_stripe.travel"}' data-stripe-id="stripe.travel">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4ChN0.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Travel"/>
# <span>Travel</span>
# </button>
# <button aria-label="remove Causes" data-id="817" data-m='{"i":817,"y":12,"l":"stripe_toggle_stripe.causes"}' data-stripe-id="stripe.causes">
# <span>Causes</span>
# </button>
# <button aria-label="remove Photos" data-id="818" data-m='{"i":818,"y":12,"l":"stripe_toggle_stripe.photos"}' data-stripe-id="stripe.photos">
# <span>Photos</span>
# </button>
# <button aria-label="remove Video" data-id="819" data-m='{"i":819,"y":12,"l":"stripe_toggle_stripe.video"}' data-stripe-id="stripe.video">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oAOK.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Video</span>
# </button>
# <button aria-label="add Movies" class="pending" data-id="820" data-m='{"i":820,"y":12,"l":"stripe_toggle_stripe.movies"}' data-stripe-id="stripe.movies">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Cser.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Movies"/>
# <span>Movies</span>
# </button>
# <button aria-label="add TV" class="pending" data-id="821" data-m='{"i":821,"y":12,"l":"stripe_toggle_stripe.tv"}' data-stripe-id="stripe.tv">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oL47.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>TV</span>
# </button>
# <button aria-label="add Music" class="pending" data-id="822" data-m='{"i":822,"y":12,"l":"stripe_toggle_stripe.music"}' data-stripe-id="stripe.music">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Csg8.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Music"/>
# <span>Music</span>
# </button>
# <button aria-label="add World" class="pending" data-id="823" data-m='{"i":823,"y":12,"l":"stripe_toggle_stripe.world"}' data-stripe-id="stripe.world">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6olcF.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>World</span>
# </button>
# <button aria-label="add US" class="pending" data-id="824" data-m='{"i":824,"y":12,"l":"stripe_toggle_stripe.national"}' data-stripe-id="stripe.national">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oAHY.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>US</span>
# </button>
# <button aria-label="add Politics" class="pending" data-id="825" data-m='{"i":825,"y":12,"l":"stripe_toggle_stripe.politics"}' data-stripe-id="stripe.politics">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oG70.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Politics</span>
# </button>
# <button aria-label="add Technology" class="pending" data-id="826" data-m='{"i":826,"y":12,"l":"stripe_toggle_stripe.tech"}' data-stripe-id="stripe.tech">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Cxu3.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Khoa học &amp; Công nghệ"/>
# <span>Technology</span>
# </button>
# <button aria-label="remove Promotions" data-id="827" data-m='{"i":827,"y":12,"l":"stripe_toggle_stripe.msstore"}' data-stripe-id="stripe.msstore">
# <span>Promotions</span>
# </button>
# <div class="loading"></div>
# </div>
# <button class="done" data-id="828" data-m='{"i":828,"y":12,"l":"stripe_personalization_submit"}'>Done</button>
# </section>
# </div>
# <div id="foot">
# <footer class="ab c2" data-id="829" data-m='{"i":829,"n":"Footer","y":2}' data-region="footer" role="contentinfo">
# <a class="copyright microsoft" data-id="830" data-m='{"i":830,"p":829,"n":"MicrosoftCopyright","y":14,"o":1}' href="https://www.microsoft.com/en-us/"><span></span><span></span>© 2019 Microsoft</a>
# <ul class="app-badges">
# <li class="apple-badge">
# <a data-id="831" data-m='{"i":831,"p":829,"n":"amsnewsft","y":11,"o":2}' href="https://itunes.apple.com/us/app/microsoft-news/id945416273?pt=80423&amp;ct=prime_footer&amp;mt=8" target="_blank" title="Download on the App Store"><img alt="Download on the App Store" src="https://linkmaker.itunes.apple.com/assets/shared/badges/en-us/appstore-lrg.svg"/></a>
# </li>
# <li class="google-badge">
# <a data-id="832" data-m='{"i":832,"p":829,"n":"gmsnewsft","y":11,"o":3}' href="https://play.google.com/store/apps/details?id=com.microsoft.amp.apps.bingnews&amp;hl=en-us&amp;referrer=utm_source=prime_footer&amp;utm_campaign=footer" target="_blank" title="Get it on Google Play"><img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png"/></a>
# </li>
# </ul>
# <ul data-facebook-button-width="9.7rem" data-facebook-like-url="https://www.facebook.com/msn" data-twitter-button-width="9.5rem" data-twitter-follow-screen-name="msn" data-twitter-show-screen-name="false" id="social-plugins">
# <li data-id="833" data-m='{"i":833,"p":829,"n":"facebook","y":11,"o":4}' id="fbcount"></li>
# <li data-id="834" data-m='{"i":834,"p":829,"n":"twitter","y":11,"o":5}' id="twcount"></li>
# </ul>
# <ul id="links">
# <li><a data-id="835" data-m='{"i":835,"p":829,"n":"footer_privacy","y":14,"o":6}' href="https://go.microsoft.com/fwlink/?LinkId=521839">
# Privacy &amp; Cookies
# </a>
# </li>
# <li><a data-id="836" data-m='{"i":836,"p":829,"n":"footer_legal","y":14,"o":7}' href="https://go.microsoft.com/fwlink/?LinkID=246338">
# Terms of use
# </a>
# </li>
# <li><a data-id="837" data-m='{"i":837,"p":829,"n":"footer_adprivacyinfo","y":14,"o":8}' href="https://go.microsoft.com/fwlink/?LinkID=286759">
# About our Ads
# </a>
# </li>
# <li><a data-id="838" data-m='{"i":838,"p":829,"n":"footer_feedback","y":14,"o":9}' href="#" id="footer_feedback" target="_self">Feedback
# </a>
# </li>
# <li><a data-id="839" data-m='{"i":839,"p":829,"n":"footer_help","y":14,"o":10}' href="https://go.microsoft.com/fwlink/?LinkId=512703">
# Help
# </a>
# </li>
# <li><a data-id="840" data-m='{"i":840,"p":829,"n":"footer_worldwide","y":14,"o":11}' href="/en-us/msn-worldwide">
# MSN Worldwide
# </a>
# </li>
# <li><a data-id="841" data-m='{"i":841,"p":829,"n":"footer_newsletter","y":14,"o":12}' href="/en-us/newslettersignup">
# Newsletter
# </a>
# </li>
# <li><a data-id="842" data-m='{"i":842,"p":829,"n":"footer_advertise","y":14,"o":13}' href="https://go.microsoft.com/fwlink/?linkid=875132">
# Advertise
# </a>
# </li>
# <li><a data-id="843" data-m='{"i":843,"p":829,"n":"footer_msn_blog","y":14,"o":14}' href="https://blog.msn.com/">
# MSN Blog
# </a>
# </li>
# <li><a data-id="844" data-m='{"i":844,"p":829,"n":"footer_aboutus","y":14,"o":15}' href="/en-us/news/us/about-us/ar-BBN0NAK">
# About Us
# </a>
# </li>
# </ul>
# </footer>
# </div>
# <div data-aop="feedback_flyout" id="feedback-flyout">
# <button data-id="845" data-m='{"i":845,"n":"feedback","y":11,"l":"close"}' id="feedback-close" title="close"></button>
# <div class="feedbackheader mainheader">
# <h2>Send MSN Feedback</h2>
# </div>
# <div class="feedbackheader thankyou">
# <h2>We appreciate your input!</h2>
# </div>
# <div id="feedback-feedbackarea">
# <div class="feedbackarea">
# <label for="feedback-inputbox">How can we improve?</label>
# <textarea aria-live="assertive" id="feedback-inputbox" maxlength="400" placeholder="Enter your feedback here. To help protect your privacy, don't include personal information, like your name or address."></textarea>
# </div>
# </div>
# <div id="feedback-starrating">
# <div class="stars">
# <p>Please give an overall site rating:</p>
# <ul aria-label="Please give an overall site rating:" data-selected="0" role="radiogroup">
# <li aria-checked="false" aria-label="1 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="2 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="3 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="4 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="5 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# </ul>
# </div>
# </div>
# <button class="footerbutton" data-id="846" data-m='{"i":846,"n":"feedback","y":11,"l":"submit"}' id="feedback-submit" title="submit">Submit</button>
# <button class="footerbutton" data-id="847" data-m='{"i":847,"n":"feedback","y":11,"l":"ok"}' id="feedback-ok" title="close">Close</button>
# <div class="feedbackfooter">
# <div id="feedback-privacy-link">
# <a class="footerlink" data-id="848" data-m='{"i":848,"n":"feedback","y":14,"l":"feedbackPrivacyLink"}' href="https://go.microsoft.com/fwlink/?LinkId=521839" target="_blank">Privacy Statement</a>
# </div>
# <div id="feedback-help-link">
# <a class="footerlink" data-id="849" data-m='{"i":849,"n":"feedback","y":14,"l":"feedbackHelpLink"}' href="https://support.microsoft.com/product/msn/msn" target="_blank">Help</a>
# </div>
# <div id="feedback-help-support-link">
# <a class="footerlink" data-id="850" data-m='{"i":850,"n":"feedback","y":14,"l":"feedbackHelpSupportLink"}' href="https://support.microsoft.com/product/msn/msn" target="_blank">Help &amp; Support</a>
# </div>
# </div>
# </div>
# <script>require(["window","document","location","trackInfo","headData","c.onload"],function(n,t,i,r,u){(function f(){var e=r.sitePage,h=e.chartBeatUID,v=e.localeCode,o=e.channel,c=e.department,l=e.chartBeatBase,y=e.chartBeatDomain||i.hostname,p=c?o+","+o+":"+c:o,s,u,w,a;h&&l?(s=n._timing||{},n._st_startpt=s.start||0,n._st_endpt=s.load||0,u=n.location.pathname,u==="/"||u==="/en-us/"?u="/en-us":u.charAt(u.length-1)=="/"&&(u=u.substr(0,u.length-1)),w="",n._sf_async_config={uid:h,sessionLength:15,domain:v+"."+y,sections:p,authors:e.cvPartner?decodeURIComponent(e.cvPartner.replace("+","%20")):"",path:u},a=(/\bsn:\s*(\w*)/.exec(t.getElementsByTagName("HEAD")[0].getAttribute("data-info"))||{})[1]||"",n._cbq=n._cbq||[],n._cbq.push(["_cdname",a]),require({js:l+"/js/chartbeat.js"})):setTimeout(f,50)})()})</script> <script>
#         require(["headData", "pageInstance", "mediator", "c.deferred"], function (headData, pageInstance, mediator)
#         {
#         var url = '//www.bizographics.com/collect/?fmt=gif&pid=7850';
#         if (headData && headData.clientSettings && headData.clientSettings.static_page)
#         {
#             mediator.pub(pageInstance.eventName);
#             var rid = pageInstance.getActivityId();
#             url = url.replace(/([?&]rid=)[^&#]*/i, "$1" + rid);
#             }
#         new Image().src = url.replace(/&amp;/g, '&');
#     });
#     </script>
# <noscript>
# <div>
# <img alt="" data-src="//www.bizographics.com/collect/?fmt=gif&amp;pid=7850&amp;ts=noscript" height="1" width="1"/>
# </div>
# </noscript>
# <script>require(["imageLoad","perfMarker","perfMeasure"],function(n,t,i){var r="TimeToImageLoadStart",u="TimeToImageLoadEnd";t(r);n.cleanup();t(u);i("TimeForImageLoad",r,u,!0)});require(["jquery","logging","webApp.tokens","c.deferred"],function(n,t,i){function r(r){var u=n(this).attr(r);i.validVersionPattern.test(u)||t.error("[staticsLinkVerifier.js] ver query parameter missing in statics url: "+u)}n("link[href*='_sc/css']").each(function(){r.call(this,"href")});n("script[src*='_sc/js']").each(function(){r.call(this,"src")})});require(["trackInfo","window","c.onload"],function(n,t){function c(){if(n.sitePage.requestId){var i=o.setupParameters("load_time");i&&(i.timeToOnload=u,i.timeToDomComplete=s,i.timeToFirstByte=h,f&&(i.timeToFirstSearchRendered=f),t.performance&&t.performance.navigation&&t.performance.navigation.type&&(i.navType=t.performance.navigation.type),require(["c.infopaneinteractive"],function(n){n&&(i.timeToInfopaneInteractive=n);o.sendUpdate(i)}))}else t.setTimeout(c,500)}var o=n.telemetryTracking,u,s,h,f,i=(t.performance||{}).timing,r,e;i&&(u=i.loadEventStart-i.navigationStart,s=i.domComplete-i.navigationStart,h=i.responseStart-i.navigationStart,t.performance&&(r=t.performance.getEntriesByName("TimeToFirstSearchRendered","mark"),r&&(e=r.length,e&&e>0&&(f=Math.round(r[0].startTime)))),u&&c())});window._perfMarker&&window._perfMarker("TimeTocDom",!0);window._perfMeasure&&window._perfMeasure("TimeForcDom","TimeToHeadStart","TimeTocDom",!0);define("c.dom",1);window.onload=function(n){function r(){clearTimeout(t);t=0;window._perfMarker&&window._perfMarker("TimeTocDeferred");window._perfMeasure&&window._perfMeasure("TimeForcDeferred","TimeTocOnload","TimeTocDeferred");define("c.deferred",1);require(["c.deferred"],function(){i=setTimeout(f,u)})}function f(){clearTimeout(i);i=0;window._perfMarker&&window._perfMarker("TimeTocPostDeferred");window._perfMeasure&&window._perfMeasure("TimeForcPostdeferred","TimeTocDeferred","TimeTocPostDeferred");define("c.postdeferred",1)}var t,i,u=2e3;return function(n){var i;n&&(i=(window.JSON&&window.JSON.parse(n)||{}).dms,u=(window.JSON&&window.JSON.parse(n)||{}).ps);t=setTimeout(r,i||3e3)}(document.getElementsByTagName("head")[0].getAttribute("data-js")),function(i){typeof n=="function"&&n(i);window._perfMarker&&window._perfMarker("TimeTocOnload",!0);window._perfMeasure&&window._perfMeasure("TimeForcOnload","TimeTocDom","TimeTocOnload",!0);define("c.onload",1);t&&(window.setImmediate?setImmediate(r):setTimeout(r,0))}}(window.onload)</script><script>define("trackingConstants",{trackingData: {lastIndex: 850 } });</script> <script>window._perfMarker && window._perfMarker("TimeToBodyEnd");window._perfMeasure && window._perfMeasure("TimeForBody","TimeToBodyStart","TimeToBodyEnd",true);</script>
# </body>
# <!--MSNAvailToken-->
# </html>

# %%
len(soup.select('img[alt="INSIDER Logo"]'))
# Out:
# 4

# %%
soup.select('img[alt="INSIDER Logo"]')
# Out:
# [<img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>,
#  <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>,
#  <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>,
#  <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>]

# %%
type(soup.select('img[alt="INSIDER Logo"]'))
# Out:
# list

# %%
soup.select('.stripecontainer[aria-label]')
# Out:
# [<div aria-label="new york" class="stripecontainer" data-section-id="stripe.localnews2" role="region">
#  <div class="news stripeouter" data-aop="stripe.localnews2_stripe" data-id="343" data-m='{"i":343,"p":25,"n":"stripe.localnews2-newyork","t":"stripe","o":5}'>
#  <button class="leftarrow" data-id="344" data-m='{"i":344,"p":343,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
#  <div class="stripe full-width">
#  <div class="stripenav" data-aop="stripe.localnews.navigation_stripenavigation" data-id="345" data-m='{"i":345,"p":343,"n":"stripe.localnews.navigation","t":"stripeNavigation","o":2}'>
#  <ul>
#  <li data-id="346" data-m='{"i":346,"p":345,"n":"Local News","y":4,"o":1}'>
#  <h2><a data-id="347" data-m='{"i":347,"p":345,"n":"Local News","y":4,"o":2}' href="/en-us/news/newyork">New York</a></h2>
#  </li>
#  </ul>
#  <div class="stripemenu" role="menu">
#  <button class="edit" data-id="348" data-m='{"i":348,"p":345,"n":"personalization","t":"dropdown","o":3}'>Edit</button>
#  <button class="remove" data-id="349" data-m='{"i":349,"p":345,"n":"remove","t":"dropdownitem","o":4}' role="menuitem">Remove Section</button>
#  <button class="up" data-id="350" data-m='{"i":350,"p":345,"n":"moveup","t":"dropdownitem","o":5}' role="menuitem">Move Section Up</button>
#  <button class="down" data-id="351" data-m='{"i":351,"p":345,"n":"movedown","t":"dropdownitem","o":6}' role="menuitem">Move Section Down</button>
#  <button class="add" data-id="352" data-m='{"i":352,"p":345,"n":"addbelow","t":"dropdownitem","o":7}' role="menuitem">Add Section Below</button>
#  </div>
#  </div>
#  <div class="paging-container">
#  <div class="stripecontent normaldensity" data-aop="local news" data-id="353" data-m='{"i":353,"p":343,"n":"stripe.localnews.topstories","t":"localnewsheadlines","o":3}' data-module-id="startpage|stripe.localnews2|stripe|stripe.localnews.topstories|localnewsheadlines">
#  <ul class="secondary" data-aop="secondary" data-id="354" data-m='{"i":354,"p":353,"n":"secondary","y":8,"o":1}'>
#  <li data-id="355" data-m='{"i":355,"p":354,"n":"HeadlineItemViewModel","y":13,"l":"AAGsx5L","h":4,"v":"travel","c":"travelnews","o":1}'>
#  <a href="/en-us/travel/news/hoboken-set-to-use-eminent-domain-to-take-union-dry-dock-from-ny-waterway/ar-AAGsx5L">
#  <img alt="Hoboken Set To Use Eminent Domain To Take Union Dry Dock From NY Waterway" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsznR.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Hoboken Set To Use Eminent Domain To Take Union Dry Dock From NY Waterway - Provided by CBS Local, a division of CBS Radio Inc"/> <div>
#  <h3 aria-label="hoboken set to use eminent domain to take union dry dock from ny waterway">Hoboken Set To Use Eminent Domain To Take Union Dry Dock From NY Waterway</h3>
#  <img alt="CBS New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/AAyW7G9.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="CBS New York"/> <span>CBS New York</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="tertiary" data-aop="tertiary" data-id="356" data-m='{"i":356,"p":353,"n":"tertiary","y":8,"o":2}'>
#  <li data-id="357" data-m='{"i":357,"p":356,"n":"HeadlineItemViewModel","y":13,"l":"AAGsmXC","h":5,"v":"movies","c":"movienews","o":1}'>
#  <a href="/en-us/movies/news/legendary-director-steven-spielberg-granted-key-to-paterson-nj/ar-AAGsmXC">
#  <img alt="Legendary director Steven Spielberg granted key to Paterson, NJ" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGssaC.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Legendary director Steven Spielberg granted key to Paterson, NJ - Provided by Entercom Radio, LLC"/> <div>
#  <h3 aria-label="legendary director steven spielberg granted key to paterson, nj">Legendary director Steven Spielberg granted key to Paterson, NJ</h3>
#  <img alt="WINS Radio New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTg0tm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WINS Radio New York"/> <span>WINS Radio New York</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="358" data-m='{"i":358,"p":356,"n":"HeadlineItemViewModel","y":13,"l":"AAGsCHv","h":6,"v":"foodanddrink","c":"newstrends","o":2}'>
#  <a href="/en-us/foodanddrink/foodnews/a-new-xian-hand-pulled-noodle-restaurant-bounces-into-williamsburg/ar-AAGsCHv">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsA8o.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="A New Xi’an Hand-Pulled Noodle Restaurant Bounces Into Williamsburg - Xi’an Town [Official]"/> <div>
#  <h3 aria-label="a new xi’an hand-pulled noodle restaurant bounces into williamsburg">A New Xi’an Hand-Pulled Noodle Restaurant Bounces Into Williamsburg</h3>
#  <img alt="Eater" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/AA565dd.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Eater"/> <span>Eater</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="359" data-m='{"i":359,"p":356,"n":"HeadlineItemViewModel","y":13,"l":"AAGsAha","h":7,"v":"news","c":"newsworld","o":3}'>
#  <a href="/en-us/news/world/63-year-old-rabbi-beat-with-brick-in-brooklyn-believes-attacker-wanted-to-kill-him/ar-AAGsAha">
#  <img alt="63-year-old Jewish grandfather beaten with brick in Crown Heights park in appare..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsMwW.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=481&amp;y=433"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="63-year-old Jewish grandfather beaten with brick in Crown Heights park in appare... - PIX11/TNS"/> <div>
#  <h3 aria-label="63-year-old rabbi beat with brick in brooklyn believes attacker wanted to kill him">63-year-old rabbi beat with brick in Brooklyn believes attacker wanted to kill him</h3>
#  <img alt="WPIX-TV New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTUVWY.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WPIX-TV New York"/> <span>WPIX-TV New York</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="tertiary" data-aop="tertiary" data-id="360" data-m='{"i":360,"p":353,"n":"tertiary","y":8,"o":3}'>
#  <li data-id="361" data-m='{"i":361,"p":360,"n":"HeadlineItemViewModel","y":13,"l":"AAGsNE4","h":8,"v":"news","c":"newspolitics","o":1}'>
#  <a href="/en-us/news/politics/trumps-second-ave-subway-tweet-prompts-cuomo-to-call-feds/ar-AAGsNE4">
#  <img alt="Trump's Second Ave Subway Tweet Prompts Cuomo To Call Feds" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsNDT.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Trump's Second Ave Subway Tweet Prompts Cuomo To Call Feds - Provided by Planck, LLC, d/b/a Patch Media"/> <div>
#  <h3 aria-label="trump's second ave subway tweet prompts cuomo to call feds">Trump's Second Ave Subway Tweet Prompts Cuomo To Call Feds</h3>
#  <img alt="Patch" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/AAyhxXG.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Patch"/> <span>Patch</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="362" data-m='{"i":362,"p":360,"n":"HeadlineItemViewModel","y":13,"l":"AAGszE8","h":9,"v":"finance","c":"finance-real-estate","o":2}'>
#  <a href="/en-us/money/realestate/for-dollar425k-an-upper-east-side-studio-with-a-huge-backyard/ar-AAGszE8">
#  <img alt="The studio’s private outdoor area." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGszDJ.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The studio’s private outdoor area. - Courtesy of Douglas Elliman"/> <div>
#  <h3 aria-label="for $425k, an upper east side studio with a huge backyard">For $425K, an Upper East Side studio with a huge backyard</h3>
#  <img alt="Curbed" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BB1ba5a.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Curbed"/> <span>Curbed</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="363" data-m='{"i":363,"p":360,"n":"HeadlineItemViewModel","y":13,"l":"AAGsAjQ","h":10,"v":"sports","c":"baseball_mlb","o":3}'>
#  <a href="/en-us/sports/mlb/jeff-mcneil-we-love-playing-for-mickey/ar-AAGsAjQ">
#  <img alt="Jeff McNeil: We Love Playing For Mickey" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsK8L.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Jeff McNeil: We Love Playing For Mickey - Provided by Entercom Radio, LLC"/> <div>
#  <h3 aria-label="jeff mcneil: we love playing for mickey">Jeff McNeil: We Love Playing For Mickey</h3>
#  <img alt="WFAN Radio New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTg0rh.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WFAN Radio New York"/> <span>WFAN Radio New York</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="tertiary" data-aop="tertiary" data-id="364" data-m='{"i":364,"p":353,"n":"tertiary","y":8,"o":4}'>
#  <li data-id="365" data-m='{"i":365,"p":364,"n":"HeadlineItemViewModel","y":13,"l":"AAGsFAg","h":11,"v":"music","c":"musicnews","o":1}'>
#  <a href="/en-us/music/news/cops-bust-french-montanas-bodyguard-at-nyc-nightclub-following-vmas/ar-AAGsFAg">
#  <div>
#  <h3 aria-label="cops bust french montana's bodyguard at nyc nightclub following vmas">Cops bust French Montana's bodyguard at NYC nightclub following VMAs</h3>
#  <img alt="New York Daily News" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/AA8I0Dg.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="New York Daily News"/> <span>New York Daily News</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="366" data-m='{"i":366,"p":364,"n":"HeadlineItemViewModel","y":13,"l":"AAGs90W","h":12,"v":"autos","c":"autosnews","o":2}'>
#  <a href="/en-us/autos/news/new-span-of-kosciuszko-bridge-opens/ar-AAGs90W">
#  <img alt="New span of Kosciuszko Bridge opens" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGslgY.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="New span of Kosciuszko Bridge opens - Provided by Entercom Radio, LLC"/> <div>
#  <h3 aria-label="new span of kosciuszko bridge opens">New span of Kosciuszko Bridge opens</h3>
#  <img alt="WINS Radio New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTg0tm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WINS Radio New York"/> <span>WINS Radio New York</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="367" data-m='{"i":367,"p":364,"n":"HeadlineItemViewModel","y":13,"l":"AAGsKzt","h":13,"v":"sports","c":"baseball_mlb","o":3}'>
#  <a href="/en-us/sports/mlb/yankees-likely-to-call-up-clint-frazier-in-september/ar-AAGsKzt">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsVqC.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Yankees likely to call up Clint Frazier in September - Adam Hunger-USA TODAY Sports"/> <div>
#  <h3 aria-label="yankees likely to call up clint frazier in september">Yankees likely to call up Clint Frazier in September</h3>
#  <img alt="Larry Brown Sports" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBjLpNF.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Larry Brown Sports"/> <span>Larry Brown Sports</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="paging"></div>
#  </div>
#  <button class="rightarrow" data-id="368" data-m='{"i":368,"p":343,"n":"rightarrow","y":12,"o":4}' tabindex="-1" title="next"></button>
#  </div>
#  </div>,
#  <div aria-label="news" class="stripecontainer" data-positions=".news .stripecontent .tertiary:nth-of-type(2) li:nth-child(3)" data-section-id="stripe.news" role="region">
#  <div class="news stripeouter" data-aop="stripe.news_stripe" data-id="369" data-m='{"i":369,"p":25,"n":"stripe.news","t":"stripe","o":6}'>
#  <button class="leftarrow" data-id="370" data-m='{"i":370,"p":369,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
#  <div class="stripe full-width">
#  <div class="stripenav" data-aop="stripe.news.navigation_stripenavigation" data-id="371" data-m='{"i":371,"p":369,"n":"stripe.news.navigation","t":"stripeNavigation","o":2}'>
#  <ul>
#  <li data-id="372" data-m='{"i":372,"p":371,"n":"news","y":4,"o":1}'>
#  <h2><a data-id="373" data-m='{"i":373,"p":371,"n":"news","y":4,"o":2}' href="/en-us/news">News</a></h2>
#  </li>
#  <li class="hide12" data-id="374" data-m='{"i":374,"p":371,"n":"listlink","y":4,"l":"US","o":3}'><a href="/en-us/news/us">US</a></li>
#  <li class="hide12" data-id="375" data-m='{"i":375,"p":371,"n":"listlink","y":4,"l":"WORLD","o":4}'><a href="/en-us/news/world">WORLD</a></li>
#  <li class="hide12" data-id="376" data-m='{"i":376,"p":371,"n":"listlink","y":4,"l":"POLITICS","o":5}'><a href="/en-us/news/politics">POLITICS</a></li>
#  <li class="hide12" data-id="377" data-m='{"i":377,"p":371,"n":"listlink","y":4,"l":"FACT CHECK","o":6}'><a href="/en-us/news/factcheck/">FACT CHECK</a></li>
#  <li class="hide12" data-id="378" data-m='{"i":378,"p":371,"n":"listlink","y":4,"l":"OPINION","o":7}'><a href="/en-us/news/opinion">OPINION</a></li>
#  <li class="hide123" data-id="379" data-m='{"i":379,"p":371,"n":"listlink","y":4,"l":"GOOD NEWS","o":8}'><a href="/en-us/news/good-news">GOOD NEWS</a></li>
#  <li class="hide123" data-id="380" data-m='{"i":380,"p":371,"n":"listlink","y":4,"l":"CRIME","o":9}'><a href="/en-us/news/crime/">CRIME</a></li>
#  <li class="hide123" data-id="381" data-m='{"i":381,"p":371,"n":"listlink","y":4,"l":"LOCAL","o":10}'><a href="/en-us/news/local">LOCAL</a></li>
#  <li class="hide123" data-id="382" data-m='{"i":382,"p":371,"n":"listlink","y":4,"l":"TECH","o":11}'><a href="/en-us/news/technology">TECH</a></li>
#  <li class="hide123" data-id="383" data-m='{"i":383,"p":371,"n":"listlink","y":4,"l":"SCIENCE","o":12}'><a href="/en-us/news/science">SCIENCE</a></li>
#  <li class="hide123" data-id="384" data-m='{"i":384,"p":371,"n":"listlink","y":4,"l":"VIDEO","o":13}'><a href="/en-us/news/video/">VIDEO</a></li>
#  <li class="hide123" data-id="385" data-m='{"i":385,"p":371,"n":"listlink","y":4,"l":"PHOTOS","o":14}'><a href="/en-us/news/photos">PHOTOS</a></li>
#  <li class="hide123" data-id="386" data-m='{"i":386,"p":371,"n":"listlink","y":4,"l":"MY TOPICS","o":15}'><a href="/en-us/news/topics">MY TOPICS</a></li>
#  </ul>
#  <div class="stripemenu" role="menu">
#  <button class="edit" data-id="387" data-m='{"i":387,"p":371,"n":"personalization","t":"dropdown","o":16}'>Edit</button>
#  <button class="remove" data-id="388" data-m='{"i":388,"p":371,"n":"remove","t":"dropdownitem","o":17}' role="menuitem">Remove Section</button>
#  <button class="up" data-id="389" data-m='{"i":389,"p":371,"n":"moveup","t":"dropdownitem","o":18}' role="menuitem">Move Section Up</button>
#  <button class="down" data-id="390" data-m='{"i":390,"p":371,"n":"movedown","t":"dropdownitem","o":19}' role="menuitem">Move Section Down</button>
#  <button class="add" data-id="391" data-m='{"i":391,"p":371,"n":"addbelow","t":"dropdownitem","o":20}' role="menuitem">Add Section Below</button>
#  </div>
#  </div>
#  <div class="paging-container">
#  <div class="stripecontent normaldensity" data-aop="top stories" data-id="392" data-m='{"i":392,"p":369,"n":"stripe.news.topStories","t":"headlines","o":3}' data-module-id="startpage|stripe.news|stripe|stripe.news.topStories|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="393" data-m='{"i":393,"p":392,"n":"secondary","y":8,"o":1}'>
#  <li data-id="394" data-m='{"i":394,"p":393,"n":"HeadlineItemViewModel","y":13,"l":"AAGsQxv","h":0,"v":"news","c":"newsus","o":1}'>
#  <a href="/en-us/news/us/without-notice-us-rejects-deferred-action-requests-from-immigrants/ar-AAGsQxv?li=BBnbcA1">
#  <img alt="A man holds an envelope from the U.S. Citizenship and Immigrations Service durin..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsQxp.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1000&amp;y=896"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Image: Citizenship Ceremony - Carlos Barria"/> <div>
#  <h3 aria-label="without notice, u.s. is rejecting requests to defer deportations-article">Without notice, U.S. is rejecting requests to defer deportations</h3>
#  <img alt="NBC News Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBAJ56P.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>NBC News</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="tertiary" data-aop="tertiary" data-id="395" data-m='{"i":395,"p":392,"n":"tertiary","y":8,"o":2}'>
#  <li data-id="396" data-m='{"i":396,"p":395,"n":"HeadlineItemViewModel","y":13,"l":"AAGpG5Z","h":0,"v":"news","c":"newsworld","o":1}'>
#  <a href="/en-us/news/world/saudi-ruler-sends-brother-to-us-as-trump-wavers-on-iran-yemen/ar-AAGpG5Z?li=BBnbcA1">
#  <img alt="The Kingdom Tower, operated by Kingdom Holding Co., left, stands alongside the K..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsIcq.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Saudi Ruler Sends Brother to U.S. as Trump Wavers on Iran, Yemen - Bloomberg"/> <div>
#  <h3 aria-label="saudi ruler sends brother to us as trump wavers on iran, yemen-article">Saudi ruler sends brother to US as Trump wavers on Iran, Yemen</h3>
#  <img alt="Bloomberg Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA3lldo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Bloomberg</span>
#  </div>
#  </a>
#  </li>
#  <li class="media photo" data-id="397" data-m='{"i":397,"p":395,"n":"HeadlineItemViewModel","y":13,"l":"AAGbMqB","h":0,"v":"news","c":"other","o":2}'>
#  <a href="/en-us/news/other/in-photos-fires-in-the-amazon/ss-AAGbMqB?li=BBnbcA1">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGrQvX.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1853&amp;y=2320"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="n area afected by forest fires is seen in Otuquis National Park, in the Pantanal... - Aizar Raldes/AFP/Getty Images"/> <div>
#  <h3 aria-label="in photos: fires ravage the amazon-slideshow">In Photos: Fires Ravage the Amazon</h3>
#  </div>
#  </a>
#  </li>
#  <li data-id="398" data-m='{"i":398,"p":395,"n":"HeadlineItemViewModel","y":13,"l":"AAGsBbE","h":0,"v":"news","c":"newsworld","o":3}'>
#  <a href="/en-us/news/world/girl-lured-to-london-by-man-she-met-on-facebook-found-safe-across-the-pond-police/ar-AAGsBbE?li=BBnbcA1">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGscSo.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=632&amp;y=465"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Girl, 16, Feared to Have Been Lured From New York to London by Older Man She Met... - Provided by CBS Interactive Inc."/> <div>
#  <h3 aria-label="girl lured to london by man she met online found safe: police-article">Girl lured to London by man she met online found safe: police</h3>
#  <img alt="New York Daily News Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA8I0Dg.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>New York Daily News</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="tertiary" data-aop="tertiary" data-id="399" data-m='{"i":399,"p":392,"n":"tertiary","y":8,"o":3}'>
#  <li data-id="400" data-m='{"i":400,"p":399,"n":"HeadlineItemViewModel","y":13,"l":"AAGsmAS","h":0,"v":"news","c":"newscrime","o":1}'>
#  <a href="/en-us/news/crime/mich-man-allegedly-killed-wife-whod-recently-given-birth-by-putting-heroin-in-her-cereal/ar-AAGsmAS?li=BBnbcA1">
#  <img alt="Christina Ann-Thompson Harris" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsmAN.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1070&amp;y=1053"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Christina Ann-Thompson Harris - Facebook"/> <div>
#  <h3 aria-label="mich. man allegedly killed wife by putting heroin in her cereal-article">Mich. man allegedly killed wife by putting heroin in her cereal</h3>
#  <img alt="People Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywHbG.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>People</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="401" data-m='{"i":401,"p":399,"n":"HeadlineItemViewModel","y":13,"l":"AAGsdJh","h":0,"v":"news","c":"newscrime","o":2}'>
#  <a href="/en-us/news/crime/day-care-worker-allegedly-twisted-babys-leg-till-it-broke-cops/ar-AAGsdJh?li=BBnbcA1">
#  <img alt="Kimberly Boykin, 51, is charged with felony negligent child abuse resulting in s..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGs08v.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=629&amp;y=370"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Day Care Worker Allegedly Twisted Baby's Leg Til It Broke: Cops - Provided by CBS Interactive Inc."/> <div>
#  <h3 aria-label="day care worker allegedly twisted baby's leg till it broke: police-article">Day care worker allegedly twisted baby's leg till it broke: police</h3>
#  <img alt="Inside Edition Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAsw4BQ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Inside Edition</span>
#  </div>
#  </a>
#  </li>
#  <li class="media photo" data-id="402" data-m='{"i":402,"p":399,"n":"HeadlineItemViewModel","y":13,"l":"AABGTFJ","h":0,"v":"news","c":"newsopinion","o":3}'>
#  <a href="/en-us/news/opinion/the-news-in-cartoons/ss-AABGTFJ?li=BBnbcA1">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsgrv.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1470&amp;y=580"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The News In Cartoons - Walt Handelsman/The Times-Picayune The Advocate"/> <div>
#  <h3 aria-label="the news in cartoons-slideshow">The News In Cartoons</h3>
#  <img alt="Photos Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBz3ebk.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Photos</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="secondary" data-aop="secondary" data-id="403" data-m='{"i":403,"p":392,"n":"secondary","y":8,"o":4}'>
#  <li data-id="404" data-m='{"i":404,"p":403,"n":"HeadlineItemViewModel","y":13,"l":"AAGqY8G","h":0,"v":"news","c":"newsgoodnews","o":1}'>
#  <a href="/en-us/news/good-news/little-rock-girl-spends-13th-birthday-donating-to-cancer-center/ar-AAGqY8G?li=BBnbcA1">
#  <img alt="Little Rock girl spends 13th birthday donating to cancer center" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGr1hb.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Little Rock girl spends 13th birthday donating to hospital where her mom became ... - Provided by TEGNA Inc."/> <div>
#  <h3 aria-label="ark. girl spends 13th birthday donating to cancer center-article">Ark. girl spends 13th birthday donating to cancer center</h3>
#  <img alt="KTHV-TV Little Rock Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAA1hnI.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>KTHV-TV Little Rock</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="paging"></div>
#  </div>
#  <button class="rightarrow" data-id="405" data-m='{"i":405,"p":369,"n":"rightarrow","y":12,"o":4}' tabindex="-1" title="next"></button>
#  </div>
#  </div>,
#  <div aria-label="from our partners" class="stripecontainer" data-section-id="sponsored.stripe.shopping" role="region">
#  <div class="news stripeouter" data-aop="sponsored.stripe.shopping_stripe" data-id="406" data-m='{"i":406,"p":25,"n":"sponsored.stripe.shopping","t":"stripe","o":7}'>
#  <button class="leftarrow" data-id="407" data-m='{"i":407,"p":406,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
#  <div class="stripe full-width">
#  <div class="stripenav" data-aop="stripe.sponsored.navigation_stripenavigation" data-id="408" data-m='{"i":408,"p":406,"n":"stripe.sponsored.Navigation","t":"stripeNavigation","o":2}'>
#  <ul>
#  <li data-id="409" data-m='{"i":409,"p":408,"n":"From Our Partners","y":4,"o":1}'>
#  <span class="adslabel" title="Ad">Ad</span>
#  <h2>From Our Partners</h2>
#  </li>
#  <li class="hide12" data-id="411" data-m='{"i":411,"p":408,"n":"listlink","y":4,"l":"STREAMING GUIDE","o":3}'><a href="/en-us/entertainment/rf-watch-online/tv-shows,movies/filter/locale-us?except_studio=bollywood">STREAMING GUIDE</a></li>
#  <li class="hide12" data-id="412" data-m='{"i":412,"p":408,"n":"listlink","y":4,"l":"BUYING GUIDES","o":4}'><a href="/en-us/lifestyle/rf-buying-guides">BUYING GUIDES</a></li>
#  <li class="hide12" data-id="413" data-m='{"i":413,"p":408,"n":"listlink","y":4,"l":"HOTELS GUIDE","o":5}'><a href="/en-us/lifestyle/rf-buying-guides/hotels/">HOTELS GUIDE</a></li>
#  </ul>
#  <div class="stripemenu" role="menu">
#  <button class="edit" data-id="414" data-m='{"i":414,"p":408,"n":"personalization","t":"dropdown","o":6}'>Edit</button>
#  <button class="remove" data-id="415" data-m='{"i":415,"p":408,"n":"remove","t":"dropdownitem","o":7}' role="menuitem">Remove Section</button>
#  <button class="up" data-id="416" data-m='{"i":416,"p":408,"n":"moveup","t":"dropdownitem","o":8}' role="menuitem">Move Section Up</button>
#  <button class="down" data-id="417" data-m='{"i":417,"p":408,"n":"movedown","t":"dropdownitem","o":9}' role="menuitem">Move Section Down</button>
#  <button class="add" data-id="418" data-m='{"i":418,"p":408,"n":"addbelow","t":"dropdownitem","o":10}' role="menuitem">Add Section Below</button>
#  </div>
#  </div>
#  <div class="paging-container">
#  <div class="stripecontent normaldensity" data-aop="hero1" data-id="419" data-m='{"i":419,"p":406,"n":"stripe.sponsored.hero1","t":"headlines","o":3}' data-module-id="startpage|sponsored.stripe.shopping|stripe|stripe.sponsored.hero1|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="420" data-m='{"i":420,"p":419,"n":"secondary","y":8,"o":1}'>
#  <li data-id="421" data-m='{"i":421,"p":420,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}'>
#  <a class="nativead" data-pg="1" data-pid="7HD66FC" href="https://308track.com/click.track?CID=428512&amp;AFID=421585&amp;ADID=2313561&amp;src=perform&amp;iris=1335682&amp;SID=MSNStripe8-28" target="_blank">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpIOb.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=206&amp;y=54"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="HerjinTank-stripe"/> <div>
#  <h3 aria-label="shark investing: $50 can lead to generational wealth-article">Shark Investing: $50 can lead to Generational Wealth</h3>
#  <span>Angels &amp; Entrepreneurs</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <style>
#  </style>
#  <div class="ec-module section-layout" data-height="271px">
#  <img alt="Loading..." src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/64/a8a064.gif"/>
#  <p data-loadtimeout="10000">Couldn't load this module, please refresh the page to see the contents.</p>
#  <iframe data-id="422" data-m='{"i":422,"p":406,"n":"externalcontent","t":"https://hvtd.s3.amazonaws.com/msn-726dcm.html","o":4}' data-url="https://hvtd.s3.amazonaws.com/msn-726dcm.html" scrolling="no" src=""></iframe>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="hero3" data-id="423" data-m='{"i":423,"p":406,"n":"stripe.sponsored.hero3","t":"headlines","o":5}' data-module-id="startpage|sponsored.stripe.shopping|stripe|stripe.sponsored.hero3|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="424" data-m='{"i":424,"p":423,"n":"secondary","y":8,"o":1}'>
#  <li data-id="425" data-m='{"i":425,"p":424,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}'>
#  <a class="nativead" data-pg="1" data-pid="7HD66FC" href="https://www.fool.com/the-ascent/credit-cards/landing/discover-it-cash-back-review/?utm_site=theascent&amp;utm_campaign=ta-cc-co-msn-discb--5-na-discbrev&amp;utm_medium=cpc&amp;utm_source=msn" target="_blank">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAAMsQf.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=309&amp;y=188"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="businessmansuit"/> <div>
#  <h3 aria-label="transferring debt to a 0% apr card is absolutely brilliant-article">Transferring Debt to a 0% APR Card is Absolutely Brilliant</h3>
#  <span>The Ascent</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="hero4" data-id="426" data-m='{"i":426,"p":406,"n":"stripe.sponsored.hero4","t":"headlines","o":6}' data-module-id="startpage|sponsored.stripe.shopping|stripe|stripe.sponsored.hero4|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="427" data-m='{"i":427,"p":426,"n":"secondary","y":8,"o":1}'>
#  <li data-id="428" data-m='{"i":428,"p":427,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}'>
#  <a class="nativead" data-pg="1" data-pid="7HD66FC" href="https://www.topixoffbeat.com/quiz/18464?cvar=tm2%3Ai-6r5-ELQ39VJI7UO6FKB0&amp;tpx_term=NPPAEM90O2S1THOK&amp;utm_campaign=18464&amp;utm_source=msn" target="_blank">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpSwm.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Arthur topix"/> <div>
#  <h3 aria-label="most adults can't pass this basic 3rd grade test-article">Most Adults Can't Pass This Basic 3rd Grade Test</h3>
#  <span>Topix</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="paging"></div>
#  </div>
#  <button class="rightarrow" data-id="429" data-m='{"i":429,"p":406,"n":"rightarrow","y":12,"o":7}' tabindex="-1" title="next"></button>
#  </div>
#  </div>,
#  <div aria-label="entertainment" class="stripecontainer" data-positions=".entertainment .stripecontent .tertiary:nth-of-type(2) li:nth-child(3)" data-section-id="stripe.entertainment" role="region">
#  <div class="entertainment stripeouter" data-aop="stripe.entertainment_stripe" data-id="430" data-m='{"i":430,"p":25,"n":"stripe.entertainment","t":"stripe","o":8}'>
#  <button class="leftarrow" data-id="431" data-m='{"i":431,"p":430,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
#  <div class="stripe full-width">
#  <div class="stripenav" data-aop="stripe.entertainment.navigation_stripenavigation" data-id="432" data-m='{"i":432,"p":430,"n":"stripe.entertainment.navigation","t":"stripeNavigation","o":2}'>
#  <ul>
#  <li data-id="433" data-m='{"i":433,"p":432,"n":"entertainment","y":4,"o":1}'>
#  <h2><a data-id="434" data-m='{"i":434,"p":432,"n":"entertainment","y":4,"o":2}' href="/en-us/entertainment">Entertainment</a></h2>
#  </li>
#  <li class="hide12" data-id="435" data-m='{"i":435,"p":432,"n":"entertainment-celebrity","y":4,"o":3}'><a href="/en-us/entertainment/celebrity">CELEBRITY</a></li>
#  <li class="hide12" data-id="436" data-m='{"i":436,"p":432,"n":"tv","y":4,"o":4}'><a href="/en-us/tv">TV</a></li>
#  <li class="hide12" data-id="437" data-m='{"i":437,"p":432,"n":"movies","y":4,"o":5}'><a href="/en-us/movies">MOVIES</a></li>
#  <li class="hide12" data-id="438" data-m='{"i":438,"p":432,"n":"music","y":4,"o":6}'><a href="/en-us/music">MUSIC</a></li>
#  <li class="hide12" data-id="439" data-m='{"i":439,"p":432,"n":"Books","y":4,"o":7}'><a href="/en-us/entertainment/books">BOOKS</a></li>
#  <li class="hide123" data-id="440" data-m='{"i":440,"p":432,"n":"Online Games","y":4,"o":8}'><a href="http://zone.msn.com/">ONLINE GAMES</a></li>
#  <li class="hide123" data-id="441" data-m='{"i":441,"p":432,"n":"news","y":4,"o":9}'><a href="/en-us/entertainment/news">NEWS</a></li>
#  <li class="hide123" data-id="442" data-m='{"i":442,"p":432,"n":"Humor","y":4,"o":10}'><a href="/en-us/entertainment/humor">HUMOR</a></li>
#  <li class="hide123" data-id="443" data-m='{"i":443,"p":432,"n":"gaming","y":4,"o":11}'><a href="/en-us/entertainment/gaming">GAMING</a></li>
#  <li class="hide123" data-id="444" data-m='{"i":444,"p":432,"n":"video","y":4,"o":12}'><a href="/en-us/entertainment/video">VIDEO</a></li>
#  <li class="hide123" data-id="445" data-m='{"i":445,"p":432,"n":"Showtimes","y":4,"o":13}'><a href="https://www.bing.com/search?q=movie+showtimes&amp;FORM=MSN148">SHOWTIMES</a></li>
#  <li class="hide123" data-id="446" data-m='{"i":446,"p":432,"n":"Emmy Awards","y":4,"o":14}'><a href="/en-us/tv/emmys">EMMY AWARDS</a></li>
#  </ul>
#  <div class="stripemenu" role="menu">
#  <button class="edit" data-id="447" data-m='{"i":447,"p":432,"n":"personalization","t":"dropdown","o":15}'>Edit</button>
#  <button class="remove" data-id="448" data-m='{"i":448,"p":432,"n":"remove","t":"dropdownitem","o":16}' role="menuitem">Remove Section</button>
#  <button class="up" data-id="449" data-m='{"i":449,"p":432,"n":"moveup","t":"dropdownitem","o":17}' role="menuitem">Move Section Up</button>
#  <button class="down" data-id="450" data-m='{"i":450,"p":432,"n":"movedown","t":"dropdownitem","o":18}' role="menuitem">Move Section Down</button>
#  <button class="add" data-id="451" data-m='{"i":451,"p":432,"n":"addbelow","t":"dropdownitem","o":19}' role="menuitem">Add Section Below</button>
#  </div>
#  </div>
#  <div class="paging-container">
#  <div class="stripecontent normaldensity" data-aop="hero" data-id="452" data-m='{"i":452,"p":430,"n":"stripe.entertainment.hero","t":"headlines","o":3}' data-module-id="startpage|stripe.entertainment|stripe|stripe.entertainment.hero|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="453" data-m='{"i":453,"p":452,"n":"secondary","y":8,"o":1}'>
#  <li class="media photo" data-id="454" data-m='{"i":454,"p":453,"n":"HeadlineItemViewModel","y":13,"l":"AAGsOLe","h":0,"v":"entertainment","c":"celebrity","o":1}'>
#  <a href="/en-us/entertainment/celebrity/taylor-swift-thought-john-travoltas-vma-gaffe-was-hilarious-plus-more-news/ss-AAGsOLe?li=BBnb2gh">
#  <img alt='Viewers across the country were mortified when &lt;a href="https://www.wonderwal...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsOQp.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1247&amp;y=450"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="2019 MTV Video Music Awards - Show - Matt Sayles/Invision/AP"/> <div>
#  <h3 aria-label="taylor swift's reaction to john travolta's vma gaffe, plus more news-slideshow">Taylor Swift's reaction to John Travolta's VMA gaffe, plus more news</h3>
#  <img alt="Wonderwall Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAfZ6og.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Wonderwall</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="top stories" data-id="455" data-m='{"i":455,"p":430,"n":"stripe.entertainment.topStories","t":"headlines","o":4}' data-module-id="startpage|stripe.entertainment|stripe|stripe.entertainment.topStories|headlines">
#  <ul class="tertiary" data-aop="tertiary" data-id="456" data-m='{"i":456,"p":455,"n":"tertiary","y":8,"o":1}'>
#  <li class="media photo" data-id="457" data-m='{"i":457,"p":456,"n":"HeadlineItemViewModel","y":13,"l":"AAGbHA6","h":0,"v":"movies","c":"movies-celebrity","o":1}'>
#  <a href="/en-us/movies/celebrity/the-biggest-female-icon-every-year-since-you-were-born/ss-AAGbHA6?li=BBnb2gh">
#  <img alt='People become idols for an array of different reasons: They star in &lt;a href="...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGbvoG.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=541&amp;y=288"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The Biggest Female Icon Every Year Since You Were Born - Provided by Best Life"/> <div>
#  <h3 aria-label="the biggest female icon every year since you were born-slideshow">The biggest female icon every year since you were born</h3>
#  <img alt="Best Life Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAxspu1.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Best Life</span>
#  </div>
#  </a>
#  </li>
#  <li class="media photo" data-id="458" data-m='{"i":458,"p":456,"n":"HeadlineItemViewModel","y":13,"l":"AAG7Br8","h":0,"v":"movies","c":"movies-gallery","o":2}'>
#  <a href="/en-us/movies/gallery/70plus-new-movies-and-tv-shows-you-need-to-watch-on-netflix-in-september/ss-AAG7Br8?li=BBnb2gh">
#  <img alt="Netflix blesses us with a whole bunch of new movies and TV shows to zone out ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG7N2W.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1091&amp;y=669"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="70+ New Movies and TV Shows You Need to Watch on Netflix in September - Netflix / Courtesy of NETFLIX"/> <div>
#  <h3 aria-label="new movies and tv shows you need to watch on netflix in september-slideshow">New movies and TV shows you need to watch on Netflix in September</h3>
#  <img alt="PopSugar Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAgnIPB.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>PopSugar</span>
#  </div>
#  </a>
#  </li>
#  <li class="media photo" data-id="459" data-m='{"i":459,"p":456,"n":"HeadlineItemViewModel","y":13,"l":"AAGskYK","h":0,"v":"tv","c":"tv-celebrity","o":3}'>
#  <a href="/en-us/tv/celebrity/tori-spelling-and-dean-mcdermott-get-hot-and-heavy-in-hawaii/ss-AAGskYK?li=BBnb2gh">
#  <img alt='More in love than ever! &lt;a href="https://www.usmagazine.com/celebrities/tori-spe...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGskYf.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=432&amp;y=407"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="More in love than ever! Tori Spelling and Dean McDermott packed on PDA in Hawaii... - Sophie Fritz/startraksphoto.com"/> <div>
#  <h3 aria-label="tori spelling and dean mcdermott pucker up in hawaii: pics-slideshow">Tori Spelling and Dean McDermott pucker up in Hawaii: pics</h3>
#  <img alt="US Weekly Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBCleeG.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>US Weekly</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="tertiary" data-aop="tertiary" data-id="460" data-m='{"i":460,"p":455,"n":"tertiary","y":8,"o":2}'>
#  <li data-id="461" data-m='{"i":461,"p":460,"n":"HeadlineItemViewModel","y":13,"l":"AAGsjJq","h":0,"v":"movies","c":"movies-celebrity","o":1}'>
#  <a href="/en-us/movies/celebrity/dakota-johnson-shares-the-look-of-love-with-chris-martin-as-the-on-again-couple-enjoy-a-romantic-night-out-in-new-york-city/ar-AAGsjJq?li=BBnb2gh">
#  <img alt="Happiness: Dakota Johnson seemed to share the look of love once again with ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGssNB.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=347&amp;y=188"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Happiness: Dakota Johnson seemed to share the look of love once again with Chris... - Provided by Associated Newspapers Limited"/> <div>
#  <h3 aria-label="dakota johnson shares look of love with chris martin in nyc: pics-article">Dakota Johnson shares look of love with Chris Martin in NYC: pics</h3>
#  <img alt="Daily Mail Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAvcS6D.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Daily Mail</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="462" data-m='{"i":462,"p":460,"n":"HeadlineItemViewModel","y":13,"l":"AAGsikF","h":0,"v":"tv","c":"tv-celebrity","o":2}'>
#  <a href="/en-us/tv/celebrity/hilary-duff-is-back-to-her-pre-baby-weight-see-her-fit-body/ar-AAGsikF?li=BBnb2gh">
#  <img alt="Hilary Duff attends the InStyle and Warner Bros. Golden Globes afterparty in Bev..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsvWG.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1455&amp;y=1017"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Hilary Duff attends the InStyle and Warner Bros. Golden Globes afterparty in Bev... - imageSPACE/REX/Shutterstock"/> <div>
#  <h3 aria-label="hilary duff celebrates hitting her pre-baby weight with new pic-article">Hilary Duff celebrates hitting her pre-baby weight with new pic</h3>
#  <img alt="Wonderwall Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAfZ6og.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Wonderwall</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="463" data-m='{"i":463,"p":460,"n":"HeadlineItemViewModel","y":13,"l":"AAGszUE","h":0,"v":"tv","c":"tv-celebrity","o":3}'>
#  <a href="/en-us/tv/celebrity/martha-stewart-details-her-worst-online-dating-experiences-after-trying-matchcom-including-an-awful-dinner-with-a-stingy-tipper-as-she-admits-she-is-looking-for-a-man-with-his-own-plane/ar-AAGszUE?li=BBnb2gh">
#  <img alt="Guru: Lifestyle entrepreneur Martha Stewart, 78, hasn't had any luck on Match.co..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsEXK.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=310&amp;y=231"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Guru: Lifestyle entrepreneur Martha Stewart, 78, hasn't had any luck on Match.co... - Provided by Associated Newspapers Limited"/> <div>
#  <h3 aria-label="martha stewart shares her worst online dating experiences-article">Martha Stewart shares her worst online dating experiences</h3>
#  <img alt="Daily Mail Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAvcS6D.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Daily Mail</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  <ul class="secondary" data-aop="secondary" data-id="464" data-m='{"i":464,"p":455,"n":"secondary","y":8,"o":3}'>
#  <li data-id="465" data-m='{"i":465,"p":464,"n":"HeadlineItemViewModel","y":13,"l":"AAGpYdh","h":0,"v":"movies","c":"movies-celebrity","o":1}'>
#  <a href="/en-us/movies/celebrity/katie-holmes-spends-quality-time-with-suri-cruise-after-jamie-foxx-split/ar-AAGpYdh?li=BBnb2gh">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpVZs.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1074&amp;y=1073"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Katie Holmes Spends Quality Time With Suri Cruise After Jamie Foxx Split - Provided by USA Today Sports Media Group LLC"/> <div>
#  <h3 aria-label="katie holmes spends quality time with suri after split-article">Katie Holmes spends quality time with Suri after split</h3>
#  <img alt="The Blast Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAAmbH8.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>The Blast</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="paging"></div>
#  </div>
#  <button class="rightarrow" data-id="466" data-m='{"i":466,"p":430,"n":"rightarrow","y":12,"o":5}' tabindex="-1" title="next"></button>
#  </div>
#  </div>,
#  <div aria-label="sports" class="stripecontainer" data-positions=".sports .stripecontent .tertiary:nth-of-type(2) li:nth-child(3)" data-section-id="stripe.sports" role="region">
#  <div class="sports stripeouter" data-aop="stripe.sports_stripe" data-id="467" data-m='{"i":467,"p":25,"n":"stripe.sports","t":"stripe","o":9}'>
#  <button class="leftarrow" data-id="468" data-m='{"i":468,"p":467,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
#  <div class="stripe full-width">
# ...
#  <div class="stripecontent normaldensity" data-aop="top videos2" data-id="765" data-m='{"i":765,"p":746,"n":"stripe.video.topstories2","t":"headlines","o":4}' data-module-id="startpage|stripe.video|stripe|stripe.video.topstories2|headlines">
#  <ul class="tertiary" data-aop="tertiary" data-id="766" data-m='{"i":766,"p":765,"n":"tertiary","y":8,"o":1}'>
#  <li class="media video" data-id="767" data-m='{"i":767,"p":766,"n":"HeadlineItemViewModel","y":13,"l":"AAGpmrq","h":1,"v":"video","c":"popculture","o":1}'>
#  <a href="/en-us/video/popculture/danish-city-embraces-historic-roots-by-replacing-traffic-lights-with-images-of-vikings/vi-AAGpmrq">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsgKj.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=342&amp;y=275"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Danish city replaces traffic lights with Viking images"/> <div>
#  <h3 aria-label="danish city replaces traffic lights with viking images-video">Danish city replaces traffic lights with Viking images</h3>
#  <img alt="Veuer Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BByCPYg.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Veuer</span>
#  </div>
#  </a>
#  </li>
#  <li class="media video" data-id="768" data-m='{"i":768,"p":766,"n":"HeadlineItemViewModel","y":13,"l":"AAGslfR","h":0,"v":"video","c":"popculture","o":2}'>
#  <a href="/en-us/video/popculture/this-3-year-old-runs-her-own-booming-lemonade-business/vi-AAGslfR">
#  <img alt="This 3-year-old runs her own booming lemonade business" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGstbO.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="This 3-year-old runs her own booming lemonade business"/> <div>
#  <h3 aria-label="this 3-year-old runs her own booming lemonade business-video">This 3-year-old runs her own booming lemonade business</h3>
#  <img alt="Inside Edition Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAsvT3F.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Inside Edition</span>
#  </div>
#  </a>
#  </li>
#  <li class="media video" data-id="769" data-m='{"i":769,"p":766,"n":"HeadlineItemViewModel","y":13,"l":"AAGrXtS","h":0,"v":"video","c":"viral","o":3}'>
#  <a href="/en-us/video/viral/veteran-carries-marine-amputee-up-mountain/vi-AAGrXtS">
#  <img alt="Veteran carries Marine amputee on his back 14 miles up mountain" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsA0C.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Veteran carries Marine amputee on his back 14 miles up mountain"/> <div>
#  <h3 aria-label="veteran carries marine amputee on his back 14 miles up mountain-video">Veteran carries Marine amputee on his back 14 miles up mountain</h3>
#  <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>CNN</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="top videos3" data-id="770" data-m='{"i":770,"p":746,"n":"stripe.video.topstories3","t":"headlines","o":5}' data-module-id="startpage|stripe.video|stripe|stripe.video.topstories3|headlines">
#  <ul class="tertiary" data-aop="tertiary" data-id="771" data-m='{"i":771,"p":770,"n":"tertiary","y":8,"o":1}'>
#  <li class="media video" data-id="772" data-m='{"i":772,"p":771,"n":"HeadlineItemViewModel","y":13,"l":"AAGp330","h":0,"v":"video","c":"animals","o":1}'>
#  <a href="/en-us/video/animals/beluga-whale-in-aquarium-splashes-man-with-water-and-laughed-about-it/vi-AAGp330">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGrqQJ.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=490&amp;y=291"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Beluga whale in aquarium splashes man with water and laughed about it"/> <div>
#  <h3 aria-label="beluga whale in aquarium splashes man with water and laughs about it-video">Beluga whale in aquarium splashes man with water and laughs about it</h3>
#  <img alt="JukinMedia Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAqsfdG.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>JukinMedia</span>
#  </div>
#  </a>
#  </li>
#  <li class="media video" data-id="773" data-m='{"i":773,"p":771,"n":"HeadlineItemViewModel","y":13,"l":"AAGsLJt","h":0,"v":"video","c":"viral","o":2}'>
#  <a href="/en-us/video/viral/heroic-man-manages-to-stop-driverless-car-from-rolling-down-road-in-china/vi-AAGsLJt">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGste2.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Heroic man manages to stop driverless car from rolling down road in China - Provided by Newsflare Limited"/> <div>
#  <h3 aria-label="heroic pair manages to stop driverless car from rolling down road-video">Heroic pair manages to stop driverless car from rolling down road</h3>
#  <img alt="Newsflare Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BByydI8.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Newsflare</span>
#  </div>
#  </a>
#  </li>
#  <li class="media video" data-id="774" data-m='{"i":774,"p":771,"n":"HeadlineItemViewModel","y":13,"l":"AAGs1vl","h":0,"v":"video","c":"viral","o":3}'>
#  <a href="/en-us/video/viral/rhino-charges-and-flips-zoo-car-in-alarming-video/vi-AAGs1vl">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGrYU3.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Rhino charges and flips zoo car in alarming video - Provided by NBCU News Group, a division of NBCUniversal Media LLC"/> <div>
#  <h3 aria-label="furious rhino charges and flips zoo car in alarming video-video">Furious rhino charges and flips zoo car in alarming video</h3>
#  <img alt="TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBph6Sm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>TODAY</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="top videos4" data-id="775" data-m='{"i":775,"p":746,"n":"stripe.video.topstories4","t":"headlines","o":6}' data-module-id="startpage|stripe.video|stripe|stripe.video.topstories4|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="776" data-m='{"i":776,"p":775,"n":"secondary","y":8,"o":1}'>
#  <li class="media video" data-id="777" data-m='{"i":777,"p":776,"n":"HeadlineItemViewModel","y":13,"l":"AAGsm8s","h":1,"v":"video","c":"animals","o":1}'>
#  <a href="/en-us/video/animals/labrador-is-super-determined-to-wake-up-his-owner/vi-AAGsm8s">
#  <img alt="Dog" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGrATf.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=252&amp;y=448"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Dog - Microsoft Ice photograb"/> <div>
#  <h3 aria-label="labrador is super determined to wake up his owner-video">Labrador is super determined to wake up his owner</h3>
#  <img alt="Rumble Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4BKPz.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Rumble</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="paging"></div>
#  </div>
#  <button class="rightarrow" data-id="778" data-m='{"i":778,"p":746,"n":"rightarrow","y":12,"o":7}' tabindex="-1" title="next"></button>
#  </div>
#  </div>,
#  <div aria-label="promotions" class="stripecontainer" data-section-id="stripe.msstore" role="region">
#  <div class="finance stripeouter" data-aop="stripe.msstore_stripe" data-id="779" data-m='{"i":779,"p":25,"n":"stripe.msstore","t":"stripe","o":19}'>
#  <button class="leftarrow" data-id="780" data-m='{"i":780,"p":779,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
#  <div class="stripe full-width">
#  <div class="stripenav" data-aop="stripe.store.navigation_stripenavigation" data-id="781" data-m='{"i":781,"p":779,"n":"stripe.store.navigation","t":"stripeNavigation","o":2}'>
#  <ul>
#  <li data-id="782" data-m='{"i":782,"p":781,"n":"Promotions","y":4,"o":1}'>
#  <span class="adslabel" title="Ad">Ad</span>
#  <h2><a data-id="783" data-m='{"i":783,"p":781,"n":"Promotions","y":4,"o":2}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_STORES_TITLE&amp;u=https://www.microsoft.com/en-us/store/b/home">Promotions</a></h2>
#  </li>
#  <li class="hide12" data-id="784" data-m='{"i":784,"p":781,"n":"listlink","y":4,"l":"OFFICE 365","o":3}'><a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_STORES_SUBNAV_OFFICE365&amp;u=https://www.microsoft.com/en-us/store/b/office">OFFICE 365</a></li>
#  <li class="hide12" data-id="785" data-m='{"i":785,"p":781,"n":"listlink","y":4,"l":"SURFACE DEALS","o":4}'><a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_STORES_SUBNAV_SURFACEDEALS&amp;u=https://www.microsoft.com/en-us/store/collections/microsoftsurfacedeals/pc">SURFACE DEALS</a></li>
#  <li class="hide12" data-id="786" data-m='{"i":786,"p":781,"n":"listlink","y":4,"l":"PC DEALS","o":5}'><a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_STORES_SUBNAV_PC_DEALS&amp;u=https://www.microsoft.com/en-us/store/b/pc">PC DEALS</a></li>
#  <li class="hide12" data-id="787" data-m='{"i":787,"p":781,"n":"listlink","y":4,"l":"XBOX DEALS","o":6}'><a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_STORES_SUBNAV_XBOX_DEALS&amp;u=https://www.microsoft.com/en-us/store/b/xbox">XBOX DEALS</a></li>
#  <li class="hide12" data-id="788" data-m='{"i":788,"p":781,"n":"listlink","y":4,"l":"WINDOWS 10","o":7}'><a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_STORES_SUBNAV_WINDOWS&amp;u=https://www.microsoft.com/en-us/store/b/windows">WINDOWS 10</a></li>
#  </ul>
#  <div class="stripemenu" role="menu">
#  <button class="edit" data-id="789" data-m='{"i":789,"p":781,"n":"personalization","t":"dropdown","o":8}'>Edit</button>
#  <button class="remove" data-id="790" data-m='{"i":790,"p":781,"n":"remove","t":"dropdownitem","o":9}' role="menuitem">Remove Section</button>
#  <button class="up" data-id="791" data-m='{"i":791,"p":781,"n":"moveup","t":"dropdownitem","o":10}' role="menuitem">Move Section Up</button>
#  <button class="down" data-id="792" data-m='{"i":792,"p":781,"n":"movedown","t":"dropdownitem","o":11}' role="menuitem">Move Section Down</button>
#  <button class="add" data-id="793" data-m='{"i":793,"p":781,"n":"addbelow","t":"dropdownitem","o":12}' role="menuitem">Add Section Below</button>
#  </div>
#  </div>
#  <div class="paging-container">
#  <style>
#  </style>
#  <div class="ec-module section-layout" data-height="271px">
#  <img alt="Loading..." src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/64/a8a064.gif"/>
#  <p data-loadtimeout="5000">Couldn't load this module, please refresh the page to see the contents.</p>
#  <iframe data-id="794" data-m='{"i":794,"p":779,"n":"externalcontent","t":"https://contextual.media.net/medianet.php?cid=8CUNL3XVM\u0026crid=115967264\u0026size=306x271\u0026https=1","o":3}' data-url="https://contextual.media.net/medianet.php?cid=8CUNL3XVM&amp;crid=115967264&amp;size=306x271&amp;https=1" scrolling="no" src=""></iframe>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="hero1" data-id="795" data-m='{"i":795,"p":779,"n":"shopping.editorspicks.hero1","t":"headlines","o":4}' data-module-id="startpage|stripe.msstore|stripe|shopping.editorspicks.hero1|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="796" data-m='{"i":796,"p":795,"n":"secondary","y":8,"o":1}'>
#  <li data-id="797" data-m='{"i":797,"p":796,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}'>
#  <a class="nativead" data-pg="TSTPRMUS32" data-pid="7HD66FC" href="https://www.msn.com/en-us/money/personalfinance/savingsrates?csource=msn&amp;esourceid=6331386&amp;ctype=ratetablepromo&amp;cchannel=content&amp;cmethod=msnmoneyDA&amp;cproduct=savingsandcds&amp;ccreative=canyouincrease22x_dollarenvelope" target="_blank">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBSC789.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="dollarenvelope"/> <div>
#  <h3 aria-label="can you increase your savings by 23x?-article">Can You Increase Your Savings By 23x?</h3>
#  <span>MSN Money</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <style>
#  </style>
#  <div class="ec-module section-layout" data-height="271px">
#  <img alt="Loading..." src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/64/a8a064.gif"/>
#  <p data-loadtimeout="5000">Couldn't load this module, please refresh the page to see the contents.</p>
#  <iframe data-id="798" data-m='{"i":798,"p":779,"n":"externalcontent","t":"https://contextual.media.net/medianet.php?cid=8CUNL3XVM\u0026crid=226006788\u0026size=306x271\u0026https=1","o":5}' data-url="https://contextual.media.net/medianet.php?cid=8CUNL3XVM&amp;crid=226006788&amp;size=306x271&amp;https=1" scrolling="no" src=""></iframe>
#  </div>
#  <div class="stripecontent normaldensity" data-aop="hero2" data-id="799" data-m='{"i":799,"p":779,"n":"shopping.editorspicks.hero2","t":"headlines","o":6}' data-module-id="startpage|stripe.msstore|stripe|shopping.editorspicks.hero2|headlines">
#  <ul class="secondary" data-aop="secondary" data-id="800" data-m='{"i":800,"p":799,"n":"secondary","y":8,"o":1}'>
#  <li data-id="801" data-m='{"i":801,"p":800,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}'>
#  <a class="nativead" data-pg="TSTPRMUS32" data-pid="7HD66FC" href="https://www.fool.com/mms/mark/all-in-advert?utm_source=msn&amp;utm_medium=contentmarketing&amp;utm_campaign=sar-allinalert&amp;paid=9223&amp;waid=9223&amp;psource=esamhpwdg0210056&amp;wsource=esamhpwdg0210056" target="_blank">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBSCqXU.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=419&amp;y=183"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="lacey"/> <div>
#  <h3 aria-label="motley fool issues rare “all in” buy alert-article">Motley Fool Issues Rare “All In” Buy Alert</h3>
#  <span>The Motley Fool</span>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="paging"></div>
#  </div>
#  <button class="rightarrow" data-id="802" data-m='{"i":802,"p":779,"n":"rightarrow","y":12,"o":7}' tabindex="-1" title="next"></button>
#  </div>
#  </div>]

# %%
soup.select('.stripecontainer[aria-label]')[9]
# Out:
# <div aria-label="food &amp; drink" class="stripecontainer" data-section-id="stripe.foodanddrink" role="region">
# <div class="fooddrink stripeouter" data-aop="stripe.foodanddrink_stripe" data-id="658" data-m='{"i":658,"p":25,"n":"stripe.foodanddrink","t":"stripe","o":14}'>
# <button class="leftarrow" data-id="659" data-m='{"i":659,"p":658,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
# <div class="stripe full-width">
# <div class="stripenav" data-aop="stripe.foodanddrink.navigation_stripenavigation" data-id="660" data-m='{"i":660,"p":658,"n":"stripe.foodanddrink.navigation","t":"stripeNavigation","o":2}'>
# <ul>
# <li data-id="661" data-m='{"i":661,"p":660,"n":"foodanddrink","y":4,"o":1}'>
# <h2><a data-id="662" data-m='{"i":662,"p":660,"n":"foodanddrink","y":4,"o":2}' href="/en-us/foodanddrink">Food &amp; Drink</a></h2>
# </li>
# <li class="hide12" data-id="663" data-m='{"i":663,"p":660,"n":"Food News","y":4,"o":3}'><a href="/en-us/foodanddrink/restaurantsandnews">FOOD NEWS</a></li>
# <li class="hide12" data-id="664" data-m='{"i":664,"p":660,"n":"Restaurants","y":4,"o":4}'><a href="/en-us/foodanddrink/restaurantsandnews/casual">RESTAURANTS</a></li>
# <li class="hide12" data-id="665" data-m='{"i":665,"p":660,"n":"Recipes","y":4,"o":5}'><a href="/en-us/foodanddrink/cooking/recipes">RECIPES</a></li>
# <li class="hide12" data-id="666" data-m='{"i":666,"p":660,"n":"Quick \u0026 Easy","y":4,"o":6}'><a href="/en-us/foodanddrink/cooking/quickandeasy">QUICK &amp; EASY</a></li>
# <li class="hide12" data-id="667" data-m='{"i":667,"p":660,"n":"Tips \u0026 Tricks","y":4,"o":7}'><a href="/en-us/foodanddrink/cooking/tipsandtricks">TIPS &amp; TRICKS</a></li>
# <li class="hide123" data-id="668" data-m='{"i":668,"p":660,"n":"Drinks","y":4,"o":8}'><a href="/en-us/foodanddrink/beverages">DRINKS</a></li>
# <li class="hide123" data-id="669" data-m='{"i":669,"p":660,"n":"videos","y":4,"o":9}'><a href="/en-us/foodanddrink/video">VIDEO</a></li>
# </ul>
# <div class="stripemenu" role="menu">
# <button class="edit" data-id="670" data-m='{"i":670,"p":660,"n":"personalization","t":"dropdown","o":10}'>Edit</button>
# <button class="remove" data-id="671" data-m='{"i":671,"p":660,"n":"remove","t":"dropdownitem","o":11}' role="menuitem">Remove Section</button>
# <button class="up" data-id="672" data-m='{"i":672,"p":660,"n":"moveup","t":"dropdownitem","o":12}' role="menuitem">Move Section Up</button>
# <button class="down" data-id="673" data-m='{"i":673,"p":660,"n":"movedown","t":"dropdownitem","o":13}' role="menuitem">Move Section Down</button>
# <button class="add" data-id="674" data-m='{"i":674,"p":660,"n":"addbelow","t":"dropdownitem","o":14}' role="menuitem">Add Section Below</button>
# </div>
# </div>
# <div class="paging-container">
# <div class="stripecontent normaldensity" data-aop="top stories" data-id="675" data-m='{"i":675,"p":658,"n":"stripe.foodanddrink.topstories","t":"headlines","o":3}' data-module-id="startpage|stripe.foodanddrink|stripe|stripe.foodanddrink.topstories|headlines">
# <ul class="secondary" data-aop="secondary" data-id="676" data-m='{"i":676,"p":675,"n":"secondary","y":8,"o":1}'>
# <li class="media photo" data-id="677" data-m='{"i":677,"p":676,"n":"HeadlineItemViewModel","y":13,"l":"AAGsqVR","h":0,"v":"foodanddrink","c":"beverages","o":1}'>
# <a href="/en-us/foodanddrink/beverages/the-best-bourbon-cocktails-are-the-classics/ss-AAGsqVR?li=BBnb7Kw">
# <img alt="There are a handful of whiskey cocktails that sit above the rest. They're uni..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsowx.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="There are a handful of whiskey cocktails that sit above the rest. They're unimpe... - Stocksy"/> <div>
# <h3 aria-label="the best bourbon cocktails are the classics-slideshow">The best bourbon cocktails are the classics</h3>
# <img alt="Esquire Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUd0DM.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Esquire</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="tertiary" data-aop="tertiary" data-id="678" data-m='{"i":678,"p":675,"n":"tertiary","y":8,"o":2}'>
# <li data-id="679" data-m='{"i":679,"p":678,"n":"HeadlineItemViewModel","y":13,"l":"AAGsehl","h":0,"v":"foodanddrink","c":"foodnews","o":1}'>
# <a href="/en-us/foodanddrink/foodnews/i-tasted-kfcs-meatless-fried-chicken-dishes-and-even-though-they-look-like-the-real-thing-they-didnt-taste-like-it/ar-AAGsehl?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGsiUa.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=1822&amp;y=565"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="I tasted KFC's meatless fried 'chicken' dishes and even though they look like th... - Ni'Kesia Pannell"/> <div>
# <h3 aria-label="i tasted kfc's new meatless 'chicken' dishes and had mixed feelings-article">I tasted KFC's new meatless 'chicken' dishes and had mixed feelings</h3>
# <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>INSIDER</span>
# </div>
# </a>
# </li>
# <li class="media photo" data-id="680" data-m='{"i":680,"p":678,"n":"HeadlineItemViewModel","y":13,"l":"AAGmwid","h":0,"v":"foodanddrink","c":"recipes","o":2}'>
# <a href="/en-us/foodanddrink/recipes/light-labor-day-appetizers-from-greek-feta-dip-to-zucchini-nachos/ss-AAGmwid?li=BBnb7Kw">
# <img alt="Summer is sadly ending, so throw a party and make the last of the long days c..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGmBgy.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=875&amp;y=1049"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Summer is sadly ending, so throw a party and make the last of the long days coun... - Ethan Calabrese"/> <div>
# <h3 aria-label="light labor day appetizers, from greek feta dip to zucchini nachos-slideshow">Light Labor Day appetizers, from Greek feta dip to zucchini nachos</h3>
# <img alt="Delish Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAaeOki.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Delish</span>
# </div>
# </a>
# </li>
# <li data-id="681" data-m='{"i":681,"p":678,"n":"HeadlineItemViewModel","y":13,"l":"AAGpyrt","h":0,"v":"foodanddrink","c":"foodnews","o":3}'>
# <a href="/en-us/foodanddrink/foodnews/alton-brown-gave-everything-he-had-for-good-eats-the-return/ar-AAGpyrt?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpCuq.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=963&amp;y=338"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Alton Brown Gave Everything He Had for ‘Good Eats: The Return’ - Food Network"/> <div>
# <h3 aria-label="alton brown gave everything he had for 'good eats: the return'-article">Alton Brown gave everything he had for 'Good Eats: The Return'</h3>
# <img alt="Eater Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA565dd.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Eater</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="tertiary" data-aop="tertiary" data-id="682" data-m='{"i":682,"p":675,"n":"tertiary","y":8,"o":3}'>
# <li class="media photo" data-id="683" data-m='{"i":683,"p":682,"n":"HeadlineItemViewModel","y":13,"l":"AAGq2B6","h":0,"v":"foodanddrink","c":"recipes","o":1}'>
# <a href="/en-us/foodanddrink/recipes/17-dishes-you-just-might-see-at-a-pioneer-woman-potluck/ss-AAGq2B6?li=BBnb7Kw">
# <img alt="Ree Drummond, also known as the Pioneer Woman, is no stranger to big-batch di..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGq0fk.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=362&amp;y=476"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="12744519_10153570917047858_5523440222412947432_n - via Facebook / Ree Drummond - The Pioneer Woman"/> <div>
# <h3 aria-label="17 dishes you just might see at a pioneer woman potluck-slideshow">17 dishes you just might see at a Pioneer Woman potluck</h3>
# <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
# </div>
# </a>
# </li>
# <li data-id="684" data-m='{"i":684,"p":682,"n":"HeadlineItemViewModel","y":13,"l":"AAGp9Oh","h":0,"v":"foodanddrink","c":"recipes","o":2}'>
# <a href="/en-us/foodanddrink/recipes/the-creamy-gorgonzola-pasta-my-moms-been-making-since-the-50s/ar-AAGp9Oh?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGoY1S.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The Creamy Gorgonzola Pasta My Mom’s Been Making Since the ’50s - Provided by Food52"/> <div>
# <h3 aria-label="the creamy pasta my mom's been making since the '50s-article">The creamy pasta my mom's been making since the '50s</h3>
# <img alt="Food52 Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBhDx7y.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Food52</span>
# </div>
# </a>
# </li>
# <li class="media photo" data-id="685" data-m='{"i":685,"p":682,"n":"HeadlineItemViewModel","y":13,"l":"BBONI6E","h":0,"v":"foodanddrink","c":"recipes","o":3}'>
# <a href="/en-us/foodanddrink/recipes/25-recipes-no-one-makes-anymore-%e2%80%93-but-should/ss-BBONI6E?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBONDL9.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=594&amp;y=340"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="It’s not the healthiest thing you can serve for dinner, but a pot pie is cozy an... - istockphoto.com"/> <div>
# <h3 aria-label="no one makes these dishes anymore, but they should-slideshow">No one makes these dishes anymore, but they should</h3>
# <img alt="The Daily Meal Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAA8PBm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>The Daily Meal</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="secondary" data-aop="secondary" data-id="686" data-m='{"i":686,"p":675,"n":"secondary","y":8,"o":4}'>
# <li class="media photo" data-id="687" data-m='{"i":687,"p":686,"n":"HeadlineItemViewModel","y":13,"l":"AADsg1v","h":0,"v":"foodanddrink","c":"restaurantsandnews","o":1}'>
# <a href="/en-us/foodanddrink/restaurantsandnews/18-best-fried-chicken-sandwiches-in-america/ss-AADsg1v?li=BBnb7Kw">
# <img alt='These days, fried chicken has flown to the top of &lt;a href="https://blog.cheap...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADs7uF.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Pecking Order - Fuku/facebook.com"/> <div>
# <h3 aria-label="18 best fried chicken sandwiches in america-slideshow">18 best fried chicken sandwiches in America</h3>
# <img alt="Cheapism Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB90I6E.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Cheapism</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="paging"></div>
# </div>
# <button class="rightarrow" data-id="688" data-m='{"i":688,"p":658,"n":"rightarrow","y":12,"o":4}' tabindex="-1" title="next"></button>
# </div>
# </div>

# %%
item = soup.select('.stripecontainer[aria-label]')[6]

# %%
type(item)
# Out:
# bs4.element.Tag

# %%
item.attrs
# Out:
# {'class': ['stripecontainer'],
#  'role': 'region',
#  'aria-label': 'lifestyle',
#  'data-positions': '.lifestyle .stripecontent .tertiary:nth-of-type(2) li:nth-child(3)',
#  'data-section-id': 'stripe.lifestyle'}

# %%
item['aria-label']
# Out:
# 'lifestyle'

# %%
item.select('ul')[1]
# Out:
# <ul class="secondary" data-aop="secondary" data-id="567" data-m='{"i":567,"p":566,"n":"secondary","y":8,"o":1}'>
# <li data-id="568" data-m='{"i":568,"p":567,"n":"HeadlineItemViewModel","y":13,"l":"AAGmnm4","h":0,"v":"lifestyle","c":"advice","o":1}'>
# <a href="/en-us/lifestyle/advice/i-found-out-my-girlfriend-of-7-years-cheated-on-me-twice-i-want-to-forgive-and-trust-her-again-but-is-that-even-possible/ar-AAGmnm4?li=BBnbcA0">
# <img alt="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpkdj.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ... - KatarzynaBialasiewicz/ iStock"/> <div>
# <h3 aria-label="ask julia: my girlfriend of 7 years cheated on me. can i trust her again?-article">Ask Julia: My girlfriend of 7 years cheated on me. Can I trust her again?</h3>
# <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>INSIDER</span>
# </div>
# </a>
# </li>
# </ul>

# %%
item_block = item.select('ul')[1]

# %%
type(item_block)
# Out:
# bs4.element.Tag

# %%
item.select('ul')[1]
# Out:
# <ul class="secondary" data-aop="secondary" data-id="567" data-m='{"i":567,"p":566,"n":"secondary","y":8,"o":1}'>
# <li data-id="568" data-m='{"i":568,"p":567,"n":"HeadlineItemViewModel","y":13,"l":"AAGmnm4","h":0,"v":"lifestyle","c":"advice","o":1}'>
# <a href="/en-us/lifestyle/advice/i-found-out-my-girlfriend-of-7-years-cheated-on-me-twice-i-want-to-forgive-and-trust-her-again-but-is-that-even-possible/ar-AAGmnm4?li=BBnbcA0">
# <img alt="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpkdj.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ... - KatarzynaBialasiewicz/ iStock"/> <div>
# <h3 aria-label="ask julia: my girlfriend of 7 years cheated on me. can i trust her again?-article">Ask Julia: My girlfriend of 7 years cheated on me. Can I trust her again?</h3>
# <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>INSIDER</span>
# </div>
# </a>
# </li>
# </ul>

# %%
item.select('ul')[1].select('h3[aria-label]')[0]['aria-label']
# Out:
# 'ask julia: my girlfriend of 7 years cheated on me. can i trust her again?-article'

# %%
item.select('ul')[1]
# Out:
# <ul class="secondary" data-aop="secondary" data-id="567" data-m='{"i":567,"p":566,"n":"secondary","y":8,"o":1}'>
# <li data-id="568" data-m='{"i":568,"p":567,"n":"HeadlineItemViewModel","y":13,"l":"AAGmnm4","h":0,"v":"lifestyle","c":"advice","o":1}'>
# <a href="/en-us/lifestyle/advice/i-found-out-my-girlfriend-of-7-years-cheated-on-me-twice-i-want-to-forgive-and-trust-her-again-but-is-that-even-possible/ar-AAGmnm4?li=BBnbcA0">
# <img alt="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpkdj.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ... - KatarzynaBialasiewicz/ iStock"/> <div>
# <h3 aria-label="ask julia: my girlfriend of 7 years cheated on me. can i trust her again?-article">Ask Julia: My girlfriend of 7 years cheated on me. Can I trust her again?</h3>
# <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>INSIDER</span>
# </div>
# </a>
# </li>
# </ul>

# %%
item.select('ul')[1].a['href']
# Out:
# '/en-us/lifestyle/advice/i-found-out-my-girlfriend-of-7-years-cheated-on-me-twice-i-want-to-forgive-and-trust-her-again-but-is-that-even-possible/ar-AAGmnm4?li=BBnbcA0'

# %%
item.select('ul')[1]
# Out:
# <ul class="secondary" data-aop="secondary" data-id="567" data-m='{"i":567,"p":566,"n":"secondary","y":8,"o":1}'>
# <li data-id="568" data-m='{"i":568,"p":567,"n":"HeadlineItemViewModel","y":13,"l":"AAGmnm4","h":0,"v":"lifestyle","c":"advice","o":1}'>
# <a href="/en-us/lifestyle/advice/i-found-out-my-girlfriend-of-7-years-cheated-on-me-twice-i-want-to-forgive-and-trust-her-again-but-is-that-even-possible/ar-AAGmnm4?li=BBnbcA0">
# <img alt="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpkdj.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="I found out my girlfriend of 7 years cheated on me twice. I want to forgive and ... - KatarzynaBialasiewicz/ iStock"/> <div>
# <h3 aria-label="ask julia: my girlfriend of 7 years cheated on me. can i trust her again?-article">Ask Julia: My girlfriend of 7 years cheated on me. Can I trust her again?</h3>
# <img alt="INSIDER Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBnGKDa.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>INSIDER</span>
# </div>
# </a>
# </li>
# </ul>

# %%
re.findall(r'\/\/(.*)\?',item.select('ul')[1].select('img')[0]['data-src'])[0]
# Out:
# 'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGpkdj.img'

# %%
df = []
for index, item in enumerate(soup.select('.stripecontainer[aria-label]'), start = 2):
    if item.select('img[alt="Business Insider Logo"]'):
#         print(item)
        print(index)
        river_position = index
        river_name = item['aria-label']
        a = item

        for item_block in item.find_all('ul'):
            if item_block.select('img[alt="Business Insider Logo"]'):
                ib = item_block
                item_block_type = item_block['data-aop']
                item_block_position = re.findall("\"o\":(\d+)",item_block['data-m'])[0]
#                 print(item_block)
                for item_block_link in item_block.select('li'):
                    if item_block_link.select('img[alt="Business Insider Logo"]'):
                        ibl = item_block_link
                        x = item_block_link
                        print(item_block_link)
                        print(len(item_block_link))
                        item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
                        article_tile = item_block_link.select('h3[aria-label]')[0]['aria-label']
                        article_link = item_block_link.a['href']
                        article_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                        article_img_small = re.findall('\/\/(.+)\"', item_block_link.a.img['data-src'])[0]
#                         artile_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                        df.append([river_position, 
                                   river_name,
                                   item_block_position,
                                   item_block_type,
                                   item_block_link_position,
                                   article_tile,
                                   article_link,
                                   article_img,
                                   article_img_small])
        
        
    else:
        print('***')
pd.DataFrame(df, columns = ['river_position',
                           'river_name',
                           'item_block_position',
                           'item_block_type',
                           'item_block_link_position',
                           'article_title',
                           'article_link',
                           'article_img',
                           'article_img_small'])

# %%
#US Weekly Logo

# %%
#### main river ####
for item in soup.select('.todaystripe.grid')[0].select('ul')[0].findAll("li", recursive=False):
#     if True:
    if (item.select('img[alt="Business Insider Logo"]')) or (item.select('img[alt="INSIDER Logo"]')):
#     if (item.select('img[alt="Sporting News Logo"]')):
        river_position = 1
        river_name = 'top river'       
        if item['class'][0] == 'infopane-placeholder':
            item_block_position = 1
            item_block_type = 'swipenav'
            for item_block_link in item.find(class_='swipenav').findAll("li", recursive=False):
#                 if (item_block_link.select('img[alt="Sporting News Logo"]')):
#                 if True:
                if (item_block_link.select('img[alt="Business Insider Logo"]')) or (item_block_link.select('img[alt="INSIDER Logo"]')):
                    item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
#                     print(item_block_link_position)
#                     TEMP2 = item_block_link

                    #### loop over link
                    for item_block_link_each in item_block_link.select('a'):
#                         if (item_block_link_each.select('img[alt="Sporting News Logo"]')):
                        if (item_block_link_each.select('img[alt="Business Insider Logo"]')) or (item_block_link_each.select('img[alt="INSIDER Logo"]')):
                            article_title = item_block_link_each.select('span[aria-label]')[0]['aria-label']
    #                         print(article_title)
    #                         print(len(item_block_link.select('span[aria-label]')))
    #                         if len(item_block_link.select('span[aria-label]')) > 1:
    #                             temptest = item_block_link
                            article_link = item_block_link_each['href']

                            try:
        #                         print('try1')
                                article_img = re.findall(r'\/\/(.*)\?',item_block_link_each.select('img')[0]['data-src'])[0]
                            except:
                                article_img = item_block_link_each.select('img')[0]['src']
                            try: 
        #                         print('try2')
                                article_img_small = re.findall('\/\/(.+)\"', item_block_link_each.select('img')[0]['data-src'])[0]
                            except:
                                article_img_small = item_block_link_each.select('img')[0]['src']
                            df.append([river_position, 
                                           river_name,
                                           item_block_position,
                                           item_block_type,
                                           item_block_link_position,
                                           article_title,
                                           article_link,
                                           article_img,
                                           article_img_small])

        #                     print(article_title, '\n', article_link, '\n',article_img,'\n',article_img_small )
        else:
            try:
#                 temp3 = item
                item_block_position = re.findall("\"o\":(\d+)",item['data-m'])[0]
                item_block_type = ' '.join(item['class'])
                item_block_link_position = 1
                try:
                    article_title = item.select('span[aria-label]')[0]['aria-label']
                except:
                    article_title = item.find(class_='title')
                article_link = item.a['href']
                article_img = re.findall(r'\/\/(.*)\?',item.select('img')[0]['data-src'])[0]
                article_img_small = re.findall('\/\/(.+)\"', item.a.img['data-src'])[0]
                df.append([river_position, 
                                           river_name,
                                           item_block_position,
                                           item_block_type,
                                           item_block_link_position,
                                           article_title,
                                           article_link,
                                           article_img,
                                           article_img_small])
            except:
                ttt.append(item)
                print(' '.join(item['class']))

# %%
pd.DataFrame(df)
# Out:
#    0          1  2         3   4  \
# 0  1  top river  1  swipenav   4
# 1  1  top river  1  swipenav  10
#
#                                                    5  \
# 0  replacement got a 24-hour notice on retirement...
# 1  matthews: packers 'told me there was no room f...
#
#                                                    6  \
# 0  /en-us/sports/nfl/andrew-luck-retires-new-colt...
# 1  /en-us/sports/nfl/rams-clay-matthews-on-leavin...
#
#                                                    7  \
# 0  static-global-s-msn-com.akamaized.net/img-resi...
# 1  static-global-s-msn-com.akamaized.net/img-resi...
#
#                                                    8
# 0  static-global-s-msn-com.akamaized.net/img-resi...
# 1  static-global-s-msn-com.akamaized.net/img-resi...

# %%
#### main river ####
for item in soup.select('.todaystripe.grid')[0].select('ul')[0].findAll("li", recursive=False):
    if True:
#     if (item.select('img[alt="Business Insider Logo"]')) or (item.select('img[alt="INSIDER Logo"]')):
#     if (item.select('img[alt="The Daily Meal Logo"]')):
        river_position = 1
        river_name = 'top river'       
        if item['class'][0] == 'infopane-placeholder':
            item_block_position = 1
            item_block_type = 'swipenav'
            for item_block_link in item.find(class_='swipenav').findAll("li", recursive=False):
                if True:
#                 if (item_block_link.select('img[alt="Business Insider Logo"]')) or (item_block_link.select('img[alt="INSIDER Logo"]')):
                    item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
#                     print(item_block_link_position)
#                     TEMP2 = item_block_link

                    #### loop over link
                    for item_block_link_each in item_block_link.select('a'):
                        article_title = item_block_link_each.select('span[aria-label]')[0]['aria-label']
#                         print(article_title)
#                         print(len(item_block_link.select('span[aria-label]')))
#                         if len(item_block_link.select('span[aria-label]')) > 1:
#                             temptest = item_block_link
                        article_link = item_block_link_each['href']

                        try:
    #                         print('try1')
                            article_img = re.findall(r'\/\/(.*)\?',item_block_link_each.select('img')[0]['data-src'])[0]
                        except:
                            article_img = item_block_link_each.select('img')[0]['src']
                        try: 
    #                         print('try2')
                            article_img_small = re.findall('\/\/(.+)\"', item_block_link_each.select('img')[0]['data-src'])[0]
                        except:
                            article_img_small = item_block_link_each.select('img')[0]['src']
                        df.append([river_position, 
                                       river_name,
                                       item_block_position,
                                       item_block_type,
                                       item_block_link_position,
                                       article_title,
                                       article_link,
                                       article_img,
                                       article_img_small])

    #                     print(article_title, '\n', article_link, '\n',article_img,'\n',article_img_small )
        else:
            try:
                temp3 = item
                item_block_position = re.findall("\"o\":(\d+)",item['data-m'])[0]
                item_block_type = ' '.join(item['class'])
                item_block_link_position = 1
                try:
                    article_title = item.select('span[aria-label]')[0]['aria-label']
                except:
                    article_title = item.find(class_='title')
                article_link = item.a['href']
                article_img = re.findall(r'\/\/(.*)\?',item.select('img')[0]['data-src'])[0]
                article_img_small = re.findall('\/\/(.+)\"', item.a.img['data-src'])[0]
                df.append([river_position, 
                                           river_name,
                                           item_block_position,
                                           item_block_type,
                                           item_block_link_position,
                                           article_title,
                                           article_link,
                                           article_img,
                                           article_img_small])
            except:
                ttt.append(item)
                print(' '.join(item['class']))
# Out:
# popularnow pos10 rowspan3
# todayshowcasead size234column
# pick pick1
# pick pick2
# pick pick3
# pick pick4

# %%
pd.DataFrame(df)
# Out:
#     0          1   2                                                  3   4  \
# 0   1  top river   1                                           swipenav   4
# 1   1  top river   1                                           swipenav  10
# 2   1  top river   1                                           swipenav   1
# 3   1  top river   1                                           swipenav   2
# 4   1  top river   1                                           swipenav   2
# 5   1  top river   1                                           swipenav   2
# 6   1  top river   1                                           swipenav   3
# 7   1  top river   1                                           swipenav   3
# 8   1  top river   1                                           swipenav   3
# 9   1  top river   1                                           swipenav   4
# 10  1  top river   1                                           swipenav   4
# 11  1  top river   1                                           swipenav   4
# 12  1  top river   1                                           swipenav   5
# 13  1  top river   1                                           swipenav   6
# 14  1  top river   1                                           swipenav   7
# 15  1  top river   1                                           swipenav   7
# 16  1  top river   1                                           swipenav   8
# 17  1  top river   1                                           swipenav   8
# 18  1  top river   1                                           swipenav   8
# 19  1  top river   1                                           swipenav   9
# 20  1  top river   1                                           swipenav  10
# 21  1  top river   1                                           swipenav  10
# 22  1  top river   1                                           swipenav  10
# 23  1  top river   1                                           swipenav  11
# 24  1  top river   1                                           swipenav  11
# 25  1  top river   1                                           swipenav  11
# 26  1  top river   1                                           swipenav  12
# 27  1  top river   1                                           swipenav  13
# 28  1  top river   1                                           swipenav  14
# 29  1  top river   1                                           swipenav  14
# 30  1  top river   1                                           swipenav  14
# 31  1  top river   1                                           swipenav  15
# 32  1  top river   1                                           swipenav  16
# 33  1  top river   1                                           swipenav  17
# 34  1  top river   1                                           swipenav  18
# 35  1  top river   1                                           swipenav  19
# 36  1  top river   1                                           swipenav  19
# 37  1  top river   1                                           swipenav  19
# 38  1  top river   1                                           swipenav  20
# 39  1  top river   1                                           swipenav  20
# 40  1  top river   1                                           swipenav  21
# 41  1  top river   1                                           swipenav  21
# 42  1  top river   2  pos1 replacead23 smalla smalla-twoimages media...   1
# 43  1  top river   3                                        pos2 smalla   1
# 44  1  top river   4                                        pos3 smalla   1
# 45  1  top river   5                                        pos4 smalla   1
# 46  1  top river   6                                            mediuma   1
# 47  1  top river   7                            pos6 smalla media photo   1
# 48  1  top river   8                            pos7 smalla media photo   1
# 49  1  top river   9                                        pos8 smalla   1
# 50  1  top river  10                       pos9 smalla smalla-twoimages   1
#
#                                                     5  \
# 0   replacement got a 24-hour notice on retirement...
# 1   matthews: packers 'told me there was no room f...
# 2   johnson & johnson ordered to pay $572m in hist...
# 3   couple aims to balance gender representation i...
# 4   suspicious package shuts down part of downtown...
# 5   police arrest woman in connection with ciprian...
# 6   analysis: as trump veers on trade, it’s whipla...
# 7   feds close to decision on charging mccabe-article
# 8   candidate drops out after voicing racist views...
# 9   luck effect: why more nfl players will retire ...
# 10   patriots clarify belichick’s luck remark-article
# 11  replacement got a 24-hour notice on retirement...
# 12  how an accidental encounter brought slavery to...
# 13   overlooked destinations in every state-slideshow
# 14  credit cards charging 0% interest until 2021-a...
# 15    4 cards charging 0% interest until 2021-article
# 16  brooke burke rebounds with new beau after divo...
# 17  brown candidly explains why she’s 'not happy'-...
# 18  vin diesel shares touching pic with walker’s b...
# 19  fallout from russia missile disaster suggests ...
# 20  matthews: packers 'told me there was no room f...
# 21  report: howard signs with la, picks unique num...
# 22       scott urges 76ers fans to boo butler-article
# 23  mtv video music awards: photos from the red ca...
# 24   the best beauty looks of the 2019 vmas-slideshow
# 25  the most memorable vma looks of all time-slide...
# 26  fox news host fact-checks trump claim that put...
# 27  analysis: biden, sanders, warren take differen...
# 28  schumer: 'appalling' trump would invite putin ...
# 29  macron hits back after brazil leader mocks wif...
# 30  trump: us won't trade wealth for windmills-art...
# 31  mom shares unbelievable 'before and after' pho...
# 32  huge hoard of muscle cars uncovered in iowa an...
# 33  dogs across america are dying due to this comm...
# 34  this stone tower in the middle of ocean was pa...
# 35  near amazon fires, residents are sick, worried...
# 36  g-7 nations blasted over $22m wildfire pledge-...
# 37  what you can do to help the amazon rainforest-...
# 38  organizations that fight for women's rights-sl...
# 39  donate to girls who code to help close the gen...
# 40  each birth month has a different color and mea...
# 41  lesser-known qualities of your zodiac sign-sli...
# 42  an inside look at a rat pack retreat a casino ...
# 43  chinese investors are pulling out of the us ho...
# 44  stills does not think advocacy will be factor ...
# 45  <span class="title">People Age 55+ Are Entitle...
# 46  la deputy who faked sniper-style attack may fa...
# 47  see ripa, consuelos' daughter go from christen...
# 48          the safest luxury suvs for 2019-slideshow
# 49  model: magazine confused me with another black...
# 50  spencer apologizes on-air for 'stupid' ballet ...
#
#                                                     6  \
# 0   /en-us/sports/nfl/andrew-luck-retires-new-colt...
# 1   /en-us/sports/nfl/rams-clay-matthews-on-leavin...
# 2   /en-us/news/us/johnson-and-johnson-to-pay-doll...
# 3   /en-us/travel/article/couple-aims-to-balance-g...
# 4   /en-us/news/us/suspicious-package-shuts-down-p...
# 5   /en-us/foodanddrink/foodnews/police-arrest-wom...
# 6   /en-us/news/world/as-trump-veers-on-trade-war-...
# 7   /en-us/news/politics/feds-in-final-stages-of-p...
# 8   /en-us/news/us/marysville-council-candidate-je...
# 9   /en-us/sports/nfl/the-andrew-luck-effect-more-...
# 10  /en-us/sports/nfl/patriots-clarify-bill-belich...
# 11  /en-us/sports/nfl/andrew-luck-retires-new-colt...
# 12  /en-us/news/us/american-slavery-began-in-1619-...
# 13  /en-us/travel/tripideas/the-most-overlooked-de...
# 14  https://www.comparecards.com/guide/pay-0-inter...
# 15  https://www.comparecards.com/guide/pay-0-inter...
# 16  /en-us/tv/celebrity/brooke-burke-is-dating-sco...
# 17  /en-us/tv/celebrity/hannah-brown-posts-candid-...
# 18  /en-us/movies/news/vin-diesel-shares-touching-...
# 19  /en-us/news/world/fallout-from-russias-mysteri...
# 20  /en-us/sports/nfl/rams-clay-matthews-on-leavin...
# 21  /en-us/sports/nba/dwight-howard-clears-waivers...
# 22  /en-us/sports/nba/mike-scott-urges-76ers-fans-...
# 23  /en-us/music/awards/2019-mtv-video-music-award...
# 24  /en-us/lifestyle/celeb-style/the-most-fire-bea...
# 25  /en-us/lifestyle/celeb-style/the-most-memorabl...
# 26  /en-us/news/politics/shep-smith-fact-checks-tr...
# 27  /en-us/news/politics/biden-sanders-and-warren-...
# 28  /en-us/news/politics/schumer-appalling-trump-w...
# 29  /en-us/news/world/brazilian-women-must-be-asha...
# 30  /en-us/news/world/trump-at-g7-nations-wealth-w...
# 31  /en-us/lifestyle/lifestyle-buzz/mom-shares-unb...
# 32  /en-us/autos/classic-cars/huge-hoard-of-muscle...
# 33  /en-us/lifestyle/lifestyle-buzz/dogs-are-dying...
# 34  /en-us/video/science/this-stone-tower-in-the-m...
# 35  /en-us/news/world/near-the-amazon-fires-reside...
# 36  /en-us/news/world/g-7-countries-slammed-over-d...
# 37  /en-us/news/world/what-you-can-do-to-help-the-...
# 38  /en-us/lifestyle/causes-gender-equality/21-org...
# 39  https://msn.benevity.org/community/fundraiser/174
# 40  /en-us/lifestyle/family-relationships/each-bir...
# 41  /en-us/lifestyle/horoscope/surprising-qualitie...
# 42  /en-us/money/realestate/step-inside-the-rat-pa...
# 43  /en-us/money/realestate/homes-for-sale-chinese...
# 44  /en-us/sports/nfl/kenny-stills-does-not-think-...
# 45  https://comation-visonging.com/82bc0f79-8d3e-4...
# 46  /en-us/news/us/los-angeles-deputy-who-faked-sn...
# 47  /en-us/tv/celebrity/lola-consuelos-is-all-grow...
# 48  /en-us/autos/autos-luxury/14-safest-luxury-suv...
# 49  /en-us/lifestyle/lifestyle-buzz/model-adut-ake...
# 50  /en-us/tv/news/gmas-lara-spencer-apologizes-on...
#
#                                                     7  \
# 0   static-global-s-msn-com.akamaized.net/img-resi...
# 1   static-global-s-msn-com.akamaized.net/img-resi...
# 2   https://static-global-s-msn-com.akamaized.net/...
# 3   static-global-s-msn-com.akamaized.net/img-resi...
# 4   static-global-s-msn-com.akamaized.net/img-resi...
# 5   static-global-s-msn-com.akamaized.net/img-resi...
# 6   static-global-s-msn-com.akamaized.net/img-resi...
# 7   static-global-s-msn-com.akamaized.net/img-resi...
# 8   static-global-s-msn-com.akamaized.net/img-resi...
# 9   static-global-s-msn-com.akamaized.net/img-resi...
# 10  static-global-s-msn-com.akamaized.net/img-resi...
# 11  static-global-s-msn-com.akamaized.net/img-resi...
# 12  static-global-s-msn-com.akamaized.net/img-resi...
# 13  static-global-s-msn-com.akamaized.net/img-resi...
# 14  static-global-s-msn-com.akamaized.net/img-resi...
# 15  static-global-s-msn-com.akamaized.net/img-resi...
# 16  static-global-s-msn-com.akamaized.net/img-resi...
# 17  static-global-s-msn-com.akamaized.net/img-resi...
# 18  static-global-s-msn-com.akamaized.net/img-resi...
# 19  static-global-s-msn-com.akamaized.net/img-resi...
# 20  static-global-s-msn-com.akamaized.net/img-resi...
# 21  static-global-s-msn-com.akamaized.net/img-resi...
# 22  static-global-s-msn-com.akamaized.net/img-resi...
# 23  static-global-s-msn-com.akamaized.net/img-resi...
# 24  static-global-s-msn-com.akamaized.net/img-resi...
# 25  static-global-s-msn-com.akamaized.net/img-resi...
# 26  static-global-s-msn-com.akamaized.net/img-resi...
# 27  static-global-s-msn-com.akamaized.net/img-resi...
# 28  static-global-s-msn-com.akamaized.net/img-resi...
# 29  static-global-s-msn-com.akamaized.net/img-resi...
# 30  static-global-s-msn-com.akamaized.net/img-resi...
# 31  static-global-s-msn-com.akamaized.net/img-resi...
# 32  static-global-s-msn-com.akamaized.net/img-resi...
# 33  static-global-s-msn-com.akamaized.net/img-resi...
# 34  static-global-s-msn-com.akamaized.net/img-resi...
# 35  static-global-s-msn-com.akamaized.net/img-resi...
# 36  static-global-s-msn-com.akamaized.net/img-resi...
# 37  static-global-s-msn-com.akamaized.net/img-resi...
# 38  static-global-s-msn-com.akamaized.net/img-resi...
# 39  static-global-s-msn-com.akamaized.net/img-resi...
# 40  static-global-s-msn-com.akamaized.net/img-resi...
# 41  static-global-s-msn-com.akamaized.net/img-resi...
# 42  static-global-s-msn-com.akamaized.net/img-resi...
# 43  static-global-s-msn-com.akamaized.net/img-resi...
# 44  static-global-s-msn-com.akamaized.net/img-resi...
# 45  static-global-s-msn-com.akamaized.net/img-resi...
# 46  static-global-s-msn-com.akamaized.net/img-resi...
# 47  static-global-s-msn-com.akamaized.net/img-resi...
# 48  static-global-s-msn-com.akamaized.net/img-resi...
# 49  static-global-s-msn-com.akamaized.net/img-resi...
# 50  static-global-s-msn-com.akamaized.net/img-resi...
#
#                                                     8
# 0   static-global-s-msn-com.akamaized.net/img-resi...
# 1   static-global-s-msn-com.akamaized.net/img-resi...
# 2   https://static-global-s-msn-com.akamaized.net/...
# 3   static-global-s-msn-com.akamaized.net/img-resi...
# 4   static-global-s-msn-com.akamaized.net/img-resi...
# 5   static-global-s-msn-com.akamaized.net/img-resi...
# 6   static-global-s-msn-com.akamaized.net/img-resi...
# 7   static-global-s-msn-com.akamaized.net/img-resi...
# 8   static-global-s-msn-com.akamaized.net/img-resi...
# 9   static-global-s-msn-com.akamaized.net/img-resi...
# 10  static-global-s-msn-com.akamaized.net/img-resi...
# 11  static-global-s-msn-com.akamaized.net/img-resi...
# 12  static-global-s-msn-com.akamaized.net/img-resi...
# 13  static-global-s-msn-com.akamaized.net/img-resi...
# 14  static-global-s-msn-com.akamaized.net/img-resi...
# 15  static-global-s-msn-com.akamaized.net/img-resi...
# 16  static-global-s-msn-com.akamaized.net/img-resi...
# 17  static-global-s-msn-com.akamaized.net/img-resi...
# 18  static-global-s-msn-com.akamaized.net/img-resi...
# 19  static-global-s-msn-com.akamaized.net/img-resi...
# 20  static-global-s-msn-com.akamaized.net/img-resi...
# 21  static-global-s-msn-com.akamaized.net/img-resi...
# 22  static-global-s-msn-com.akamaized.net/img-resi...
# 23  static-global-s-msn-com.akamaized.net/img-resi...
# 24  static-global-s-msn-com.akamaized.net/img-resi...
# 25  static-global-s-msn-com.akamaized.net/img-resi...
# 26  static-global-s-msn-com.akamaized.net/img-resi...
# 27  static-global-s-msn-com.akamaized.net/img-resi...
# 28  static-global-s-msn-com.akamaized.net/img-resi...
# 29  static-global-s-msn-com.akamaized.net/img-resi...
# 30  static-global-s-msn-com.akamaized.net/img-resi...
# 31  static-global-s-msn-com.akamaized.net/img-resi...
# 32  static-global-s-msn-com.akamaized.net/img-resi...
# 33  static-global-s-msn-com.akamaized.net/img-resi...
# 34  static-global-s-msn-com.akamaized.net/img-resi...
# 35  static-global-s-msn-com.akamaized.net/img-resi...
# 36  static-global-s-msn-com.akamaized.net/img-resi...
# 37  static-global-s-msn-com.akamaized.net/img-resi...
# 38  static-global-s-msn-com.akamaized.net/img-resi...
# 39  static-global-s-msn-com.akamaized.net/img-resi...
# 40  static-global-s-msn-com.akamaized.net/img-resi...
# 41  static-global-s-msn-com.akamaized.net/img-resi...
# 42  static-global-s-msn-com.akamaized.net/img-resi...
# 43  static-global-s-msn-com.akamaized.net/img-resi...
# 44  static-global-s-msn-com.akamaized.net/img-resi...
# 45  static-global-s-msn-com.akamaized.net/img-resi...
# 46  static-global-s-msn-com.akamaized.net/img-resi...
# 47  static-global-s-msn-com.akamaized.net/img-resi...
# 48  static-global-s-msn-com.akamaized.net/img-resi...
# 49  static-global-s-msn-com.akamaized.net/img-resi...
# 50  static-global-s-msn-com.akamaized.net/img-resi...

# %%
item_block_link_each.select('img')[0]['src']
# Out:
# 'https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGmyGy.img?h=368&w=622&m=6&q=60&u=t&o=t&l=f&f=jpg&x=1952&y=1170'

# %%
item_block_link_each.select('span[aria-label]')
# Out:
# [<span aria-label="johnson &amp; johnson ordered to pay $572m in historic opioid trial-article" class="title">Johnson &amp; Johnson ordered to pay $572M in historic opioid trial</span>]

# %%
temptest.select('span[aria-label]')
# Out:
# [<span aria-label="each birth month has a different color and meaning-slideshow" class="title">Each birth month has a different color and meaning</span>,
#  <span aria-label="lesser-known qualities of your zodiac sign-slideshow" class="title">Lesser-known qualities of your zodiac sign</span>]

# %%
temptest['data-m']
# Out:
# '{"i":176,"p":118,"n":"headtohead","y":8,"o":21}'

# %%
temptest.select('a')[1].select('img')
# Out:
# [<img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAEA5ZL.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Scorpio: Has a Top-Notch Sense of Humor - StockSnap / Priscilla Westra"/>,
#  <img alt="PopSugar Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAgnIPB.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>]

# %%
pd.DataFrame(df)
# Out:
#     0          1   2                                                  3   4  \
# 0   1  top river   1                                           swipenav   1
# 1   1  top river   1                                           swipenav   2
# 2   1  top river   1                                           swipenav   3
# 3   1  top river   1                                           swipenav   4
# 4   1  top river   1                                           swipenav   5
# 5   1  top river   1                                           swipenav   6
# 6   1  top river   1                                           swipenav   7
# 7   1  top river   1                                           swipenav   8
# 8   1  top river   1                                           swipenav   9
# 9   1  top river   1                                           swipenav  10
# 10  1  top river   1                                           swipenav  11
# 11  1  top river   1                                           swipenav  12
# 12  1  top river   1                                           swipenav  13
# 13  1  top river   1                                           swipenav  14
# 14  1  top river   1                                           swipenav  15
# 15  1  top river   1                                           swipenav  16
# 16  1  top river   1                                           swipenav  17
# 17  1  top river   1                                           swipenav  18
# 18  1  top river   1                                           swipenav  19
# 19  1  top river   1                                           swipenav  20
# 20  1  top river   1                                           swipenav  21
# 21  1  top river   2  pos1 replacead23 smalla smalla-twoimages media...   1
# 22  1  top river   3                                        pos2 smalla   1
# 23  1  top river   4                                        pos3 smalla   1
# 24  1  top river   5                                        pos4 smalla   1
# 25  1  top river   6                                            mediuma   1
# 26  1  top river   7                            pos6 smalla media photo   1
# 27  1  top river   8                            pos7 smalla media photo   1
# 28  1  top river   9                                        pos8 smalla   1
# 29  1  top river  10                       pos9 smalla smalla-twoimages   1
#
#                                                     5  \
# 0   johnson & johnson ordered to pay $572m in hist...
# 1   hackers target long island school district wit...
# 2   feds close to deciding whether to charge mccab...
# 3   luck's replacement got a 24-hour notice on ret...
# 4   how an accidental encounter brought slavery to...
# 5    overlooked destinations in every state-slideshow
# 6   credit cards charging 0% interest until 2021-a...
# 7   eddie murphy is finally returning to 'snl'-art...
# 8   fallout from russia missile disaster suggests ...
# 9   report: howard signs with la, picks unique num...
# 10  2019 mtv video music awards: see all the photo...
# 11  fox news host fact-checks trump claim that put...
# 12  poll: biden plunges into tie with warren, sand...
# 13  trump, iran's president talk of possible meeti...
# 14  mom shares unbelievable 'before and after' pho...
# 15  huge hoard of muscle cars uncovered in iowa an...
# 16  dodging sticky fingers: how to outfox pickpock...
# 17  this stone tower in the middle of ocean was pa...
# 18  near amazon fires, residents are sick, worried...
# 19  organizations that fight for women's rights-sl...
# 20  each birth month has a different color and mea...
# 21  hilarious audience reactions at awards shows-s...
# 22  chinese investors are pulling out of the us ho...
# 23  stills does not think advocacy will be factor ...
# 24  <span class="title">People Age 55+ Are Entitle...
# 25  la deputy who faked sniper-style attack may fa...
# 26  see ripa, consuelos' daughter go from christen...
# 27          the safest luxury suvs for 2019-slideshow
# 28  model: magazine confused me with another black...
# 29  spencer apologizes on-air for 'stupid' ballet ...
#
#                                                     6  \
# 0   /en-us/news/us/johnson-and-johnson-to-pay-doll...
# 1   /en-us/news/us/back-to-school-for-scammers-hac...
# 2   /en-us/news/politics/feds-in-final-stages-of-p...
# 3   /en-us/sports/nfl/andrew-luck-retires-new-colt...
# 4   /en-us/news/us/american-slavery-began-in-1619-...
# 5   /en-us/travel/tripideas/the-most-overlooked-de...
# 6   https://www.comparecards.com/guide/pay-0-inter...
# 7   /en-us/tv/news/woody-harrelson-to-host-snl-sea...
# 8   /en-us/news/world/fallout-from-russias-mysteri...
# 9   /en-us/sports/nba/dwight-howard-clears-waivers...
# 10  /en-us/music/awards/2019-mtv-video-music-award...
# 11  /en-us/news/politics/shep-smith-fact-checks-tr...
# 12  /en-us/news/politics/biden-plunges-tied-with-w...
# 13  /en-us/news/world/trump-irans-president-talk-o...
# 14  /en-us/lifestyle/lifestyle-buzz/mom-shares-unb...
# 15  /en-us/autos/classic-cars/huge-hoard-of-muscle...
# 16  /en-us/travel/tips/dodging-sticky-fingers-how-...
# 17  /en-us/video/science/this-stone-tower-in-the-m...
# 18  /en-us/news/world/near-the-amazon-fires-reside...
# 19  /en-us/lifestyle/causes-gender-equality/21-org...
# 20  /en-us/lifestyle/family-relationships/each-bir...
# 21  /en-us/music/awards/hilarious-awards-show-audi...
# 22  /en-us/money/realestate/homes-for-sale-chinese...
# 23  /en-us/sports/nfl/kenny-stills-does-not-think-...
# 24  https://comation-visonging.com/82bc0f79-8d3e-4...
# 25  /en-us/news/us/los-angeles-deputy-who-faked-sn...
# 26  /en-us/tv/celebrity/lola-consuelos-is-all-grow...
# 27  /en-us/autos/autos-luxury/14-safest-luxury-suv...
# 28  /en-us/lifestyle/lifestyle-buzz/model-adut-ake...
# 29  /en-us/tv/news/gmas-lara-spencer-apologizes-on...
#
#                                                     7  \
# 0   https://static-global-s-msn-com.akamaized.net/...
# 1   static-global-s-msn-com.akamaized.net/img-resi...
# 2   static-global-s-msn-com.akamaized.net/img-resi...
# 3   static-global-s-msn-com.akamaized.net/img-resi...
# 4   static-global-s-msn-com.akamaized.net/img-resi...
# 5   static-global-s-msn-com.akamaized.net/img-resi...
# 6   static-global-s-msn-com.akamaized.net/img-resi...
# 7   static-global-s-msn-com.akamaized.net/img-resi...
# 8   static-global-s-msn-com.akamaized.net/img-resi...
# 9   static-global-s-msn-com.akamaized.net/img-resi...
# 10  static-global-s-msn-com.akamaized.net/img-resi...
# 11  static-global-s-msn-com.akamaized.net/img-resi...
# 12  static-global-s-msn-com.akamaized.net/img-resi...
# 13  static-global-s-msn-com.akamaized.net/img-resi...
# 14  static-global-s-msn-com.akamaized.net/img-resi...
# 15  static-global-s-msn-com.akamaized.net/img-resi...
# 16  static-global-s-msn-com.akamaized.net/img-resi...
# 17  static-global-s-msn-com.akamaized.net/img-resi...
# 18  static-global-s-msn-com.akamaized.net/img-resi...
# 19  static-global-s-msn-com.akamaized.net/img-resi...
# 20  static-global-s-msn-com.akamaized.net/img-resi...
# 21  static-global-s-msn-com.akamaized.net/img-resi...
# 22  static-global-s-msn-com.akamaized.net/img-resi...
# 23  static-global-s-msn-com.akamaized.net/img-resi...
# 24  static-global-s-msn-com.akamaized.net/img-resi...
# 25  static-global-s-msn-com.akamaized.net/img-resi...
# 26  static-global-s-msn-com.akamaized.net/img-resi...
# 27  static-global-s-msn-com.akamaized.net/img-resi...
# 28  static-global-s-msn-com.akamaized.net/img-resi...
# 29  static-global-s-msn-com.akamaized.net/img-resi...
#
#                                                     8
# 0   https://static-global-s-msn-com.akamaized.net/...
# 1   static-global-s-msn-com.akamaized.net/img-resi...
# 2   static-global-s-msn-com.akamaized.net/img-resi...
# 3   static-global-s-msn-com.akamaized.net/img-resi...
# 4   static-global-s-msn-com.akamaized.net/img-resi...
# 5   static-global-s-msn-com.akamaized.net/img-resi...
# 6   static-global-s-msn-com.akamaized.net/img-resi...
# 7   static-global-s-msn-com.akamaized.net/img-resi...
# 8   static-global-s-msn-com.akamaized.net/img-resi...
# 9   static-global-s-msn-com.akamaized.net/img-resi...
# 10  static-global-s-msn-com.akamaized.net/img-resi...
# 11  static-global-s-msn-com.akamaized.net/img-resi...
# 12  static-global-s-msn-com.akamaized.net/img-resi...
# 13  static-global-s-msn-com.akamaized.net/img-resi...
# 14  static-global-s-msn-com.akamaized.net/img-resi...
# 15  static-global-s-msn-com.akamaized.net/img-resi...
# 16  static-global-s-msn-com.akamaized.net/img-resi...
# 17  static-global-s-msn-com.akamaized.net/img-resi...
# 18  static-global-s-msn-com.akamaized.net/img-resi...
# 19  static-global-s-msn-com.akamaized.net/img-resi...
# 20  static-global-s-msn-com.akamaized.net/img-resi...
# 21  static-global-s-msn-com.akamaized.net/img-resi...
# 22  static-global-s-msn-com.akamaized.net/img-resi...
# 23  static-global-s-msn-com.akamaized.net/img-resi...
# 24  static-global-s-msn-com.akamaized.net/img-resi...
# 25  static-global-s-msn-com.akamaized.net/img-resi...
# 26  static-global-s-msn-com.akamaized.net/img-resi...
# 27  static-global-s-msn-com.akamaized.net/img-resi...
# 28  static-global-s-msn-com.akamaized.net/img-resi...
# 29  static-global-s-msn-com.akamaized.net/img-resi...

# %%
item
# Out:
# <li class="pos4 smalla" data-aop="river&gt;4" data-id="184" data-m='{"i":184,"p":117,"n":"NativeAdHeadlineItemViewModel","y":13,"o":5}'>
# <a class="nativead" data-pg="1" data-pid="7HD66FC" href="https://comation-visonging.com/82bc0f79-8d3e-4d95-91b4-df269d02531f?s1=ms061219eoabrs8sendisc1" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADOllJ.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="300x210sen13"/>
# <div class="caption">
# <span class="title">People Age 55+ Are Entitled To These Discounts</span>
# <span class="sourcename">
# <span class="adslabel" title="Ad">Ad</span>
# ConsumersTricks            </span>
# </div>
# </a>
# </li>

# %%
item.find(class_='title')
# Out:
# <span class="title">People Age 55+ Are Entitled To These Discounts</span>

# %%
#### main river ####
for item in soup.select('.todaystripe.grid')[0].select('ul')[0].findAll("li", recursive=False):
    if (item.select('img[alt="Business Insider Logo"]')) or (item.select('img[alt="INSIDER Logo"]')):
#     if (item.select('img[alt="The Daily Meal Logo"]')):
        river_position = 1
        river_name = 'top river'       
        if item['class'][0] == 'infopane-placeholder':
            item_block_position = 1
            item_block_type = 'swipenav'
            for item_block_link in item.find(class_='swipenav').findAll("li", recursive=False):
                if (item_block_link.select('img[alt="Business Insider Logo"]')) or (item_block_link.select('img[alt="INSIDER Logo"]')):
                    item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
#                     print(item_block_link_position)
#                     TEMP2 = item_block_link
                    article_title = item_block_link.select('span[aria-label]')[0]['aria-label']
                    article_link = item_block_link.a['href']
                    article_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                    article_img_small = re.findall('\/\/(.+)\"', item_block_link.a.img['data-src'])[0]
                    df.append([river_position, 
                                   river_name,
                                   item_block_position,
                                   item_block_type,
                                   item_block_link_position,
                                   article_title,
                                   article_link,
                                   article_img,
                                   article_img_small])
            
                    print(article_title, '\n', article_link, '\n',article_img,'\n',article_img_small )
        else:
            temp3 = item
            item_block_position = re.findall("\"o\":(\d+)",item['data-m'])[0]
            item_block_type = ' '.join(item['class'])
            item_block_link_position = 1
            try:
                article_title = item.select('span[aria-label]')[0]['aria-label']
            except:
                article_title = item.find(class_='title')
            article_link = item.a['href']
            article_img = re.findall(r'\/\/(.*)\?',item.select('img')[0]['data-src'])[0]
            article_img_small = re.findall('\/\/(.+)\"', item.a.img['data-src'])[0]
            df.append([river_position, 
                                   river_name,
                                   item_block_position,
                                   item_block_type,
                                   item_block_link_position,
                                   article_title,
                                   article_link,
                                   article_img,
                                   article_img_small])
# Out:
# fallout from russia missile disaster suggests nuclear reactor blew up-article
#  /en-us/news/world/fallout-from-russias-mysterious-missile-disaster-suggests-a-nuclear-reactor-blew-up/ar-AAGmb6N?li=BBnb7Kz
#  static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFArpW.img
#  static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFArpW.img?h=368&w=622&m=6&q=60&u=t&o=t&l=f&f=jpg&x=837&y=422
# organizations that fight for women's rights-slideshow
#  /en-us/lifestyle/causes-gender-equality/21-organizations-that-are-fighting-for-womens-rights-in-the-us-and-abroad/ss-AAFQWLI?li=BBnb7Kz
#  static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFRfBF.img
#  static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFRfBF.img?h=333&w=311&m=6&q=60&u=t&o=t&l=f&f=jpg&x=1359&y=1048

# %%
df
# Out:
# [[1,
#   'top river',
#   1,
#   'swipenav',
#   '9',
#   'fallout from russia missile disaster suggests nuclear reactor blew up-article',
#   '/en-us/news/world/fallout-from-russias-mysterious-missile-disaster-suggests-a-nuclear-reactor-blew-up/ar-AAGmb6N?li=BBnb7Kz',
#   'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFArpW.img',
#   'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFArpW.img?h=368&w=622&m=6&q=60&u=t&o=t&l=f&f=jpg&x=837&y=422'],
#  [1,
#   'top river',
#   1,
#   'swipenav',
#   '20',
#   "organizations that fight for women's rights-slideshow",
#   '/en-us/lifestyle/causes-gender-equality/21-organizations-that-are-fighting-for-womens-rights-in-the-us-and-abroad/ss-AAFQWLI?li=BBnb7Kz',
#   'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFRfBF.img',
#   'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFRfBF.img?h=333&w=311&m=6&q=60&u=t&o=t&l=f&f=jpg&x=1359&y=1048'],
#  [1,
#   'top river',
#   '9',
#   'pos8 smalla',
#   1,
#   'model: magazine confused me with another black female-article',
#   '/en-us/lifestyle/lifestyle-buzz/model-adut-akech-says-a-magazine-used-a-photo-of-a-different-black-woman-in-an-article-about-her-this-wouldve-not-happened-to-a-white-model/ar-AAGm6Eo?li=BBnbfcL',
#   'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGm2pH.img',
#   'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGm2pH.img?h=75&w=100&m=6&q=60&u=t&o=t&l=f&f=jpg&x=539&y=183']]

# %%
for index, item in enumerate(soup.select('.stripecontainer[aria-label]'), start = 2):
    if (item.select('img[alt="Business Insider Logo"]')) or item.select('img[alt="INSIDER Logo"]'):
#         print(item)
#         print(index)
        river_position = index
        river_name = item['aria-label']
#         a = item

        for item_block in item.find_all('ul'):
            if (item_block.select('img[alt="Business Insider Logo"]')) or item_block.select('img[alt="INSIDER Logo"]'):
#                 ib = item_block
                item_block_type = item_block['data-aop']
                item_block_position = re.findall("\"o\":(\d+)",item_block['data-m'])[0]
#                 print(item_block)
                for item_block_link in item_block.select('li'):
                    if (item_block_link.select('img[alt="Business Insider Logo"]')) or item_block_link.select('img[alt="INSIDER Logo"]'):
#                         ibl = item_block_link
#                         x = item_block_link
#                         print(item_block_link)
#                         print(len(item_block_link))
                        item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
                        article_tile = item_block_link.select('h3[aria-label]')[0]['aria-label']
                        article_link = item_block_link.a['href']
                        article_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                        article_img_small = re.findall('\/\/(.+)\"', item_block_link.a.img['data-src'])[0]
#                         artile_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                        df.append([river_position, 
                                   river_name,
                                   item_block_position,
                                   item_block_type,
                                   item_block_link_position,
                                   article_tile,
                                   article_link,
                                   article_img,
                                   article_img_small])
        
        
#     else:
#         print('***')
df = pd.DataFrame(df, columns = ['river_position',
                           'river_name',
                           'item_block_position',
                           'item_block_type',
                           'item_block_link_position',
                           'article_title',
                           'article_link',
                           'article_img',
                           'article_img_small'])
df
# Out:
#    river_position        river_name item_block_position item_block_type  \
# 0               1         top river                   1        swipenav
# 1               1         top river                   1        swipenav
# 2               1         top river                   9     pos8 smalla
# 3               8         lifestyle                   2        tertiary
# 4               8         lifestyle                   3        tertiary
# 5              10  health & fitness                   5       secondary
# 6              11      food & drink                   3        tertiary
#
#   item_block_link_position                                      article_title  \
# 0                        9  fallout from russia missile disaster suggests ...
# 1                       20  organizations that fight for women's rights-sl...
# 2                        1  model: magazine confused me with another black...
# 3                        3  the explanation behind 6 popular design elemen...
# 4                        2  trump helicopter left scorch marks on buckingh...
# 5                        1  a trainer debunks the 7 biggest fitness myths ...
# 6                        2  a fried deep dish bbq chicken 'pizzadilla' is ...
#
#                                         article_link  \
# 0  /en-us/news/world/fallout-from-russias-mysteri...
# 1  /en-us/lifestyle/causes-gender-equality/21-org...
# 2  /en-us/lifestyle/lifestyle-buzz/model-adut-ake...
# 3  /en-us/lifestyle/did-you-know/the-explanation-...
# 4  /en-us/lifestyle/royals/its-ruined-queen-eliza...
# 5  /en-us/health/fitness/a-trainer-whos-worked-wi...
# 6  /en-us/foodanddrink/foodnews/a-fried-deep-dish...
#
#                                          article_img  \
# 0  static-global-s-msn-com.akamaized.net/img-resi...
# 1  static-global-s-msn-com.akamaized.net/img-resi...
# 2  static-global-s-msn-com.akamaized.net/img-resi...
# 3  static-global-s-msn-com.akamaized.net/img-resi...
# 4  static-global-s-msn-com.akamaized.net/img-resi...
# 5  static-global-s-msn-com.akamaized.net/img-resi...
# 6  static-global-s-msn-com.akamaized.net/img-resi...
#
#                                    article_img_small
# 0  static-global-s-msn-com.akamaized.net/img-resi...
# 1  static-global-s-msn-com.akamaized.net/img-resi...
# 2  static-global-s-msn-com.akamaized.net/img-resi...
# 3  static-global-s-msn-com.akamaized.net/img-resi...
# 4  static-global-s-msn-com.akamaized.net/img-resi...
# 5  static-global-s-msn-com.akamaized.net/img-resi...
# 6  static-global-s-msn-com.akamaized.net/img-resi...

# %%
df['time'] = current_datetime.strftime('%Y%m%d %H:%M')

# %%
df.set_index(df.columns[-1], inplace = True)   #df_bq.set_index(df_bq.columns[-1], inplace = True)

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/wzhang/Documents/WorkFile/GoogleAPI/insideradrevenue-3e1aa74bcbfe.json"

# %%
df
# Out:
#                 river_position        river_name item_block_position  \
# time
# 20190826 14:06               1         top river                   1
# 20190826 14:06               1         top river                   1
# 20190826 14:06               1         top river                   1
# 20190826 14:06               1         top river                   1
# 20190826 14:06               3              news                   2
# 20190826 14:06               8         lifestyle                   2
# 20190826 14:06               8         lifestyle                   3
# 20190826 14:06              10  health & fitness                   4
# 20190826 14:06              11      food & drink                   2
# 20190826 14:06              11      food & drink                   3
#
#                item_block_type item_block_link_position  \
# time
# 20190826 14:06        swipenav                       15
# 20190826 14:06        swipenav                       18
# 20190826 14:06        swipenav                       19
# 20190826 14:06        swipenav                       21
# 20190826 14:06        tertiary                        2
# 20190826 14:06        tertiary                        3
# 20190826 14:06        tertiary                        3
# 20190826 14:06       secondary                        1
# 20190826 14:06        tertiary                        1
# 20190826 14:06        tertiary                        1
#
#                                                     article_title  \
# time
# 20190826 14:06  disneyland's massive marvel expansion: what to...
# 20190826 14:06  royal photographer shares favorite photos of t...
# 20190826 14:06  what happens to your body when you cut out dai...
# 20190826 14:06  women whose inventions were credited to men-sl...
# 20190826 14:06  is trump quieting the fears of american doomsd...
# 20190826 14:06  the explanation behind 6 popular design elemen...
# 20190826 14:06  trump helicopter left scorch marks on buckingh...
# 20190826 14:06  a trainer debunks the 7 biggest fitness myths ...
# 20190826 14:06  this calzone is stuffed with 10 pounds of past...
# 20190826 14:06  11 snacks you used to see in every movie theat...
#
#                                                      article_link  \
# time
# 20190826 14:06  /en-us/travel/tripideas/a-massive-marvel-theme...
# 20190826 14:06  /en-us/lifestyle/royals/a-royal-photographer-s...
# 20190826 14:06  /en-us/health/nutrition/heres-what-happens-to-...
# 20190826 14:06  /en-us/lifestyle/causes-gender-equality/14-wor...
# 20190826 14:06  /en-us/news/us/doomsday-preppers-are-thinning-...
# 20190826 14:06  /en-us/lifestyle/did-you-know/the-explanation-...
# 20190826 14:06  /en-us/lifestyle/royals/its-ruined-queen-eliza...
# 20190826 14:06  /en-us/health/fitness/a-trainer-whos-worked-wi...
# 20190826 14:06  /en-us/foodanddrink/video/this-calzone-is-stuf...
# 20190826 14:06  /en-us/foodanddrink/foodnews/11-snacks-you-use...
#
#                                                       article_img  \
# time
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
#
#                                                 article_img_small
# time
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...
# 20190826 14:06  static-global-s-msn-com.akamaized.net/img-resi...

# %%
client = bigquery.Client()

# %%
df['river_position'] = (df['river_position']).astype(int)
df['item_block_position'] = (df['item_block_position']).astype(int)
df['item_block_link_position'] = (df['item_block_link_position']).astype(int)

# %%
table_ref = client.dataset("MSN", project='insideradrevenue').table(
            "MSN_HP_{}".format(table_name))

job_config = bigquery.LoadJobConfig()
job_config.write_disposition = 'WRITE_APPEND'
job_config.autodetect = True
job = client.load_table_from_dataframe(
        df,
        table_ref,
        location='US',
        job_config=job_config)

# %%
soup.select('img[alt="Business Insider Logo"]')
# Out:
# [<img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>,
#  <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>]

# %%
soup.select('.todaystripe.grid')[0].select('li')[0]['class'][0]
# Out:
# 'infopane-placeholder'

# %%
len(soup.select('.todaystripe.grid')[0].select('ul')[0].findAll("li", recursive=False))
# Out:
# 16

# %%
#### main river ####
for item in soup.select('.todaystripe.grid')[0].select('ul')[0].findAll("li", recursive=False):
#     if (item.select('img[alt="Business Insider Logo"]')) or (item.select('img[alt="INSIDER Logo"]')):
    if (item.select('img[alt="The Daily Meal Logo"]')):
        river_position = 1
        river_name = 'top river'       
        if item['class'][0] == 'infopane-placeholder':
            item_block_position = 1
            item_block_type = 'swipenav'
            for item_block_link in item.find(class_='swipenav').findAll("li", recursive=False):
                if (item_block_link.select('img[alt="Business Insider Logo"]')) or (item_block_link.select('img[alt="INSIDER Logo"]')):
                    item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
                    print(item_block_link_position)
                    TEMP2 = item_block_link
                    article_title = item_block_link.select('span[aria-label]')[0]['aria-label']
                    article_link = item_block_link.a['href']
                    article_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                    article_img_small = re.findall('\/\/(.+)\"', item_block_link.a.img['data-src'])[0]
            
                    print(article_title, '\n', article_link, '\n',article_img,'\n',article_img_small )
        else:
            temp3 = item
            item_block_position = re.findall("\"o\":(\d+)",item['data-m'])[0]
            item_block_type = ' '.join(item['class'])
            item_block_link_position = 1
            article_title = item.select('span[aria-label]')[0]['aria-label']
            article_link = item.a['href']
            article_img = re.findall(r'\/\/(.*)\?',item.select('img')[0]['data-src'])[0]
            article_img_small = re.findall('\/\/(.+)\"', item.a.img['data-src'])[0]
            
            
            
#         temp = item
#         article_img = 
#         article_img_small = 
#         print(item['class'])
        
        
        
        
# 'river_position',
#                            'river_name',
#                            'item_block_position',
#                            'item_block_type',
#                            'item_block_link_position',
#                            'article_title',
#                            'article_link',
#                            'article_img',
#                            'article_img_small'   


#                         article_tile = item_block_link.select('h3[aria-label]')[0]['aria-label']
#                         article_link = item_block_link.a['href']
#                         article_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
#                         article_img_small = re.findall('\/\/(.+)\"', item_block_link.a.img['data-src'])[0]

# %%
re.findall(r'\/\/(.*)\?',temp3.select('img')[0]['data-src'])[0]
# Out:
# 'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG55P4.img'

# %%
re.findall("\"o\":(\d+)",temp3['data-m'])[0]
# Out:
# '2'

# %%
temp3
# Out:
# <li class="pos1 replacead23 smalla smalla-twoimages media photo" data-aop="river&gt;1" data-id="183" data-m='{"i":183,"p":117,"n":"HeadlineItemViewModel","y":13,"l":"AAG4Sxa","h":0,"v":"foodanddrink","c":"foodnews","o":2}'>
# <a href="/en-us/foodanddrink/foodnews/20-things-you-didnt-know-about-french-fries/ss-AAG4Sxa?li=BBnbfcL">
# <img alt='Of all the &lt;a href="https://www.thedailymeal.com/cook/50-great-ways-cook-pota...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG55P4.img?h=250&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="french fries - istockphoto.com"/><img alt='Of all the &lt;a href="https://www.thedailymeal.com/cook/50-great-ways-cook-pota...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG55P4.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="french fries - istockphoto.com"/>
# <div class="caption">
# <span aria-label="20 things you didn't know about french fries-slideshow" class="title">20 things you didn't know about French fries</span>
# <span class="sourcename">
# <img alt="The Daily Meal Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAA8PBm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Daily Meal            </span>
# </div>
# </a>
# </li>

# %%
'-'.join(temp3['class'])
# Out:
# 'pos1-replacead23-smalla-smalla-twoimages-media-photo'

# %%
re.findall("\"o\":(\d+)",temp3['data-m'])[0]
# Out:
# '2'

# %%
TEMP2.select('span["aria-label"]')
# Out:
# {'tabindex': '0',
#  'class': ['single', 'hasimage', 'media', 'photo'],
#  'data-aop': 'slide19>single ',
#  'data-id': '175',
#  'data-m': '{"i":175,"p":118,"n":"single","y":8,"o":20}'}

# %%
TEMP2.select('span[aria-label]')[0]['aria-label']
# Out:
# "actors you've seen everywhere whose names you still don't know-slideshow"

# %% [markdown]
# TEMP2.article_link

# %%
TEMP2.a['href']
# Out:
# '/en-us/movies/gallery/20-actors-that-have-been-in-dozens-of-movies-and-tv-shows-whose-name-you-probably-still-dont-know/ss-AAGb2zQ?li=BBnb7Kz'

# %%
temp['class'][0]
# Out:
# 'infopane-placeholder'

# %%
for xyz in temp.find(class_='swipenav').findAll("li", recursive=False):
    print(xyz['class'])
    print(xyz['data-m'])
    print(re.findall("\"o\":(\d+)",xyz['data-m'])[0])
# Out:
# ['mosaic', 'hasimage', 'selected']
# {"i":119,"p":118,"n":"mosaic","y":8,"o":1}
# 1
# ['mosaic']
# {"i":123,"p":118,"n":"mosaic","y":8,"o":2,"f":"Y_cec865fe-ed84-49a8-b88a-4a23446ea7f1"}
# 2
# ['mosaic', 'hasimage']
# {"i":127,"p":118,"n":"mosaic","y":8,"o":3}
# 3
# ['mosaic', 'hasimage']
# {"i":131,"p":118,"n":"mosaic","y":8,"o":4}
# 4
# ['single', 'hasimage']
# {"i":135,"p":118,"n":"single","y":8,"o":5}
# 5
# ['single', 'hasimage', 'media', 'photo']
# {"i":137,"p":118,"n":"single","y":8,"o":6}
# 6
# ['head-to-head', 'hasimage']
# {"i":139,"p":118,"n":"headtohead","y":8,"o":7}
# 7
# ['single', 'hasimage']
# {"i":142,"p":118,"n":"single","y":8,"o":8}
# 8
# ['mosaic', 'hasimage']
# {"i":144,"p":118,"n":"mosaic","y":8,"o":9}
# 9
# ['single', 'hasimage']
# {"i":148,"p":118,"n":"single","y":8,"o":10}
# 10
# ['mosaic', 'hasimage']
# {"i":150,"p":118,"n":"mosaic","y":8,"o":11}
# 11
# ['single', 'hasimage']
# {"i":154,"p":118,"n":"single","y":8,"o":12}
# 12
# ['single', 'hasimage', 'media', 'photo']
# {"i":156,"p":118,"n":"single","y":8,"o":13}
# 13
# ['mosaic', 'hasimage']
# {"i":158,"p":118,"n":"mosaic","y":8,"o":14}
# 14
# ['head-to-head', 'hasimage']
# {"i":162,"p":118,"n":"headtohead","y":8,"o":15}
# 15
# ['mosaic', 'hasimage', 'media', 'video']
# {"i":165,"p":118,"n":"mosaic","y":8,"o":16}
# 16
# ['single', 'hasimage']
# {"i":169,"p":118,"n":"single","y":8,"o":17}
# 17
# ['single', 'hasimage']
# {"i":171,"p":118,"n":"single","y":8,"o":18}
# 18
# ['single', 'hasimage']
# {"i":173,"p":118,"n":"single","y":8,"o":19}
# 19
# ['single', 'hasimage', 'media', 'photo']
# {"i":175,"p":118,"n":"single","y":8,"o":20}
# 20
# ['mosaic', 'hasimage', 'media', 'photo']
# {"i":177,"p":118,"n":"mosaic","y":8,"o":21}
# 21

# %%
temp.select('img[alt="Business Insider Logo"]')[0].parent.parent
# Out:
# <div class="caption">
# <span aria-label="what cities looked like before the epa regulated pollution-slideshow" class="title">What cities looked like before the EPA regulated pollution</span>
# <span class="sourcename">
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Business Insider        </span>
# </div>

# %%
soup.select('.todaystripe.grid')[0].attrs
# Out:
# {'class': ['todaystripe',
#   'grid',
#   'layout-large',
#   'popnow',
#   'popnow3',
#   'edpicks'],
#  'data-section-id': 'today',
#  'data-module-id': 'startpage|today|todaystripe|today.Hero|todayStripeHeadlines',
#  'data-uipr': '2',
#  'data-aop': 'today.hero_todaystripeheadlines',
#  'data-id': '117',
#  'data-m': '{"i":117,"p":25,"n":"today.Hero","t":"todayStripeHeadlines","o":4}'}

# %%
soup.select('.todaystripe.grid')[0].children.select('li')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-aa3f7b699c7a> in <module>
# ----> 1 soup.select('.todaystripe.grid')[0].children.select('li')
#
# AttributeError: 'list_iterator' object has no attribute 'select'

# %%
for xyz, zyx in enumerate(soup.select('.todaystripe.grid')[0].children):
    print(xyz)
    print(zyx)
# Out:
# 0
#
#
# 1
# <h2 class="hide">Latest Stories</h2>
# 2
#
#
# 3
# <ul>
# <li class="infopane-placeholder">
# <div class="ip infopanestripe slideshow" data-aop="infopane_a_infopanestripeheadlines" data-id="118" data-m='{"i":118,"p":117,"n":"infopane_a","t":"infopaneStripeHeadlines","o":1}' data-module-id="startpage|infopane|infopanestripe|infopane_a|infopaneStripeHeadlines" data-placements="infopane-triptych-1:3;infopane-triptych-2:3;infopane-triptych-3:3;News-Stripe:1;Sports-Stripe:1;Entertainment-Stripe:1;Lifestyle-Stripe:1" data-positions="4,9,12" data-section-id="infopane" data-uipr="1">
# <ul class="swipenav">
# <li class="mosaic hasimage selected" data-aop="slide1&gt;mosaic " data-id="119" data-m='{"i":119,"p":118,"n":"mosaic","y":8,"o":1}' tabindex="0">
# <h3>G-7 SUMMIT</h3>
# <a data-id="120" data-m='{"i":120,"p":119,"n":"HeadlineItemViewModel","y":13,"l":"AAGkZmU","h":0,"v":"news","c":"newsworld","o":1,"s":1}' href="/en-us/news/world/trump-claims-g-7-unity-on-iran-after-unannounced-invite/ar-AAGkZmU?li=BBnb7Kz">
# <img alt="US President Donald Trump reacts during his a bilateral meeting with Egyptian Pr..." onerror="this.className='err'" onload="this.className='loaded'" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlb7b.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2643&amp;y=1269" title="FRANCE-G7-SUMMIT - NICHOLAS KAMM/AFP/Getty Images"/>
# <div class="caption">
# <span aria-label="trump claims g-7 'unity' on iran after unannounced invite-article" class="title">Trump claims G-7 'unity' on Iran after unannounced invite</span>
# <span class="sourcename">
# <img alt="Associated Press Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywufo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Associated Press        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="121" data-m='{"i":121,"p":119,"n":"HeadlineItemViewModel","y":13,"l":"AAGjy2A","h":0,"v":"finance","c":"markets","o":2,"s":1}' href="/en-us/money/markets/trump-offers-contradictory-signals-on-china-trade-war/ar-AAGjy2A?li=BBnb7Kz">
# <img alt="" onerror="this.className='err'" onload="this.className='loaded'" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB10BuL.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=845&amp;y=1287" title="American and Chinese flags - Ng Han Guan / AP"/>
# <div class="caption">
# <span aria-label="trump sends conflicting signs on trade war-article" class="title">Trump sends conflicting signs on trade war</span>
# <span class="sourcename">
# <img alt="The New York Times Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA3l3r5.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The New York Times        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="122" data-m='{"i":122,"p":119,"n":"HeadlineItemViewModel","y":13,"l":"AAGlB1N","h":0,"v":"news","c":"newspolitics","o":3,"s":1}' href="/en-us/news/politics/trump-says-his-miami-golf-resort-a-contender-to-host-next-g-7/ar-AAGlB1N?li=BBnb7Kz">
# <img alt="U.S. President Donald Trump gestures during family photo session at the G7 summi..." onerror="this.className='err'" onload="this.className='loaded'" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlutl.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1100&amp;y=614" title="G7 summit in Biarritz - Christian Hartmann/Pool/ REUTERS"/>
# <div class="caption">
# <span aria-label="trump says his miami resort could host next g-7-article" class="title">Trump says his Miami resort could host next G-7</span>
# <span class="sourcename">
# <img alt="The Hill Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUvpML.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Hill        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="mosaic" data-id="123" data-m='{"i":123,"p":118,"n":"mosaic","y":8,"o":2,"f":"Y_cec865fe-ed84-49a8-b88a-4a23446ea7f1"}' tabindex="0">
# <h3>New York</h3>
# <a data-id="124" data-m='{"i":124,"p":123,"n":"HeadlineItemViewModel","y":13,"l":"AAGk87e","h":2,"v":"news","c":"newsus","o":1}' href="/en-us/news/us/mayor-ras-baraka-silent-as-newark-faces-water-crisis/ar-AAGk87e">
# <img alt="Mayor Ras Baraka silent as Newark faces water crisis" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGk87c.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1037&amp;y=372"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Mayor Ras Baraka silent as Newark faces water crisis - WPIX-TV/TNS"/>
# <div class="caption">
# <span aria-label="mayor ras baraka silent as newark faces water crisis" class="title">Mayor Ras Baraka silent as Newark faces water crisis</span>
# <span class="subtitle">Mayor Ras Baraka silent as Newark faces water crisis</span>
# <span class="sourcename">
# <img alt="WPIX-TV New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTUVWY.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WPIX-TV New York"/>WPIX-TV New York        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="125" data-m='{"i":125,"p":123,"n":"HeadlineItemViewModel","y":13,"l":"AAGlwks","h":3,"v":"travel","c":"travelnews","o":2}' href="/en-us/travel/news/newark-braces-for-heavy-traffic-street-closures-as-mtv-video-music-awards-come-to-town/ar-AAGlwks">
# <img alt="Newark Braces For Heavy Traffic, Street Closures As MTV Video Music Awards Come ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGltF1.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Newark Braces For Heavy Traffic, Street Closures As MTV Vide Music Awards Come T... - Provided by CBS Local, a division of CBS Radio Inc"/>
# <div class="caption">
# <span aria-label="newark braces for heavy traffic, street closures as mtv video music awards come to town" class="title">Newark Braces For Heavy Traffic, Street Closures As MTV Video Music Awards Come To Town</span>
# <span class="subtitle">Newark Braces For Heavy Traffic, Street Closures As MTV Video Music Awards Come To Town</span>
# <span class="sourcename">
# <img alt="CBS New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/AAyW7G9.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="CBS New York"/>CBS New York        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="126" data-m='{"i":126,"p":123,"n":"HeadlineItemViewModel","y":13,"l":"AAG7sWe","h":4,"v":"foodanddrink","c":"newstrends","o":3}' href="/en-us/foodanddrink/foodnews/beloved-brooklyn-pizza-joint-di-fara-shut-down-due-to-unpaid-taxes/ar-AAG7sWe">
# <img alt="Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG7pSj.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes - Provided by Entercom Radio, LLC"/>
# <div class="caption">
# <span aria-label="beloved brooklyn pizza joint di fara shut down due to unpaid taxes" class="title">Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes</span>
# <span class="subtitle">Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes</span>
# <span class="sourcename">
# <img alt="WINS Radio New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTg0tm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WINS Radio New York"/>WINS Radio New York        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="mosaic hasimage" data-aop="slide2&gt;mosaic " data-id="127" data-m='{"i":127,"p":118,"n":"mosaic","y":8,"o":3}' tabindex="0">
# <h3>LATEST NEWS</h3>
# <a data-id="128" data-m='{"i":128,"p":127,"n":"HeadlineItemViewModel","y":13,"l":"AAGkLoy","h":0,"v":"news","c":"newsscienceandtechnology","o":1,"s":1}' href="/en-us/news/technology/nasa-astronaut-accused-of-first-ever-space-crime-denies-allegations/ar-AAGkLoy?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGk7Nk.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=656&amp;y=340"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="NASA investigators probe an astronaut accused of committing a crime in space - Provided by PG Publishing Co., Inc."/>
# <div class="caption">
# <span aria-label="us astronaut accused of first space crime denies claims-article" class="title">US astronaut accused of first space crime denies claims</span>
# <span class="sourcename">
# <img alt="The Next Web Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAla3Lx.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Next Web        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="129" data-m='{"i":129,"p":127,"n":"HeadlineItemViewModel","y":13,"l":"AAGlyy0","h":0,"v":"news","c":"newsworld","o":2,"s":1}' href="/en-us/news/world/brazils-bolsonaro-endorses-sexist-post-about-french-first-lady/ar-AAGlyy0?li=BBnb7Kz">
# <img alt="Bolsonaro endorsed a post mocking the appearance of Brigitte Macron and comparin..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlyxU.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=324&amp;y=229"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Bolsonaro endorsed a post mocking the appearance of Brigitte Macron and comparin... - Thomas SAMSON"/>
# <div class="caption">
# <span aria-label="brazil leader endorses sexist post about macron's wife-article" class="title">Brazil leader endorses sexist post about Macron's wife</span>
# <span class="sourcename">
# <img alt="AFP Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyXiwM.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>AFP        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="130" data-m='{"i":130,"p":127,"n":"HeadlineItemViewModel","y":13,"l":"AAGjCSX","h":0,"v":"weather","c":"weathertopstories","o":3,"s":1}' href="/en-us/weather/topstories/dorian-could-be-hurricane-when-it-reaches-puerto-rico/ar-AAGjCSX?li=BBnb7Kz">
# <img alt="Hurricane Fred is seen near the Cape Verde Islands in this NOAA Goes East satell..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAdO42d.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1030&amp;y=733"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Hurricane Fred is seen near the Cape Verde Islands in this NOAA Goes East satell... - NOAA/Reuters"/>
# <div class="caption">
# <span aria-label="dorian strengthens, could become hurricane-article" class="title">Dorian strengthens, could become hurricane</span>
# <span class="sourcename">
# <img alt="NBC News Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBAJ56P.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>NBC News        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="mosaic hasimage" data-aop="slide3&gt;mosaic " data-id="131" data-m='{"i":131,"p":118,"n":"mosaic","y":8,"o":4}' tabindex="0">
# <h3>POLITICS</h3>
# <a data-id="132" data-m='{"i":132,"p":131,"n":"HeadlineItemViewModel","y":13,"l":"AAGkt6t","h":0,"v":"news","c":"newspolitics","o":1,"s":1}' href="/en-us/news/politics/when-they-go-low-dems-navigating-nasty-race-against-trump/ar-AAGkt6t?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlRIT.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1977&amp;y=939"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="In this Aug. 21, 2019 file photo, Democratic presidential candidate Elizabeth Wa... - Provided by The Associated Press"/>
# <div class="caption">
# <span aria-label="democrats navigating nasty race against trump-article" class="title">Democrats navigating nasty race against Trump</span>
# <span class="sourcename">
# <img alt="Associated Press Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywufo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Associated Press        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="133" data-m='{"i":133,"p":131,"n":"HeadlineItemViewModel","y":13,"l":"AAGlJS1","h":0,"v":"news","c":"newspolitics","o":2,"s":1}' href="/en-us/news/politics/joe-walsh-says-he-is-challenging-trump-to-make-the-moral-case-against-him/ar-AAGlJS1?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlNGi.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=563&amp;y=352"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Walsh: Americans are embarrassed or disgusted with Trump - Provided by Cable News Network, Inc."/>
# <div class="caption">
# <span aria-label="walsh explains why he's challenging trump-article" class="title">Walsh explains why he's challenging Trump</span>
# <span class="sourcename">
# <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNN        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="134" data-m='{"i":134,"p":131,"n":"HeadlineItemViewModel","y":13,"l":"AAGkw1i","h":0,"v":"news","c":"factcheck","o":3,"s":1}' href="/en-us/news/factcheck/ap-fact-check-trumps-illusory-claims-of-gains-from-tariffs/ar-AAGkw1i?li=BBnb7Kz">
# <img alt="U.S President Donald Trump smiles during a news conference with Japanese Prime M..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGkwcz.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2033&amp;y=1416"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="U.S President Donald Trump smiles during a news conference with Japanese Prime M... - Provided by The Associated Press"/>
# <div class="caption">
# <span aria-label="fact check: trump's claims of gains from tariffs-article" class="title">Fact check: Trump's claims of gains from tariffs</span>
# <span class="sourcename">
# <img alt="Associated Press Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywufo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Associated Press        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide4&gt;single " data-id="135" data-m='{"i":135,"p":118,"n":"single","y":8,"o":5}' tabindex="0">
# <a data-id="136" data-m='{"i":136,"p":135,"n":"HeadlineItemViewModel","y":13,"l":"AAGjpTZ","h":0,"v":"sports","c":"football_nfl","o":1,"s":1}' href="/en-us/sports/nfl/retired-nfl-fullback-leron-mcclain-pleads-for-help-i-have-to-get-my-head-checked/ar-AAGjpTZ?li=BBnb7Kz">
# <img alt="Getty" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjg4E.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2618&amp;y=836"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Getty - Getty"/>
# <div class="caption">
# <span aria-label="retired nfl fb pleads for help: ‘i have to get my head checked’-article" class="title">Retired NFL FB pleads for help: ‘I have to get my head checked’</span>
# <span class="sourcename">
# <img alt="For The Win Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAgymO6.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>For The Win        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage media photo" data-aop="slide5&gt;single " data-id="137" data-m='{"i":137,"p":118,"n":"single","y":8,"o":6}' tabindex="0">
# <a class="media photo" data-id="138" data-m='{"i":138,"p":137,"n":"HeadlineItemViewModel","y":13,"l":"AABUaQV","h":0,"v":"health","c":"medical","o":1}' href="/en-us/health/medical/45-sneaky-signs-youre-unhealthier-than-you-may-think/ss-AABUaQV?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AABUcS8.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=652&amp;y=357"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="22. You have shoulder pain. - Provided by Best Life"/>
# <div class="caption">
# <span aria-label="signs you're unhealthier than you think-slideshow" class="title">Signs you're unhealthier than you think</span>
# <span class="sourcename">
# <img alt="Best Life Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAxspu1.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Best Life        </span>
# </div>
# </a>
# </li>
# <li class="head-to-head hasimage" data-aop="slide6&gt;head-to-head " data-id="139" data-m='{"i":139,"p":118,"n":"headtohead","y":8,"o":7}' tabindex="0">
# <a class="nativead" data-id="140" data-m='{"i":140,"p":139,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}' data-pg="1" data-pid="7HD66FC" href="https://www.comparecards.com/guide/pay-0-interest-until-2021?utm_source=msnhp&amp;grp=pay-0-2021&amp;utm_medium=native&amp;pla=www.msn.com&amp;tar=cms&amp;acqs=prospecting&amp;bdst=cpm&amp;esourceid=6381636&amp;utm_campaign=20190826&amp;utm_content=get+almost+2+years+interestfree+with+1+of+these+cards&amp;adt=hatcoffeegirl&amp;c3=am&amp;mtaid=5E29E&amp;placement_name=cms&amp;ad_headline=get+almost+2+years+interestfree+with+1+of+these+cards&amp;ad_image_name=hatcoffeegirl&amp;ad_group_name=pay-0-2021&amp;campaign_date=20190826&amp;day_part=am" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AABDJeL.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=412&amp;y=134"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="hatcoffeegirl"/>
# <div class="caption">
# <span aria-label="get almost 2 years interest-free with 1 of these cards-article" class="title">Get almost 2 years interest-free with 1 of these cards</span>
# <span class="sourcename">
# <span class="adslabel" title="Ad">Ad</span>
# CompareCards        </span>
# </div>
# </a>
# <a class="nativead" data-id="141" data-m='{"i":141,"p":139,"n":"NativeAdHeadlineItemViewModel","y":13,"o":2}' data-pg="1" data-pid="7HD66FC" href="https://www.comparecards.com/guide/pay-0-interest-until-2021?utm_source=msnhp&amp;grp=pay-0-2021&amp;utm_medium=native&amp;pla=www.msn.com&amp;tar=cms&amp;acqs=prospecting&amp;bdst=cpm&amp;esourceid=6381636&amp;utm_campaign=20190826&amp;utm_content=3+cards+offering+0+interest+for+18+months&amp;adt=flaggcc5&amp;c3=am&amp;mtaid=5E29E&amp;placement_name=cms&amp;ad_headline=3+cards+offering+0+interest+for+18+months&amp;ad_image_name=flaggcc5&amp;ad_group_name=pay-0-2021&amp;campaign_date=20190826&amp;day_part=am" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAxOc9T.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <div class="caption">
# <span aria-label="3 cards offering 0% interest for 18 months-article" class="title">3 cards offering 0% interest for 18 months</span>
# <span class="sourcename">
# <span class="adslabel" title="Ad">Ad</span>
# CompareCards        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage" data-aop="slide7&gt;single " data-id="142" data-m='{"i":142,"p":118,"n":"single","y":8,"o":8}' tabindex="0">
# <a data-id="143" data-m='{"i":143,"p":142,"n":"HeadlineItemViewModel","y":13,"l":"AAG8wJU","h":0,"v":"news","c":"newsus","o":1,"s":1}' href="/en-us/news/us/american-slavery-began-in-1619-project-documents-brutal-journey/ar-AAG8wJU?li=BBnb7Kz">
# <img alt="The founding family you’ve never heard of: The black Tuckers of Hampton, Virgini..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG8PMN.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The founding family you’ve never heard of: The black Tuckers of Hampton, Virgini... - Provided by USA TODAY, a division of Gannett Satellite Information Network, Inc."/>
# <div class="caption">
# <span aria-label="how an accidental encounter brought slavery to the us-article" class="title">How an accidental encounter brought slavery to the US</span>
# <span class="sourcename">
# <img alt="USA TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBNvr53.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage" data-aop="slide8&gt;mosaic " data-id="144" data-m='{"i":144,"p":118,"n":"mosaic","y":8,"o":9}' tabindex="0">
# <h3>NFL BUZZ</h3>
# <a data-id="145" data-m='{"i":145,"p":144,"n":"HeadlineItemViewModel","y":13,"l":"AAGlK61","h":0,"v":"sports","c":"football_nfl","o":1,"s":1}' href="/en-us/sports/nfl/troy-aikman-rips-into-doug-gottlieb-over-andrew-luck-tweet/ar-AAGlK61?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlOPs.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1233&amp;y=778"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Troy Aikman rips into Doug Gottlieb over Andrew Luck tweet - Denny Medley-USA TODAY Sports"/>
# <div class="caption">
# <span aria-label="aikman blasts fellow fox analyst over luck tweet-article" class="title">Aikman blasts fellow FOX analyst over Luck tweet</span>
# <span class="sourcename">
# <img alt="Larry Brown Sports Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBjLpNF.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Larry Brown Sports        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="146" data-m='{"i":146,"p":144,"n":"HeadlineItemViewModel","y":13,"l":"AAGjDCh","h":0,"v":"sports","c":"football_nfl","o":2,"s":1}' href="/en-us/sports/nfl/nfl-fans-immediately-ripped-nbcs-weird-camera-angle-for-the-steelers-titans-game/ar-AAGjDCh?li=BBnb7Kz">
# <img alt="File Photo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjtHZ.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1402&amp;y=662"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="File Photo - File Photo"/>
# <div class="caption">
# <span aria-label="nfl fans blast nbc's 'high sky' view-article" class="title">NFL fans blast NBC's 'High Sky' view</span>
# <span class="sourcename">
# <img alt="For The Win Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAgymO6.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>For The Win        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="147" data-m='{"i":147,"p":144,"n":"HeadlineItemViewModel","y":13,"l":"AAGjBL0","h":0,"v":"sports","c":"football_nfl","o":3,"s":1}' href="/en-us/sports/nfl/winners-and-losers-from-nfl-preseason-week-3/ar-AAGjBL0?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjRvu.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1354&amp;y=721"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Winners and losers from NFL preseason Week 3 - Jim Brown-USA TODAY Sports"/>
# <div class="caption">
# <span aria-label="winners and losers from nfl preseason week 3-article" class="title">Winners and losers from NFL preseason Week 3</span>
# <span class="sourcename">
# <img alt="Sportsnaut Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBjLpNF.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Sportsnaut        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide9&gt;single " data-id="148" data-m='{"i":148,"p":118,"n":"single","y":8,"o":10}' tabindex="0">
# <a data-id="149" data-m='{"i":149,"p":148,"n":"HeadlineItemViewModel","y":13,"l":"AAGkaCQ","h":0,"v":"finance","c":"finance-career","o":1,"s":1}' href="/en-us/money/career/this-is-americas-no-1-college-major-for-salary-and-job-availability/ar-AAGkaCQ?li=BBnb7Kz">
# <img alt="The best majors to go from higher education to ready for hire. " data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGkt3z.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=424&amp;y=249"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The best majors to go from higher education to ready for hire. - Samuel Goldwyn Films/courtesy Everett Collection"/>
# <div class="caption">
# <span aria-label="this is america’s no. 1 college major for salary and job availability-article" class="title">This is America’s No. 1 college major for salary and job availability</span>
# <span class="sourcename">
# <img alt="MarketWatch Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBqlEdK.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>MarketWatch        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage" data-aop="slide10&gt;mosaic " data-id="150" data-m='{"i":150,"p":118,"n":"mosaic","y":8,"o":11}' tabindex="0">
# <h3>CELEB NEWS</h3>
# <a data-id="151" data-m='{"i":151,"p":150,"n":"HeadlineItemViewModel","y":13,"l":"AAGlJus","h":0,"v":"tv","c":"tvnews","o":1,"s":1}' href="/en-us/tv/news/gmas-lara-spencer-apologizes-on-air-for-mocking-prince-georges-ballet-lessons-my-comment-was-stupid-and-insensitive-watch-video/ar-AAGlJus?li=BBnb7Kz">
# <img alt="Lara Spencer attends 'Good Morning America' at SummerStage at Rumsey Playfield, ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlOEz.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=936&amp;y=527"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Lara Spencer - Noam Galai/Getty Images"/>
# <div class="caption">
# <span aria-label="spencer apologizes on-air for 'stupid' ballet remarks-article" class="title">Spencer apologizes on-air for 'stupid' ballet remarks</span>
# <span class="sourcename">
# <img alt="TVLine Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB1w6aD.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>TVLine        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="152" data-m='{"i":152,"p":150,"n":"HeadlineItemViewModel","y":13,"l":"AAGjDzo","h":0,"v":"tv","c":"tvnews","o":2,"s":1}' href="/en-us/tv/news/big-bang-theorys-johnny-galecki-teases-return-to-the-conners-in-season-2/ar-AAGjDzo?li=BBnb7Kz">
# <img alt="Big Bang Theory's Johnny Galecki teases return to 'The Conners' in season 2" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjKx0.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1303&amp;y=670"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Big Bang Theory's Johnny Galecki teases return to 'The Conners' in season 2 - Jason LaVeris/FilmMagic"/>
# <div class="caption">
# <span aria-label="galecki teases return to 'the conners'-article" class="title">Galecki teases return to 'The Conners'</span>
# <span class="sourcename">
# <img alt="Entertainment Weekly Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAesHLQ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Entertainment Weekly        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="153" data-m='{"i":153,"p":150,"n":"HeadlineItemViewModel","y":13,"l":"AAGkslt","h":0,"v":"movies","c":"movies-celebrity","o":3,"s":1}' href="/en-us/movies/celebrity/charlize-theron-shares-rare-photo-of-one-of-her-kids-from-vacation/ar-AAGkslt?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGkXdY.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=312&amp;y=124"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="https://www.gannett-cdn.com/presto/2019/08/26/USAT/d73cc819-1550-40ba-80be-dced5... - Provided by USA TODAY, a division of Gannett Satellite Information Network, Inc."/>
# <div class="caption">
# <span aria-label="charlize theron posts rare pic of one of her kids-article" class="title">Charlize Theron posts rare pic of one of her kids</span>
# <span class="sourcename">
# <img alt="USA TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBNvr53.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide11&gt;single " data-id="154" data-m='{"i":154,"p":118,"n":"single","y":8,"o":12}' tabindex="0">
# <a data-id="155" data-m='{"i":155,"p":154,"n":"HeadlineItemViewModel","y":13,"l":"AAGlI3B","h":0,"v":"news","c":"newspolitics","o":1,"s":1}' href="/en-us/news/politics/trump-denies-that-he-suggested-nuking-hurricanes-but-the-government-once-studied-the-idea/ar-AAGlI3B?li=BBnb7Kz">
# <img alt="President Trump speaks with reporters as he walks to Marine One on the South Law..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGloVg.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2103&amp;y=1073"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="President Trump speaks with reporters as he walks to Marine One on the South Law... - Alex Brandon/AP"/>
# <div class="caption">
# <span aria-label="trump denies suggesting nuking hurricanes, but u.s. once studied it-article" class="title">Trump denies suggesting nuking hurricanes, but U.S. once studied it</span>
# <span class="sourcename">
# <img alt="The Washington Post Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyxkRJ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Washington Post        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage media photo" data-aop="slide12&gt;single " data-id="156" data-m='{"i":156,"p":118,"n":"single","y":8,"o":13}' tabindex="0">
# <a class="media photo" data-id="157" data-m='{"i":157,"p":156,"n":"HeadlineItemViewModel","y":13,"l":"AAFNWId","h":0,"v":"news","c":"newsus","o":1,"s":1}' href="/en-us/news/us/35-vintage-photos-taken-by-the-epa-reveal-what-american-cities-looked-like-before-pollution-was-regulated/ss-AAFNWId?li=BBnb7Kz">
# <img alt='New York is one of the most photographed cities for "The Documerica Project." He...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFNKU6.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title='New York is one of the most photographed cities for "The Documerica Project." He... - Gary Miller / EPA'/>
# <div class="caption">
# <span aria-label="what cities looked like before the epa regulated pollution-slideshow" class="title">What cities looked like before the EPA regulated pollution</span>
# <span class="sourcename">
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Business Insider        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage" data-aop="slide13&gt;mosaic " data-id="158" data-m='{"i":158,"p":118,"n":"mosaic","y":8,"o":14}' tabindex="0">
# <h3>AMAZON FIRES</h3>
# <a data-id="159" data-m='{"i":159,"p":158,"n":"HeadlineItemViewModel","y":13,"l":"AAGl5GO","h":0,"v":"news","c":"newsworld","o":1,"s":1}' href="/en-us/news/world/all-you-can-see-is-death-the-regions-reeling-from-the-amazon-rainforest-fires/ar-AAGl5GO?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGl5Gr.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="'All you can see is death.' The regions reeling from the Amazon rainforest fires - Natalie Gallón/CNN"/>
# <div class="caption">
# <span aria-label="'all you can see is death.' regions reeling from fires-article" class="title">'All you can see is death.' Regions reeling from fires</span>
# <span class="sourcename">
# <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNN        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="160" data-m='{"i":160,"p":158,"n":"HeadlineItemViewModel","y":13,"l":"AAGlC71","h":0,"v":"news","c":"newsworld","o":2,"s":1}' href="/en-us/news/world/g7-to-finance-fire-fighting-aircraft-for-amazon/ar-AAGlC71?li=BBnb7Kz">
# <img alt="Nearly 80,000 forest fires have been detected in Brazil since the beginning of t..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlEvf.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Nearly 80,000 forest fires have been detected in Brazil since the beginning of t... - Victor MORIYAMA"/>
# <div class="caption">
# <span aria-label="g-7 leaders pledge $22 million to fight fires-article" class="title">G-7 leaders pledge $22 million to fight fires</span>
# <span class="sourcename">
# <img alt="AFP Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyXiwM.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>AFP        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="161" data-m='{"i":161,"p":158,"n":"HeadlineItemViewModel","y":13,"l":"AAGd2xy","h":0,"v":"news","c":"newsworld","o":3,"s":1}' href="/en-us/news/world/what-you-can-do-to-help-the-burning-amazon-rainforest/ar-AAGd2xy?li=BBnb7Kz">
# <img alt="Amazon jungle fire" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG66S6.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1294&amp;y=900"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="A tract of Amazon jungle is seen burning as it is being cleared by loggers and f... - Reuters"/>
# <div class="caption">
# <span aria-label="what you can do to help the amazon rainforest-article" class="title">What you can do to help the Amazon rainforest</span>
# <span class="sourcename">
# <img alt="CBS News Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAy3CUU.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CBS News        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="head-to-head hasimage" data-aop="slide14&gt;head-to-head " data-id="162" data-m='{"i":162,"p":118,"n":"headtohead","y":8,"o":15}' tabindex="0">
# <h3>LUCK RETIRES</h3>
# <a data-id="163" data-m='{"i":163,"p":162,"n":"HeadlineItemViewModel","y":13,"l":"AAGjDdN","h":0,"v":"sports","c":"football_nfl","o":1,"s":1}' href="/en-us/sports/nfl/years-of-exhaustion-in-andrew-lucks-football-life-forced-him-to-carry-out-a-vow/ar-AAGjDdN?li=BBnb7Kz">
# <img alt="Andrew Luck said goodbye to the NFL on Saturday night, to the shock of the sport..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjDdJ.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1630&amp;y=1061"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="INDIANAPOLIS, IN - AUGUST 24: Andrew Luck #12 of the Indianapolis Colts watches ... - Provided by Oath Inc."/>
# <div class="caption">
# <span aria-label="years of football exhaustion forced luck to carry out vow-article" class="title">Years of football exhaustion forced Luck to carry out vow</span>
# <span class="sourcename">
# <img alt="Yahoo! Sports Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBPMoha.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Yahoo! Sports        </span>
# </div>
# </a>
# <a data-id="164" data-m='{"i":164,"p":162,"n":"HeadlineItemViewModel","y":13,"l":"AAGlPYC","h":0,"v":"sports","c":"football_nfl","o":2,"s":1}' href="/en-us/sports/nfl/nfl-andrew-luck-retirement-spurs-emotional-tweet-from-wr-ty-hilton/ar-AAGlPYC?li=BBnb7Kz">
# <img alt="INDIANAPOLIS, IN - AUGUST 17: T.Y. Hilton #13 of the Indianapolis Colts is seen ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlTky.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1947&amp;y=1342"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Cleveland Browns v Indianapolis Colts - Michael Hickey/Getty Images"/>
# <div class="caption">
# <span aria-label="colts receiver posts emotional farewell to luck-article" class="title">Colts receiver posts emotional farewell to Luck</span>
# <span class="sourcename">
# <img alt="USA TODAY SPORTS Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB4kwAp.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY SPORTS        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage media video" data-aop="slide15&gt;mosaic " data-id="165" data-m='{"i":165,"p":118,"n":"mosaic","y":8,"o":16}' tabindex="0">
# <h3>ICYMI VIDEOS</h3>
# <a data-id="166" data-m='{"i":166,"p":165,"n":"HeadlineItemViewModel","y":13,"l":"AAGe6EY","h":0,"v":"video","c":"viral","o":1,"s":1}' href="/en-us/video/viral/retirees-skip-fishing-to-go-golfing-trout-falls-from-the-sky-as-they-tee-off/vi-AAGe6EY">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGeiIc.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=582&amp;y=153"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Retirees Skip Fishing to Go Golfing, Trout Falls From the Sky as They Tee Off - Provided by Zazoom, LLC"/>
# <div class="caption">
# <span aria-label="retirees skip fishing to go golfing, trout falls from sky-video" class="title">Retirees skip fishing to go golfing, trout falls from sky</span>
# <span class="sourcename">
# <img alt="Buzz60 Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BByCIyx.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Buzz60        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="167" data-m='{"i":167,"p":165,"n":"HeadlineItemViewModel","y":13,"l":"AAG7HEt","h":0,"v":"video","c":"animals","o":2,"s":1}' href="/en-us/video/animals/giant-bison-slams-into-car-at-yellowstone-during-stampede/vi-AAG7HEt">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG7K3S.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=765&amp;y=638"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Giant bison slams into car at Yellowstone during stampede - Provided by USA TODAY, a division of Gannett Satellite Information Network, Inc."/>
# <div class="caption">
# <span aria-label="giant bison slams into car at yellowstone-video" class="title">Giant bison slams into car at Yellowstone</span>
# <span class="sourcename">
# <img alt="USA TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBNvr53.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="168" data-m='{"i":168,"p":165,"n":"HeadlineItemViewModel","y":13,"l":"AAGdOMe","h":0,"v":"video","c":"viral","o":3,"s":1}' href="/en-us/video/viral/illinois-police-traffic-stop-turns-into-marriage-proposal/vi-AAGdOMe">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlwsU.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=346&amp;y=271"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Illinois police traffic stop turns into marriage proposal"/>
# <div class="caption">
# <span aria-label="police traffic stop turns into marriage proposal-video" class="title">Police traffic stop turns into marriage proposal</span>
# <span class="sourcename">
# <img alt="Storyful Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB1Qgoh.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Storyful        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide16&gt;single " data-id="169" data-m='{"i":169,"p":118,"n":"single","y":8,"o":17}' tabindex="0">
# <a data-id="170" data-m='{"i":170,"p":169,"n":"HeadlineItemViewModel","y":13,"l":"AAGj2cb","h":0,"v":"weather","c":"weathertopstories","o":1,"s":1}' href="/en-us/weather/topstories/a-giant-pumice-stone-floating-in-the-pacific-could-help-heal-australias-great-barrier-reef/ar-AAGj2cb?li=BBnb7Kz">
# <img alt="pumice raft seen by NASA's Terra satellite on August 13 2019" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGj2c8.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=515&amp;y=328"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="pumice raft seen by NASA's Terra satellite on August 13 2019 - NASA's Terra satellite"/>
# <div class="caption">
# <span aria-label="a giant pumice stone floating in the pacific could help heal australia's great barrier reef-article" class="title">A giant pumice stone floating in the Pacific could help heal Australia's Great Barrier Reef</span>
# <span class="sourcename">
# <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNN        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage" data-aop="slide17&gt;single " data-id="171" data-m='{"i":171,"p":118,"n":"single","y":8,"o":18}' tabindex="0">
# <a data-id="172" data-m='{"i":172,"p":171,"n":"HeadlineItemViewModel","y":13,"l":"AAGjtg2","h":0,"v":"finance","c":"markets","o":1,"s":1}' href="/en-us/money/markets/trump-wants-us-companies-to-leave-china-heres-what-it-could-mean-for-chinese-businesses/ar-AAGjtg2?li=BBnb7Kz">
# <img alt="A Chinese denim factory" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjHKJ.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=984&amp;y=311"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="A Chinese denim factory - Provided by CNBC LLC"/>
# <div class="caption">
# <span aria-label="trump wants us companies to leave china. what could that mean for china's businesses?-article" class="title">Trump wants US companies to leave China. What could that mean for China's businesses?</span>
# <span class="sourcename">
# <img alt="CNBC Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA3ltd8.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNBC        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage" data-aop="slide18&gt;single " data-id="173" data-m='{"i":173,"p":118,"n":"single","y":8,"o":19}' tabindex="0">
# <a data-id="174" data-m='{"i":174,"p":173,"n":"HeadlineItemViewModel","y":13,"l":"AAGjpUh","h":0,"v":"news","c":"newsworld","o":1,"s":1}' href="/en-us/news/world/environmentalists-filmed-irans-vanishing-cheetahs-now-they-could-be-executed-for-spying/ar-AAGjpUh?li=BBnb7Kz">
# <img alt="This photograph of an Asiatic cheetah was taken by a low-resolution camera trap,..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjust.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1557&amp;y=731"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="This photograph of an Asiatic cheetah was taken by a low-resolution camera trap,... - Frans Lanting/National Geographic Image Collection"/>
# <div class="caption">
# ...
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagbjth-en-us-campaign-enus-amp-2-label" aria-posinset="3" aria-setsize="4" role="radio">
# <input data-id="310" data-m='{"i":310,"p":272,"n":"poll_answer","y":10,"o":38}' id="pa-aagbjth-en-us-campaign-enus-amp-2" name="pa-aagbjth-en-us-campaign-enus-amp" type="radio" value="2"/>
# <label class="answer" for="pa-aagbjth-en-us-campaign-enus-amp-2" id="pa-aagbjth-en-us-campaign-enus-amp-2-label"><span class="radio-icon"><span></span></span>Ford</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagbjth-en-us-campaign-enus-amp-3-label" aria-posinset="4" aria-setsize="4" role="radio">
# <input data-id="311" data-m='{"i":311,"p":272,"n":"poll_answer","y":10,"o":39}' id="pa-aagbjth-en-us-campaign-enus-amp-3" name="pa-aagbjth-en-us-campaign-enus-amp" type="radio" value="3"/>
# <label class="answer" for="pa-aagbjth-en-us-campaign-enus-amp-3" id="pa-aagbjth-en-us-campaign-enus-amp-3-label"><span class="radio-icon"><span></span></span>Cadillac</label>
# </li>
# </ul>
# <div class="ctr"><button data-id="312" data-m='{"i":312,"p":272,"n":"poll_submit","y":11,"o":40}' disabled="disabled" id="poll-button-aagbjth-en-us-campaign-enus-amp" name="vote">ANSWER</button></div>
# </div>
# </form>
# <div class="results">
# <header>
# <button aria-label="previous quiz results" class="prev" type="button">Previous</button>
# <h3>QUIZ RESULTS</h3>
# <button aria-label="next quiz results" class="next" type="button">Next</button>
# </header>
# <h4>Go further</h4>
# <ul>
# <li>
# <div class="resultsdivpadding">
# <div class="value">36%</div>
# <div class="answer">Buick<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="36" class="meter" role="progressbar" style="width:36%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">25%</div>
# <div class="answer">Chevrolet <div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="25" class="meter" role="progressbar" style="width:25%;"></div></div>
# </div>
# </div>
# </li>
# <li class="correct">
# <div class="resultsdivpadding">
# <div class="value">18%</div>
# <div class="answer">Ford<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="18" class="meter" role="progressbar" style="width:18%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">21%</div>
# <div class="answer">Cadillac<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="21" class="meter" role="progressbar" style="width:21%;"></div></div>
# </div>
# </div>
# </li>
# </ul>
# <div class="ctr">
# <footer>
# <p>Total responses: 52,441 votes</p>
# </footer>
# </div>
# </div>
# </div>
# <div class="poll" data-pollresultsuptodate="True">
# <form aria-label="tagline quiz" tabindex="0">
# <header>
# <button aria-label="previous tagline quiz" class="prev" type="button">Previous</button>
# <h3>TAGLINE QUIZ</h3>
# <button aria-label="next tagline quiz" class="next" type="button">Next</button>
# </header>
# <div class="questions" data-action="https://ratingsedge.rnr.microsoft.com/v1.0/ratingsedge/polls/vote/aagegbb-en-us-campaign-enus-amp/" id="poll-aagegbb-en-us-campaign-enus-amp">
# <h4 id="pollquestion-aagegbb-en-us-campaign-enus-amp">Think big</h4>
# <ul aria-labelledby="pollquestion-aagegbb-en-us-campaign-enus-amp" role="radiogroup">
# <li aria-checked="false" aria-labelledby="pa-aagegbb-en-us-campaign-enus-amp-0-label" aria-posinset="1" aria-setsize="4" role="radio">
# <input data-id="313" data-m='{"i":313,"p":272,"n":"poll_answer","y":10,"o":41}' id="pa-aagegbb-en-us-campaign-enus-amp-0" name="pa-aagegbb-en-us-campaign-enus-amp" type="radio" value="0"/>
# <label class="answer" for="pa-aagegbb-en-us-campaign-enus-amp-0" id="pa-aagegbb-en-us-campaign-enus-amp-0-label"><span class="radio-icon"><span></span></span>Imax</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagegbb-en-us-campaign-enus-amp-1-label" aria-posinset="2" aria-setsize="4" role="radio">
# <input data-id="314" data-m='{"i":314,"p":272,"n":"poll_answer","y":10,"o":42}' id="pa-aagegbb-en-us-campaign-enus-amp-1" name="pa-aagegbb-en-us-campaign-enus-amp" type="radio" value="1"/>
# <label class="answer" for="pa-aagegbb-en-us-campaign-enus-amp-1" id="pa-aagegbb-en-us-campaign-enus-amp-1-label"><span class="radio-icon"><span></span></span>Apple</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagegbb-en-us-campaign-enus-amp-2-label" aria-posinset="3" aria-setsize="4" role="radio">
# <input data-id="315" data-m='{"i":315,"p":272,"n":"poll_answer","y":10,"o":43}' id="pa-aagegbb-en-us-campaign-enus-amp-2" name="pa-aagegbb-en-us-campaign-enus-amp" type="radio" value="2"/>
# <label class="answer" for="pa-aagegbb-en-us-campaign-enus-amp-2" id="pa-aagegbb-en-us-campaign-enus-amp-2-label"><span class="radio-icon"><span></span></span>IBM</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagegbb-en-us-campaign-enus-amp-3-label" aria-posinset="4" aria-setsize="4" role="radio">
# <input data-id="316" data-m='{"i":316,"p":272,"n":"poll_answer","y":10,"o":44}' id="pa-aagegbb-en-us-campaign-enus-amp-3" name="pa-aagegbb-en-us-campaign-enus-amp" type="radio" value="3"/>
# <label class="answer" for="pa-aagegbb-en-us-campaign-enus-amp-3" id="pa-aagegbb-en-us-campaign-enus-amp-3-label"><span class="radio-icon"><span></span></span>Sony</label>
# </li>
# </ul>
# <div class="ctr"><button data-id="317" data-m='{"i":317,"p":272,"n":"poll_submit","y":11,"o":45}' disabled="disabled" id="poll-button-aagegbb-en-us-campaign-enus-amp" name="vote">ANSWER</button></div>
# </div>
# </form>
# <div class="results">
# <header>
# <button aria-label="previous quiz results" class="prev" type="button">Previous</button>
# <h3>QUIZ RESULTS</h3>
# <button aria-label="next quiz results" class="next" type="button">Next</button>
# </header>
# <h4>Think big</h4>
# <ul>
# <li class="correct">
# <div class="resultsdivpadding">
# <div class="value">24%</div>
# <div class="answer">Imax<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="24" class="meter" role="progressbar" style="width:24%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">38%</div>
# <div class="answer">Apple<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="38" class="meter" role="progressbar" style="width:38%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">32%</div>
# <div class="answer">IBM<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="32" class="meter" role="progressbar" style="width:32%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">6%</div>
# <div class="answer">Sony<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="6" class="meter" role="progressbar" style="width:6%;"></div></div>
# </div>
# </div>
# </li>
# </ul>
# <div class="ctr">
# <footer>
# <p>Total responses: 51,299 votes</p>
# </footer>
# </div>
# </div>
# </div>
# <div class="poll" data-pollresultsuptodate="True">
# <form aria-label="tagline quiz" tabindex="0">
# <header>
# <button aria-label="previous tagline quiz" class="prev" type="button">Previous</button>
# <h3>TAGLINE QUIZ</h3>
# <button aria-label="next tagline quiz" class="next" disabled="disabled" type="button">Next</button>
# </header>
# <div class="questions" data-action="https://ratingsedge.rnr.microsoft.com/v1.0/ratingsedge/polls/vote/aagbaza-en-us-campaign-enus-amp/" id="poll-aagbaza-en-us-campaign-enus-amp">
# <h4 id="pollquestion-aagbaza-en-us-campaign-enus-amp">Share moments. Share life.</h4>
# <ul aria-labelledby="pollquestion-aagbaza-en-us-campaign-enus-amp" role="radiogroup">
# <li aria-checked="false" aria-labelledby="pa-aagbaza-en-us-campaign-enus-amp-0-label" aria-posinset="1" aria-setsize="4" role="radio">
# <input data-id="318" data-m='{"i":318,"p":272,"n":"poll_answer","y":10,"o":46}' id="pa-aagbaza-en-us-campaign-enus-amp-0" name="pa-aagbaza-en-us-campaign-enus-amp" type="radio" value="0"/>
# <label class="answer" for="pa-aagbaza-en-us-campaign-enus-amp-0" id="pa-aagbaza-en-us-campaign-enus-amp-0-label"><span class="radio-icon"><span></span></span>Facebook</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagbaza-en-us-campaign-enus-amp-1-label" aria-posinset="2" aria-setsize="4" role="radio">
# <input data-id="319" data-m='{"i":319,"p":272,"n":"poll_answer","y":10,"o":47}' id="pa-aagbaza-en-us-campaign-enus-amp-1" name="pa-aagbaza-en-us-campaign-enus-amp" type="radio" value="1"/>
# <label class="answer" for="pa-aagbaza-en-us-campaign-enus-amp-1" id="pa-aagbaza-en-us-campaign-enus-amp-1-label"><span class="radio-icon"><span></span></span>Twitter</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagbaza-en-us-campaign-enus-amp-2-label" aria-posinset="3" aria-setsize="4" role="radio">
# <input data-id="320" data-m='{"i":320,"p":272,"n":"poll_answer","y":10,"o":48}' id="pa-aagbaza-en-us-campaign-enus-amp-2" name="pa-aagbaza-en-us-campaign-enus-amp" type="radio" value="2"/>
# <label class="answer" for="pa-aagbaza-en-us-campaign-enus-amp-2" id="pa-aagbaza-en-us-campaign-enus-amp-2-label"><span class="radio-icon"><span></span></span>Instagram</label>
# </li>
# <li aria-checked="false" aria-labelledby="pa-aagbaza-en-us-campaign-enus-amp-3-label" aria-posinset="4" aria-setsize="4" role="radio">
# <input data-id="321" data-m='{"i":321,"p":272,"n":"poll_answer","y":10,"o":49}' id="pa-aagbaza-en-us-campaign-enus-amp-3" name="pa-aagbaza-en-us-campaign-enus-amp" type="radio" value="3"/>
# <label class="answer" for="pa-aagbaza-en-us-campaign-enus-amp-3" id="pa-aagbaza-en-us-campaign-enus-amp-3-label"><span class="radio-icon"><span></span></span>Kodak</label>
# </li>
# </ul>
# <div class="ctr"><button data-id="322" data-m='{"i":322,"p":272,"n":"poll_submit","y":11,"o":50}' disabled="disabled" id="poll-button-aagbaza-en-us-campaign-enus-amp" name="vote">ANSWER</button></div>
# </div>
# </form>
# <div class="results">
# <header>
# <button aria-label="previous quiz results" class="prev" type="button">Previous</button>
# <h3>QUIZ RESULTS</h3>
# <button aria-label="next quiz results" class="next" disabled="disabled" type="button">Next</button>
# </header>
# <h4>Share moments. Share life.</h4>
# <ul>
# <li>
# <div class="resultsdivpadding">
# <div class="value">19%</div>
# <div class="answer">Facebook<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="19" class="meter" role="progressbar" style="width:19%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">4%</div>
# <div class="answer">Twitter<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="4" class="meter" role="progressbar" style="width:4%;"></div></div>
# </div>
# </div>
# </li>
# <li>
# <div class="resultsdivpadding">
# <div class="value">17%</div>
# <div class="answer">Instagram<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="17" class="meter" role="progressbar" style="width:17%;"></div></div>
# </div>
# </div>
# </li>
# <li class="correct">
# <div class="resultsdivpadding">
# <div class="value">60%</div>
# <div class="answer">Kodak<div class="bar"><div aria-valuemax="100" aria-valuemin="0" aria-valuenow="60" class="meter" role="progressbar" style="width:60%;"></div></div>
# </div>
# </div>
# </li>
# </ul>
# <div class="ctr">
# <footer>
# <p>Total responses: 50,443 votes</p>
# <a data-id="323" data-m='{"i":323,"p":272,"n":"PollModuleResultTextLink","y":14,"o":51}' href="https://www.bing.com/search?q=bing+homepage+quiz&amp;form=MY0172&amp;OCID=MY0172" target="_blank">
# <span>Take the Daily Bing Quiz!</span>
# </a>
# </footer>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="pick pick4">
# <div class="editorialheadline pipedheadlinelistwithimage entertainment adlinks" data-id="324" data-m='{"i":324,"p":117,"n":"adLinkModule","t":"editorialPopularNowTopic","o":16}' data-module-id="startpage|today|todaystripe|adLinkModule|editorialPopularNowTopic">
# <h3><a data-id="325" data-m='{"i":325,"p":324,"n":"Play Free Online Games","y":13,"o":1}' href="https://www.msn.com/en-us/entertainment/onlinegames">Play Free Online Games</a></h3>
# <ul>
# <li>
# <ul>
# <li class="">
# <a data-id="326" data-m='{"i":326,"p":324,"n":"HeadlineItemViewModel","y":13,"o":2}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=ogname" target="_blank">
# Try a daily challenge </a>
# </li>
# <li class="headline-img-container">
# <a data-id="327" data-m='{"i":327,"p":324,"n":"HeadlineItemViewModel","y":13,"o":3}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFrs.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Solitaire Collection - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="">
# <a data-id="328" data-m='{"i":328,"p":324,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=ogname" target="_blank">
# Keep your mind sharp </a>
# </li>
# <li class="headline-img-container">
# <a data-id="329" data-m='{"i":329,"p":324,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAE8xlk.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Games - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="">
# <a data-id="330" data-m='{"i":330,"p":324,"n":"HeadlineItemViewModel","y":13,"o":6}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=ogname" target="_blank">
# Connect tiles to make words </a>
# </li>
# <li class="headline-img-container">
# <a data-id="331" data-m='{"i":331,"p":324,"n":"HeadlineItemViewModel","y":13,"o":7}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBV4sWb.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Wordament - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="">
# <a data-id="332" data-m='{"i":332,"p":324,"n":"HeadlineItemViewModel","y":13,"o":8}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=ogname" target="_blank">
# Test your game skills </a>
# </li>
# <li class="headline-img-container">
# <a data-id="333" data-m='{"i":333,"p":324,"n":"HeadlineItemViewModel","y":13,"o":9}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFvK.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Mahjong - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="">
# <a data-id="334" data-m='{"i":334,"p":324,"n":"HeadlineItemViewModel","y":13,"o":10}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=ogname" target="_blank">
# Ready for a quick game? </a>
# </li>
# <li class="headline-img-container">
# <a data-id="335" data-m='{"i":335,"p":324,"n":"HeadlineItemViewModel","y":13,"o":11}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUE38v.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="All Games - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# 4

# %%
for xyz in soup.select('.todaystripe.grid')[0].descendants:
    print(xyz)
# Out:
# <h2 class="hide">Latest Stories</h2>
# Latest Stories
#
#
# <ul>
# <li class="infopane-placeholder">
# <div class="ip infopanestripe slideshow" data-aop="infopane_a_infopanestripeheadlines" data-id="118" data-m='{"i":118,"p":117,"n":"infopane_a","t":"infopaneStripeHeadlines","o":1}' data-module-id="startpage|infopane|infopanestripe|infopane_a|infopaneStripeHeadlines" data-placements="infopane-triptych-1:3;infopane-triptych-2:3;infopane-triptych-3:3;News-Stripe:1;Sports-Stripe:1;Entertainment-Stripe:1;Lifestyle-Stripe:1" data-positions="4,9,12" data-section-id="infopane" data-uipr="1">
# <ul class="swipenav">
# <li class="mosaic hasimage selected" data-aop="slide1&gt;mosaic " data-id="119" data-m='{"i":119,"p":118,"n":"mosaic","y":8,"o":1}' tabindex="0">
# <h3>G-7 SUMMIT</h3>
# <a data-id="120" data-m='{"i":120,"p":119,"n":"HeadlineItemViewModel","y":13,"l":"AAGkZmU","h":0,"v":"news","c":"newsworld","o":1,"s":1}' href="/en-us/news/world/trump-claims-g-7-unity-on-iran-after-unannounced-invite/ar-AAGkZmU?li=BBnb7Kz">
# <img alt="US President Donald Trump reacts during his a bilateral meeting with Egyptian Pr..." onerror="this.className='err'" onload="this.className='loaded'" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlb7b.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2643&amp;y=1269" title="FRANCE-G7-SUMMIT - NICHOLAS KAMM/AFP/Getty Images"/>
# <div class="caption">
# <span aria-label="trump claims g-7 'unity' on iran after unannounced invite-article" class="title">Trump claims G-7 'unity' on Iran after unannounced invite</span>
# <span class="sourcename">
# <img alt="Associated Press Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywufo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Associated Press        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="121" data-m='{"i":121,"p":119,"n":"HeadlineItemViewModel","y":13,"l":"AAGjy2A","h":0,"v":"finance","c":"markets","o":2,"s":1}' href="/en-us/money/markets/trump-offers-contradictory-signals-on-china-trade-war/ar-AAGjy2A?li=BBnb7Kz">
# <img alt="" onerror="this.className='err'" onload="this.className='loaded'" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB10BuL.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=845&amp;y=1287" title="American and Chinese flags - Ng Han Guan / AP"/>
# <div class="caption">
# <span aria-label="trump sends conflicting signs on trade war-article" class="title">Trump sends conflicting signs on trade war</span>
# <span class="sourcename">
# <img alt="The New York Times Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA3l3r5.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The New York Times        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="122" data-m='{"i":122,"p":119,"n":"HeadlineItemViewModel","y":13,"l":"AAGlB1N","h":0,"v":"news","c":"newspolitics","o":3,"s":1}' href="/en-us/news/politics/trump-says-his-miami-golf-resort-a-contender-to-host-next-g-7/ar-AAGlB1N?li=BBnb7Kz">
# <img alt="U.S. President Donald Trump gestures during family photo session at the G7 summi..." onerror="this.className='err'" onload="this.className='loaded'" src="https://static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlutl.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1100&amp;y=614" title="G7 summit in Biarritz - Christian Hartmann/Pool/ REUTERS"/>
# <div class="caption">
# <span aria-label="trump says his miami resort could host next g-7-article" class="title">Trump says his Miami resort could host next G-7</span>
# <span class="sourcename">
# <img alt="The Hill Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUvpML.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Hill        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="mosaic" data-id="123" data-m='{"i":123,"p":118,"n":"mosaic","y":8,"o":2,"f":"Y_cec865fe-ed84-49a8-b88a-4a23446ea7f1"}' tabindex="0">
# <h3>New York</h3>
# <a data-id="124" data-m='{"i":124,"p":123,"n":"HeadlineItemViewModel","y":13,"l":"AAGk87e","h":2,"v":"news","c":"newsus","o":1}' href="/en-us/news/us/mayor-ras-baraka-silent-as-newark-faces-water-crisis/ar-AAGk87e">
# <img alt="Mayor Ras Baraka silent as Newark faces water crisis" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGk87c.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1037&amp;y=372"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Mayor Ras Baraka silent as Newark faces water crisis - WPIX-TV/TNS"/>
# <div class="caption">
# <span aria-label="mayor ras baraka silent as newark faces water crisis" class="title">Mayor Ras Baraka silent as Newark faces water crisis</span>
# <span class="subtitle">Mayor Ras Baraka silent as Newark faces water crisis</span>
# <span class="sourcename">
# <img alt="WPIX-TV New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTUVWY.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WPIX-TV New York"/>WPIX-TV New York        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="125" data-m='{"i":125,"p":123,"n":"HeadlineItemViewModel","y":13,"l":"AAGlwks","h":3,"v":"travel","c":"travelnews","o":2}' href="/en-us/travel/news/newark-braces-for-heavy-traffic-street-closures-as-mtv-video-music-awards-come-to-town/ar-AAGlwks">
# <img alt="Newark Braces For Heavy Traffic, Street Closures As MTV Video Music Awards Come ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGltF1.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Newark Braces For Heavy Traffic, Street Closures As MTV Vide Music Awards Come T... - Provided by CBS Local, a division of CBS Radio Inc"/>
# <div class="caption">
# <span aria-label="newark braces for heavy traffic, street closures as mtv video music awards come to town" class="title">Newark Braces For Heavy Traffic, Street Closures As MTV Video Music Awards Come To Town</span>
# <span class="subtitle">Newark Braces For Heavy Traffic, Street Closures As MTV Video Music Awards Come To Town</span>
# <span class="sourcename">
# <img alt="CBS New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/AAyW7G9.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="CBS New York"/>CBS New York        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="126" data-m='{"i":126,"p":123,"n":"HeadlineItemViewModel","y":13,"l":"AAG7sWe","h":4,"v":"foodanddrink","c":"newstrends","o":3}' href="/en-us/foodanddrink/foodnews/beloved-brooklyn-pizza-joint-di-fara-shut-down-due-to-unpaid-taxes/ar-AAG7sWe">
# <img alt="Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG7pSj.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes - Provided by Entercom Radio, LLC"/>
# <div class="caption">
# <span aria-label="beloved brooklyn pizza joint di fara shut down due to unpaid taxes" class="title">Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes</span>
# <span class="subtitle">Beloved Brooklyn pizza joint Di Fara shut down due to unpaid taxes</span>
# <span class="sourcename">
# <img alt="WINS Radio New York" data-src='{"default":"//img-s-msn-com.akamaized.net/tenant/amp/entityid/BBTg0tm.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="WINS Radio New York"/>WINS Radio New York        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="mosaic hasimage" data-aop="slide2&gt;mosaic " data-id="127" data-m='{"i":127,"p":118,"n":"mosaic","y":8,"o":3}' tabindex="0">
# <h3>LATEST NEWS</h3>
# <a data-id="128" data-m='{"i":128,"p":127,"n":"HeadlineItemViewModel","y":13,"l":"AAGkLoy","h":0,"v":"news","c":"newsscienceandtechnology","o":1,"s":1}' href="/en-us/news/technology/nasa-astronaut-accused-of-first-ever-space-crime-denies-allegations/ar-AAGkLoy?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGk7Nk.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=656&amp;y=340"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="NASA investigators probe an astronaut accused of committing a crime in space - Provided by PG Publishing Co., Inc."/>
# <div class="caption">
# <span aria-label="us astronaut accused of first space crime denies claims-article" class="title">US astronaut accused of first space crime denies claims</span>
# <span class="sourcename">
# <img alt="The Next Web Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAla3Lx.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Next Web        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="129" data-m='{"i":129,"p":127,"n":"HeadlineItemViewModel","y":13,"l":"AAGlyy0","h":0,"v":"news","c":"newsworld","o":2,"s":1}' href="/en-us/news/world/brazils-bolsonaro-endorses-sexist-post-about-french-first-lady/ar-AAGlyy0?li=BBnb7Kz">
# <img alt="Bolsonaro endorsed a post mocking the appearance of Brigitte Macron and comparin..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlyxU.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=324&amp;y=229"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Bolsonaro endorsed a post mocking the appearance of Brigitte Macron and comparin... - Thomas SAMSON"/>
# <div class="caption">
# <span aria-label="brazil leader endorses sexist post about macron's wife-article" class="title">Brazil leader endorses sexist post about Macron's wife</span>
# <span class="sourcename">
# <img alt="AFP Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyXiwM.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>AFP        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="130" data-m='{"i":130,"p":127,"n":"HeadlineItemViewModel","y":13,"l":"AAGjCSX","h":0,"v":"weather","c":"weathertopstories","o":3,"s":1}' href="/en-us/weather/topstories/dorian-could-be-hurricane-when-it-reaches-puerto-rico/ar-AAGjCSX?li=BBnb7Kz">
# <img alt="Hurricane Fred is seen near the Cape Verde Islands in this NOAA Goes East satell..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAdO42d.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1030&amp;y=733"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Hurricane Fred is seen near the Cape Verde Islands in this NOAA Goes East satell... - NOAA/Reuters"/>
# <div class="caption">
# <span aria-label="dorian strengthens, could become hurricane-article" class="title">Dorian strengthens, could become hurricane</span>
# <span class="sourcename">
# <img alt="NBC News Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBAJ56P.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>NBC News        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="mosaic hasimage" data-aop="slide3&gt;mosaic " data-id="131" data-m='{"i":131,"p":118,"n":"mosaic","y":8,"o":4}' tabindex="0">
# <h3>POLITICS</h3>
# <a data-id="132" data-m='{"i":132,"p":131,"n":"HeadlineItemViewModel","y":13,"l":"AAGkt6t","h":0,"v":"news","c":"newspolitics","o":1,"s":1}' href="/en-us/news/politics/when-they-go-low-dems-navigating-nasty-race-against-trump/ar-AAGkt6t?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlRIT.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1977&amp;y=939"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="In this Aug. 21, 2019 file photo, Democratic presidential candidate Elizabeth Wa... - Provided by The Associated Press"/>
# <div class="caption">
# <span aria-label="democrats navigating nasty race against trump-article" class="title">Democrats navigating nasty race against Trump</span>
# <span class="sourcename">
# <img alt="Associated Press Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywufo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Associated Press        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="133" data-m='{"i":133,"p":131,"n":"HeadlineItemViewModel","y":13,"l":"AAGlJS1","h":0,"v":"news","c":"newspolitics","o":2,"s":1}' href="/en-us/news/politics/joe-walsh-says-he-is-challenging-trump-to-make-the-moral-case-against-him/ar-AAGlJS1?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlNGi.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=563&amp;y=352"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Walsh: Americans are embarrassed or disgusted with Trump - Provided by Cable News Network, Inc."/>
# <div class="caption">
# <span aria-label="walsh explains why he's challenging trump-article" class="title">Walsh explains why he's challenging Trump</span>
# <span class="sourcename">
# <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNN        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="134" data-m='{"i":134,"p":131,"n":"HeadlineItemViewModel","y":13,"l":"AAGkw1i","h":0,"v":"news","c":"factcheck","o":3,"s":1}' href="/en-us/news/factcheck/ap-fact-check-trumps-illusory-claims-of-gains-from-tariffs/ar-AAGkw1i?li=BBnb7Kz">
# <img alt="U.S President Donald Trump smiles during a news conference with Japanese Prime M..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGkwcz.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2033&amp;y=1416"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="U.S President Donald Trump smiles during a news conference with Japanese Prime M... - Provided by The Associated Press"/>
# <div class="caption">
# <span aria-label="fact check: trump's claims of gains from tariffs-article" class="title">Fact check: Trump's claims of gains from tariffs</span>
# <span class="sourcename">
# <img alt="Associated Press Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywufo.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Associated Press        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide4&gt;single " data-id="135" data-m='{"i":135,"p":118,"n":"single","y":8,"o":5}' tabindex="0">
# <a data-id="136" data-m='{"i":136,"p":135,"n":"HeadlineItemViewModel","y":13,"l":"AAGjpTZ","h":0,"v":"sports","c":"football_nfl","o":1,"s":1}' href="/en-us/sports/nfl/retired-nfl-fullback-leron-mcclain-pleads-for-help-i-have-to-get-my-head-checked/ar-AAGjpTZ?li=BBnb7Kz">
# <img alt="Getty" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjg4E.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2618&amp;y=836"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Getty - Getty"/>
# <div class="caption">
# <span aria-label="retired nfl fb pleads for help: ‘i have to get my head checked’-article" class="title">Retired NFL FB pleads for help: ‘I have to get my head checked’</span>
# <span class="sourcename">
# <img alt="For The Win Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAgymO6.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>For The Win        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage media photo" data-aop="slide5&gt;single " data-id="137" data-m='{"i":137,"p":118,"n":"single","y":8,"o":6}' tabindex="0">
# <a class="media photo" data-id="138" data-m='{"i":138,"p":137,"n":"HeadlineItemViewModel","y":13,"l":"AABUaQV","h":0,"v":"health","c":"medical","o":1}' href="/en-us/health/medical/45-sneaky-signs-youre-unhealthier-than-you-may-think/ss-AABUaQV?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AABUcS8.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=652&amp;y=357"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="22. You have shoulder pain. - Provided by Best Life"/>
# <div class="caption">
# <span aria-label="signs you're unhealthier than you think-slideshow" class="title">Signs you're unhealthier than you think</span>
# <span class="sourcename">
# <img alt="Best Life Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAxspu1.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Best Life        </span>
# </div>
# </a>
# </li>
# <li class="head-to-head hasimage" data-aop="slide6&gt;head-to-head " data-id="139" data-m='{"i":139,"p":118,"n":"headtohead","y":8,"o":7}' tabindex="0">
# <a class="nativead" data-id="140" data-m='{"i":140,"p":139,"n":"NativeAdHeadlineItemViewModel","y":13,"o":1}' data-pg="1" data-pid="7HD66FC" href="https://www.comparecards.com/guide/pay-0-interest-until-2021?utm_source=msnhp&amp;grp=pay-0-2021&amp;utm_medium=native&amp;pla=www.msn.com&amp;tar=cms&amp;acqs=prospecting&amp;bdst=cpm&amp;esourceid=6381636&amp;utm_campaign=20190826&amp;utm_content=get+almost+2+years+interestfree+with+1+of+these+cards&amp;adt=hatcoffeegirl&amp;c3=am&amp;mtaid=5E29E&amp;placement_name=cms&amp;ad_headline=get+almost+2+years+interestfree+with+1+of+these+cards&amp;ad_image_name=hatcoffeegirl&amp;ad_group_name=pay-0-2021&amp;campaign_date=20190826&amp;day_part=am" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AABDJeL.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=412&amp;y=134"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="hatcoffeegirl"/>
# <div class="caption">
# <span aria-label="get almost 2 years interest-free with 1 of these cards-article" class="title">Get almost 2 years interest-free with 1 of these cards</span>
# <span class="sourcename">
# <span class="adslabel" title="Ad">Ad</span>
# CompareCards        </span>
# </div>
# </a>
# <a class="nativead" data-id="141" data-m='{"i":141,"p":139,"n":"NativeAdHeadlineItemViewModel","y":13,"o":2}' data-pg="1" data-pid="7HD66FC" href="https://www.comparecards.com/guide/pay-0-interest-until-2021?utm_source=msnhp&amp;grp=pay-0-2021&amp;utm_medium=native&amp;pla=www.msn.com&amp;tar=cms&amp;acqs=prospecting&amp;bdst=cpm&amp;esourceid=6381636&amp;utm_campaign=20190826&amp;utm_content=3+cards+offering+0+interest+for+18+months&amp;adt=flaggcc5&amp;c3=am&amp;mtaid=5E29E&amp;placement_name=cms&amp;ad_headline=3+cards+offering+0+interest+for+18+months&amp;ad_image_name=flaggcc5&amp;ad_group_name=pay-0-2021&amp;campaign_date=20190826&amp;day_part=am" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAxOc9T.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <div class="caption">
# <span aria-label="3 cards offering 0% interest for 18 months-article" class="title">3 cards offering 0% interest for 18 months</span>
# <span class="sourcename">
# <span class="adslabel" title="Ad">Ad</span>
# CompareCards        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage" data-aop="slide7&gt;single " data-id="142" data-m='{"i":142,"p":118,"n":"single","y":8,"o":8}' tabindex="0">
# <a data-id="143" data-m='{"i":143,"p":142,"n":"HeadlineItemViewModel","y":13,"l":"AAG8wJU","h":0,"v":"news","c":"newsus","o":1,"s":1}' href="/en-us/news/us/american-slavery-began-in-1619-project-documents-brutal-journey/ar-AAG8wJU?li=BBnb7Kz">
# <img alt="The founding family you’ve never heard of: The black Tuckers of Hampton, Virgini..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG8PMN.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The founding family you’ve never heard of: The black Tuckers of Hampton, Virgini... - Provided by USA TODAY, a division of Gannett Satellite Information Network, Inc."/>
# <div class="caption">
# <span aria-label="how an accidental encounter brought slavery to the us-article" class="title">How an accidental encounter brought slavery to the US</span>
# <span class="sourcename">
# <img alt="USA TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBNvr53.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage" data-aop="slide8&gt;mosaic " data-id="144" data-m='{"i":144,"p":118,"n":"mosaic","y":8,"o":9}' tabindex="0">
# <h3>NFL BUZZ</h3>
# <a data-id="145" data-m='{"i":145,"p":144,"n":"HeadlineItemViewModel","y":13,"l":"AAGlK61","h":0,"v":"sports","c":"football_nfl","o":1,"s":1}' href="/en-us/sports/nfl/troy-aikman-rips-into-doug-gottlieb-over-andrew-luck-tweet/ar-AAGlK61?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlOPs.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1233&amp;y=778"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Troy Aikman rips into Doug Gottlieb over Andrew Luck tweet - Denny Medley-USA TODAY Sports"/>
# <div class="caption">
# <span aria-label="aikman blasts fellow fox analyst over luck tweet-article" class="title">Aikman blasts fellow FOX analyst over Luck tweet</span>
# <span class="sourcename">
# <img alt="Larry Brown Sports Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBjLpNF.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Larry Brown Sports        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="146" data-m='{"i":146,"p":144,"n":"HeadlineItemViewModel","y":13,"l":"AAGjDCh","h":0,"v":"sports","c":"football_nfl","o":2,"s":1}' href="/en-us/sports/nfl/nfl-fans-immediately-ripped-nbcs-weird-camera-angle-for-the-steelers-titans-game/ar-AAGjDCh?li=BBnb7Kz">
# <img alt="File Photo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjtHZ.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1402&amp;y=662"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="File Photo - File Photo"/>
# <div class="caption">
# <span aria-label="nfl fans blast nbc's 'high sky' view-article" class="title">NFL fans blast NBC's 'High Sky' view</span>
# <span class="sourcename">
# <img alt="For The Win Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAgymO6.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>For The Win        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="147" data-m='{"i":147,"p":144,"n":"HeadlineItemViewModel","y":13,"l":"AAGjBL0","h":0,"v":"sports","c":"football_nfl","o":3,"s":1}' href="/en-us/sports/nfl/winners-and-losers-from-nfl-preseason-week-3/ar-AAGjBL0?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjRvu.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1354&amp;y=721"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Winners and losers from NFL preseason Week 3 - Jim Brown-USA TODAY Sports"/>
# <div class="caption">
# <span aria-label="winners and losers from nfl preseason week 3-article" class="title">Winners and losers from NFL preseason Week 3</span>
# <span class="sourcename">
# <img alt="Sportsnaut Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBjLpNF.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Sportsnaut        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide9&gt;single " data-id="148" data-m='{"i":148,"p":118,"n":"single","y":8,"o":10}' tabindex="0">
# <a data-id="149" data-m='{"i":149,"p":148,"n":"HeadlineItemViewModel","y":13,"l":"AAGkaCQ","h":0,"v":"finance","c":"finance-career","o":1,"s":1}' href="/en-us/money/career/this-is-americas-no-1-college-major-for-salary-and-job-availability/ar-AAGkaCQ?li=BBnb7Kz">
# <img alt="The best majors to go from higher education to ready for hire. " data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGkt3z.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=424&amp;y=249"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The best majors to go from higher education to ready for hire. - Samuel Goldwyn Films/courtesy Everett Collection"/>
# <div class="caption">
# <span aria-label="this is america’s no. 1 college major for salary and job availability-article" class="title">This is America’s No. 1 college major for salary and job availability</span>
# <span class="sourcename">
# <img alt="MarketWatch Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBqlEdK.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>MarketWatch        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage" data-aop="slide10&gt;mosaic " data-id="150" data-m='{"i":150,"p":118,"n":"mosaic","y":8,"o":11}' tabindex="0">
# <h3>CELEB NEWS</h3>
# <a data-id="151" data-m='{"i":151,"p":150,"n":"HeadlineItemViewModel","y":13,"l":"AAGlJus","h":0,"v":"tv","c":"tvnews","o":1,"s":1}' href="/en-us/tv/news/gmas-lara-spencer-apologizes-on-air-for-mocking-prince-georges-ballet-lessons-my-comment-was-stupid-and-insensitive-watch-video/ar-AAGlJus?li=BBnb7Kz">
# <img alt="Lara Spencer attends 'Good Morning America' at SummerStage at Rumsey Playfield, ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlOEz.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=936&amp;y=527"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Lara Spencer - Noam Galai/Getty Images"/>
# <div class="caption">
# <span aria-label="spencer apologizes on-air for 'stupid' ballet remarks-article" class="title">Spencer apologizes on-air for 'stupid' ballet remarks</span>
# <span class="sourcename">
# <img alt="TVLine Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB1w6aD.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>TVLine        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="152" data-m='{"i":152,"p":150,"n":"HeadlineItemViewModel","y":13,"l":"AAGjDzo","h":0,"v":"tv","c":"tvnews","o":2,"s":1}' href="/en-us/tv/news/big-bang-theorys-johnny-galecki-teases-return-to-the-conners-in-season-2/ar-AAGjDzo?li=BBnb7Kz">
# <img alt="Big Bang Theory's Johnny Galecki teases return to 'The Conners' in season 2" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjKx0.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1303&amp;y=670"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Big Bang Theory's Johnny Galecki teases return to 'The Conners' in season 2 - Jason LaVeris/FilmMagic"/>
# <div class="caption">
# <span aria-label="galecki teases return to 'the conners'-article" class="title">Galecki teases return to 'The Conners'</span>
# <span class="sourcename">
# <img alt="Entertainment Weekly Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAesHLQ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Entertainment Weekly        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="153" data-m='{"i":153,"p":150,"n":"HeadlineItemViewModel","y":13,"l":"AAGkslt","h":0,"v":"movies","c":"movies-celebrity","o":3,"s":1}' href="/en-us/movies/celebrity/charlize-theron-shares-rare-photo-of-one-of-her-kids-from-vacation/ar-AAGkslt?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGkXdY.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=312&amp;y=124"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="https://www.gannett-cdn.com/presto/2019/08/26/USAT/d73cc819-1550-40ba-80be-dced5... - Provided by USA TODAY, a division of Gannett Satellite Information Network, Inc."/>
# <div class="caption">
# <span aria-label="charlize theron posts rare pic of one of her kids-article" class="title">Charlize Theron posts rare pic of one of her kids</span>
# <span class="sourcename">
# <img alt="USA TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBNvr53.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide11&gt;single " data-id="154" data-m='{"i":154,"p":118,"n":"single","y":8,"o":12}' tabindex="0">
# <a data-id="155" data-m='{"i":155,"p":154,"n":"HeadlineItemViewModel","y":13,"l":"AAGlI3B","h":0,"v":"news","c":"newspolitics","o":1,"s":1}' href="/en-us/news/politics/trump-denies-that-he-suggested-nuking-hurricanes-but-the-government-once-studied-the-idea/ar-AAGlI3B?li=BBnb7Kz">
# <img alt="President Trump speaks with reporters as he walks to Marine One on the South Law..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGloVg.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=2103&amp;y=1073"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="President Trump speaks with reporters as he walks to Marine One on the South Law... - Alex Brandon/AP"/>
# <div class="caption">
# <span aria-label="trump denies suggesting nuking hurricanes, but u.s. once studied it-article" class="title">Trump denies suggesting nuking hurricanes, but U.S. once studied it</span>
# <span class="sourcename">
# <img alt="The Washington Post Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyxkRJ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>The Washington Post        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage media photo" data-aop="slide12&gt;single " data-id="156" data-m='{"i":156,"p":118,"n":"single","y":8,"o":13}' tabindex="0">
# <a class="media photo" data-id="157" data-m='{"i":157,"p":156,"n":"HeadlineItemViewModel","y":13,"l":"AAFNWId","h":0,"v":"news","c":"newsus","o":1,"s":1}' href="/en-us/news/us/35-vintage-photos-taken-by-the-epa-reveal-what-american-cities-looked-like-before-pollution-was-regulated/ss-AAFNWId?li=BBnb7Kz">
# <img alt='New York is one of the most photographed cities for "The Documerica Project." He...' data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAFNKU6.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title='New York is one of the most photographed cities for "The Documerica Project." He... - Gary Miller / EPA'/>
# <div class="caption">
# <span aria-label="what cities looked like before the epa regulated pollution-slideshow" class="title">What cities looked like before the EPA regulated pollution</span>
# <span class="sourcename">
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Business Insider        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage" data-aop="slide13&gt;mosaic " data-id="158" data-m='{"i":158,"p":118,"n":"mosaic","y":8,"o":14}' tabindex="0">
# <h3>AMAZON FIRES</h3>
# <a data-id="159" data-m='{"i":159,"p":158,"n":"HeadlineItemViewModel","y":13,"l":"AAGl5GO","h":0,"v":"news","c":"newsworld","o":1,"s":1}' href="/en-us/news/world/all-you-can-see-is-death-the-regions-reeling-from-the-amazon-rainforest-fires/ar-AAGl5GO?li=BBnb7Kz">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGl5Gr.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="'All you can see is death.' The regions reeling from the Amazon rainforest fires - Natalie Gallón/CNN"/>
# <div class="caption">
# <span aria-label="'all you can see is death.' regions reeling from fires-article" class="title">'All you can see is death.' Regions reeling from fires</span>
# <span class="sourcename">
# <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNN        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="160" data-m='{"i":160,"p":158,"n":"HeadlineItemViewModel","y":13,"l":"AAGlC71","h":0,"v":"news","c":"newsworld","o":2,"s":1}' href="/en-us/news/world/g7-to-finance-fire-fighting-aircraft-for-amazon/ar-AAGlC71?li=BBnb7Kz">
# <img alt="Nearly 80,000 forest fires have been detected in Brazil since the beginning of t..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlEvf.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Nearly 80,000 forest fires have been detected in Brazil since the beginning of t... - Victor MORIYAMA"/>
# <div class="caption">
# <span aria-label="g-7 leaders pledge $22 million to fight fires-article" class="title">G-7 leaders pledge $22 million to fight fires</span>
# <span class="sourcename">
# <img alt="AFP Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyXiwM.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>AFP        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="161" data-m='{"i":161,"p":158,"n":"HeadlineItemViewModel","y":13,"l":"AAGd2xy","h":0,"v":"news","c":"newsworld","o":3,"s":1}' href="/en-us/news/world/what-you-can-do-to-help-the-burning-amazon-rainforest/ar-AAGd2xy?li=BBnb7Kz">
# <img alt="Amazon jungle fire" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG66S6.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1294&amp;y=900"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="A tract of Amazon jungle is seen burning as it is being cleared by loggers and f... - Reuters"/>
# <div class="caption">
# <span aria-label="what you can do to help the amazon rainforest-article" class="title">What you can do to help the Amazon rainforest</span>
# <span class="sourcename">
# <img alt="CBS News Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAy3CUU.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CBS News        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="head-to-head hasimage" data-aop="slide14&gt;head-to-head " data-id="162" data-m='{"i":162,"p":118,"n":"headtohead","y":8,"o":15}' tabindex="0">
# <h3>LUCK RETIRES</h3>
# <a data-id="163" data-m='{"i":163,"p":162,"n":"HeadlineItemViewModel","y":13,"l":"AAGjDdN","h":0,"v":"sports","c":"football_nfl","o":1,"s":1}' href="/en-us/sports/nfl/years-of-exhaustion-in-andrew-lucks-football-life-forced-him-to-carry-out-a-vow/ar-AAGjDdN?li=BBnb7Kz">
# <img alt="Andrew Luck said goodbye to the NFL on Saturday night, to the shock of the sport..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjDdJ.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1630&amp;y=1061"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="INDIANAPOLIS, IN - AUGUST 24: Andrew Luck #12 of the Indianapolis Colts watches ... - Provided by Oath Inc."/>
# <div class="caption">
# <span aria-label="years of football exhaustion forced luck to carry out vow-article" class="title">Years of football exhaustion forced Luck to carry out vow</span>
# <span class="sourcename">
# <img alt="Yahoo! Sports Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBPMoha.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Yahoo! Sports        </span>
# </div>
# </a>
# <a data-id="164" data-m='{"i":164,"p":162,"n":"HeadlineItemViewModel","y":13,"l":"AAGlPYC","h":0,"v":"sports","c":"football_nfl","o":2,"s":1}' href="/en-us/sports/nfl/nfl-andrew-luck-retirement-spurs-emotional-tweet-from-wr-ty-hilton/ar-AAGlPYC?li=BBnb7Kz">
# <img alt="INDIANAPOLIS, IN - AUGUST 17: T.Y. Hilton #13 of the Indianapolis Colts is seen ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlTky.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1947&amp;y=1342"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Cleveland Browns v Indianapolis Colts - Michael Hickey/Getty Images"/>
# <div class="caption">
# <span aria-label="colts receiver posts emotional farewell to luck-article" class="title">Colts receiver posts emotional farewell to Luck</span>
# <span class="sourcename">
# <img alt="USA TODAY SPORTS Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB4kwAp.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY SPORTS        </span>
# </div>
# </a>
# </li>
# <li class="mosaic hasimage media video" data-aop="slide15&gt;mosaic " data-id="165" data-m='{"i":165,"p":118,"n":"mosaic","y":8,"o":16}' tabindex="0">
# <h3>ICYMI VIDEOS</h3>
# <a data-id="166" data-m='{"i":166,"p":165,"n":"HeadlineItemViewModel","y":13,"l":"AAGe6EY","h":0,"v":"video","c":"viral","o":1,"s":1}' href="/en-us/video/viral/retirees-skip-fishing-to-go-golfing-trout-falls-from-the-sky-as-they-tee-off/vi-AAGe6EY">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGeiIc.img?h=333&amp;w=311&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=582&amp;y=153"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Retirees Skip Fishing to Go Golfing, Trout Falls From the Sky as They Tee Off - Provided by Zazoom, LLC"/>
# <div class="caption">
# <span aria-label="retirees skip fishing to go golfing, trout falls from sky-video" class="title">Retirees skip fishing to go golfing, trout falls from sky</span>
# <span class="sourcename">
# <img alt="Buzz60 Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BByCIyx.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Buzz60        </span>
# </div>
# </a>
# <ul>
# <li>
# <a data-id="167" data-m='{"i":167,"p":165,"n":"HeadlineItemViewModel","y":13,"l":"AAG7HEt","h":0,"v":"video","c":"animals","o":2,"s":1}' href="/en-us/video/animals/giant-bison-slams-into-car-at-yellowstone-during-stampede/vi-AAG7HEt">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAG7K3S.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=765&amp;y=638"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Giant bison slams into car at Yellowstone during stampede - Provided by USA TODAY, a division of Gannett Satellite Information Network, Inc."/>
# <div class="caption">
# <span aria-label="giant bison slams into car at yellowstone-video" class="title">Giant bison slams into car at Yellowstone</span>
# <span class="sourcename">
# <img alt="USA TODAY Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBNvr53.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>USA TODAY        </span>
# </div>
# </a>
# </li>
# <li>
# <a data-id="168" data-m='{"i":168,"p":165,"n":"HeadlineItemViewModel","y":13,"l":"AAGdOMe","h":0,"v":"video","c":"viral","o":3,"s":1}' href="/en-us/video/viral/illinois-police-traffic-stop-turns-into-marriage-proposal/vi-AAGdOMe">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGlwsU.img?h=166&amp;w=310&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=346&amp;y=271"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Illinois police traffic stop turns into marriage proposal"/>
# <div class="caption">
# <span aria-label="police traffic stop turns into marriage proposal-video" class="title">Police traffic stop turns into marriage proposal</span>
# <span class="sourcename">
# <img alt="Storyful Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BB1Qgoh.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>Storyful        </span>
# </div>
# </a>
# </li>
# </ul>
# </li>
# <li class="single hasimage" data-aop="slide16&gt;single " data-id="169" data-m='{"i":169,"p":118,"n":"single","y":8,"o":17}' tabindex="0">
# <a data-id="170" data-m='{"i":170,"p":169,"n":"HeadlineItemViewModel","y":13,"l":"AAGj2cb","h":0,"v":"weather","c":"weathertopstories","o":1,"s":1}' href="/en-us/weather/topstories/a-giant-pumice-stone-floating-in-the-pacific-could-help-heal-australias-great-barrier-reef/ar-AAGj2cb?li=BBnb7Kz">
# <img alt="pumice raft seen by NASA's Terra satellite on August 13 2019" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGj2c8.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=515&amp;y=328"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="pumice raft seen by NASA's Terra satellite on August 13 2019 - NASA's Terra satellite"/>
# <div class="caption">
# <span aria-label="a giant pumice stone floating in the pacific could help heal australia's great barrier reef-article" class="title">A giant pumice stone floating in the Pacific could help heal Australia's Great Barrier Reef</span>
# <span class="sourcename">
# <img alt="CNN Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywGC0.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNN        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage" data-aop="slide17&gt;single " data-id="171" data-m='{"i":171,"p":118,"n":"single","y":8,"o":18}' tabindex="0">
# <a data-id="172" data-m='{"i":172,"p":171,"n":"HeadlineItemViewModel","y":13,"l":"AAGjtg2","h":0,"v":"finance","c":"markets","o":1,"s":1}' href="/en-us/money/markets/trump-wants-us-companies-to-leave-china-heres-what-it-could-mean-for-chinese-businesses/ar-AAGjtg2?li=BBnb7Kz">
# <img alt="A Chinese denim factory" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjHKJ.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=984&amp;y=311"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="A Chinese denim factory - Provided by CNBC LLC"/>
# <div class="caption">
# <span aria-label="trump wants us companies to leave china. what could that mean for china's businesses?-article" class="title">Trump wants US companies to leave China. What could that mean for China's businesses?</span>
# <span class="sourcename">
# <img alt="CNBC Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA3ltd8.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>CNBC        </span>
# </div>
# </a>
# </li>
# <li class="single hasimage" data-aop="slide18&gt;single " data-id="173" data-m='{"i":173,"p":118,"n":"single","y":8,"o":19}' tabindex="0">
# <a data-id="174" data-m='{"i":174,"p":173,"n":"HeadlineItemViewModel","y":13,"l":"AAGjpUh","h":0,"v":"news","c":"newsworld","o":1,"s":1}' href="/en-us/news/world/environmentalists-filmed-irans-vanishing-cheetahs-now-they-could-be-executed-for-spying/ar-AAGjpUh?li=BBnb7Kz">
# <img alt="This photograph of an Asiatic cheetah was taken by a low-resolution camera trap,..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjust.img?h=368&amp;w=622&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg&amp;x=1557&amp;y=731"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="This photograph of an Asiatic cheetah was taken by a low-resolution camera trap,... - Frans Lanting/National Geographic Image Collection"/>
# <div class="caption">
# ...
# <a data-id="327" data-m='{"i":327,"p":324,"n":"HeadlineItemViewModel","y":13,"o":3}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFrs.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Solitaire Collection - Microsoft Games"/> </a>
# </li>
# </ul>
#
#
# <li class="">
# <a data-id="326" data-m='{"i":326,"p":324,"n":"HeadlineItemViewModel","y":13,"o":2}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=ogname" target="_blank">
# Try a daily challenge </a>
# </li>
#
#
# <a data-id="326" data-m='{"i":326,"p":324,"n":"HeadlineItemViewModel","y":13,"o":2}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=ogname" target="_blank">
# Try a daily challenge </a>
#
# Try a daily challenge
#
#
#
#
# <li class="headline-img-container">
# <a data-id="327" data-m='{"i":327,"p":324,"n":"HeadlineItemViewModel","y":13,"o":3}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFrs.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Solitaire Collection - Microsoft Games"/> </a>
# </li>
#
#
# <a data-id="327" data-m='{"i":327,"p":324,"n":"HeadlineItemViewModel","y":13,"o":3}' href="https://www.msn.com/en-us/entertainment/onlinegames/5-best-solitaire-games/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFrs.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Solitaire Collection - Microsoft Games"/> </a>
#
#
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFrs.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Solitaire Collection - Microsoft Games"/>
#
#
#
#
#
#
#
#
#
# <li>
# <ul>
# <li class="">
# <a data-id="328" data-m='{"i":328,"p":324,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=ogname" target="_blank">
# Keep your mind sharp </a>
# </li>
# <li class="headline-img-container">
# <a data-id="329" data-m='{"i":329,"p":324,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAE8xlk.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Games - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
#
#
# <ul>
# <li class="">
# <a data-id="328" data-m='{"i":328,"p":324,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=ogname" target="_blank">
# Keep your mind sharp </a>
# </li>
# <li class="headline-img-container">
# <a data-id="329" data-m='{"i":329,"p":324,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAE8xlk.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Games - Microsoft Games"/> </a>
# </li>
# </ul>
#
#
# <li class="">
# <a data-id="328" data-m='{"i":328,"p":324,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=ogname" target="_blank">
# Keep your mind sharp </a>
# </li>
#
#
# <a data-id="328" data-m='{"i":328,"p":324,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=ogname" target="_blank">
# Keep your mind sharp </a>
#
# Keep your mind sharp
#
#
#
#
# <li class="headline-img-container">
# <a data-id="329" data-m='{"i":329,"p":324,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAE8xlk.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Games - Microsoft Games"/> </a>
# </li>
#
#
# <a data-id="329" data-m='{"i":329,"p":324,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://www.msn.com/en-us/entertainment/onlinegames/crosswords/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAE8xlk.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Games - Microsoft Games"/> </a>
#
#
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAE8xlk.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Games - Microsoft Games"/>
#
#
#
#
#
#
#
#
#
# <li>
# <ul>
# <li class="">
# <a data-id="330" data-m='{"i":330,"p":324,"n":"HeadlineItemViewModel","y":13,"o":6}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=ogname" target="_blank">
# Connect tiles to make words </a>
# </li>
# <li class="headline-img-container">
# <a data-id="331" data-m='{"i":331,"p":324,"n":"HeadlineItemViewModel","y":13,"o":7}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBV4sWb.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Wordament - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
#
#
# <ul>
# <li class="">
# <a data-id="330" data-m='{"i":330,"p":324,"n":"HeadlineItemViewModel","y":13,"o":6}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=ogname" target="_blank">
# Connect tiles to make words </a>
# </li>
# <li class="headline-img-container">
# <a data-id="331" data-m='{"i":331,"p":324,"n":"HeadlineItemViewModel","y":13,"o":7}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBV4sWb.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Wordament - Microsoft Games"/> </a>
# </li>
# </ul>
#
#
# <li class="">
# <a data-id="330" data-m='{"i":330,"p":324,"n":"HeadlineItemViewModel","y":13,"o":6}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=ogname" target="_blank">
# Connect tiles to make words </a>
# </li>
#
#
# <a data-id="330" data-m='{"i":330,"p":324,"n":"HeadlineItemViewModel","y":13,"o":6}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=ogname" target="_blank">
# Connect tiles to make words </a>
#
# Connect tiles to make words
#
#
#
#
# <li class="headline-img-container">
# <a data-id="331" data-m='{"i":331,"p":324,"n":"HeadlineItemViewModel","y":13,"o":7}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBV4sWb.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Wordament - Microsoft Games"/> </a>
# </li>
#
#
# <a data-id="331" data-m='{"i":331,"p":324,"n":"HeadlineItemViewModel","y":13,"o":7}' href="https://www.msn.com/en-us/entertainment/onlinegames/wordament/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBV4sWb.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Wordament - Microsoft Games"/> </a>
#
#
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBV4sWb.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Wordament - Microsoft Games"/>
#
#
#
#
#
#
#
#
#
# <li>
# <ul>
# <li class="">
# <a data-id="332" data-m='{"i":332,"p":324,"n":"HeadlineItemViewModel","y":13,"o":8}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=ogname" target="_blank">
# Test your game skills </a>
# </li>
# <li class="headline-img-container">
# <a data-id="333" data-m='{"i":333,"p":324,"n":"HeadlineItemViewModel","y":13,"o":9}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFvK.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Mahjong - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
#
#
# <ul>
# <li class="">
# <a data-id="332" data-m='{"i":332,"p":324,"n":"HeadlineItemViewModel","y":13,"o":8}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=ogname" target="_blank">
# Test your game skills </a>
# </li>
# <li class="headline-img-container">
# <a data-id="333" data-m='{"i":333,"p":324,"n":"HeadlineItemViewModel","y":13,"o":9}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFvK.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Mahjong - Microsoft Games"/> </a>
# </li>
# </ul>
#
#
# <li class="">
# <a data-id="332" data-m='{"i":332,"p":324,"n":"HeadlineItemViewModel","y":13,"o":8}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=ogname" target="_blank">
# Test your game skills </a>
# </li>
#
#
# <a data-id="332" data-m='{"i":332,"p":324,"n":"HeadlineItemViewModel","y":13,"o":8}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=ogname" target="_blank">
# Test your game skills </a>
#
# Test your game skills
#
#
#
#
# <li class="headline-img-container">
# <a data-id="333" data-m='{"i":333,"p":324,"n":"HeadlineItemViewModel","y":13,"o":9}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFvK.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Mahjong - Microsoft Games"/> </a>
# </li>
#
#
# <a data-id="333" data-m='{"i":333,"p":324,"n":"HeadlineItemViewModel","y":13,"o":9}' href="https://www.msn.com/en-us/entertainment/onlinegames/classic-microsoft-mahjong/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFvK.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Mahjong - Microsoft Games"/> </a>
#
#
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUDFvK.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Microsoft Mahjong - Microsoft Games"/>
#
#
#
#
#
#
#
#
#
# <li>
# <ul>
# <li class="">
# <a data-id="334" data-m='{"i":334,"p":324,"n":"HeadlineItemViewModel","y":13,"o":10}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=ogname" target="_blank">
# Ready for a quick game? </a>
# </li>
# <li class="headline-img-container">
# <a data-id="335" data-m='{"i":335,"p":324,"n":"HeadlineItemViewModel","y":13,"o":11}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUE38v.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="All Games - Microsoft Games"/> </a>
# </li>
# </ul>
# </li>
#
#
# <ul>
# <li class="">
# <a data-id="334" data-m='{"i":334,"p":324,"n":"HeadlineItemViewModel","y":13,"o":10}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=ogname" target="_blank">
# Ready for a quick game? </a>
# </li>
# <li class="headline-img-container">
# <a data-id="335" data-m='{"i":335,"p":324,"n":"HeadlineItemViewModel","y":13,"o":11}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUE38v.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="All Games - Microsoft Games"/> </a>
# </li>
# </ul>
#
#
# <li class="">
# <a data-id="334" data-m='{"i":334,"p":324,"n":"HeadlineItemViewModel","y":13,"o":10}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=ogname" target="_blank">
# Ready for a quick game? </a>
# </li>
#
#
# <a data-id="334" data-m='{"i":334,"p":324,"n":"HeadlineItemViewModel","y":13,"o":10}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=ogname" target="_blank">
# Ready for a quick game? </a>
#
# Ready for a quick game?
#
#
#
#
# <li class="headline-img-container">
# <a data-id="335" data-m='{"i":335,"p":324,"n":"HeadlineItemViewModel","y":13,"o":11}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUE38v.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="All Games - Microsoft Games"/> </a>
# </li>
#
#
# <a data-id="335" data-m='{"i":335,"p":324,"n":"HeadlineItemViewModel","y":13,"o":11}' href="https://www.msn.com/en-us/entertainment/onlinegames/?ocid=oglogo" target="_blank">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUE38v.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="All Games - Microsoft Games"/> </a>
#
#
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBUE38v.img?h=22&amp;w=96&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="All Games - Microsoft Games"/>

# %%
for zz in soup.select('.todaystripe.grid')[0].descendants.select('li'):
              print(zz['class'][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-f9912d55ce6f> in <module>
# ----> 1 for zz in soup.select('.todaystripe.grid')[0].descendants.select('li'):
#       2               print(zz['class'][0])
#
# AttributeError: 'generator' object has no attribute 'select'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="hiperf" dir="ltr" lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" style="font-size:62.5%">
# <head data-client-settings='{"geo_country":"us","geo_subdivision":"new york","geo_zip":"10006","geo_ip":"4.16.132.0","geo_lat":"40.7064","geo_long":"-74.0155","os_region":"","apps_locale":"","base_url":"/en-us/homepage/","aid":"1fc9b86a4539446990913fc1d41fb869","sid":null,"v":"20190816_17716915","static_page":false,"empty_gif":"//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif","functionalonly_cookie_experience":false,"functional_cookies":"","functional_cookie_patterns":"","fbid":"132970837947","lvk":"homepage","vk":"homepage","cat":null,"autorefresh":true,"bingssl":false,"autorefreshsettings":{"is_market_enabled":false,"timeout":0,"idle_enabled":false,"idle_timeout":"2"},"uipr":true,"uiprsettings":{"enabled":true,"frequency_minutes":5,"banner_delay_minutes":null,"maxfresh_display":null,"minfresh_count":"5","ajaxtimeoutinseconds":"60"},"imgsrc":{"quality_high":"60","quality_low":"5","order_timeout":"1000"},"adsettings":{"wait_for_ad_in_sec":"3","retry_for_ad":"2"},"mecontroluri":"https://mem.gfx.ms/meversion/?partner=msn&amp;market=en-us","mecontrolv2uri":"","lazyload":{"enabled":true}}' data-delayed-js="//static-global-s-msn-com.akamaized.net/hp-eus/en-us/homepage/_sc/js/b443689a-2923b6c2/direction=ltr.locales=en-us.themes=start.dpi=resolution1x/41-0bee62-68ddb2ab?ver=20190816_17716915&amp;fdhead=msnallexpusers,muidflt47cf,adflt-gal1sec,muidflt52cf,muidflt301cf,mmxandroid1cf,pneedge2cf,moneyhp3cf,bingcollabhp2cf,moneyhz1cf,adrtscanconfiant,compliancehz1cf,article2cf,jslltelemetry&amp;csopd=20190813221457&amp;csopdb=20190814203844" data-info="v:20190816_17716915;a:1fc9b86a-4539-4469-9091-3fc1d41fb869;cn:77;az:{did:9a9a6dcc560c4a5a958f3f1a2bcb24f4, rid: 77, sn: eastus-prod-hp, dt: 2019-08-26T11:10:04.9736929Z, bt: 2019-08-17T00:14:26.0932994Z};ddpi:1;dpio:;dpi:1;dg:tmx.pc.webkit.chrome.chrome76plus;th:start;PageName:startPage;m:en-us;cb:;l:en-us;mu:en-us;ud:{cid:,vk:homepage,n:,l:en-us,ck:};xd:BBnbhK2;ovc:f;al:;fxd:f;xdpub:2019-08-26 06:45:53Z;xdmap:2019-08-26 14:20:26Z;axd:;f:msnallexpusers,muidflt47cf,adflt-gal1sec,muidflt52cf,muidflt301cf,mmxandroid1cf,pneedge2cf,moneyhp3cf,bingcollabhp2cf,moneyhz1cf,adrtscanconfiant,compliancehz1cf,article2cf,jslltelemetry;userOptOut:false;userOptOutOptions:" data-js='{"dpi":1.0,"ddpi":1.0,"dpio":null,"forcedpi":null,"dms":6000,"ps":1000,"bds":7,"dg":"tmx.pc.webkit.chrome.chrome76plus","ssl":true,"moduleapi":"https://www.msn.com/en-us/homepage/api/modules/fetch","cdnmoduleapi":"https://static-global-s-msn-com.akamaized.net/en-us/homepage/api/modules/cdnfetch","pdpdeltaupdateapi":"https://www.msn.com/en-us/homepage/api/pdp/updatepdpdata","xd":"bbnbhk2","signedin":0,"sso":"https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;checkda=1&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=lbi&amp;wreply=https%3a%2f%2fwww.msn.com%2fen-us%2fhomepage%2fsecure%2fsilentpassport%3fsecure%3dtrue&amp;lc=1033&amp;id=1184&amp;mkt=en-us","exchangeenabled":true,"twitterimpenabled":true,"greenidcallenabled":false,"ispreload":false,"anonckname":"","ssocomplete":false}' data-xd-id="BBnbhK2" iris-modules-settings='[{"n":"banner","pid":"10837393","phdiv":"irisbannerph","tmpl":"Banner_Generic1","pos":"top","canvas":"homepage"}]'>
# <script>if(window&&(typeof window.performance=="object")){if(typeof window.performance.mark=="function"){window.performance.mark("TimeToHeadStart");}}</script>
# <meta charset="utf-8"/>
# <script>window.performance&&window.performance.mark&&window.performance.mark("Ars-begin")</script>
# <script>
#                 /*<![CDATA[*///Copyright Instart Tue Aug 06 2019 - All rights reserved - version: 10.9.5
# function Ka(){var t=window;if(function(){var n=!0,i=!1,e="";try{var r="object"==typeof t.IXC_218_36696624189794647&&t.IXC_218_36696624189794647;if(n=!r||void 0===r.CanRun||"_218_36696624189794647"!==r._218_36696624189794647||r.CanRun("abd"))r=t.IXC_218_36696624189794647=t.IXC_218_36696624189794647||{},r.InitStartTime=(t.performance?t.performance:Date).now(),r._218_36696624189794647="_218_36696624189794647",t.INSTART_TARGET_NAME="abd",t.I12C=t.I12C||{};else{var o=t.INSTART_TARGET_NAME;e="double nanovisor injection: abd after "+o,(i="abd"!==o)&&console.warn(e)}t.INSTART=t.INSTART||{},t.INSTART.Init=function(){i&&console.error("ignored Init call after ",e)},r&&(r.ComputeAll=(function(){var module={exports:{}};var exports=module.exports;//copyright Mon Aug 26 2019 09:57:00 GMT+0000 (Coordinated Universal Time)
# Object.defineProperty(exports,"__esModule",{value:!0});var i=function(t,n){n({iadb:{ipknildaoler:[{ias:"script",irusl:["https://www.googletagservices.com/tag/js/gpt.js","https://securepubads.g.doubleclick.net/gpt/pubads_impl_2019032901.js","https://www.googletagservices.com/activeview/js/current/osd.js","https://c.amazon-adsystem.com/aax2/apstag.js","https://z.moatads.com/nativo483ETsY34/moatad.js"]},{ias:"style",irusl:["https://cdn.revcontent.com/build/css/rev2.min.css"]}]}})},r=function(t,n){(t.req.browser("chrome",46,1e3)||t.req.browser("safari",10,1e3))&&n({iadb:{ierelbanenoitcerid:!0}}),(t.req.browser("chrome",46,1e3)||t.req.browser("firefox",38,1e3)||t.req.browser("safari",10,1e3)||t.req.browser("ie",10,1e3)&&document&&document.documentMode<10||t.req.browser("edge",12,1e3))&&n({iadb:{idelbanenoitcete:!0}}),n({iadb:{ivetatselbaira:"MorphState",iolbetatseulavdekc:"blocked",ilbtonetatseulavdekco:"not-blocked",iycnetalelbairav:"Abdt",iircsdekcolbmunsrotcetedkniltp:4,ihtnemelemunsrotcetededi:4,iidekcolbmunsrotcetedgm:4,inoitceteddlohserht:3,ilufelbanenoitcetedl:!0,iyrotsihelbanenoitceriderrof:!1,irotsihmundlohserhty:1,itemeletdbatniopdneyr:"/g00/2_d3d3LmJvc3Rvbi5jb20%3D_/TU9SRVBIRVVTOCRodHRwOi8vY3AtaW4ubmFub3Zpc29yLmlvL2NsaWVudHByb2ZpbGVyL2FkYj9pMTBjLm1hcmsuc2NyaXB0LnR5cGU%3D_$/$/$",iceriderelbasidnoissesrofnoit:!1,isabnoitceriderelbanesrotcetedkniltpircsde:!0,ietedtratsemitnoitc:0,iolbnoreggirterutangisrekc:!1}}),t.req.cookie("i10c.expt.link","true")&&i(t,n),t.req.browser("safari",10,1e3)&&n({iadb:{icolbdaslru_k:["https://s0.2mdn.net/ads/richmedia/studio/pv2/60282074/20170720084443516/script.js","https://cdn.doubleverify.com/dv-match4.js","https://cdn.springserve.com/vd/vd0.2.82.8.js","https://cdn.revcontent.com/build/css/rev2.min.css","https://c.betrad.com/a/n/269/635.js","https://s0.2mdn.net/6440533/1495124845208/Raise%20Your%20Hands_728x90/global.min.css"]}}),(t.req.browser("firefox",38,1e3)||t.req.browser("safari",10,1e3)||t.req.browser("ie",10,1e3)&&document&&document.documentMode<10||t.req.browser("edge",12,1e3))&&n({iadb:{ilufelbanenoitcetedl:!1,iyrotsihelbanenoitceriderrof:!1,iceriderelbasidnoissesrofnoit:!1}})},e=function(t,n){t.req.host("www.101x.com")&&n({iadb:{ithdekcolbstnemelelm:['<div data-size="970x90"></div>',"<div amp4ads></div>"]}})},u=function(t,n){t.req.idtoorniamo("popsci.com")&&n({iadb:{isabnoitceriderelbanesrotcetedkniltpircsde:!1}})},o=function(t,n){t.req.idtoorniamo("cnet.com")&&!(t.req.host("www.cnet.com")||t.req.host("test.cnet.com")||t.req.host("download.cnet.com")||t.req.host("download.stage.cnet.com"))&&n({iadb:{idelbanenoitcete:!1}}),t.req.browser("firefox")&&t.req.host("test.cnet.com")&&n({iadb:{ierelbanenoitcerid:!0}}),t.req.host("www.cnet.com")&&n({iadb:{ithdekcolbstnemelelm:['<div data-load-complete="true"></div>','<div class="d2016-topdeals"></div>','<div data-ad="incontent-ad-plus-billboard-top"></div>',"<div data-ad-cid></div>",'<div class="trc_elastic"></div>','<div data-load-complete="true"></div>']}}),t.req.domain("www.cbssports.com")&&(n({iadb:{ithdekcolbstnemelelm:['<div class="cc-skybox"></div>','<div class="leaderboard-wrap"></div>','<div data-ad="incontent-ad-plus-billboard-top"></div>','<div id="skybox-top-wrapper"></div>']}}),i(t,n))},s=function(t,n){t.req.idtoorniamo("diversitybestpractices.com")&&n({iadb:{iolbnoreggirterutangisrekc:!0}})},c=function(t,n){t.req.idtoorniamo("homes.com")&&t.req.browser("firefox",54,1e3)&&n({iadb:{ierelbanenoitcerid:!0}})},a=function(t,n){t.req.idtoorniamo("edmunds.com")&&t.req.browser("firefox",54,1e3)&&n({iadb:{ierelbanenoitcerid:!0}})},h=function(t,n){t.req.idtoorniamo("geek.com")&&n({iadb:{ipknildaoler:[{ias:"script",irusl:["https://securepubads.g.doubleclick.net/gpt/pubads_impl_2019032901.js","https://googleads.g.doubleclick.net/pagead/xbfe_backfill.js"]}]}})},f=function(t,n){t.req.idtoorniamo("trend-chaser.com")&&t.req.browser("firefox",54,1e3)&&n({iadb:{ierelbanenoitcerid:!0}})},l=function(t,n){(t.req.host("www.msn.com")||t.req.host("int1 ...
#         </script>
# <script>Object.prototype.watch||(Object.defineProperty(Object.prototype,"watch",{value:function(n,t){var i=this[n],r=function(){return i},u=function(r){var u=i;return i=r,u!=r?i=t.call(this,n,u,r):i};delete this[n]&&(Object.defineProperty?Object.defineProperty(this,n,{get:r,set:u}):Object.prototype.__defineGetter__&&Object.prototype.__defineSetter__&&(Object.prototype.__defineGetter__.call(this,n,r),Object.prototype.__defineSetter__.call(this,n,u)))},enumerable:!1,writable:!0}),Object.defineProperty(Object.prototype,"unwatch",{value:function(n){var t=this[n];delete this[n];this[n]=t},enumerable:!1}));window.performance&&window.performance.mark&&(window.performance.mark("Ars-end"),window.performance.measure&&window.performance.measure("InstartExecutionTime","Ars-begin","Ars-end"))</script>
# <meta content="index, follow" name="robots"/> <link as="font" crossorigin="anonymous" href="//static-global-s-msn-com.akamaized.net/hp-eus/sc/57/06635e.woff2" rel="preload" type="font/woff2"/>
# <link href="img-s-msn-com.akamaized.net" rel="preconnect"/><link href="c.msn.com" rel="preconnect"/><link href="c.msn.cn" rel="preconnect"/><link href="https://www.bing.com" rel="preconnect"/><link href="//web.vortex.data.msn.com" rel="preconnect"/><link href="img-s-msn-com.akamaized.net" rel="dns-prefetch"/><link href="c.msn.com" rel="dns-prefetch"/><link href="c.msn.cn" rel="dns-prefetch"/><link href="https://www.bing.com" rel="dns-prefetch"/><link href="//web.vortex.data.msn.com" rel="dns-prefetch"/><link href="https://www.msn.com/" rel="canonical"/><meta content="#224f7b" name="msapplication-TileColor"/><meta content="//static-global-s-msn-com.akamaized.net/hp-eus/sc/1f/08ced4.png" name="msapplication-TileImage"/><meta content="none" name="msapplication-config"/><link href="https://chrome.google.com/webstore/detail/msn-homepage-bing-search/aodojjhnfnfhaplflfohfddffmjkdjak" rel="chrome-webstore-item"/> <title>MSN | Outlook, Office, Skype, Bing, Breaking News, and Latest Videos</title>
# <meta content="Your customizable and curated collection of the best in trusted news plus coverage of sports, entertainment, money, weather, travel, health and lifestyle, combined with Outlook/Hotmail, Facebook, Twitter, Bing, Skype and more." name="description"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/>
# <link href="//static-global-s-msn-com.akamaized.net/hp-eus/en-us/homepage/_sc/css/b443689a-29c081be/direction=ltr.locales=en-us.themes=start.dpi=resolution1x/2e-eefbdd-c1936139/8e-044ac4-d0192583/31-c31fb0-68ddb2ab/49-481f80-677c872a/b4-ee7adb-f64ad38d/d8-789b17-d91a920/69-8f5e1d-d8da69e2/25-dd7b49-d55835e5/85-d5cc0b-f6fc6aac/18-56aa26-dbc6220a/7e-9493f9-5fe1842f/b8-cbc6ea-793099c5/67-f5a030-95aa7dda/1e-ed96c4-6163f058/b5-77bbe0-e1d32d27/d0-c37c5e-e329ca6a/18-840e30-8975ceac/89-b918c0-e8cb1e4c/c3-6de9e8-d256b11b/ee-376c22-e92f4bc3/50-43536d-a174d24c/bd-a43d36-423c26e1/ae-0f4566-a484bc65/7f-3aeb1d-f1c08ae4/eb-0afd66-dd61d236/23-5d0d80-cbf31fb5/8a-19583d-17636285/be-cca965-3380d0ba?ver=20190816_17716915&amp;fdhead=msnallexpusers,muidflt47cf,adflt-gal1sec,muidflt52cf,muidflt301cf,mmxandroid1cf,pneedge2cf,moneyhp3cf,bingcollabhp2cf,moneyhz1cf,adrtscanconfiant,compliancehz1cf,article2cf,jslltelemetry&amp;csopd=20190813221457&amp;csopdb=20190814203844" media="all" rel="stylesheet" type="text/css"/><script>(function(n){function i(i,r){try{var u=new n.FontFace(i,r,{}).load();t.push(u)}catch(f){}}var t=[];typeof n.FontFace=="function"&&i("ps_g","url(//static-global-s-msn-com.akamaized.net/hp-eus/sc/57/06635e.woff2)")})(window),function(n,t){function h(n,i,r){typeof n!="string"&&(r=i,i=n,n=t);i&&i.splice||(r=i,i=[]);n==it?a=!0:n==rt&&(v=!0);l(n,i,r,!1,!1)}function l(n,t,i,r,f,e){var s,y;if(!n||!c[n]){var h=ot(n,t),o=h.dependencyNotFound,l=h.resolved;if(o){typeof u[o]=="undefined"&&(u[o]=[]);u[o].push(e||{i:n,d:t,f:i,r:r,s:f});return}s=typeof i=="function";y=v&&a&&s&&!f;y?et(n,i,l,r):ft(s,n,i,l,r)}}function ft(n,t,i,r,u){var f;f=n?i.apply(null,r):i;d(t,f,u)}function et(n,t,i,r){setTimeout(function(){var u=t.apply(null,i);d(n,u,r)},1)}function d(t,i,r){r&&(i={});t&&(i?(c[t]=i,f.push(t),g()):n.console&&console.error("Dependencies resolved, but object still not defined (or is otherwise falsey). id:"+t+"; typeof obj: "+typeof i))}function g(){var t,s,h,i,o,c,r,n;if(e)e&&(e=2);else{t=[];do{for(e=1,h=f.length,i=0;i<h;i++)o=f[i],c=u[o]||[],t=t.concat(c),delete u[o];for(f=[],s=t.length,r=0;r<s;r++)n=t[r],l(n.i,n.d,n.f,n.r,n.s,n);t=[]}while(e>1);e=0}}function ot(n,t){for(var e,i=[],r,o=t?t.length:0,u=0;u<o;u++){var f=t[u],s=c[f],h=typeof s!="undefined";if(!h){if(e=st(n,f),e){i.push(e);continue}r||(r=f);break}i.push(s)}return o===i.length?{resolved:i}:{dependencyNotFound:r}}function st(i,r){var f=k.exec(r),e,u;if(f){if(e=f[1],u=n[e],u!==t)return u;s||(s=setTimeout(nt,w))}}function nt(){var i,r,e,o,h;s=0;i=!1;for(r in u)e=k.exec(r),e&&(o=e[1],h=n[o],h!==t?f.push(r):i=!0);i&&!s&&(s=setTimeout(nt,w));f.length&&g()}function ht(n,t,i){if((typeof n!="object"||n&&n.splice)&&(i=t,t=n,n={}),t&&t.splice||(i=t,t=[]),ct(n.js),i){var r,u=n.synchronous||!1;l(r,t,i,!0,u)}}function ct(n){if(typeof n=="string")tt(n);else if(n)for(var t=0;t<n.length;t++)tt(n[t])}function tt(n){if(!b[n]){b[n]=1;var i=o.getElementsByTagName("script")[0],t=o.createElement("script");t.src=n;t.onload=t.onreadystatechange=function(){this.readyState&&this.readyState!="loaded"&&this.readyState!="complete"||(t.onload=t.onreadystatechange=null,t.parentNode&&t.parentNode.removeChild(t))};i.parentNode.insertBefore(t,i)}}function lt(n){return ut?n?i.now():Math.round(i.now()):new Date-y}var it=n._jsLoaderAsyncCanary||"c.dom",rt="c.pageReveal",a=!1,v=typeof n._jsLoaderRevealMode=="undefined"?!0:n._jsLoaderRevealMode,i=n.performance,ut=i&&typeof i.now=="function",r=" ----- ",y=((i||{}).timing||{}).navigationStart||+new Date,o=n.document,p=null;try{p=n.localStorage}catch(at){}var c={date:Date,document:o,image:n.Image,localStorage:p,location:o&&o.location,navigator:navigator,pageStart:y,pageTime:lt,screen:n.screen,window:n},u={},f=[],e,w=50,s,b={},k=/^window\.(.+)$/;h.amd={jQuery:1};h.is=function(n){return typeof c[n]!="undefined"};n.define=h;n.require=ht;h.showUserMarks=function(){var n=["Mark Name"+r+"Start time in ms"];return i.getEntriesByType("mark").forEach(function(t){n.push(t.name+r+t.startT ...
# <script>(function(){function u(){window.performance.mark("frame");console.timeStamp("frame");i||s();performance.now()<o&&requestAnimationFrame(u)}function s(){r=n;n=performance.now();n-r<=e?n-t>=f&&(window._pageTimings||(window._pageTimings={}),window._pageTimings.TimeToPageInteractive=Math.round(t),i=!0):t=n}var i=!1,n=0,r=0,t=0,f=1e3,e=200,o=3e4;window.performance&&window.performance.mark&&window.performance.now&&window.requestAnimationFrame&&requestAnimationFrame(u)})()</script>
# <script>window._perfMarker && window._perfMarker("TimeToHeadEnd"); window._perfMeasure && window._perfMeasure("TimeForHead", "TimeToHeadStart", "TimeToHeadEnd", true);</script>
# </head>
# <body class="startpage sp center-content start tmx pc webkit chrome chrome76plus fltmsnallexpusers fltmuidflt47cf fltadflt-gal1sec fltmuidflt52cf fltmuidflt301cf fltmmxandroid1cf fltpneedge2cf fltmoneyhp3cf fltbingcollabhp2cf fltmoneyhz1cf fltadrtscanconfiant fltcompliancehz1cf fltarticle2cf fltjslltelemetry">
# <script>window._perfMarker && window._perfMarker("TimeToBodyStart");</script>
# <script>
#                 require(["headData", "pageInstance", "mediator"], function (headData, pageInstance, mediator)
#                 {
#                     var url = '//c.msn.com/c.gif?udc=true&rid=1fc9b86a4539446990913fc1d41fb869&rnd=637024261372398288&rf=&tp=https%253A%252F%252Fwww.msn.com%252F&di=340&lng=en-us&activityId=1fc9b86a4539446990913fc1d41fb869&d.dgk=tmx.pc.webkit.chrome.chrome76plus&d.imd=0&st.dpt=&st.sdpt=&subcvs=homepage&pg.n=startpage&pg.t=hp&pg.c=&pg.p=prime&anoncknm=&issso=0&aadState=0';
#                     if (headData && headData.clientSettings && headData.clientSettings.static_page)
#                     {
#                         mediator.pub(pageInstance.eventName);
#                         var rid = pageInstance.getActivityId();
#                         url = url.replace(/([?&]rid=)[^&#]*/i, "$1" + rid);
#                     }
#
#                     var img = new Image();
#                     img.onload = img.onerror = function ()
#                     {
#                         img.onload = img.onerror = null;
#                     };
#                     img.src = url;
#
#  });
# </script>
# <script>
# /*<![CDATA[*/
#  require(["jsll-bootstrap"],function(jsllbt){jsllbt.initialize({"isLoggedIn":"False","logLevel":"1","jsError":"false","env":"prod","appId":"MSN","endpoint":"https://web.vortex.data.msn.com/collect/v1"});});require(["track","track.generic","c.track.mobi"],function(t,g,o){t.extend({"sitePage":{"department":"","subDepartment":"","channel":"homepage","page_name":"startpage","page_type":"hp","page_product":"prime","storeocid":"msn","pageUrl":"https%3A%2F%2Fwww.msn.com%2F","autoRefresh":"0","requestId":"1fc9b86a4539446990913fc1d41fb869","serverImpressionGuid":"1fc9b86a4539446990913fc1d41fb869","canvas":"Browser","vertical":"homepage","entityId":"","entityCollectionId":"","entitySrc":"","cvAuthor":"","d_dgk":"tmx.pc.webkit.chrome.chrome76plus","d_imd":"0","cvPartner":"","cvPublcat":"","provid":"","templ":"RR:0;lo:Y_cec865fe-ed84-49a8-b88a-4a23446ea7f1;EAggMo:0;bingclicklda;IP:Cb;RV:Cb;infopane:0;cat:0;EP:0;CI:0;mIpH:2;mRvH:2","pageIndex":"","pageTotalCount":"","isStaticPage":"False","pageVersion":"15","contentType":"unknown_use_metadata_to_set_the_content_type","isCorePV":"","chartBeatUID":"42635","chartBeatDomain":"msn.com","chartBeatBase":"https://static.chartbeat.com","otfURL":"//otf.msn.com/c.gif?","flightid":"msnallexpusers,muidflt47cf,adflt-gal1sec,muidflt52cf,muidflt301cf,mmxandroid1cf,pneedge2cf,moneyhp3cf,bingcollabhp2cf,moneyhz1cf,adrtscanconfiant,compliancehz1cf,article2cf,jslltelemetry","exa":"msnallexpusers,muidflt47cf,adflt-gal1sec,muidflt52cf,muidflt301cf,mmxandroid1cf,pneedge2cf,moneyhp3cf,bingcollabhp2cf,moneyhz1cf,adrtscanconfiant,compliancehz1cf,article2cf,jslltelemetry","device":"Unknown Unknown","domainId":"340","propertyId":"","propertySpecifier":"","pageMode":"","localeCode":"en-us"},"userStatic":{"isSignedIn":"False","beginRequestTicks":"637024261372398288"}});t.register(new g({"base":"//c.msn.com/c.gif?","id":"ctag","disableOnAutoRefresh":"scorecard","isGeneratedEarly":1,"rmca":1,"impr":{"param":{'udc': 'true'},"paramMap":{"event":{'evt':'type'},"userDynamic":{'rid':'requestId','rnd':'timeStamp'},"client":{'rf':'referrer','tp':'pageUrl','scr':'screenResolution','anoncknm':'getAnonCookieName','issso':'getSsoComplete','aadState':'getAadAuthentication'},"sitePage":{'di':'domainId','lng':'localeCode','activityId':'requestId','d.dgk':'d_dgk','d.imd':'d_imd','st.dpt':'department','st.sdpt':'subDepartment','subcvs':'vertical','pg.n':'page_name','pg.t':'page_type','pg.c':'page_configuration','pg.p':'page_product'}}}}),new g({"base":"https://sb.scorecardresearch.com/b?","id":"scorecard","disableOnAutoRefresh":"scorecard","isGeneratedEarly":0,"impr":{"param":{'c1': '2', 'c2': '3000001', 'cs_ucfr': '1'},"paramMap":{"userDynamic":{'rn':'timeStamp'},"client":{'c7':'pageUrl','c8':'pageTitle','c9':'referrer'}}},"page_candidate":{"paramMap":{"event":{'evt':'type'},"userDynamic":{'rn':'timeStamp'},"client":{'c7':'pageUrl','c8':'pageTitle','c9':'referrer'}}}}),new g({"base":"//otf.msn.com/c.gif?","id":"udc","disableOnAutoRefresh":"scorecard","commonMap":{"userDynamic":{'rid':'requestId','cts':'timeStamp','idx':'currentEventIndex'},"client":{'clid':'clientId','anoncknm':'getAnonCookieName','issso':'getSsoComplete','aadState':'getAadAuthentication'},"sitePage":{'di':'domainId','mkt':'localeCode','su':'pageUrl','flightid':'flightid','activityId':'requestId','cvs':'canvas','subcvs':'vertical','pg.n':'page_name','pg.t':'page_type','pg.c':'page_configuration','pg.p':'page_product','pivot':'pagePivot','pageuid':'pageUserId','pageutype':'pageUserType'}},"isGeneratedEarly":0,"impr":{"param":{'evt': 'impr', 'js': '1'},"paramMap":{"userStatic":{'pp':'isSignedIn'},"userDynamic":{'dv.snlogin':'settings','dv.grpfrmod':'defaultSlotTrees'},"client":{'rf':'referrer','cu':'pageUrl','scr':'screenResolution','bh':'height','bw':'width','dv.Title1':'pageTitle','viewType':'viewType','e1':'OTFTelemetry','prs':'personalization','oscm':'connectionMode','osver':'buildVersion'},"sitePage":{'st.dpt':'department','st.sdpt':'subDepartment','cv.partner':'cvP ...
# //]]>
# </script>
# <noscript>
# <img alt="image beacon" height="1" src="//c.msn.com/c.gif?udc=true&amp;rid=1fc9b86a4539446990913fc1d41fb869&amp;rnd=637024261372398288&amp;rf=&amp;tp=https%253A%252F%252Fwww.msn.com%252F&amp;di=340&amp;lng=en-us&amp;activityId=1fc9b86a4539446990913fc1d41fb869&amp;d.dgk=tmx.pc.webkit.chrome.chrome76plus&amp;d.imd=0&amp;st.dpt=&amp;st.sdpt=&amp;subcvs=homepage&amp;pg.n=startpage&amp;pg.t=hp&amp;pg.c=&amp;pg.p=prime&amp;anoncknm=&amp;issso=0&amp;aadState=0" width="1"/><img alt="image beacon" height="1" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=3000001&amp;cs_ucfr=1&amp;rn=637024261372398288&amp;c7=https%253A%252F%252Fwww.msn.com%252F&amp;c8=&amp;c9=" width="1"/><img alt="image beacon" height="1" src="https://web.vortex.data.msn.com/collect/v1/t.gif?name='Ms.Webi.PageView'&amp;ver='2.1'&amp;appId='JS:MSN'&amp;ext-app-env='prod'&amp;ext-javascript-libver='4.0.0-beta-10'&amp;ext-user-localId='t:35C7EDEF0AF66FD429A0E02B0B7E6E2D'&amp;*baseType='Ms.Content.PageView'&amp;*isJs=False&amp;*title=''&amp;*isLoggedIn=False&amp;*isManual=True&amp;*serverImpressionGuid='1fc9b86a-4539-4469-9091-3fc1d41fb869'&amp;-ver='1.0'&amp;-impressionGuid='1fc9b86a-4539-4469-9091-3fc1d41fb869'&amp;-pageName='startpage'&amp;-uri='https%253A%252F%252Fwww.msn.com%252F'&amp;-referrerUri=''&amp;-pageTags='{&quot;pg.t&quot;:&quot;hp&quot;%2C&quot;pg.p&quot;:&quot;prime&quot;%2C&quot;pg.c&quot;:&quot;&quot;%2C&quot;ex&quot;:&quot;&quot;%2C&quot;rid&quot;:&quot;1fc9b86a-4539-4469-9091-3fc1d41fb869&quot;%2C&quot;di&quot;:&quot;340&quot;%2C&quot;partner&quot;:&quot;&quot;%2C&quot;publcat&quot;:&quot;&quot;%2C&quot;cvs&quot;:&quot;Browser&quot;%2C&quot;subcvs&quot;:&quot;homepage&quot;%2C&quot;entityId&quot;:&quot;&quot;%2C&quot;entitySrc&quot;:&quot;&quot;%2C&quot;provid&quot;:&quot;&quot;%2C&quot;dpt&quot;:&quot;&quot;%2C&quot;sdpt&quot;:&quot;&quot;%2C&quot;ar&quot;:&quot;0&quot;%2C&quot;dgk&quot;:&quot;tmx.pc.webkit.chrome.chrome76plus&quot;%2C&quot;imd&quot;:&quot;0&quot;%2C&quot;parentId&quot;:&quot;&quot;%2C&quot;pgIdx&quot;:&quot;&quot;%2C&quot;pgTot&quot;:&quot;&quot;%2C&quot;anoncknm&quot;:&quot;&quot;%2C&quot;issso&quot;:&quot;0&quot;%2C&quot;aadState&quot;:&quot;0&quot;}'&amp;-behavior=0&amp;-market='en-us'" width="1"/>
# </noscript>
# <div id="irisbannerph"></div>
# <div class="head">
# <header class="no-overlay" data-id="1" data-m='{"i":1,"n":"header","y":6}' data-region="header" id="header-common" role="banner">
# <h1 class="h1">
# <a aria-label="back to msn home" class="logo" data-id="2" data-m='{"i":2,"p":1,"n":"msnLogo","y":14,"l":"homepage","o":1}' href="/en-us" tabindex="2">
# <span class="">msn</span> <span class="logohover">refresh page</span>
# </a>
# <a aria-haspopup="true" class="vertical" data-id="3" data-m='{"i":3,"p":1,"n":"HeaderVerticalLink","y":14,"l":"homepage","o":2}' href="/en-us" tabindex="2">msn</a>
# </h1>
# <div class="logosubtitle">
#  powered by <span class="msnews">Microsoft News</span>
# </div>
# <ul>
# <li>
# <section class="" data-aop="search" data-id="4" data-m='{"i":4,"p":1,"n":"headersearch","y":9,"o":3}' id="header-search" role="search">
# <form action="https://www.bing.com/search?scope=web" data-bing-action-uri="https://www.bing.com/search?scope=web" data-form-code="PRUSEN" id="srchfrm" method="get" target="_blank">
# <div class="qc">
# <input accesskey="S" aria-label="Search:" autocomplete="off" data-id="5" data-m='{"i":5,"p":4,"n":"searchinput","y":9,"o":1}' id="q" maxlength="250" name="q" title="enter your search term" type="search" value=""/>
# </div>
# <div class="buttons">
# <svg class="bingicon" role="img" viewbox="0 0 40 40" xmlns="http://www.w3.org/2000/svg">
# <path d="M 14 30.94 v -28.14 l -8 -2.8 v 35.54 l 8 4.46 l 20 -11.5 v -9.1 Z" fill="#666"></path>
# <path d="M 25.28 24.43 l 8.72 -5.03 l -17.74 -6.2 l 3.47 8.65 l 5.55 2.58 Z" fill="#666" opacity=".75"></path>
# </svg>
# <button class="text" data-id="6" data-m='{"i":6,"p":4,"n":"search_websearch","y":9,"o":2}' id="sb_form_go" title="web search">web search</button>
# </div>
# <input name="form" type="hidden" value="PRUSEN"/>
# <input name="mkt" type="hidden" value="en-us"/>
# <input name="httpsmsn" type="hidden" value="1"/>
# <input name="refig" type="hidden" value="1fc9b86a4539446990913fc1d41fb869"/>
# </form>
# <button data-id="7" data-m='{"i":7,"p":4,"n":"search_sb","y":9,"o":3}' id="sb" title="web search" type="button"></button>
# </section>
# </li>
# <li>
# <button class="skip-to" data-id="8" data-m='{"i":8,"p":1,"n":"skip_to_nav","y":11,"o":4}' id="skip_to_nav">Skip To Navigation</button>
# </li>
# <li>
# <button class="skip-to" data-id="9" data-m='{"i":9,"p":1,"n":"skip_to_con","y":11,"o":5}' id="skip_to_con">Skip To Content</button>
# </li>
# <li>
# <button class="skip-to" data-id="10" data-m='{"i":10,"p":1,"n":"skip_to_footer","y":11,"o":6}' id="skip_to_footer">Skip To Footer</button>
# </li>
# <li>
# <ul data-dhp_cookie_days="0" data-id="11" data-m='{"i":11,"p":1,"n":"header-signin","t":"signin","o":7}' data-module-id="startpage|start.header|header|header-signin|signin" data-sso-dependent="true" id="user-profile">
# <li id="sign-in">
# <div data-anonckname="" data-me-url="https://login.live.com/me.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2F%2Fwww.msn.com%2Fen-us%2Fhomepage%2FSecure%2FPassport%3Fru%3Dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us" data-sign-in-url="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True" data-sign-out-url="https://login.live.com/logout.srf?ct=1566829338&amp;rver=7.0.6730.0&amp;lc=1033&amp;id=1184&amp;lru=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f&amp;mkt=en-us&amp;pcexp=True" id="meCtrl">
# <a data-id="12" data-m='{"i":12,"p":11,"n":"SignInNavigation","y":14,"o":1}' href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True" title="Sign in">
# <span class="mectrlname mectrlsignin">Sign in</span>
# </a>
# </div>
# <script>require(["refreshSigninModule", "c.sso"], function (r) { r() })</script>
# </li>
# <li id="settings" role="presentation">
# <a alt="settings" aria-label="page settings" data-id="13" data-m='{"i":13,"p":11,"n":"settings","y":14,"o":2}' href="#temp"></a>
# <ul>
# <li role="presentation">
# <label>Change language &amp; content:</label>
# <select aria-label="Change language &amp; content:" data-id="14" data-m='{"i":14,"p":11,"n":"changemarket","y":14,"o":3}' id="site-market" rel="nofollow" role="menuitem">
# <option data-mkt="es-xl" data-mkt-url="//www.msn.com/es-xl">América Latina (español)</option>
# <option data-mkt="es-ar" data-mkt-url="//www.msn.com/es-ar">Argentina (español)</option>
# <option data-mkt="en-au" data-mkt-url="//www.msn.com/en-au">Australia (English)</option>
# <option data-mkt="nl-be" data-mkt-url="//www.msn.com/nl-be">België (Nederlands)</option>
# <option data-mkt="fr-be" data-mkt-url="//www.msn.com/fr-be">Belgique (français)</option>
# <option data-mkt="pt-br" data-mkt-url="//www.msn.com/pt-br">Brasil (português)</option>
# <option data-mkt="en-ca" data-mkt-url="//www.msn.com/en-ca">Canada (English)</option>
# <option data-mkt="fr-ca" data-mkt-url="//www.msn.com/fr-ca">Canada (français)</option>
# <option data-mkt="cs-cz" data-mkt-url="//www.msn.com/cs-cz">Česká republika (čeština)</option>
# <option data-mkt="es-cl" data-mkt-url="//www.msn.com/es-cl">Chile (español)</option>
# <option data-mkt="es-co" data-mkt-url="//www.msn.com/es-co">Colombia (español)</option>
# <option data-mkt="da-dk" data-mkt-url="//www.msn.com/da-dk">Danmark (Dansk)</option>
# <option data-mkt="de-de" data-mkt-url="//www.msn.com/de-de">Deutschland (Deutsch)</option>
# <option data-mkt="es-es" data-mkt-url="//www.msn.com/es-es">España (español)</option>
# <option data-mkt="fr-fr" data-mkt-url="//www.msn.com/fr-fr">France (français)</option>
# <option data-mkt="en-in" data-mkt-url="//www.msn.com/en-in">India (English)</option>
# <option data-mkt="mr-in" data-mkt-url="//www.msn.com/mr-in">India (मराठी)</option>
# <option data-mkt="hi-in" data-mkt-url="//www.msn.com/hi-in">India (हिंदी)</option>
# <option data-mkt="te-in" data-mkt-url="//www.msn.com/te-in">India (తెలుగు)</option>
# <option data-mkt="id-id" data-mkt-url="//u.msn.com/id-id">Indonesia (Bahasa Indonesia)</option>
# <option data-mkt="en-xl" data-mkt-url="//www.msn.com/en-xl">International Edition (English)</option>
# <option data-mkt="en-ie" data-mkt-url="//www.msn.com/en-ie">Ireland (English)</option>
# <option data-mkt="it-it" data-mkt-url="//www.msn.com/it-it">Italia (italiano)</option>
# <option data-mkt="hu-hu" data-mkt-url="//www.msn.com/hu-hu">Magyarország (magyar)</option>
# <option data-mkt="en-my" data-mkt-url="//www.msn.com/en-my">Malaysia (English)</option>
# <option data-mkt="es-mx" data-mkt-url="//prodigy.msn.com/es-mx">México (español)</option>
# <option data-mkt="nl-nl" data-mkt-url="//www.msn.com/nl-nl">Nederland (Nederlands)</option>
# <option data-mkt="en-nz" data-mkt-url="//www.msn.com/en-nz">New Zealand (English)</option>
# <option data-mkt="nb-no" data-mkt-url="//www.msn.com/nb-no">Norge (norsk, bokmål)</option>
# <option data-mkt="de-at" data-mkt-url="//www.msn.com/de-at">Österreich (Deutsch)</option>
# <option data-mkt="es-pe" data-mkt-url="//www.msn.com/es-pe">Perú (español)</option>
# <option data-mkt="en-ph" data-mkt-url="//www.msn.com/en-ph">Philippines (English)</option>
# <option data-mkt="pl-pl" data-mkt-url="//www.msn.com/pl-pl">Polska (polski)</option>
# <option data-mkt="pt-pt" data-mkt-url="//www.msn.com/pt-pt">Portugal (Português)</option>
# <option data-mkt="de-ch" data-mkt-url="//www.msn.com/de-ch">Schweiz (Deutsch)</option>
# <option data-mkt="en-sg" data-mkt-url="//www.msn.com/en-sg">Singapore (English)</option>
# <option data-mkt="en-za" data-mkt-url="//www.msn.com/en-za">South Africa (English)</option>
# <option data-mkt="fr-ch" data-mkt-url="//www.msn.com/fr-ch">Suisse (français)</option>
# <option data-mkt="fi-fi" data-mkt-url="//www.msn.com/fi-fi">Suomi (suomi)</option>
# <option data-mkt="sv-se" data-mkt-url="//www.msn.com/sv-se">Sverige (svenska)</option>
# <option data-mkt="tr-tr" data-mkt-url="//www.msn.com/tr-tr">Türkiye (Türkçe)</option>
# <option data-mkt="en-ae" data-mkt-url="//www.msn.com/en-ae">United Arab Emirates (English)</option>
# <option data-mkt="en-gb" data-mkt-url="//www.msn.com/en-gb">United Kingdom (English)</option>
# <option data-mkt="en-us" data-mkt-url="//www.msn.com/en-us" selected="">United States (English)</option>
# <option data-mkt="es-us" data-mkt-url="//www.msn.com/es-us">United States (español)</option>
# <option data-mkt="es-ve" data-mkt-url="//www.msn.com/es-ve">Venezuela (español)</option>
# <option data-mkt="vi-vn" data-mkt-url="//www.msn.com/vi-vn">Việt Nam (Tiếng Việt)</option>
# <option data-mkt="el-gr" data-mkt-url="//www.msn.com/el-gr">Ελλάδα (ελληνικά)</option>
# <option data-mkt="ru-ru" data-mkt-url="//www.msn.com/ru-ru">Россия (Pусский)</option>
# <option data-mkt="he-il" data-mkt-url="//www.msn.com/he-il">ישראל (עברית)‏</option>
# <option data-mkt="ar-ae" data-mkt-url="//www.msn.com/ar-ae">الإمارات العربية المتحدة (العربية‏)</option>
# <option data-mkt="ar-sa" data-mkt-url="//www.msn.com/ar-sa">المملكة العربية السعودية (العربية‏)</option>
# <option data-mkt="ar-eg" data-mkt-url="//www.msn.com/ar-eg">مصر (العربية‏)</option>
# <option data-mkt="th-th" data-mkt-url="//www.msn.com/th-th">ไทย (ไทย)</option>
# <option data-mkt="ko-kr" data-mkt-url="//www.msn.com/ko-kr">한국 (한국어)</option>
# <option data-mkt="zh-cn" data-mkt-url="//www.msn.cn/zh-cn">中华人民共和国 (简体中文)</option>
# <option data-mkt="zh-tw" data-mkt-url="//www.msn.com/zh-tw">台灣 (繁體中文)</option>
# <option data-mkt="ja-jp" data-mkt-url="//www.msn.com/ja-jp">日本 (日本語)</option>
# <option data-mkt="zh-hk" data-mkt-url="//www.msn.com/zh-hk">香港特别行政區 (繁體中文)</option>
# </select>
# </li>
# <li class="marketswitch" data-id="15" data-m='{"i":15,"p":11,"n":"marketswitch","y":14,"o":4}' data-mkt="es-us" data-mkt-url="//www.msn.com/es-us" role="presentation">
# <button data-customhandled="" role="menuitem">Switch to Latino (Español)</button>
# </li>
# <li class="global" role="presentation">
# <button class="personalization" data-id="16" data-m='{"i":16,"p":11,"n":"personalization","y":11,"o":5}' role="menuitem">Customize this page</button>
# </li>
# <li role="presentation">
# <a data-id="17" data-m='{"i":17,"p":11,"n":"homepagelink","y":14,"l":"homepage","o":6}' href="https://chrome.google.com/webstore/detail/msn-homepage-bing-search/aodojjhnfnfhaplflfohfddffmjkdjak" id="makehomepage" role="menuitem" target="_blank">Make MSN my homepage</a>
# </li>
# <li class="feedback" role="presentation">
# <a data-id="18" data-m='{"i":18,"p":11,"n":"feedback","y":14,"o":7}' href="#" id="usermenu-feedback" role="menuitem">
#  Feedback
# </a>
# </li>
# <li role="presentation">
# <a data-id="19" data-m='{"i":19,"p":11,"n":"helpLink","y":14,"l":"homepage","o":8}' href="https://support.microsoft.com/product/msn/msn" role="menuitem" target="_blank">Help</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <div data-id="20" data-m='{"i":20,"p":1,"n":"header-languagetoggle","t":"languagetoggle","o":8}' id="language-toggle">
# <button aria-haspopup="true" aria-label="Choose a language" id="langtoggle">en</button>
# <ul>
# <li>Choose a language</li>
# <li class="langtoggle selected" data-mkt="en-us" data-mkt-url="//www.msn.com/en-us" tabindex="0">United States (English) - <span>en</span></li>
# <li class="langtoggle" data-mkt="es-us" data-mkt-url="//www.msn.com/es-us" tabindex="0">United States (español) - <span>es</span></li>
# </ul>
# </div>
# </li>
# </ul>
# </header>
# <div class="search-overlay" data-aop="search-overlay"></div>
# </div>
# <div data-id="21" data-m='{"i":21,"n":"precontent","y":6}' data-region="precontent" id="precontent">
# <div class="custombanner invisible" data-aop="uipr_bar" data-id="22" data-m='{"i":22,"n":"UIPR_render","y":8}' id="refreshbar" title="refresh page">
# <div class="refreshbody">
# <a data-id="23" data-m='{"i":23,"p":22,"n":"UIPR_button","y":11,"o":1}' href="https://www.msn.com:443/">
# <span class="icon reset"></span>
# <span aria-hidden="true" class="text">New content is available. <span class="underline">Click here to refresh the page.</span></span>
# <span class="button" role="button">REFRESH</span>
# </a>
# <a class="icon delete" data-id="24" data-m='{"i":24,"p":22,"n":"UIPR_close","y":11,"o":2}' href="#" title="close"></a>
# </div>
# </div>
# <div id="mestripebg"></div>
# </div>
# <div id="maincontent">
# <div class="content" id="content">
# <main data-id="25" data-m='{"i":25,"n":"main","y":6}' data-region="main" id="main" role="main">
# <div class="stripeouter mestripeouter" data-aop="mestripe_mestripe" data-emptygif="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" data-id="26" data-m='{"i":26,"p":25,"n":"meStripe","t":"meStripe","o":1}' data-section-id="mestripe">
# <div class="mestripescrollfix">
# <button class="stripearrow" data-aop="leftarrow" data-id="27" data-m='{"i":27,"p":26,"n":"leftarrow","y":12,"o":1}' title="previous"></button>
# <div class="mestripe">
# <h2 class="hide">Portals Navigation</h2>
# <ul role="menubar">
# <li class="mail" data-aop="mestripe.mail_me" data-id="28" data-m='{"i":28,"p":26,"n":"meStripe.mail","t":"me","o":2}' role="presentation">
# <a data-piitxt="mail" href="https://outlook.com/" piiurl="https://outlook.com/" target="_blank">
# <h3>Outlook.com<span></span></h3>
# </a>
# </li>
# <li class="store" data-aop="mestripe.store_mestore2" data-id="29" data-m='{"i":29,"p":26,"n":"meStripe.store","t":"meStore2","o":3}' role="presentation">
# <a data-piitxt="store" href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/home?icid=MSN_storeTILE" piiurl="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/home?icid=MSN_storeTILE" target="_blank">
# <h3>Microsoft Store<span></span></h3>
# </a>
# </li>
# <li class="jsskype" data-aop="mestripe.jsskype_mejsskype" data-id="30" data-m='{"i":30,"p":26,"n":"meStripe.jsSkype","t":"meJsSkype","o":4}' role="presentation">
# <a data-piitxt="jsSkype" href="https://www.skype.com/" piiurl="https://www.skype.com/" target="_blank">
# <h3>Skype<span></span></h3>
# </a>
# </li>
# <li class="custom bingshopping" data-aop="mestripe.bingshopping_me" data-id="31" data-m='{"i":31,"p":26,"n":"meStripe.BingShopping","t":"me","o":5}' onhovercolor="#f24d5c" role="presentation">
# <a data-piitxt="custom BingShopping" href="https://www.bing.com/shop?q=shopping&amp;FORM=PHMSBI" piiurl="https://www.bing.com/shop?q=shopping&amp;FORM=PHMSBI" target="_blank">
# <h3>Shopping<span></span></h3>
# </a>
# </li>
# <li class="bingrewards" data-aop="mestripe.mebingrewards_mebingrewards" data-id="32" data-m='{"i":32,"p":26,"n":"meStripe.mebingrewards","t":"meBingRewards","o":6}' data-module-id="startpage|meStripe|meStripe|meStripe.mebingrewards|meBingRewards" role="presentation">
# <a data-piitxt="bingrewards" href="https://www.bing.com/rewards/dashboard" piiurl="https://www.bing.com/rewards/dashboard" target="_blank">
# <h3>Rewards<span></span></h3>
# </a>
# </li>
# <li class="facebooklite" data-aop="mestripe.facebooklite2_mefacebooklite" data-id="33" data-m='{"i":33,"p":26,"n":"meStripe.facebooklite2","t":"meFacebookLite","o":7}' role="presentation">
# <a data-piitxt="facebooklite" href="https://www.facebook.com/" piiurl="https://www.facebook.com/" target="_blank">
# <h3>Facebook<span></span></h3>
# </a>
# </li>
# <li class="office" data-aop="mestripe.office_meoffice" data-id="34" data-m='{"i":34,"p":26,"n":"meStripe.office","t":"meOffice","o":8}' role="presentation">
# <a data-piitxt="office" href="//afflnk.microsoft.com/c/1239701/439025/7804?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.office.com/?omkt=en-us%26WT.mc_id=MSN_site" piiurl="//afflnk.microsoft.com/c/1239701/439025/7804?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.office.com/?omkt=en-us%26WT.mc_id=MSN_site" target="_blank">
# <h3>Office<span></span></h3>
# </a>
# </li>
# <li class="onedrive" data-aop="mestripe.onedrive_me" data-id="35" data-m='{"i":35,"p":26,"n":"meStripe.onedrive","t":"me","o":9}' role="presentation">
# <a data-piitxt="onedrive" href="https://onedrive.live.com/?wt.mc_id=oo_msn_msnhomepage_header" piiurl="https://onedrive.live.com/?wt.mc_id=oo_msn_msnhomepage_header" target="_blank">
# <h3>OneDrive<span></span></h3>
# </a>
# </li>
# <li class="maps" data-aop="mestripe.maps_memaps" data-id="36" data-m='{"i":36,"p":26,"n":"meStripe.maps","t":"meMaps","o":10}' role="presentation">
# <a data-piitxt="maps" href="https://bing.com/maps/?FORM=MSNMAP" piiurl="https://bing.com/maps/?FORM=MSNMAP" target="_blank">
# <h3>Maps<span></span></h3>
# </a>
# </li>
# <li class="onenote" data-aop="mestripe.onenote_meonenote" data-id="37" data-m='{"i":37,"p":26,"n":"meStripe.onenote","t":"meOneNote","o":11}' role="presentation">
# <a data-piitxt="onenote" href="https://www.onenote.com/notebooks?WT.mc_id=MSN_OneNote_TopMenu&amp;auth=1&amp;wdorigin=msn" piiurl="https://www.onenote.com/notebooks?WT.mc_id=MSN_OneNote_TopMenu&amp;auth=1&amp;wdorigin=msn" target="_blank">
# <h3>OneNote<span></span></h3>
# </a>
# </li>
# <li class="twitter" data-aop="mestripe.twitter_me" data-id="38" data-m='{"i":38,"p":26,"n":"meStripe.twitter","t":"me","o":12}' role="presentation">
# <a data-piitxt="twitter" href="https://twitter.com/" piiurl="https://twitter.com/" target="_blank">
# <h3>Twitter<span></span></h3>
# </a>
# </li>
# </ul>
# </div>
# <button class="stripearrow" data-aop="rightarrow" data-id="39" data-m='{"i":39,"p":26,"n":"rightarrow","y":12,"o":13}' title="next"></button>
# </div>
# <div class="meflyouts">
# <div class="meflyoutcontainer mail" data-id="40" data-m='{"i":40,"p":26,"n":"meStripe.mail","y":5,"o":14}'>
# <div class="meflyout signout">
# <section>
# <div class="mailsignedoutflyout signout" data-aop="outlooksignedoutflyout" data-id="41" data-m='{"i":41,"p":40,"n":"outlooksignedoutflyout","y":8,"o":1}'>
# <section>
# <h2>Get your mail here</h2>
# <ul>
# <li>See your recent emails</li>
# <li>Send a quick email</li>
# <li>Manage your calendar with easy access</li>
# </ul>
# </section>
# <h3>Sign in with any Microsoft account: Outlook, Hotmail, MSN, Live</h3>
# <p><a data-id="42" data-m='{"i":42,"p":41,"n":"mailsignedoutflyout-accounthelp","y":12,"o":1}' href="https://go.microsoft.com/fwlink/?LinkID=254486">What is a Microsoft account?</a></p>
# <ul>
# <li>
# <a data-id="43" data-m='{"i":43,"p":41,"n":"mailsignedoutflyout-signin","y":12,"o":2}' href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True">SIGN IN</a>
# </li>
# <li>
# <a data-id="44" data-m='{"i":44,"p":41,"n":"mailsignedoutflyout-createaccount","y":12,"o":3}' href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True">Create Now</a>
# </li>
# </ul>
# </div>
# </section>
# </div>
# </div>
# <div class="meflyoutcontainer store" data-id="45" data-m='{"i":45,"p":26,"n":"meStripe.store","y":5,"o":15}'>
# <div class="meflyout signin">
# <section>
# <a data-id="46" data-m='{"i":46,"p":45,"n":"store","y":14,"l":"me_store_headerText_signIn","o":1}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/home?icid=MSN_storeHL" target="_blank"><h3>Microsoft Store</h3></a>
# <div>
# <ul data-module-id="startpage|meStripe|meStripe|meStripe.store|meStore2">
# <li>
# <a data-id="47" data-m='{"i":47,"p":45,"n":"HeadlineItemViewModel","y":13,"o":2}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L1_OFFICE&amp;u=https://products.office.com/en-US/compare-all-microsoft-office-products-b?tab=1" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAf2cjT.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Office - Microsoft"/> <h3>Access your files with Office 365. Save, edit, &amp; share, virtually anywhere</h3>
# </div>
# </a>
# </li>
# <li>
# <a data-id="48" data-m='{"i":48,"p":45,"n":"HeadlineItemViewModel","y":13,"o":3}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L3_SURFACEBUNDLES&amp;u=https://www.microsoft.com/en-us/store/collections/surfacebundles" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBRMWiy.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Surface Essential Bundles - Microsoft"/> <h3>Save BIG on Surface Essentials Bundles</h3>
# </div>
# </a>
# </li>
# <li>
# <a data-id="49" data-m='{"i":49,"p":45,"n":"HeadlineItemViewModel","y":13,"o":4}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L4_CONNECTEDLIFE&amp;u=https://www.microsoft.com/en-us/store/b/connected-life" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBMIwGM.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="LIFX Mini Color Smart Light Bulb - Microsoft"/> <h3>Streamline your day-to-day with the latest smart devices</h3>
# </div>
# </a>
# </li>
# <li>
# <a data-id="50" data-m='{"i":50,"p":45,"n":"HeadlineItemViewModel","y":13,"o":5}' href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME_L5_XBOX_DEALS&amp;u=https://www.microsoft.com/en-us/store/b/xbox-deals" target="_blank">
# <div>
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/BBQx6uR.img?h=50&amp;w=50&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=jpg"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Xbox One Prime - Microsoft"/> <h3>Xbox Sales &amp; Specials: Last minute deals on consoles and more</h3>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </section>
# <ul>
# <li data-id="51" data-m='{"i":51,"p":45,"n":"store","y":14,"l":"me_store_taskLinks_surface","o":6}'>
# <a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/surface?icid=MSN_surface" target="_blank">Surface<span></span></a>
# </li>
# <li data-id="52" data-m='{"i":52,"p":45,"n":"store","y":14,"l":"me_store_taskLinks_windows","o":7}'>
# <a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://www.microsoft.com/en-us/store/b/windows?icid=MSN_Win10" target="_blank">Windows<span></span></a>
# </li>
# <li data-id="53" data-m='{"i":53,"p":45,"n":"store","y":14,"l":"me_store_taskLinks_support","o":8}'>
# <a href="https://afflnk.microsoft.com/c/1239701/433017/7593?sharedid=PRIME_ENUS_HP_ME&amp;u=https://support.microsoft.com/en-us/products/store" target="_blank">Support<span></span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="meflyoutcontainer jsskype" data-id="54" data-m='{"i":54,"p":26,"n":"meStripe.jsSkype","y":5,"o":16}'>
# <div class="meflyout signout">
# <section>
# <div>
# <div>
# <p class="meloading"></p>
# <a class="loginlink" href="https://login.live.com/login.srf?wa=wsignin1.0&amp;rpsnv=13&amp;ct=1566829337&amp;rver=7.0.6730.0&amp;wp=LBI&amp;wreply=https:%2f%2fwww.msn.com%2fen-us%2fhomepage%2fSecure%2fPassport%3fru%3dhttps%253a%252f%252fwww.msn.com%252f%253fpfr%253d1&amp;lc=1033&amp;id=1184&amp;mkt=en-us&amp;pcexp=True" target="_blank">Sign In</a>
# <div class="skype-recents" data-locale="en-us" data-style="msn"></div>
# </div>
# </div>
# </section>
# </div>
# </div>
# <div class="meflyoutcontainer custom bingshopping" data-id="55" data-m='{"i":55,"p":26,"n":"meStripe.BingShopping","y":5,"o":17}'>
# <div class="meflyout signin">
# <section>
# <a data-id="56" data-m='{"i":56,"p":55,"n":"custom BingShopping","y":14,"o":1}' href="https://www.bing.com/shop?q=shopping&amp;FORM=PHMSBI" target="_blank"><h3>Shop on Bing</h3></a>
# <div>
# <ul>
# <li>
# <a href="https://www.bing.com/shop?q=Laptop+backpacks&amp;form=PHMSBI" target="_blank">
# <div>
# ...
# <span>Lifestyle</span>
# </button>
# <button aria-label="remove Autos" data-id="805" data-m='{"i":805,"y":12,"l":"stripe_toggle_stripe.autos"}' data-stripe-id="stripe.autos">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Ca1l.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Autos"/>
# <span>Autos</span>
# </button>
# <button aria-label="remove Health &amp; Fitness" data-id="806" data-m='{"i":806,"y":12,"l":"stripe_toggle_stripe.health"}' data-stripe-id="stripe.health">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA5YKmV.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Health &amp; Fitness</span>
# </button>
# <button aria-label="remove Food &amp; Drink" data-id="807" data-m='{"i":807,"y":12,"l":"stripe_toggle_stripe.foodanddrink"}' data-stripe-id="stripe.foodanddrink">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA5Ypq6.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Food &amp; Drink</span>
# </button>
# <button aria-label="remove Travel" data-id="808" data-m='{"i":808,"y":12,"l":"stripe_toggle_stripe.travel"}' data-stripe-id="stripe.travel">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4ChN0.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Travel"/>
# <span>Travel</span>
# </button>
# <button aria-label="remove Causes" data-id="809" data-m='{"i":809,"y":12,"l":"stripe_toggle_stripe.causes"}' data-stripe-id="stripe.causes">
# <span>Causes</span>
# </button>
# <button aria-label="remove Photos" data-id="810" data-m='{"i":810,"y":12,"l":"stripe_toggle_stripe.photos"}' data-stripe-id="stripe.photos">
# <span>Photos</span>
# </button>
# <button aria-label="remove Video" data-id="811" data-m='{"i":811,"y":12,"l":"stripe_toggle_stripe.video"}' data-stripe-id="stripe.video">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oAOK.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Video</span>
# </button>
# <button aria-label="add Movies" class="pending" data-id="812" data-m='{"i":812,"y":12,"l":"stripe_toggle_stripe.movies"}' data-stripe-id="stripe.movies">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Cser.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Movies"/>
# <span>Movies</span>
# </button>
# <button aria-label="add TV" class="pending" data-id="813" data-m='{"i":813,"y":12,"l":"stripe_toggle_stripe.tv"}' data-stripe-id="stripe.tv">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oL47.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>TV</span>
# </button>
# <button aria-label="add Music" class="pending" data-id="814" data-m='{"i":814,"y":12,"l":"stripe_toggle_stripe.music"}' data-stripe-id="stripe.music">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Csg8.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Music"/>
# <span>Music</span>
# </button>
# <button aria-label="add World" class="pending" data-id="815" data-m='{"i":815,"y":12,"l":"stripe_toggle_stripe.world"}' data-stripe-id="stripe.world">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6olcF.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>World</span>
# </button>
# <button aria-label="add US" class="pending" data-id="816" data-m='{"i":816,"y":12,"l":"stripe_toggle_stripe.national"}' data-stripe-id="stripe.national">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oAHY.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>US</span>
# </button>
# <button aria-label="add Politics" class="pending" data-id="817" data-m='{"i":817,"y":12,"l":"stripe_toggle_stripe.politics"}' data-stripe-id="stripe.politics">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA6oG70.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>
# <span>Politics</span>
# </button>
# <button aria-label="add Technology" class="pending" data-id="818" data-m='{"i":818,"y":12,"l":"stripe_toggle_stripe.tech"}' data-stripe-id="stripe.tech">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA4Cxu3.img?h=108&amp;w=145&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Khoa học &amp; Công nghệ"/>
# <span>Technology</span>
# </button>
# <button aria-label="remove Promotions" data-id="819" data-m='{"i":819,"y":12,"l":"stripe_toggle_stripe.msstore"}' data-stripe-id="stripe.msstore">
# <span>Promotions</span>
# </button>
# <div class="loading"></div>
# </div>
# <button class="done" data-id="820" data-m='{"i":820,"y":12,"l":"stripe_personalization_submit"}'>Done</button>
# </section>
# </div>
# <div id="foot">
# <footer class="ab c2" data-id="821" data-m='{"i":821,"n":"Footer","y":2}' data-region="footer" role="contentinfo">
# <a class="copyright microsoft" data-id="822" data-m='{"i":822,"p":821,"n":"MicrosoftCopyright","y":14,"o":1}' href="https://www.microsoft.com/en-us/"><span></span><span></span>© 2019 Microsoft</a>
# <ul class="app-badges">
# <li class="apple-badge">
# <a data-id="823" data-m='{"i":823,"p":821,"n":"amsnewsft","y":11,"o":2}' href="https://itunes.apple.com/us/app/microsoft-news/id945416273?pt=80423&amp;ct=prime_footer&amp;mt=8" target="_blank" title="Download on the App Store"><img alt="Download on the App Store" src="https://linkmaker.itunes.apple.com/assets/shared/badges/en-us/appstore-lrg.svg"/></a>
# </li>
# <li class="google-badge">
# <a data-id="824" data-m='{"i":824,"p":821,"n":"gmsnewsft","y":11,"o":3}' href="https://play.google.com/store/apps/details?id=com.microsoft.amp.apps.bingnews&amp;hl=en-us&amp;referrer=utm_source=prime_footer&amp;utm_campaign=footer" target="_blank" title="Get it on Google Play"><img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png"/></a>
# </li>
# </ul>
# <ul data-facebook-button-width="9.7rem" data-facebook-like-url="https://www.facebook.com/msn" data-twitter-button-width="9.5rem" data-twitter-follow-screen-name="msn" data-twitter-show-screen-name="false" id="social-plugins">
# <li data-id="825" data-m='{"i":825,"p":821,"n":"facebook","y":11,"o":4}' id="fbcount"></li>
# <li data-id="826" data-m='{"i":826,"p":821,"n":"twitter","y":11,"o":5}' id="twcount"></li>
# </ul>
# <ul id="links">
# <li><a data-id="827" data-m='{"i":827,"p":821,"n":"footer_privacy","y":14,"o":6}' href="https://go.microsoft.com/fwlink/?LinkId=521839">
# Privacy &amp; Cookies
# </a>
# </li>
# <li><a data-id="828" data-m='{"i":828,"p":821,"n":"footer_legal","y":14,"o":7}' href="https://go.microsoft.com/fwlink/?LinkID=246338">
# Terms of use
# </a>
# </li>
# <li><a data-id="829" data-m='{"i":829,"p":821,"n":"footer_adprivacyinfo","y":14,"o":8}' href="https://go.microsoft.com/fwlink/?LinkID=286759">
# About our Ads
# </a>
# </li>
# <li><a data-id="830" data-m='{"i":830,"p":821,"n":"footer_feedback","y":14,"o":9}' href="#" id="footer_feedback" target="_self">Feedback
# </a>
# </li>
# <li><a data-id="831" data-m='{"i":831,"p":821,"n":"footer_help","y":14,"o":10}' href="https://go.microsoft.com/fwlink/?LinkId=512703">
# Help
# </a>
# </li>
# <li><a data-id="832" data-m='{"i":832,"p":821,"n":"footer_worldwide","y":14,"o":11}' href="/en-us/msn-worldwide">
# MSN Worldwide
# </a>
# </li>
# <li><a data-id="833" data-m='{"i":833,"p":821,"n":"footer_newsletter","y":14,"o":12}' href="/en-us/newslettersignup">
# Newsletter
# </a>
# </li>
# <li><a data-id="834" data-m='{"i":834,"p":821,"n":"footer_advertise","y":14,"o":13}' href="https://go.microsoft.com/fwlink/?linkid=875132">
# Advertise
# </a>
# </li>
# <li><a data-id="835" data-m='{"i":835,"p":821,"n":"footer_msn_blog","y":14,"o":14}' href="https://blog.msn.com/">
# MSN Blog
# </a>
# </li>
# <li><a data-id="836" data-m='{"i":836,"p":821,"n":"footer_aboutus","y":14,"o":15}' href="/en-us/news/us/about-us/ar-BBN0NAK">
# About Us
# </a>
# </li>
# </ul>
# </footer>
# </div>
# <div data-aop="feedback_flyout" id="feedback-flyout">
# <button data-id="837" data-m='{"i":837,"n":"feedback","y":11,"l":"close"}' id="feedback-close" title="close"></button>
# <div class="feedbackheader mainheader">
# <h2>Send MSN Feedback</h2>
# </div>
# <div class="feedbackheader thankyou">
# <h2>We appreciate your input!</h2>
# </div>
# <div id="feedback-feedbackarea">
# <div class="feedbackarea">
# <label for="feedback-inputbox">How can we improve?</label>
# <textarea aria-live="assertive" id="feedback-inputbox" maxlength="400" placeholder="Enter your feedback here. To help protect your privacy, don't include personal information, like your name or address."></textarea>
# </div>
# </div>
# <div id="feedback-starrating">
# <div class="stars">
# <p>Please give an overall site rating:</p>
# <ul aria-label="Please give an overall site rating:" data-selected="0" role="radiogroup">
# <li aria-checked="false" aria-label="1 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="2 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="3 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="4 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# <li aria-checked="false" aria-label="5 out of 5 star rating" class="sensoryStars" role="radio" tabindex="0"></li>
# </ul>
# </div>
# </div>
# <button class="footerbutton" data-id="838" data-m='{"i":838,"n":"feedback","y":11,"l":"submit"}' id="feedback-submit" title="submit">Submit</button>
# <button class="footerbutton" data-id="839" data-m='{"i":839,"n":"feedback","y":11,"l":"ok"}' id="feedback-ok" title="close">Close</button>
# <div class="feedbackfooter">
# <div id="feedback-privacy-link">
# <a class="footerlink" data-id="840" data-m='{"i":840,"n":"feedback","y":14,"l":"feedbackPrivacyLink"}' href="https://go.microsoft.com/fwlink/?LinkId=521839" target="_blank">Privacy Statement</a>
# </div>
# <div id="feedback-help-link">
# <a class="footerlink" data-id="841" data-m='{"i":841,"n":"feedback","y":14,"l":"feedbackHelpLink"}' href="https://support.microsoft.com/product/msn/msn" target="_blank">Help</a>
# </div>
# <div id="feedback-help-support-link">
# <a class="footerlink" data-id="842" data-m='{"i":842,"n":"feedback","y":14,"l":"feedbackHelpSupportLink"}' href="https://support.microsoft.com/product/msn/msn" target="_blank">Help &amp; Support</a>
# </div>
# </div>
# </div>
# <script>require(["window","document","location","trackInfo","headData","c.onload"],function(n,t,i,r,u){(function f(){var e=r.sitePage,h=e.chartBeatUID,v=e.localeCode,o=e.channel,c=e.department,l=e.chartBeatBase,y=e.chartBeatDomain||i.hostname,p=c?o+","+o+":"+c:o,s,u,w,a;h&&l?(s=n._timing||{},n._st_startpt=s.start||0,n._st_endpt=s.load||0,u=n.location.pathname,u==="/"||u==="/en-us/"?u="/en-us":u.charAt(u.length-1)=="/"&&(u=u.substr(0,u.length-1)),w="",n._sf_async_config={uid:h,sessionLength:15,domain:v+"."+y,sections:p,authors:e.cvPartner?decodeURIComponent(e.cvPartner.replace("+","%20")):"",path:u},a=(/\bsn:\s*(\w*)/.exec(t.getElementsByTagName("HEAD")[0].getAttribute("data-info"))||{})[1]||"",n._cbq=n._cbq||[],n._cbq.push(["_cdname",a]),require({js:l+"/js/chartbeat.js"})):setTimeout(f,50)})()})</script> <script>
#         require(["headData", "pageInstance", "mediator", "c.deferred"], function (headData, pageInstance, mediator)
#         {
#         var url = '//www.bizographics.com/collect/?fmt=gif&pid=7850';
#         if (headData && headData.clientSettings && headData.clientSettings.static_page)
#         {
#             mediator.pub(pageInstance.eventName);
#             var rid = pageInstance.getActivityId();
#             url = url.replace(/([?&]rid=)[^&#]*/i, "$1" + rid);
#             }
#         new Image().src = url.replace(/&amp;/g, '&');
#     });
#     </script>
# <noscript>
# <div>
# <img alt="" data-src="//www.bizographics.com/collect/?fmt=gif&amp;pid=7850&amp;ts=noscript" height="1" width="1"/>
# </div>
# </noscript>
# <script>require(["imageLoad","perfMarker","perfMeasure"],function(n,t,i){var r="TimeToImageLoadStart",u="TimeToImageLoadEnd";t(r);n.cleanup();t(u);i("TimeForImageLoad",r,u,!0)});require(["jquery","logging","webApp.tokens","c.deferred"],function(n,t,i){function r(r){var u=n(this).attr(r);i.validVersionPattern.test(u)||t.error("[staticsLinkVerifier.js] ver query parameter missing in statics url: "+u)}n("link[href*='_sc/css']").each(function(){r.call(this,"href")});n("script[src*='_sc/js']").each(function(){r.call(this,"src")})});require(["trackInfo","window","c.onload"],function(n,t){function c(){if(n.sitePage.requestId){var i=o.setupParameters("load_time");i&&(i.timeToOnload=u,i.timeToDomComplete=s,i.timeToFirstByte=h,f&&(i.timeToFirstSearchRendered=f),t.performance&&t.performance.navigation&&t.performance.navigation.type&&(i.navType=t.performance.navigation.type),require(["c.infopaneinteractive"],function(n){n&&(i.timeToInfopaneInteractive=n);o.sendUpdate(i)}))}else t.setTimeout(c,500)}var o=n.telemetryTracking,u,s,h,f,i=(t.performance||{}).timing,r,e;i&&(u=i.loadEventStart-i.navigationStart,s=i.domComplete-i.navigationStart,h=i.responseStart-i.navigationStart,t.performance&&(r=t.performance.getEntriesByName("TimeToFirstSearchRendered","mark"),r&&(e=r.length,e&&e>0&&(f=Math.round(r[0].startTime)))),u&&c())});window._perfMarker&&window._perfMarker("TimeTocDom",!0);window._perfMeasure&&window._perfMeasure("TimeForcDom","TimeToHeadStart","TimeTocDom",!0);define("c.dom",1);window.onload=function(n){function r(){clearTimeout(t);t=0;window._perfMarker&&window._perfMarker("TimeTocDeferred");window._perfMeasure&&window._perfMeasure("TimeForcDeferred","TimeTocOnload","TimeTocDeferred");define("c.deferred",1);require(["c.deferred"],function(){i=setTimeout(f,u)})}function f(){clearTimeout(i);i=0;window._perfMarker&&window._perfMarker("TimeTocPostDeferred");window._perfMeasure&&window._perfMeasure("TimeForcPostdeferred","TimeTocDeferred","TimeTocPostDeferred");define("c.postdeferred",1)}var t,i,u=2e3;return function(n){var i;n&&(i=(window.JSON&&window.JSON.parse(n)||{}).dms,u=(window.JSON&&window.JSON.parse(n)||{}).ps);t=setTimeout(r,i||3e3)}(document.getElementsByTagName("head")[0].getAttribute("data-js")),function(i){typeof n=="function"&&n(i);window._perfMarker&&window._perfMarker("TimeTocOnload",!0);window._perfMeasure&&window._perfMeasure("TimeForcOnload","TimeTocDom","TimeTocOnload",!0);define("c.onload",1);t&&(window.setImmediate?setImmediate(r):setTimeout(r,0))}}(window.onload)</script><script>define("trackingConstants",{trackingData: {lastIndex: 842 } });</script> <script>window._perfMarker && window._perfMarker("TimeToBodyEnd");window._perfMeasure && window._perfMeasure("TimeForBody","TimeToBodyStart","TimeToBodyEnd",true);</script>
# </body>
# <!--MSNAvailToken-->
# </html>

# %%
for index, item in enumerate(soup.select('.stripecontainer[aria-label]'), start = 2):

        print(item['aria-label'])
# Out:
# new york
# news
# from our partners
# entertainment
# sports
# money
# lifestyle
# autos
# health & fitness
# food & drink
# travel
# causes
# video
# promotions

# %%
ib.attrs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4279b4e5bd8d> in <module>
# ----> 1 ib.attrs
#
# NameError: name 'ib' is not defined

# %%
re.findall("\"o\":(\d+)",ib['data-m'])[0]
# Out:
# '2'

# %%
ibl
# Out:
# <li data-id="624" data-m='{"i":624,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":3}'>
# <a href="/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=902&amp;y=1027"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The CEO of Popeyes' parent company breaks down the massive success of its chicke... - Irene Jiang / Business Insider"/> <div>
# <h3 aria-label="popeyes' parent company ceo on chicken sandwich success-article">Popeyes' parent company CEO on chicken sandwich success</h3>
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Business Insider</span>
# </div>
# </a>
# </li>

# %%
ibl.attrs
# Out:
# {'data-id': '624',
#  'data-m': '{"i":624,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":3}'}

# %%
item_block_link.attrs
# Out:
# {'data-id': '673',
#  'data-m': '{"i":673,"p":670,"n":"HeadlineItemViewModel","y":13,"l":"BBTBwqL","h":0,"v":"foodanddrink","c":"foodnews","o":3}',
#  'class': ['media', 'photo']}

# %%
x
# Out:
# <li data-id="672" data-m='{"i":672,"p":670,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":2}'>
# <a href="/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=902&amp;y=1027"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The CEO of Popeyes' parent company breaks down the massive success of its chicke... - Irene Jiang / Business Insider"/> <div>
# <h3 aria-label="popeyes' parent company ceo on chicken sandwich success-article">Popeyes' parent company CEO on chicken sandwich success</h3>
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Business Insider</span>
# </div>
# </a>
# </li>

# %%
re.findall('\/\/(.+)\"', x.a.img['data-src'])[0]
# Out:
# 'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&w=100&m=6&q=60&u=t&o=t&l=f&x=902&y=1027'

# %%
x.a.img['data-src']
# Out:
# '{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&w=100&m=6&q=60&u=t&o=t&l=f&x=902&y=1027"}'

# %%
x.a['href']
# Out:
# '/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw'

# %%
df = []
for index, item in enumerate(soup.select('.stripecontainer[aria-label]'), start = 2):
    if item.select('img[alt="Business Insider Logo"]'):
#         print(item)
        print(index)
        river_position = index
        river_name = item['aria-label']
        a = item

        for item_block in item.find_all('ul'):
            if item_block.select('img[alt="Business Insider Logo"]'):
                ib = item_block
                item_block_type = item_block['data-aop']
                item_block_position = re.findall("\"o\":(\d+)",item_block['data-m'])[0]
#                 print(item_block)
                for item_block_link in item_block.select('li'):
                    if item_block_link.select('img[alt="Business Insider Logo"]'):
                        ibl = item_block_link
                        x = item_block_link
                        print(item_block_link)
                        print(len(item_block_link))
                        item_block_link_position = re.findall("\"o\":(\d+)",item_block_link['data-m'])[0]
                        article_tile = item_block_link.select('h3[aria-label]')[0]['aria-label']
                        article_link = item_block_link.a['href']
                        article_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                        article_img_small = re.findall('\/\/(.+)\"', item_block_link.a.img['data-src'])[0]
#                         artile_img = re.findall(r'\/\/(.*)\?',item_block_link.select('img')[0]['data-src'])[0]
                        df.append([river_position, 
                                   river_name,
                                   item_block_position,
                                   item_block_type,
                                   item_block_link_position,
                                   article_tile,
                                   article_link,
                                   article_img,
                                   article_img_small])
        
        
    else:
        print('***')
pd.DataFrame(df, columns = ['river_position',
                           'river_name',
                           'item_block_position',
                           'item_block_type',
                           'item_block_link_position',
                           'article_title',
                           'article_link',
                           'article_img',
                           'article_img_small'])
# Out:
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# 11
# <li data-id="672" data-m='{"i":672,"p":670,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":2}'>
# <a href="/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=902&amp;y=1027"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The CEO of Popeyes' parent company breaks down the massive success of its chicke... - Irene Jiang / Business Insider"/> <div>
# <h3 aria-label="popeyes' parent company ceo on chicken sandwich success-article">Popeyes' parent company CEO on chicken sandwich success</h3>
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Business Insider</span>
# </div>
# </a>
# </li>
# 3
# ***
# ***
# ***
# ***
#    river_position    river_name item_block_position item_block_type  \
# 0              11  food & drink                   2        tertiary
#
#   item_block_link_position                                      article_title  \
# 0                        2  popeyes' parent company ceo on chicken sandwic...
#
#                                         article_link  \
# 0  /en-us/foodanddrink/foodnews/the-ceo-of-popeye...
#
#                                          article_img  \
# 0  static-global-s-msn-com.akamaized.net/img-resi...
#
#                                    article_img_small
# 0  static-global-s-msn-com.akamaized.net/img-resi...

# %%
x
# Out:
# <li data-id="624" data-m='{"i":624,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":3}'>
# <a href="/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=902&amp;y=1027"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The CEO of Popeyes' parent company breaks down the massive success of its chicke... - Irene Jiang / Business Insider"/> <div>
# <h3 aria-label="popeyes' parent company ceo on chicken sandwich success-article">Popeyes' parent company CEO on chicken sandwich success</h3>
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Business Insider</span>
# </div>
# </a>
# </li>

# %%
x.select('h3[aria-label]')[0]['aria-label']
# Out:
# "popeyes' parent company ceo on chicken sandwich success-article"

# %%
re.findall(r'\/\/(.*)\?',x.select('img[alt=""]')[0]['data-src'])[0]
# Out:
# 'static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img'

# %%
x.select('img[alt=""]')[0]['data-src']
# Out:
# '{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&w=100&m=6&q=60&u=t&o=t&l=f&x=902&y=1027"}'

# %%
a.select('.stripecontainer[aria-label]')
# Out:
# []

# %%
a.find_all('ul')
# Out:
# [<ul>
#  <li data-id="604" data-m='{"i":604,"p":603,"n":"foodanddrink","y":4,"o":1}'>
#  <h2><a data-id="605" data-m='{"i":605,"p":603,"n":"foodanddrink","y":4,"o":2}' href="/en-us/foodanddrink">Food &amp; Drink</a></h2>
#  </li>
#  <li class="hide12" data-id="606" data-m='{"i":606,"p":603,"n":"Food News","y":4,"o":3}'><a href="/en-us/foodanddrink/restaurantsandnews">FOOD NEWS</a></li>
#  <li class="hide12" data-id="607" data-m='{"i":607,"p":603,"n":"Restaurants","y":4,"o":4}'><a href="/en-us/foodanddrink/restaurantsandnews/casual">RESTAURANTS</a></li>
#  <li class="hide12" data-id="608" data-m='{"i":608,"p":603,"n":"Recipes","y":4,"o":5}'><a href="/en-us/foodanddrink/cooking/recipes">RECIPES</a></li>
#  <li class="hide12" data-id="609" data-m='{"i":609,"p":603,"n":"Quick \u0026 Easy","y":4,"o":6}'><a href="/en-us/foodanddrink/cooking/quickandeasy">QUICK &amp; EASY</a></li>
#  <li class="hide12" data-id="610" data-m='{"i":610,"p":603,"n":"Tips \u0026 Tricks","y":4,"o":7}'><a href="/en-us/foodanddrink/cooking/tipsandtricks">TIPS &amp; TRICKS</a></li>
#  <li class="hide123" data-id="611" data-m='{"i":611,"p":603,"n":"Drinks","y":4,"o":8}'><a href="/en-us/foodanddrink/beverages">DRINKS</a></li>
#  <li class="hide123" data-id="612" data-m='{"i":612,"p":603,"n":"videos","y":4,"o":9}'><a href="/en-us/foodanddrink/video">VIDEO</a></li>
#  </ul>,
#  <ul class="secondary" data-aop="secondary" data-id="619" data-m='{"i":619,"p":618,"n":"secondary","y":8,"o":1}'>
#  <li class="media photo" data-id="620" data-m='{"i":620,"p":619,"n":"HeadlineItemViewModel","y":13,"l":"AAEUc5d","h":0,"v":"foodanddrink","c":"tipsandtricks","o":1}'>
#  <a href="/en-us/foodanddrink/tipsandtricks/10-mistakes-everyone-makes-when-buying-bread/ss-AAEUc5d?li=BBnb7Kw">
#  <img alt="While bread does need a pinch of sugar to activate the yeast, it shouldn't be de..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAEUnWr.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=541&amp;y=555"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Not checking for hidden sugar - TY Lim/Shutterstock"/> <div>
#  <h3 aria-label="10 mistakes everyone makes when buying bread-slideshow">10 mistakes everyone makes when buying bread</h3>
#  <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
#  </div>
#  </a>
#  </li>
#  </ul>,
#  <ul class="tertiary" data-aop="tertiary" data-id="621" data-m='{"i":621,"p":618,"n":"tertiary","y":8,"o":2}'>
#  <li class="media photo" data-id="622" data-m='{"i":622,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGbZsZ","h":0,"v":"foodanddrink","c":"recipes","o":1}'>
#  <a href="/en-us/foodanddrink/recipes/the-most-in-demand-cake-of-every-decade/ss-AAGbZsZ?li=BBnb7Kw">
#  <img alt="The turn of the century saw the first chocol..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AACT56D.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=691&amp;y=507"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Classic Chocolate Cake - Taste of Home"/> <div>
#  <h3 aria-label="the most in-demand cake of every decade-slideshow">The most in-demand cake of every decade</h3>
#  <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="623" data-m='{"i":623,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGeg96","h":0,"v":"foodanddrink","c":"tipsandtricks","o":2}'>
#  <a href="/en-us/foodanddrink/tipsandtricks/pork-shoulder-is-the-new-steak/ar-AAGeg96?li=BBnb7Kw">
#  <img alt="Pork Shoulder Is the New Steak" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGeg8N.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=2096&amp;y=1515"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Pork Shoulder Is the New Steak - Photo by Joseph De Leo, Food Styling by Erika Joyce"/> <div>
#  <h3 aria-label="pork shoulder is the new steak-article">Pork shoulder is the new steak</h3>
#  <img alt="Epicurious Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA9Aicg.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Epicurious</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="624" data-m='{"i":624,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":3}'>
#  <a href="/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw">
#  <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=902&amp;y=1027"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The CEO of Popeyes' parent company breaks down the massive success of its chicke... - Irene Jiang / Business Insider"/> <div>
#  <h3 aria-label="popeyes' parent company ceo on chicken sandwich success-article">Popeyes' parent company CEO on chicken sandwich success</h3>
#  <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Business Insider</span>
#  </div>
#  </a>
#  </li>
#  </ul>,
#  <ul class="tertiary" data-aop="tertiary" data-id="625" data-m='{"i":625,"p":618,"n":"tertiary","y":8,"o":3}'>
#  <li class="media photo" data-id="626" data-m='{"i":626,"p":625,"n":"HeadlineItemViewModel","y":13,"l":"AAGegWs","h":0,"v":"foodanddrink","c":"tipsandtricks","o":1}'>
#  <a href="/en-us/foodanddrink/tipsandtricks/17-secret-waiter-tricks-that-diners-never-notice/ss-AAGegWs?li=BBnb7Kw">
#  <img alt="When you’re a server or bartender wanting to rake in some tips, it’s in your ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGeuHT.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=662&amp;y=172"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="17 Secret Waiter Tricks That Diners Never Notice - Provided by Eat This, Not That!"/> <div>
#  <h3 aria-label="17 secret waiter tricks that diners never notice-slideshow">17 secret waiter tricks that diners never notice</h3>
#  <img alt="Eat This, Not That! Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA9YFNL.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Eat This, Not That!</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="627" data-m='{"i":627,"p":625,"n":"HeadlineItemViewModel","y":13,"l":"AAGbbAS","h":0,"v":"foodanddrink","c":"tipsandtricks","o":2}'>
#  <a href="/en-us/foodanddrink/tipsandtricks/we-tried-13-popular-potato-chip-brands-and-our-top-and-bottom-picks-might-just-surprise-you/ar-AAGbbAS?li=BBnb7Kw">
#  <img alt="From left to right: Utz, Herr’s and Route 11." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGaXIx.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=417&amp;y=313"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="From left to right: Utz, Herr’s and Route 11."/> <div>
#  <h3 aria-label="we tried 13 popular chips. our best &amp; worst picks might surprise-article">We tried 13 popular chips. Our best &amp; worst picks might surprise</h3>
#  <img alt="The Washington Post Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyxkRJ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>The Washington Post</span>
#  </div>
#  </a>
#  </li>
#  <li data-id="628" data-m='{"i":628,"p":625,"n":"HeadlineItemViewModel","y":13,"l":"AAGasWk","h":0,"v":"foodanddrink","c":"tipsandtricks","o":3}'>
#  <a href="/en-us/foodanddrink/tipsandtricks/the-one-dish-you-should-bring-to-your-next-potluck-according-to-ree-drummond/ar-AAGasWk?li=BBnb7Kw">
#  <img alt="Ree Drummond is pictured during an interview in Pawhuska, Okla, Wednesday, June ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjhNv.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=2825&amp;y=799"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Hearst Magazines' Unbound Access MagFront - 2017 Getty Images"/> <div>
#  <h3 aria-label="ree drummond on the one dish you should bring to your next potluck-article">Ree Drummond on the one dish you should bring to your next potluck</h3>
#  <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
#  </div>
#  </a>
#  </li>
#  </ul>,
#  <ul class="secondary" data-aop="secondary" data-id="629" data-m='{"i":629,"p":618,"n":"secondary","y":8,"o":4}'>
#  <li data-id="630" data-m='{"i":630,"p":629,"n":"HeadlineItemViewModel","y":13,"l":"AAGeulV","h":0,"v":"foodanddrink","c":"tipsandtricks","o":1}'>
#  <a href="/en-us/foodanddrink/tipsandtricks/heres-the-secret-to-making-the-best-apple-pie/ar-AAGeulV?li=BBnb7Kw">
#  <img alt="Here’s the Secret to Making the Best Apple Pie" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGewYp.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=362&amp;y=766"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Here’s the Secret to Making the Best Apple Pie - Ted + Chelsea Cavanaugh"/> <div>
#  <h3 aria-label="here's the secret to making the best apple pie-article">Here's the secret to making the best apple pie</h3>
#  <img alt="Real Simple Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAfojr6.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Real Simple</span>
#  </div>
#  </a>
#  </li>
#  </ul>]

# %%
a
# Out:
# <div aria-label="food &amp; drink" class="stripecontainer" data-section-id="stripe.foodanddrink" role="region">
# <div class="fooddrink stripeouter" data-aop="stripe.foodanddrink_stripe" data-id="601" data-m='{"i":601,"p":25,"n":"stripe.foodanddrink","t":"stripe","o":14}'>
# <button class="leftarrow" data-id="602" data-m='{"i":602,"p":601,"n":"leftarrow","y":12,"o":1}' tabindex="-1" title="previous"></button>
# <div class="stripe full-width">
# <div class="stripenav" data-aop="stripe.foodanddrink.navigation_stripenavigation" data-id="603" data-m='{"i":603,"p":601,"n":"stripe.foodanddrink.navigation","t":"stripeNavigation","o":2}'>
# <ul>
# <li data-id="604" data-m='{"i":604,"p":603,"n":"foodanddrink","y":4,"o":1}'>
# <h2><a data-id="605" data-m='{"i":605,"p":603,"n":"foodanddrink","y":4,"o":2}' href="/en-us/foodanddrink">Food &amp; Drink</a></h2>
# </li>
# <li class="hide12" data-id="606" data-m='{"i":606,"p":603,"n":"Food News","y":4,"o":3}'><a href="/en-us/foodanddrink/restaurantsandnews">FOOD NEWS</a></li>
# <li class="hide12" data-id="607" data-m='{"i":607,"p":603,"n":"Restaurants","y":4,"o":4}'><a href="/en-us/foodanddrink/restaurantsandnews/casual">RESTAURANTS</a></li>
# <li class="hide12" data-id="608" data-m='{"i":608,"p":603,"n":"Recipes","y":4,"o":5}'><a href="/en-us/foodanddrink/cooking/recipes">RECIPES</a></li>
# <li class="hide12" data-id="609" data-m='{"i":609,"p":603,"n":"Quick \u0026 Easy","y":4,"o":6}'><a href="/en-us/foodanddrink/cooking/quickandeasy">QUICK &amp; EASY</a></li>
# <li class="hide12" data-id="610" data-m='{"i":610,"p":603,"n":"Tips \u0026 Tricks","y":4,"o":7}'><a href="/en-us/foodanddrink/cooking/tipsandtricks">TIPS &amp; TRICKS</a></li>
# <li class="hide123" data-id="611" data-m='{"i":611,"p":603,"n":"Drinks","y":4,"o":8}'><a href="/en-us/foodanddrink/beverages">DRINKS</a></li>
# <li class="hide123" data-id="612" data-m='{"i":612,"p":603,"n":"videos","y":4,"o":9}'><a href="/en-us/foodanddrink/video">VIDEO</a></li>
# </ul>
# <div class="stripemenu" role="menu">
# <button class="edit" data-id="613" data-m='{"i":613,"p":603,"n":"personalization","t":"dropdown","o":10}'>Edit</button>
# <button class="remove" data-id="614" data-m='{"i":614,"p":603,"n":"remove","t":"dropdownitem","o":11}' role="menuitem">Remove Section</button>
# <button class="up" data-id="615" data-m='{"i":615,"p":603,"n":"moveup","t":"dropdownitem","o":12}' role="menuitem">Move Section Up</button>
# <button class="down" data-id="616" data-m='{"i":616,"p":603,"n":"movedown","t":"dropdownitem","o":13}' role="menuitem">Move Section Down</button>
# <button class="add" data-id="617" data-m='{"i":617,"p":603,"n":"addbelow","t":"dropdownitem","o":14}' role="menuitem">Add Section Below</button>
# </div>
# </div>
# <div class="paging-container">
# <div class="stripecontent normaldensity" data-aop="top stories" data-id="618" data-m='{"i":618,"p":601,"n":"stripe.foodanddrink.topstories","t":"headlines","o":3}' data-module-id="startpage|stripe.foodanddrink|stripe|stripe.foodanddrink.topstories|headlines">
# <ul class="secondary" data-aop="secondary" data-id="619" data-m='{"i":619,"p":618,"n":"secondary","y":8,"o":1}'>
# <li class="media photo" data-id="620" data-m='{"i":620,"p":619,"n":"HeadlineItemViewModel","y":13,"l":"AAEUc5d","h":0,"v":"foodanddrink","c":"tipsandtricks","o":1}'>
# <a href="/en-us/foodanddrink/tipsandtricks/10-mistakes-everyone-makes-when-buying-bread/ss-AAEUc5d?li=BBnb7Kw">
# <img alt="While bread does need a pinch of sugar to activate the yeast, it shouldn't be de..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAEUnWr.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=541&amp;y=555"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Not checking for hidden sugar - TY Lim/Shutterstock"/> <div>
# <h3 aria-label="10 mistakes everyone makes when buying bread-slideshow">10 mistakes everyone makes when buying bread</h3>
# <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="tertiary" data-aop="tertiary" data-id="621" data-m='{"i":621,"p":618,"n":"tertiary","y":8,"o":2}'>
# <li class="media photo" data-id="622" data-m='{"i":622,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGbZsZ","h":0,"v":"foodanddrink","c":"recipes","o":1}'>
# <a href="/en-us/foodanddrink/recipes/the-most-in-demand-cake-of-every-decade/ss-AAGbZsZ?li=BBnb7Kw">
# <img alt="The turn of the century saw the first chocol..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AACT56D.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=691&amp;y=507"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Classic Chocolate Cake - Taste of Home"/> <div>
# <h3 aria-label="the most in-demand cake of every decade-slideshow">The most in-demand cake of every decade</h3>
# <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
# </div>
# </a>
# </li>
# <li data-id="623" data-m='{"i":623,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGeg96","h":0,"v":"foodanddrink","c":"tipsandtricks","o":2}'>
# <a href="/en-us/foodanddrink/tipsandtricks/pork-shoulder-is-the-new-steak/ar-AAGeg96?li=BBnb7Kw">
# <img alt="Pork Shoulder Is the New Steak" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGeg8N.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=2096&amp;y=1515"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Pork Shoulder Is the New Steak - Photo by Joseph De Leo, Food Styling by Erika Joyce"/> <div>
# <h3 aria-label="pork shoulder is the new steak-article">Pork shoulder is the new steak</h3>
# <img alt="Epicurious Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA9Aicg.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Epicurious</span>
# </div>
# </a>
# </li>
# <li data-id="624" data-m='{"i":624,"p":621,"n":"HeadlineItemViewModel","y":13,"l":"AAGh0FD","h":0,"v":"foodanddrink","c":"foodnews","o":3}'>
# <a href="/en-us/foodanddrink/foodnews/the-ceo-of-popeyes-parent-company-breaks-down-the-massive-success-of-its-chicken-sandwich/ar-AAGh0FD?li=BBnb7Kw">
# <img alt="" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGgYGw.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=902&amp;y=1027"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="The CEO of Popeyes' parent company breaks down the massive success of its chicke... - Irene Jiang / Business Insider"/> <div>
# <h3 aria-label="popeyes' parent company ceo on chicken sandwich success-article">Popeyes' parent company CEO on chicken sandwich success</h3>
# <img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Business Insider</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="tertiary" data-aop="tertiary" data-id="625" data-m='{"i":625,"p":618,"n":"tertiary","y":8,"o":3}'>
# <li class="media photo" data-id="626" data-m='{"i":626,"p":625,"n":"HeadlineItemViewModel","y":13,"l":"AAGegWs","h":0,"v":"foodanddrink","c":"tipsandtricks","o":1}'>
# <a href="/en-us/foodanddrink/tipsandtricks/17-secret-waiter-tricks-that-diners-never-notice/ss-AAGegWs?li=BBnb7Kw">
# <img alt="When you’re a server or bartender wanting to rake in some tips, it’s in your ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGeuHT.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=662&amp;y=172"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="17 Secret Waiter Tricks That Diners Never Notice - Provided by Eat This, Not That!"/> <div>
# <h3 aria-label="17 secret waiter tricks that diners never notice-slideshow">17 secret waiter tricks that diners never notice</h3>
# <img alt="Eat This, Not That! Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AA9YFNL.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Eat This, Not That!</span>
# </div>
# </a>
# </li>
# <li data-id="627" data-m='{"i":627,"p":625,"n":"HeadlineItemViewModel","y":13,"l":"AAGbbAS","h":0,"v":"foodanddrink","c":"tipsandtricks","o":2}'>
# <a href="/en-us/foodanddrink/tipsandtricks/we-tried-13-popular-potato-chip-brands-and-our-top-and-bottom-picks-might-just-surprise-you/ar-AAGbbAS?li=BBnb7Kw">
# <img alt="From left to right: Utz, Herr’s and Route 11." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGaXIx.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=417&amp;y=313"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="From left to right: Utz, Herr’s and Route 11."/> <div>
# <h3 aria-label="we tried 13 popular chips. our best &amp; worst picks might surprise-article">We tried 13 popular chips. Our best &amp; worst picks might surprise</h3>
# <img alt="The Washington Post Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAyxkRJ.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>The Washington Post</span>
# </div>
# </a>
# </li>
# <li data-id="628" data-m='{"i":628,"p":625,"n":"HeadlineItemViewModel","y":13,"l":"AAGasWk","h":0,"v":"foodanddrink","c":"tipsandtricks","o":3}'>
# <a href="/en-us/foodanddrink/tipsandtricks/the-one-dish-you-should-bring-to-your-next-potluck-according-to-ree-drummond/ar-AAGasWk?li=BBnb7Kw">
# <img alt="Ree Drummond is pictured during an interview in Pawhuska, Okla, Wednesday, June ..." data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGjhNv.img?h=75&amp;w=100&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=2825&amp;y=799"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Hearst Magazines' Unbound Access MagFront - 2017 Getty Images"/> <div>
# <h3 aria-label="ree drummond on the one dish you should bring to your next potluck-article">Ree Drummond on the one dish you should bring to your next potluck</h3>
# <img alt="Taste of Home Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AADeDDC.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Taste of Home</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="secondary" data-aop="secondary" data-id="629" data-m='{"i":629,"p":618,"n":"secondary","y":8,"o":4}'>
# <li data-id="630" data-m='{"i":630,"p":629,"n":"HeadlineItemViewModel","y":13,"l":"AAGeulV","h":0,"v":"foodanddrink","c":"tipsandtricks","o":1}'>
# <a href="/en-us/foodanddrink/tipsandtricks/heres-the-secret-to-making-the-best-apple-pie/ar-AAGeulV?li=BBnb7Kw">
# <img alt="Here’s the Secret to Making the Best Apple Pie" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAGewYp.img?h=194&amp;w=300&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;x=362&amp;y=766"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif" title="Here’s the Secret to Making the Best Apple Pie - Ted + Chelsea Cavanaugh"/> <div>
# <h3 aria-label="here's the secret to making the best apple pie-article">Here's the secret to making the best apple pie</h3>
# <img alt="Real Simple Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAfojr6.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/> <span>Real Simple</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="paging"></div>
# </div>
# <button class="rightarrow" data-id="631" data-m='{"i":631,"p":601,"n":"rightarrow","y":12,"o":4}' tabindex="-1" title="next"></button>
# </div>
# </div>

# %%
a.attrs
# Out:
# {'class': ['stripecontainer'],
#  'role': 'region',
#  'aria-label': 'food & drink',
#  'data-section-id': 'stripe.foodanddrink'}

# %%
a.select('img[alt="Business Insider Logo"]')
# Out:
# [<img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>]

# %%
df
# Out:
# [[11, 'food & drink'], {11, 'food & drink'}]

# %%
pd.DataFrame(df)
# Out:
#               0             1
# 0            11  food & drink
# 1  food & drink            11

# %%
soup.select('.stripecontainer[aria-label]')[9].select('img[alt="Business Insider Logo"]')
# Out:
# [<img alt="Business Insider Logo" data-src='{"default":"//static-global-s-msn-com.akamaized.net/img-resizer/tenant/amp/entityid/AAywSGf.img?h=16&amp;w=16&amp;m=6&amp;q=60&amp;u=t&amp;o=t&amp;l=f&amp;f=png"}' src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/9b/e151e5.gif"/>]
