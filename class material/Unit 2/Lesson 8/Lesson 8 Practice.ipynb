# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind = 'bar', color = ['grey','blue'])

# %%
df.Embarked.head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='barh')

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='bar')

# %%
from IPython.display import Image
Image(filename = '/Users/wzhang/Dropbox/Screenshots/Screenshot 2019-07-03 14.29.10.png')

# %%
df.groupby('Sex')['Age','Fare'].mean().plot(kind='bar')
plt.title('Average Age and Fare by Passenger Gender')
# Out:
# Text(0.5, 1.0, 'Average Age and Fare by Passenger Gender')

# %%
df.groupby('Sex')[['Age','Fare']].mean().plot(kind='bar')

# %%
df.Embarked.value_counts().plot(kind = 'pie')

# %%
df.Age.plot(kind = 'Hist')

# %%
df.Age.plot(kind = 'Hist', bins = 25)

# %%
df.hist(column = 'Age', by = 'Embarked')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11584de80>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', layout = (1, 3))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x115a0b080>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', layout = (3,1))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x115dd65f8>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', layout = (1,3), figsize = (12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1168012e8>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', layout = (1,3), figsize = (12,4), sharey = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11696d780>,
# ...
#       dtype=object)

# %%
df.hist(column = 'Age', by = 'Embarked', layout = (1,3), figsize = (12,4), sharex = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x116af3cf8>,
# ...
#       dtype=object)

# %%
df['Age'].plot(kind = 'kde')

# %%
df['Age'].plot(kind = 'density')

# %%
df['Age'].plot(kind = 'area')

# %%
df.plot('Age','Fare',kind='scatter')

# %%
fig, ax = plt.subplots(1,2)
df[df.Sex == 'female'].plot('Age', 'Fare', kind = 'Scatter', ax = ax[0], color = 'red', label = 'Females')
df[df.Sex == 'male'].plot('Age', 'Fare', kind = 'Scatter', ax = ax[1], color = 'blue', label = 'Males')

# %%
fig, ax = plt.subplots(1,2, sharex = True, sharey = True, figsize = (12, 4))
df[df.Sex == 'female'].plot('Age', 'Fare', kind = 'Scatter', ax = ax[0], color = 'red', label = 'Females')
df[df.Sex == 'male'].plot('Age', 'Fare', kind = 'Scatter', ax = ax[1], color = 'blue', label = 'Males')

# %%
fig, ax = plt.subplots(2, 2)

# %%
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a19c9a128>,
# ...
#       dtype=object)

# %%
ax[0]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a19c9a128>,
# ...
#       dtype=object)

# %%
ax[0,0]

# %%
ax[0][0]

# %%
import seaborn as sns

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df)

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'swarm')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'strip')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'box')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'boxen')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'violin')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'point')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'bar')

# %%
sns.catplot(x = 'Pclass', y= 'Age', data = df, kind = 'swarm', hue = 'Sex')

# %%
sns.catplot(x = 'Pclass', y= 'Fare', data = df, kind = 'swarm', col = 'Sex')

# %%
sns.catplot(x = 'Pclass', y= 'Fare', data = df, kind = 'swarm', row = 'Sex')

# %%
sns.catplot(x = 'Pclass', y= 'Survived', data = df, kind = 'bar')
plt.title('Survival Rate by Passenger Class/Sex')
# Out:
# Text(0.5, 1.0, 'Survival Rate by Passenger Class/Sex')

# %%
sns.lmplot(x = 'Pclass', y = 'Survived', data = df)

# %%
df['Age'] = df['Age'].fillna(29)
sns.distplot(df.Age)

# %%
sns.jointplot(x = 'Age', y = 'Fare', data = df[df.Sex == 'male'])

# %%
ax = sns.distplot(df[df.Sex == 'female']['Age'], label = 'Females')
sns.distplot(df[df.Sex == 'male']['Age'], label = 'Males', ax = ax)
plt.legend(loc = 'best')

# %%
sns.pairplot(df, x_vars = ['Pclass', 'Age', 'Fare', 'SibSp'], y_vars = ['Age'])

# %%
sns.heatmap(df.corr())
