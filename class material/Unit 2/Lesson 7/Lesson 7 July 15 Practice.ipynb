# %%
pwd
# Out:
# '/Users/wzhang/GeneralAssembly/DAT-06-24/class material/Unit 2/Lesson 7'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
drink = pd.read_csv('../data/drinks.csv')

# %%
drink.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drink.rename(columns = {'beer_servings':'beer', 'wine_servings':'wine'})
# Out:
#                   country  beer  spirit_servings  wine  \
# 0             Afghanistan     0                0     0
# 1                 Albania    89              132    54
# 2                 Algeria    25                0    14
# 3                 Andorra   245              138   312
# 4                  Angola   217               57    45
# 5       Antigua & Barbuda   102              128    45
# 6               Argentina   193               25   221
# 7                 Armenia    21              179    11
# 8               Australia   261               72   212
# 9                 Austria   279               75   191
# 10             Azerbaijan    21               46     5
# 11                Bahamas   122              176    51
# 12                Bahrain    42               63     7
# 13             Bangladesh     0                0     0
# 14               Barbados   143              173    36
# 15                Belarus   142              373    42
# ...

# %%
drink.rename(columns = {'beer_servings':'beer', 'wine_servings':'wine'}, inplace = True)

# %%
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
drink = pd.read_csv('class material/Unit 2/data/drinks.csv', header= 0 , names = drink_cols)

# %%
drink.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drink.continent.value_counts(dropna = False)
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
drink.continent.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174     True
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184     True
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
drink.continent.isnull().sum()
# Out:
# 23

# %%
drink[drink.continent.notnull()].head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drink.isnull().sum().plot(kind = 'bar')
plt.title('Number of null values per column')
# Out:
# Text(0.5, 1.0, 'Number of null values per column')

# %%
len(drink)
# Out:
# 193

# %%
len(drink.dropna())
# Out:
# 170

# %%
len(drink)
# Out:
# 193

# %%
drink.dropna(how = 'all') # Drop a row only if ALL values are missing.
# Out:
#                   country  beer  spirit  wine  liters continent
# 0             Afghanistan     0       0     0     0.0        AS
# 1                 Albania    89     132    54     4.9        EU
# 2                 Algeria    25       0    14     0.7        AF
# 3                 Andorra   245     138   312    12.4        EU
# 4                  Angola   217      57    45     5.9        AF
# 5       Antigua & Barbuda   102     128    45     4.9       NaN
# 6               Argentina   193      25   221     8.3        SA
# 7                 Armenia    21     179    11     3.8        EU
# 8               Australia   261      72   212    10.4        OC
# 9                 Austria   279      75   191     9.7        EU
# 10             Azerbaijan    21      46     5     1.3        EU
# 11                Bahamas   122     176    51     6.3       NaN
# 12                Bahrain    42      63     7     2.0        AS
# 13             Bangladesh     0       0     0     0.0        AS
# ...

# %%
drink.continent.fillna(value='NA')
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
# 5      NA
# 6      SA
# 7      EU
# 8      OC
# 9      EU
# 10     EU
# 11     NA
# 12     AS
# 13     AS
# 14     NA
# 15     EU
# 16     EU
# 17     NA
# 18     AF
# 19     AS
# 20     SA
# 21     EU
# 22     AF
# 23     SA
# 24     AS
# 25     EU
# 26     AF
# 27     AF
# 28     AF
# 29     AF
#        ..
# 163    SA
# 164    AF
# 165    EU
# 166    EU
# 167    AS
# 168    AS
# 169    AS
# 170    EU
# 171    AS
# 172    AF
# 173    OC
# 174    NA
# 175    AF
# 176    AS
# 177    AS
# 178    OC
# 179    AF
# 180    EU
# 181    AS
# 182    EU
# 183    AF
# 184    NA
# 185    SA
# 186    AS
# 187    OC
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, Length: 193, dtype: object

# %%
drinks = pd.read_csv('../data/drinks.csv', header=0, names=drink_cols, na_filter=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-14a5efdb848e> in <module>
# ----> 1 drinks = pd.read_csv('../data/drinks.csv', header=0, names=drink_cols, na_filter=False)
#
# NameError: name 'drink_cols' is not defined

# %%
drinks = pd.read_csv('../data/drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.groupby('continent')['beer_servings'].mean()
# drinks.groupby('continent').beer_searvings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
drinks.groupby('continent').beer_servings.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
def test(x):
    return max(x)*100000
drinks.groupby('continent').beer_servings.agg(['count', 'mean', 'min','max', test]).
# Out:
#            count        mean  min  max      test
# continent
# AF            53   61.471698    0  376  37600000
# AS            44   37.045455    0  247  24700000
# EU            45  193.777778    0  361  36100000
# OC            16   89.687500    0  306  30600000
# SA            12  175.083333   93  333  33300000

# %%
drinks.groupby('continent').beer_servings.agg(['count', 'mean', 'min','max', test]).sort_values('mean')
# Out:
#            count        mean  min  max      test
# continent
# AS            44   37.045455    0  247  24700000
# AF            53   61.471698    0  376  37600000
# OC            16   89.687500    0  306  30600000
# SA            12  175.083333   93  333  33300000
# EU            45  193.777778    0  361  36100000

# %%
drinks.groupby('continent').describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings              ... wine_servings         \
#              max           count        mean  ...           75%    max
# continent                                     ...
# AF         376.0            53.0   16.339623  ...         13.00  233.0
# AS         247.0            44.0   60.840909  ...          8.00  123.0
# EU         361.0            45.0  132.555556  ...        195.00  370.0
# ...
